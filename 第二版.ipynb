# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 数据读入

# %%
import pandas as pd

train_data = pd.read_csv("data\main\df_train_b1.csv", index_col=0)
test_data = pd.read_csv('data\main\df_test_b1.csv', index_col=0)

# %% [markdown]
# ## 要读入除了main之外的数在此处添加

# %%
# import os
# filenames = [  "data\detail\df_basic_b1.csv",
#     "data\detail\df_corp_b1.csv",
#     "data\detail\df_judicial_b1.csv",
#     "data\detail\df_loan2_b1.csv",
#     "data\detail\df_query_b1.csv"
# ]
# for filename in filenames:
#     temp = pd.read_csv(filename)
#     train_data = pd.merge(train_data, temp, on="cust_id",
#                           how="left", suffixes=("", "_y"))
#     test_data = pd.merge(test_data, temp, on="cust_id",
#                          how="left", suffixes=("", "_y"))

# %%
# train_data['is_judicial'] = [0 if pd.isna(
#     i) else 1 for i in train_data['judicial_reason']]
# test_data['is_judicial'] = [0 if pd.isna(
#     i) else 1 for i in test_data['judicial_reason']]

# %%
# train_data['nan_num'] = (train_data == 0).astype(int).sum(axis=1)
# test_data['nan_num'] = (test_data == 0).astype(int).sum(axis=1)

# %%
drop_col = []

train_data.drop(drop_col, inplace=True)
test_data.drop(drop_col, inplace=True)

# %% [markdown]
# ## loan1表

# %%
if True:

    import pandas as pd
    temp_df = pd.read_csv("./data/detail/df_loan1_b1.csv")

    def chuli_loan(df, colname, ways):
        cust_id = list(range(len(set(df['cust_id']))))
        res_df = pd.DataFrame({'cust_id': cust_id})
        
        if len(ways) == 0:
            return res_df
        if 'mean' in ways:
            res_df[colname+'_mean'] = df.groupby('cust_id')[colname].mean()
        if 'sum' in ways:
            res_df[colname+'_sum'] = df.groupby('cust_id')[colname].sum()
        if 'count' in ways:
            res_df[colname+'_count'] = df.groupby('cust_id')[colname].count()
        if 'std' in ways:
            res_df[colname+'_std'] = df.groupby('cust_id')[colname].std()
        if 'diff_std' in ways:
            res_df[colname+'_diff_std'] = df.groupby('cust_id')[colname].apply(
                lambda x: x.sort_values(ascending=True).diff()[2:].std())
        return res_df

    for colname in ['loan1_2','loan1_3','loan1_7','loan1_9']:
        df = chuli_loan(temp_df, colname, ('sum','std'))
        train_data = pd.merge(train_data, df, on="cust_id",
                              how="left", suffixes=("", "_y"))
        test_data = pd.merge(test_data, df, on="cust_id",
                             how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_3', ('count',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_1', ('std', 'diff_std'))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_10', ('mean',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_11', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_12', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    train_data.to_csv('./data/df_train.csv')
    test_data.to_csv('./data/df_test.csv')

# %%
# data = temp_df.dropna(axis=0,subset = ["date_1"])
# data['date2-date1'] = data['date_2'] - data['date_1']
# data['date3-date2'] = data['date_3'] - data['date_2']
# data['dateinterval_max'] = data[['date2-date1','date3-date2']].max(axis=1)
# data = data.groupby('cust_id').agg({'date_2':['count'],'date_3':['count'],'dateinterval_max':['mean']})
# train_data = pd.merge(train_data, data, on="cust_id",
#                           how="left", suffixes=("", "_y"))
# test_data = pd.merge(test_data, data, on="cust_id",
#                          how="left", suffixes=("", "_y"))

# %% [markdown]
# ## 处理NAN

# %%
def delnan(df):
    df = df.dropna(how="all", axis=1)  # 删除全是空值的列
    df = df.fillna(-99)
    return df

# %%
df_train = delnan(train_data)
df_test = delnan(test_data)

# %% [markdown]
# ## 处理-99

# %%
# df_train.replace(-99, -1, inplace=True)
# df_test.replace(-99, -1, inplace=True)

# %% [markdown]
# ## 主成分分析（效果不好）

# %%
# from sklearn.decomposition import PCA

# full_col_name = list(df_train.columns)
# pca_col=[i for i in full_col_name if "loan" in i]

# modelPCA=PCA(n_components=0.9)
# temp=modelPCA.fit_transform(df_train[pca_col])
# temp1=modelPCA.transform(df_test[pca_col])
# for i in range(temp.shape[1]):
#     df_train['loan_pca'+str(i)]=temp[:,i]
#     df_test['loan_pca'+str(i)]=temp1[:,i]

# %% [markdown]
# ## 处理分类变量

# %%
cat_way = "no"

# %% [markdown]
# ## 转化为one-hot编码（不宜采用）

# %%
def to_one_hot(df, colnames):
    df = pd.get_dummies(df, columns=colnames)
    return df

# %% [markdown]
# ## 类型计数

# %%
type_count_cols = ['industry', 'scope', 'basic_13']

# %%
# def type_count(cols):
#     global df_train, df_test
#     df1 = df_train[['cust_id']+cols]
#     df2 = df_test[['cust_id']+cols]
#     df = pd.concat([df1, df2], axis=0, ignore_index=True)
#     for i in cols:
#         temp_df = df.groupby(i)['cust_id'].count()
#         temp_df = pd.DataFrame({(i+"_num"): temp_df})
#         df = pd.merge(df, temp_df, on=i, how="left")
#         del df[i], df1[i], df2[i]
#     df_train = pd.merge(df_train, df, on="cust_id",
#                         how="left", suffixes=("", "_y"))
#     df_test = pd.merge(df_test, df, on="cust_id",
#                        how="left", suffixes=("", "_y"))


# type_count(type_count_cols)

# %% [markdown]
# ## 证据权重

# %%
import pandas as pd
import numpy as np


def cal_woe(df, df_no_label, x_cols, y_col):
    for i in x_cols:
        x_set = pd.unique(df[i])
        x1_set = pd.unique(df_no_label[i])
        for j in x1_set:
            if j not in x_set:
                df_no_label[i].replace(j, 0.03, inplace=True)
                print(i, j, '不存在')
        for j in x_set:
            woe = np.mean(df[df[i] == j][y_col])
            if woe >= 0.1:
                n = np.sum(df[df[i] == j][y_col])
                print(i, '列：', j, ' 共有', int(n/woe), '个,其中',
                      int(n), '个label为1,woe为', woe, sep="")
            df[i].replace(j, woe, inplace=True)
            df_no_label[i].replace(j, woe, inplace=True)
    return df, df_no_label

# %%
type_col = ["basic_1",
            "basic_10",
            "basic_12",
            "basic_14",
            "loan1_16",
            "loan1_20",
            "loan1_23",
            "loan1_25",]

# df_train,df_test=cal_woe(df_train,df_test,type_col,"label")

# %%
if cat_way == "auto" or cat_way=="no":
    type_col = ["basic_1",
                "basic_10",
                "basic_12",
                "basic_14",
                "loan1_16",
                "loan1_20",
                "loan1_23",
                "loan1_25",
                "loan2_1_y",
                "query_2_y",
                "query_3_y",
                "query_4_y",
                "query_5_y",
                "query_6_y", ]
if cat_way == "manual":
    woe_col = ['basic_1',
               'basic_5',
               'basic_6',
               'basic_10',
               'loan1_16',
               'loan1_20',
               'loan1_25',
               'loan1_23',
               'loan1_32',
               'loan2_4',
               'loan2_6',
               'overdue_2',
               'overdue_20',
               'overdue_21',
               'overdue_26',
               'overdue_27',
               'query_1',
               'query_2',
               'query_3',
               'query_4',
               'query_6',
               'query_7',
               'query_8',
               'query_10',
               'query_11', ]

    onehot_col = ['basic_12',
                  'basic_14',
                  'loan1_8',
                  'loan1_9',
                  'overdue_1',
                  'overdue_3',
                  'overdue_4',
                  'overdue_5',
                  'overdue_6',
                  'overdue_7',
                  'overdue_8',
                  'overdue_9',
                  'overdue_10',
                  'overdue_11',
                  'overdue_12',
                  'overdue_14',
                  'overdue_15',
                  'overdue_16',
                  'overdue_17',
                  'overdue_18',
                  'overdue_22',
                  'overdue_23',
                  'overdue_24',
                  'overdue_25',
                  'overdue_28',
                  'overdue_29',
                  'query_5',
                  'query_9', ]

    df_train, df_test = cal_woe(df_train, df_test, woe_col, "label")
    df_train = to_one_hot(df_train, onehot_col)
    df_test = to_one_hot(df_test, onehot_col)
    for i in df_train.columns:
        if i not in df_test.columns:
            df_test[i] = 0

# %%
full_col_name = list(df_train.columns)
basic_col = [i for i in full_col_name if "basic" in i]
loan_col = [i for i in full_col_name if "loan" in i]
overdue_col = [i for i in full_col_name if "overdue" in i]
query_col = [i for i in full_col_name if "query" in i]
judicial_col = [i for i in full_col_name if "judicial" in i]
date_col = [i for i in full_col_name if "date" in i]
# loan_pca_col = [i for i in full_col_name if "loan_pca" in i]

# for i in judicial_col:
#     df_train[i].astype("float")
#     df_test[i].astype("float")

# %% [markdown]
# ## rank化

# %%
def rank(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = np.argsort(df[i])
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


a = ['loan1_1', 'loan1_3', 'loan1_7', 'loan1_9']
b = ['_sum', '_mean']
c = []
for i in a:
    for j in b:
        c.append(i+j)
# rank(c)

# %% [markdown]
# ## 归一化

# %%
def norm(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.min(df[i]))/(np.max(df[i])-np.min(df[i]))
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# norm([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 标准化

# %%
def stand(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.mean(df[i], axis=0))/np.std(df[i], axis=0)
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# stand([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 设置哪些x作为模型自变量输入

# %%
# x_col = basic_col+loan_col+['nan_num'] + ['is_judicial']+ overdue_col+query_col
# x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col+['scope_num'] + \
#     ['industry_num']+['date_3_count', 'date_1_std', 'date_1_diff_std']

x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col
x_col = [i for i in x_col if i in full_col_name]

if cat_way == "auto":
    type_col = [i for i in type_col if i in x_col]
# categorize(df_train,type_col)
# categorize(df_test,type_col)

print('自变量个数为', len(x_col))
print(x_col)
# Out:
# 自变量个数为 108
# ['basic_1', 'basic_2', 'basic_3', 'basic_4', 'basic_5', 'basic_6', 'basic_7', 'basic_8', 'basic_9', 'basic_10', 'basic_11', 'basic_12', 'basic_13', 'basic_14', 'basic_15', 'loan1_1', 'loan1_2', 'loan1_3', 'loan1_4', 'loan1_5', 'loan1_6', 'loan1_7', 'loan1_8', 'loan1_9', 'loan1_10', 'loan1_11', 'loan1_12', 'loan1_13', 'loan1_14', 'loan1_15', 'loan1_16', 'loan1_17', 'loan1_18', 'loan1_19', 'loan1_20', 'loan1_21', 'loan1_22', 'loan1_23', 'loan1_24', 'loan1_25', 'loan1_26', 'loan1_27', 'loan1_28', 'loan1_29', 'loan1_30', 'loan1_31', 'loan1_32', 'loan1_33', 'loan2_1', 'loan2_2', 'loan2_3', 'loan2_4', 'loan2_5', 'loan2_6', 'loan2_7', 'loan2_8', 'loan2_9', 'loan2_10', 'loan2_11', 'loan2_12', 'loan1_2_sum', 'loan1_2_std', 'loan1_3_sum', 'loan1_3_std', 'loan1_7_sum', 'loan1_7_std', 'loan1_9_sum', 'loan1_9_std', 'query_1', 'query_2', 'query_3', 'query_4', 'query_5', 'query_6', 'query_7', 'query_8', 'query_9', 'query_10', 'query_11', 'overdue_1', 'overdue_2', 'overdue_3', 'overdue_4', 'overdue_5', 'overdue_6', 'overdue_7', 'overdue_8', 'overdue_9', 'overdue_10', 'overdue_11', 'overdue_12', 'overdue_13', 'overdue_14', 'overdue_15', 'overdue_16', 'overdue_17', 'overdue_18', 'overdue_19', 'overdue_20', 'overdue_21', 'overdue_22', 'overdue_23', 'overdue_24', 'overdue_25', 'overdue_26', 'overdue_27', 'overdue_28', 'overdue_29']

# %%
df_train = df_train[x_col+['label', 'cust_id']]
df_test = df_test[x_col+['cust_id']]

df_test.to_csv("test_input.csv", encoding='utf-8')

# %% [markdown]
# ## 对抗验证

# %%
from sklearn import model_selection
import xgboost as xgb

df_full=pd.concat([df_train[x_col+['cust_id']],df_test],axis=0, ignore_index=True)
df_full['label_test']=[1 if i in df_test['cust_id'] else 0 for i in df_full['cust_id']]

df_full.to_csv("full.csv",encoding='utf-8')

# %%
X = df_full[x_col+['cust_id']]
Y = df_full['label_test']

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(
    X, Y, test_size=0.5, stratify=Y, random_state=2022)

dtrain=xgb.DMatrix(X_train[x_col],label=Y_train)
dtest=xgb.DMatrix(X_test[x_col],label=Y_test)

param = {'max_depth': 5,
         'eta': 0.01,
         'objective': 'binary:logistic',
         "eval_metric":"auc",
         "scale_pos_weight":1,
         "subsample":1,
         "min_child_weight":1,
         'tree_method': 'gpu_hist',
         'gpu_id': 0,}

bst = xgb.train(param, dtrain, 4000, evals=[(dtrain,"train"),(dtest,"test")],
                    early_stopping_rounds=300, verbose_eval=True)
bst1 = xgb.train(param, dtest, 4000, evals=[(dtest,"train"),(dtrain,"test")],
                    early_stopping_rounds=300, verbose_eval=False)
# Out:
# [0]	train-auc:0.54198	test-auc:0.49113
# [1]	train-auc:0.54205	test-auc:0.49168
# [2]	train-auc:0.54158	test-auc:0.49209
# [3]	train-auc:0.54115	test-auc:0.49183
# [4]	train-auc:0.54114	test-auc:0.49194
# [5]	train-auc:0.54460	test-auc:0.48984
# [6]	train-auc:0.54439	test-auc:0.48983
# [7]	train-auc:0.54465	test-auc:0.48994
# [8]	train-auc:0.54481	test-auc:0.48990
# [9]	train-auc:0.54485	test-auc:0.48992
# [10]	train-auc:0.54606	test-auc:0.49033
# [11]	train-auc:0.54622	test-auc:0.49023
# [12]	train-auc:0.54637	test-auc:0.49027
# [13]	train-auc:0.54653	test-auc:0.49014
# [14]	train-auc:0.54697	test-auc:0.49008
# [15]	train-auc:0.54705	test-auc:0.49010
# [16]	train-auc:0.54751	test-auc:0.49010
# [17]	train-auc:0.54818	test-auc:0.49023
# [18]	train-auc:0.54815	test-auc:0.49019
# [19]	train-auc:0.54900	test-auc:0.48974
# [20]	train-auc:0.54913	test-auc:0.48996
# [21]	train-auc:0.55913	test-auc:0.48761
# [22]	train-auc:0.56065	test-auc:0.48796
# [23]	train-auc:0.56371	test-auc:0.48738
# [24]	train-auc:0.56534	test-auc:0.48778
# [25]	train-auc:0.56542	test-auc:0.48755
# [26]	train-auc:0.56613	test-auc:0.48697
# [27]	train-auc:0.56755	test-auc:0.48698
# [28]	train-auc:0.56853	test-auc:0.48671
# [29]	train-auc:0.56834	test-auc:0.48668
# [30]	train-auc:0.57201	test-auc:0.48682
# [31]	train-auc:0.57231	test-auc:0.48710
# [32]	train-auc:0.57241	test-auc:0.48718
# [33]	train-auc:0.57265	test-auc:0.48738
# [34]	train-auc:0.57272	test-auc:0.48713
# [35]	train-auc:0.57344	test-auc:0.48744
# [36]	train-auc:0.57417	test-auc:0.48752
# [37]	train-auc:0.57423	test-auc:0.48791
# [38]	train-auc:0.57435	test-auc:0.48807
# [39]	train-auc:0.57423	test-auc:0.48787
# [40]	train-auc:0.57659	test-auc:0.48779
# [41]	train-auc:0.57709	test-auc:0.48799
# [42]	train-auc:0.57779	test-auc:0.48799
# [43]	train-auc:0.57831	test-auc:0.48804
# [44]	train-auc:0.57944	test-auc:0.48806
# [45]	train-auc:0.57969	test-auc:0.48808
# [46]	train-auc:0.58176	test-auc:0.48823
# [47]	train-auc:0.58401	test-auc:0.48719
# [48]	train-auc:0.58416	test-auc:0.48685
# [49]	train-auc:0.59348	test-auc:0.48765
# [50]	train-auc:0.59364	test-auc:0.48758
# [51]	train-auc:0.59440	test-auc:0.48766
# [52]	train-auc:0.59771	test-auc:0.48809
# [53]	train-auc:0.59782	test-auc:0.48818
# [54]	train-auc:0.59824	test-auc:0.48796
# [55]	train-auc:0.60097	test-auc:0.49013
# [56]	train-auc:0.60122	test-auc:0.49037
# [57]	train-auc:0.60177	test-auc:0.49072
# [58]	train-auc:0.60175	test-auc:0.49059
# [59]	train-auc:0.60280	test-auc:0.49105
# [60]	train-auc:0.60639	test-auc:0.49077
# [61]	train-auc:0.60646	test-auc:0.49071
# [62]	train-auc:0.60658	test-auc:0.49064
# [63]	train-auc:0.60984	test-auc:0.49144
# [64]	train-auc:0.61114	test-auc:0.49102
# [65]	train-auc:0.61300	test-auc:0.49143
# [66]	train-auc:0.61317	test-auc:0.49148
# [67]	train-auc:0.61509	test-auc:0.49153
# [68]	train-auc:0.61759	test-auc:0.49145
# [69]	train-auc:0.61766	test-auc:0.49149
# [70]	train-auc:0.61857	test-auc:0.49216
# [71]	train-auc:0.61871	test-auc:0.49216
# [72]	train-auc:0.61999	test-auc:0.49216
# [73]	train-auc:0.62144	test-auc:0.49202
# [74]	train-auc:0.62361	test-auc:0.49135
# [75]	train-auc:0.62463	test-auc:0.49152
# [76]	train-auc:0.62578	test-auc:0.49060
# [77]	train-auc:0.62666	test-auc:0.49115
# [78]	train-auc:0.62699	test-auc:0.49094
# [79]	train-auc:0.62888	test-auc:0.48954
# [80]	train-auc:0.62987	test-auc:0.48942
# [81]	train-auc:0.63192	test-auc:0.48954
# [82]	train-auc:0.63219	test-auc:0.48981
# [83]	train-auc:0.63253	test-auc:0.49020
# [84]	train-auc:0.63376	test-auc:0.49081
# [85]	train-auc:0.63479	test-auc:0.49075
# [86]	train-auc:0.63498	test-auc:0.49092
# [87]	train-auc:0.63558	test-auc:0.49110
# [88]	train-auc:0.63570	test-auc:0.49096
# [89]	train-auc:0.63732	test-auc:0.49096
# [90]	train-auc:0.63764	test-auc:0.49143
# [91]	train-auc:0.64385	test-auc:0.49198
# [92]	train-auc:0.64702	test-auc:0.49248
# [93]	train-auc:0.64858	test-auc:0.49308
# [94]	train-auc:0.64953	test-auc:0.49251
# [95]	train-auc:0.65112	test-auc:0.49179
# [96]	train-auc:0.65218	test-auc:0.49174
# [97]	train-auc:0.65263	test-auc:0.49212
# [98]	train-auc:0.65417	test-auc:0.49199
# [99]	train-auc:0.65420	test-auc:0.49191
# [100]	train-auc:0.65538	test-auc:0.49161
# [101]	train-auc:0.65878	test-auc:0.49180
# [102]	train-auc:0.65889	test-auc:0.49204
# [103]	train-auc:0.65981	test-auc:0.49190
# [104]	train-auc:0.66261	test-auc:0.49203
# [105]	train-auc:0.66291	test-auc:0.49213
# [106]	train-auc:0.66516	test-auc:0.49253
# [107]	train-auc:0.66674	test-auc:0.49292
# [108]	train-auc:0.66734	test-auc:0.49254
# [109]	train-auc:0.66931	test-auc:0.49277
# [110]	train-auc:0.66965	test-auc:0.49286
# [111]	train-auc:0.67109	test-auc:0.49328
# [112]	train-auc:0.67269	test-auc:0.49333
# [113]	train-auc:0.67635	test-auc:0.49397
# [114]	train-auc:0.67777	test-auc:0.49404
# [115]	train-auc:0.67849	test-auc:0.49362
# [116]	train-auc:0.67936	test-auc:0.49332
# [117]	train-auc:0.68174	test-auc:0.49322
# [118]	train-auc:0.68501	test-auc:0.49373
# [119]	train-auc:0.68524	test-auc:0.49363
# [120]	train-auc:0.68788	test-auc:0.49411
# [121]	train-auc:0.69084	test-auc:0.49357
# [122]	train-auc:0.69113	test-auc:0.49371
# [123]	train-auc:0.69305	test-auc:0.49409
# [124]	train-auc:0.69402	test-auc:0.49412
# [125]	train-auc:0.69484	test-auc:0.49392
# [126]	train-auc:0.69626	test-auc:0.49379
# [127]	train-auc:0.69776	test-auc:0.49419
# [128]	train-auc:0.69775	test-auc:0.49414
# [129]	train-auc:0.69865	test-auc:0.49423
# [130]	train-auc:0.70064	test-auc:0.49410
# [131]	train-auc:0.70098	test-auc:0.49412
# [132]	train-auc:0.70137	test-auc:0.49384
# [133]	train-auc:0.70293	test-auc:0.49432
# [134]	train-auc:0.70348	test-auc:0.49442
# [135]	train-auc:0.70418	test-auc:0.49443
# [136]	train-auc:0.70432	test-auc:0.49441
# [137]	train-auc:0.70541	test-auc:0.49496
# [138]	train-auc:0.70650	test-auc:0.49480
# [139]	train-auc:0.70705	test-auc:0.49485
# [140]	train-auc:0.70816	test-auc:0.49462
# [141]	train-auc:0.70810	test-auc:0.49478
# [142]	train-auc:0.70866	test-auc:0.49462
# [143]	train-auc:0.71038	test-auc:0.49499
# [144]	train-auc:0.71111	test-auc:0.49482
# [145]	train-auc:0.71142	test-auc:0.49480
# [146]	train-auc:0.71251	test-auc:0.49562
# [147]	train-auc:0.71360	test-auc:0.49588
# [148]	train-auc:0.71412	test-auc:0.49570
# [149]	train-auc:0.71497	test-auc:0.49597
# [150]	train-auc:0.71504	test-auc:0.49611
# [151]	train-auc:0.71612	test-auc:0.49658
# [152]	train-auc:0.71710	test-auc:0.49629
# [153]	train-auc:0.71743	test-auc:0.49608
# [154]	train-auc:0.71777	test-auc:0.49626
# [155]	train-auc:0.71792	test-auc:0.49630
# [156]	train-auc:0.71822	test-auc:0.49677
# [157]	train-auc:0.71893	test-auc:0.49665
# [158]	train-auc:0.71921	test-auc:0.49681
# [159]	train-auc:0.71962	test-auc:0.49681
# [160]	train-auc:0.72000	test-auc:0.49667
# [161]	train-auc:0.72047	test-auc:0.49671
# [162]	train-auc:0.72057	test-auc:0.49688
# [163]	train-auc:0.72090	test-auc:0.49680
# [164]	train-auc:0.72135	test-auc:0.49669
# [165]	train-auc:0.72191	test-auc:0.49720
# [166]	train-auc:0.72215	test-auc:0.49744
# [167]	train-auc:0.72288	test-auc:0.49708
# [168]	train-auc:0.72279	test-auc:0.49728
# [169]	train-auc:0.72315	test-auc:0.49718
# [170]	train-auc:0.72370	test-auc:0.49680
# [171]	train-auc:0.72391	test-auc:0.49682
# [172]	train-auc:0.72435	test-auc:0.49719
# [173]	train-auc:0.72557	test-auc:0.49740
# [174]	train-auc:0.72580	test-auc:0.49745
# [175]	train-auc:0.72614	test-auc:0.49734
# [176]	train-auc:0.72630	test-auc:0.49728
# [177]	train-auc:0.72751	test-auc:0.49740
# [178]	train-auc:0.72790	test-auc:0.49746
# [179]	train-auc:0.72846	test-auc:0.49713
# [180]	train-auc:0.72850	test-auc:0.49720
# [181]	train-auc:0.72960	test-auc:0.49697
# [182]	train-auc:0.73004	test-auc:0.49676
# [183]	train-auc:0.73039	test-auc:0.49695
# [184]	train-auc:0.73041	test-auc:0.49686
# [185]	train-auc:0.73141	test-auc:0.49700
# [186]	train-auc:0.73186	test-auc:0.49712
# [187]	train-auc:0.73195	test-auc:0.49706
# [188]	train-auc:0.73250	test-auc:0.49714
# [189]	train-auc:0.73291	test-auc:0.49702
# [190]	train-auc:0.73327	test-auc:0.49711
# [191]	train-auc:0.73347	test-auc:0.49703
# [192]	train-auc:0.73379	test-auc:0.49694
# [193]	train-auc:0.73440	test-auc:0.49722
# [194]	train-auc:0.73510	test-auc:0.49726
# [195]	train-auc:0.73601	test-auc:0.49742
# [196]	train-auc:0.73625	test-auc:0.49752
# [197]	train-auc:0.73665	test-auc:0.49785
# [198]	train-auc:0.73679	test-auc:0.49776
# [199]	train-auc:0.73781	test-auc:0.49756
# [200]	train-auc:0.73801	test-auc:0.49769
# [201]	train-auc:0.73806	test-auc:0.49774
# [202]	train-auc:0.73848	test-auc:0.49774
# [203]	train-auc:0.73875	test-auc:0.49746
# [204]	train-auc:0.73896	test-auc:0.49761
# [205]	train-auc:0.73956	test-auc:0.49771
# [206]	train-auc:0.74004	test-auc:0.49784
# [207]	train-auc:0.74008	test-auc:0.49793
# [208]	train-auc:0.74034	test-auc:0.49777
# [209]	train-auc:0.74117	test-auc:0.49758
# [210]	train-auc:0.74185	test-auc:0.49772
# [211]	train-auc:0.74277	test-auc:0.49732
# [212]	train-auc:0.74270	test-auc:0.49730
# [213]	train-auc:0.74278	test-auc:0.49723
# [214]	train-auc:0.74307	test-auc:0.49740
# [215]	train-auc:0.74425	test-auc:0.49744
# [216]	train-auc:0.74424	test-auc:0.49749
# [217]	train-auc:0.74435	test-auc:0.49746
# [218]	train-auc:0.74456	test-auc:0.49730
# [219]	train-auc:0.74463	test-auc:0.49744
# [220]	train-auc:0.74557	test-auc:0.49707
# [221]	train-auc:0.74610	test-auc:0.49756
# [222]	train-auc:0.74599	test-auc:0.49753
# [223]	train-auc:0.74710	test-auc:0.49748
# [224]	train-auc:0.74723	test-auc:0.49745
# [225]	train-auc:0.74763	test-auc:0.49738
# [226]	train-auc:0.74760	test-auc:0.49747
# [227]	train-auc:0.74802	test-auc:0.49754
# [228]	train-auc:0.74852	test-auc:0.49756
# [229]	train-auc:0.74871	test-auc:0.49762
# [230]	train-auc:0.74878	test-auc:0.49764
# [231]	train-auc:0.74913	test-auc:0.49761
# [232]	train-auc:0.74972	test-auc:0.49762
# [233]	train-auc:0.74960	test-auc:0.49758
# [234]	train-auc:0.75028	test-auc:0.49768
# [235]	train-auc:0.75126	test-auc:0.49785
# [236]	train-auc:0.75163	test-auc:0.49776
# [237]	train-auc:0.75180	test-auc:0.49781
# [238]	train-auc:0.75172	test-auc:0.49781
# [239]	train-auc:0.75179	test-auc:0.49784
# [240]	train-auc:0.75187	test-auc:0.49798
# [241]	train-auc:0.75255	test-auc:0.49766
# [242]	train-auc:0.75282	test-auc:0.49766
# [243]	train-auc:0.75303	test-auc:0.49761
# [244]	train-auc:0.75296	test-auc:0.49766
# [245]	train-auc:0.75345	test-auc:0.49765
# [246]	train-auc:0.75365	test-auc:0.49770
# [247]	train-auc:0.75361	test-auc:0.49775
# [248]	train-auc:0.75364	test-auc:0.49774
# [249]	train-auc:0.75424	test-auc:0.49829
# [250]	train-auc:0.75416	test-auc:0.49831
# [251]	train-auc:0.75436	test-auc:0.49827
# [252]	train-auc:0.75447	test-auc:0.49834
# [253]	train-auc:0.75455	test-auc:0.49835
# [254]	train-auc:0.75467	test-auc:0.49853
# [255]	train-auc:0.75494	test-auc:0.49856
# [256]	train-auc:0.75519	test-auc:0.49856
# [257]	train-auc:0.75522	test-auc:0.49856
# [258]	train-auc:0.75534	test-auc:0.49856
# [259]	train-auc:0.75617	test-auc:0.49865
# [260]	train-auc:0.75691	test-auc:0.49856
# [261]	train-auc:0.75752	test-auc:0.49867
# [262]	train-auc:0.75776	test-auc:0.49868
# [263]	train-auc:0.75772	test-auc:0.49863
# [264]	train-auc:0.75758	test-auc:0.49860
# [265]	train-auc:0.75786	test-auc:0.49853
# [266]	train-auc:0.75788	test-auc:0.49852
# [267]	train-auc:0.75811	test-auc:0.49836
# [268]	train-auc:0.75824	test-auc:0.49842
# [269]	train-auc:0.75888	test-auc:0.49857
# [270]	train-auc:0.75889	test-auc:0.49865
# [271]	train-auc:0.75891	test-auc:0.49864
# [272]	train-auc:0.75886	test-auc:0.49868
# [273]	train-auc:0.75983	test-auc:0.49870
# [274]	train-auc:0.76005	test-auc:0.49871
# [275]	train-auc:0.76068	test-auc:0.49879
# [276]	train-auc:0.76095	test-auc:0.49871
# [277]	train-auc:0.76090	test-auc:0.49879
# [278]	train-auc:0.76091	test-auc:0.49878
# [279]	train-auc:0.76075	test-auc:0.49872
# [280]	train-auc:0.76097	test-auc:0.49865
# [281]	train-auc:0.76146	test-auc:0.49880
# [282]	train-auc:0.76224	test-auc:0.49901
# [283]	train-auc:0.76226	test-auc:0.49898
# [284]	train-auc:0.76246	test-auc:0.49905
# [285]	train-auc:0.76257	test-auc:0.49899
# [286]	train-auc:0.76251	test-auc:0.49899
# [287]	train-auc:0.76253	test-auc:0.49897
# [288]	train-auc:0.76247	test-auc:0.49909
# [289]	train-auc:0.76254	test-auc:0.49905
# [290]	train-auc:0.76289	test-auc:0.49911
# [291]	train-auc:0.76310	test-auc:0.49914
# [292]	train-auc:0.76322	test-auc:0.49904
# [293]	train-auc:0.76351	test-auc:0.49917
# [294]	train-auc:0.76361	test-auc:0.49914
# [295]	train-auc:0.76404	test-auc:0.49916
# [296]	train-auc:0.76430	test-auc:0.49895
# [297]	train-auc:0.76429	test-auc:0.49898
# [298]	train-auc:0.76445	test-auc:0.49904
# [299]	train-auc:0.76480	test-auc:0.49914
# [300]	train-auc:0.76481	test-auc:0.49912
# [301]	train-auc:0.76503	test-auc:0.49925
# [302]	train-auc:0.76536	test-auc:0.49932
# [303]	train-auc:0.76553	test-auc:0.49933
# [304]	train-auc:0.76620	test-auc:0.49958
# [305]	train-auc:0.76618	test-auc:0.49955
# [306]	train-auc:0.76702	test-auc:0.49959
# [307]	train-auc:0.76706	test-auc:0.49960
# [308]	train-auc:0.76722	test-auc:0.49947
# [309]	train-auc:0.76723	test-auc:0.49946
# [310]	train-auc:0.76762	test-auc:0.49946
# [311]	train-auc:0.76763	test-auc:0.49946
# [312]	train-auc:0.76773	test-auc:0.49943
# [313]	train-auc:0.76805	test-auc:0.49947
# [314]	train-auc:0.76799	test-auc:0.49954
# [315]	train-auc:0.76814	test-auc:0.49942
# [316]	train-auc:0.76945	test-auc:0.49932
# [317]	train-auc:0.76942	test-auc:0.49938
# [318]	train-auc:0.76980	test-auc:0.49938
# [319]	train-auc:0.76992	test-auc:0.49948
# [320]	train-auc:0.76995	test-auc:0.49947
# [321]	train-auc:0.77012	test-auc:0.49950
# [322]	train-auc:0.77061	test-auc:0.49953
# [323]	train-auc:0.77096	test-auc:0.49957
# [324]	train-auc:0.77109	test-auc:0.49961
# [325]	train-auc:0.77121	test-auc:0.49946
# [326]	train-auc:0.77123	test-auc:0.49945
# [327]	train-auc:0.77204	test-auc:0.49934
# [328]	train-auc:0.77209	test-auc:0.49932
# [329]	train-auc:0.77216	test-auc:0.49931
# [330]	train-auc:0.77273	test-auc:0.49946
# [331]	train-auc:0.77304	test-auc:0.49960
# [332]	train-auc:0.77323	test-auc:0.49963
# [333]	train-auc:0.77355	test-auc:0.49964
# [334]	train-auc:0.77383	test-auc:0.49958
# [335]	train-auc:0.77440	test-auc:0.49966
# [336]	train-auc:0.77464	test-auc:0.49964
# [337]	train-auc:0.77468	test-auc:0.49965
# [338]	train-auc:0.77495	test-auc:0.49970
# [339]	train-auc:0.77521	test-auc:0.49975
# [340]	train-auc:0.77521	test-auc:0.49974
# [341]	train-auc:0.77546	test-auc:0.49977
# [342]	train-auc:0.77552	test-auc:0.49978
# [343]	train-auc:0.77582	test-auc:0.49982
# [344]	train-auc:0.77630	test-auc:0.49981
# [345]	train-auc:0.77635	test-auc:0.49982
# [346]	train-auc:0.77651	test-auc:0.49991
# [347]	train-auc:0.77684	test-auc:0.49978
# [348]	train-auc:0.77727	test-auc:0.49989
# [349]	train-auc:0.77822	test-auc:0.49975
# [350]	train-auc:0.77842	test-auc:0.49976
# [351]	train-auc:0.77851	test-auc:0.49994
# [352]	train-auc:0.77875	test-auc:0.50000
# [353]	train-auc:0.77898	test-auc:0.50006
# [354]	train-auc:0.77898	test-auc:0.50011
# [355]	train-auc:0.77908	test-auc:0.50005
# [356]	train-auc:0.77937	test-auc:0.50015
# [357]	train-auc:0.77973	test-auc:0.50021
# [358]	train-auc:0.77987	test-auc:0.50015
# [359]	train-auc:0.78003	test-auc:0.50007
# [360]	train-auc:0.78005	test-auc:0.50003
# [361]	train-auc:0.78026	test-auc:0.50010
# [362]	train-auc:0.78047	test-auc:0.50016
# [363]	train-auc:0.78073	test-auc:0.50015
# [364]	train-auc:0.78086	test-auc:0.50011
# [365]	train-auc:0.78096	test-auc:0.50009
# [366]	train-auc:0.78109	test-auc:0.50018
# [367]	train-auc:0.78139	test-auc:0.50019
# [368]	train-auc:0.78172	test-auc:0.50014
# [369]	train-auc:0.78189	test-auc:0.50021
# [370]	train-auc:0.78203	test-auc:0.50010
# [371]	train-auc:0.78215	test-auc:0.50016
# [372]	train-auc:0.78217	test-auc:0.50015
# [373]	train-auc:0.78236	test-auc:0.50021
# [374]	train-auc:0.78327	test-auc:0.50005
# [375]	train-auc:0.78337	test-auc:0.50008
# [376]	train-auc:0.78334	test-auc:0.50010
# [377]	train-auc:0.78352	test-auc:0.50012
# [378]	train-auc:0.78371	test-auc:0.50019
# [379]	train-auc:0.78385	test-auc:0.50014
# [380]	train-auc:0.78411	test-auc:0.50010
# [381]	train-auc:0.78409	test-auc:0.50010
# [382]	train-auc:0.78408	test-auc:0.50013
# [383]	train-auc:0.78419	test-auc:0.50012
# [384]	train-auc:0.78428	test-auc:0.50018
# [385]	train-auc:0.78430	test-auc:0.50019
# [386]	train-auc:0.78447	test-auc:0.50025
# [387]	train-auc:0.78479	test-auc:0.50056
# [388]	train-auc:0.78472	test-auc:0.50061
# [389]	train-auc:0.78494	test-auc:0.50063
# [390]	train-auc:0.78504	test-auc:0.50065
# [391]	train-auc:0.78518	test-auc:0.50058
# [392]	train-auc:0.78532	test-auc:0.50061
# [393]	train-auc:0.78536	test-auc:0.50062
# [394]	train-auc:0.78549	test-auc:0.50061
# [395]	train-auc:0.78566	test-auc:0.50053
# [396]	train-auc:0.78564	test-auc:0.50054
# [397]	train-auc:0.78571	test-auc:0.50054
# [398]	train-auc:0.78585	test-auc:0.50059
# [399]	train-auc:0.78601	test-auc:0.50049
# [400]	train-auc:0.78614	test-auc:0.50050
# [401]	train-auc:0.78617	test-auc:0.50052
# [402]	train-auc:0.78623	test-auc:0.50046
# [403]	train-auc:0.78642	test-auc:0.50050
# [404]	train-auc:0.78686	test-auc:0.50052
# [405]	train-auc:0.78712	test-auc:0.50078
# [406]	train-auc:0.78707	test-auc:0.50077
# [407]	train-auc:0.78758	test-auc:0.50076
# [408]	train-auc:0.78759	test-auc:0.50072
# [409]	train-auc:0.78774	test-auc:0.50078
# [410]	train-auc:0.78816	test-auc:0.50086
# [411]	train-auc:0.78820	test-auc:0.50086
# [412]	train-auc:0.78830	test-auc:0.50086
# [413]	train-auc:0.78854	test-auc:0.50079
# [414]	train-auc:0.78861	test-auc:0.50074
# [415]	train-auc:0.78873	test-auc:0.50072
# [416]	train-auc:0.78875	test-auc:0.50069
# [417]	train-auc:0.78877	test-auc:0.50070
# [418]	train-auc:0.78889	test-auc:0.50076
# [419]	train-auc:0.78895	test-auc:0.50085
# [420]	train-auc:0.78935	test-auc:0.50080
# [421]	train-auc:0.78979	test-auc:0.50079
# [422]	train-auc:0.78993	test-auc:0.50085
# [423]	train-auc:0.79011	test-auc:0.50084
# [424]	train-auc:0.79042	test-auc:0.50077
# [425]	train-auc:0.79045	test-auc:0.50082
# [426]	train-auc:0.79041	test-auc:0.50081
# [427]	train-auc:0.79060	test-auc:0.50089
# [428]	train-auc:0.79105	test-auc:0.50092
# [429]	train-auc:0.79101	test-auc:0.50088
# [430]	train-auc:0.79109	test-auc:0.50088
# [431]	train-auc:0.79122	test-auc:0.50090
# [432]	train-auc:0.79159	test-auc:0.50098
# [433]	train-auc:0.79203	test-auc:0.50131
# [434]	train-auc:0.79209	test-auc:0.50129
# [435]	train-auc:0.79222	test-auc:0.50126
# [436]	train-auc:0.79242	test-auc:0.50114
# [437]	train-auc:0.79255	test-auc:0.50116
# [438]	train-auc:0.79257	test-auc:0.50116
# [439]	train-auc:0.79261	test-auc:0.50118
# [440]	train-auc:0.79277	test-auc:0.50120
# [441]	train-auc:0.79283	test-auc:0.50116
# [442]	train-auc:0.79288	test-auc:0.50120
# [443]	train-auc:0.79300	test-auc:0.50123
# [444]	train-auc:0.79305	test-auc:0.50126
# [445]	train-auc:0.79317	test-auc:0.50132
# [446]	train-auc:0.79356	test-auc:0.50133
# [447]	train-auc:0.79361	test-auc:0.50120
# [448]	train-auc:0.79360	test-auc:0.50117
# [449]	train-auc:0.79379	test-auc:0.50113
# [450]	train-auc:0.79389	test-auc:0.50101
# [451]	train-auc:0.79402	test-auc:0.50105
# [452]	train-auc:0.79437	test-auc:0.50115
# [453]	train-auc:0.79447	test-auc:0.50119
# [454]	train-auc:0.79446	test-auc:0.50115
# [455]	train-auc:0.79452	test-auc:0.50123
# [456]	train-auc:0.79462	test-auc:0.50131
# [457]	train-auc:0.79490	test-auc:0.50127
# [458]	train-auc:0.79526	test-auc:0.50157
# [459]	train-auc:0.79532	test-auc:0.50153
# [460]	train-auc:0.79540	test-auc:0.50156
# [461]	train-auc:0.79558	test-auc:0.50155
# [462]	train-auc:0.79570	test-auc:0.50155
# [463]	train-auc:0.79598	test-auc:0.50158
# [464]	train-auc:0.79671	test-auc:0.50156
# [465]	train-auc:0.79689	test-auc:0.50151
# [466]	train-auc:0.79689	test-auc:0.50144
# [467]	train-auc:0.79690	test-auc:0.50145
# [468]	train-auc:0.79705	test-auc:0.50143
# [469]	train-auc:0.79711	test-auc:0.50143
# [470]	train-auc:0.79714	test-auc:0.50143
# [471]	train-auc:0.79719	test-auc:0.50141
# [472]	train-auc:0.79721	test-auc:0.50145
# [473]	train-auc:0.79729	test-auc:0.50147
# [474]	train-auc:0.79728	test-auc:0.50140
# [475]	train-auc:0.79736	test-auc:0.50142
# [476]	train-auc:0.79763	test-auc:0.50141
# [477]	train-auc:0.79785	test-auc:0.50144
# [478]	train-auc:0.79782	test-auc:0.50150
# [479]	train-auc:0.79799	test-auc:0.50148
# [480]	train-auc:0.79841	test-auc:0.50153
# [481]	train-auc:0.79854	test-auc:0.50145
# [482]	train-auc:0.79866	test-auc:0.50143
# [483]	train-auc:0.79877	test-auc:0.50141
# [484]	train-auc:0.79878	test-auc:0.50141
# [485]	train-auc:0.79875	test-auc:0.50145
# [486]	train-auc:0.79873	test-auc:0.50139
# [487]	train-auc:0.79941	test-auc:0.50128
# [488]	train-auc:0.79954	test-auc:0.50131
# [489]	train-auc:0.79974	test-auc:0.50135
# [490]	train-auc:0.79974	test-auc:0.50135
# [491]	train-auc:0.79980	test-auc:0.50134
# [492]	train-auc:0.79981	test-auc:0.50131
# [493]	train-auc:0.80038	test-auc:0.50138
# [494]	train-auc:0.80079	test-auc:0.50135
# [495]	train-auc:0.80088	test-auc:0.50142
# [496]	train-auc:0.80102	test-auc:0.50145
# [497]	train-auc:0.80134	test-auc:0.50147
# [498]	train-auc:0.80145	test-auc:0.50144
# [499]	train-auc:0.80151	test-auc:0.50144
# [500]	train-auc:0.80150	test-auc:0.50136
# [501]	train-auc:0.80150	test-auc:0.50136
# [502]	train-auc:0.80150	test-auc:0.50146
# [503]	train-auc:0.80162	test-auc:0.50144
# [504]	train-auc:0.80198	test-auc:0.50163
# [505]	train-auc:0.80229	test-auc:0.50154
# [506]	train-auc:0.80269	test-auc:0.50136
# [507]	train-auc:0.80302	test-auc:0.50138
# [508]	train-auc:0.80325	test-auc:0.50141
# [509]	train-auc:0.80335	test-auc:0.50140
# [510]	train-auc:0.80335	test-auc:0.50139
# [511]	train-auc:0.80356	test-auc:0.50135
# [512]	train-auc:0.80361	test-auc:0.50138
# [513]	train-auc:0.80366	test-auc:0.50144
# [514]	train-auc:0.80381	test-auc:0.50143
# [515]	train-auc:0.80381	test-auc:0.50149
# [516]	train-auc:0.80399	test-auc:0.50155
# [517]	train-auc:0.80401	test-auc:0.50156
# [518]	train-auc:0.80414	test-auc:0.50162
# [519]	train-auc:0.80410	test-auc:0.50158
# [520]	train-auc:0.80490	test-auc:0.50152
# [521]	train-auc:0.80489	test-auc:0.50152
# [522]	train-auc:0.80497	test-auc:0.50150
# [523]	train-auc:0.80502	test-auc:0.50154
# [524]	train-auc:0.80511	test-auc:0.50160
# [525]	train-auc:0.80519	test-auc:0.50160
# [526]	train-auc:0.80529	test-auc:0.50154
# [527]	train-auc:0.80550	test-auc:0.50156
# [528]	train-auc:0.80585	test-auc:0.50158
# [529]	train-auc:0.80601	test-auc:0.50161
# [530]	train-auc:0.80600	test-auc:0.50162
# [531]	train-auc:0.80601	test-auc:0.50163
# [532]	train-auc:0.80601	test-auc:0.50168
# [533]	train-auc:0.80615	test-auc:0.50172
# [534]	train-auc:0.80613	test-auc:0.50166
# [535]	train-auc:0.80613	test-auc:0.50166
# [536]	train-auc:0.80628	test-auc:0.50157
# [537]	train-auc:0.80634	test-auc:0.50163
# [538]	train-auc:0.80632	test-auc:0.50173
# [539]	train-auc:0.80700	test-auc:0.50169
# [540]	train-auc:0.80714	test-auc:0.50171
# [541]	train-auc:0.80714	test-auc:0.50170
# [542]	train-auc:0.80712	test-auc:0.50162
# [543]	train-auc:0.80744	test-auc:0.50156
# [544]	train-auc:0.80812	test-auc:0.50145
# [545]	train-auc:0.80822	test-auc:0.50149
# [546]	train-auc:0.80831	test-auc:0.50151
# [547]	train-auc:0.80851	test-auc:0.50156
# [548]	train-auc:0.80851	test-auc:0.50156
# [549]	train-auc:0.80850	test-auc:0.50155
# [550]	train-auc:0.80853	test-auc:0.50155
# [551]	train-auc:0.80869	test-auc:0.50157
# [552]	train-auc:0.80877	test-auc:0.50161
# [553]	train-auc:0.80907	test-auc:0.50169
# [554]	train-auc:0.80914	test-auc:0.50161
# [555]	train-auc:0.80918	test-auc:0.50163
# [556]	train-auc:0.80932	test-auc:0.50167
# [557]	train-auc:0.80947	test-auc:0.50165
# [558]	train-auc:0.81024	test-auc:0.50143
# [559]	train-auc:0.81034	test-auc:0.50149
# [560]	train-auc:0.81040	test-auc:0.50153
# [561]	train-auc:0.81070	test-auc:0.50166
# [562]	train-auc:0.81082	test-auc:0.50160
# [563]	train-auc:0.81096	test-auc:0.50160
# [564]	train-auc:0.81104	test-auc:0.50158
# [565]	train-auc:0.81103	test-auc:0.50163
# [566]	train-auc:0.81102	test-auc:0.50165
# [567]	train-auc:0.81101	test-auc:0.50174
# [568]	train-auc:0.81128	test-auc:0.50177
# [569]	train-auc:0.81171	test-auc:0.50172
# [570]	train-auc:0.81198	test-auc:0.50163
# [571]	train-auc:0.81205	test-auc:0.50164
# [572]	train-auc:0.81212	test-auc:0.50171
# [573]	train-auc:0.81213	test-auc:0.50172
# [574]	train-auc:0.81232	test-auc:0.50178
# [575]	train-auc:0.81256	test-auc:0.50172
# [576]	train-auc:0.81257	test-auc:0.50174
# [577]	train-auc:0.81256	test-auc:0.50173
# [578]	train-auc:0.81268	test-auc:0.50174
# [579]	train-auc:0.81268	test-auc:0.50176
# [580]	train-auc:0.81267	test-auc:0.50178
# [581]	train-auc:0.81272	test-auc:0.50177
# [582]	train-auc:0.81272	test-auc:0.50177
# [583]	train-auc:0.81277	test-auc:0.50183
# [584]	train-auc:0.81283	test-auc:0.50191
# [585]	train-auc:0.81301	test-auc:0.50193
# [586]	train-auc:0.81331	test-auc:0.50197
# [587]	train-auc:0.81338	test-auc:0.50200
# [588]	train-auc:0.81342	test-auc:0.50200
# [589]	train-auc:0.81340	test-auc:0.50199
# [590]	train-auc:0.81337	test-auc:0.50203
# [591]	train-auc:0.81363	test-auc:0.50193
# [592]	train-auc:0.81373	test-auc:0.50195
# [593]	train-auc:0.81379	test-auc:0.50191
# [594]	train-auc:0.81382	test-auc:0.50195
# [595]	train-auc:0.81389	test-auc:0.50201
# [596]	train-auc:0.81395	test-auc:0.50202
# [597]	train-auc:0.81400	test-auc:0.50204
# [598]	train-auc:0.81400	test-auc:0.50204
# [599]	train-auc:0.81398	test-auc:0.50205
# [600]	train-auc:0.81394	test-auc:0.50200
# [601]	train-auc:0.81400	test-auc:0.50207
# [602]	train-auc:0.81436	test-auc:0.50195
# [603]	train-auc:0.81440	test-auc:0.50199
# [604]	train-auc:0.81459	test-auc:0.50198
# [605]	train-auc:0.81462	test-auc:0.50193
# [606]	train-auc:0.81466	test-auc:0.50194
# [607]	train-auc:0.81472	test-auc:0.50192
# [608]	train-auc:0.81503	test-auc:0.50184
# [609]	train-auc:0.81515	test-auc:0.50193
# [610]	train-auc:0.81521	test-auc:0.50191
# [611]	train-auc:0.81527	test-auc:0.50194
# [612]	train-auc:0.81530	test-auc:0.50193
# [613]	train-auc:0.81527	test-auc:0.50191
# [614]	train-auc:0.81532	test-auc:0.50208
# [615]	train-auc:0.81534	test-auc:0.50208
# [616]	train-auc:0.81539	test-auc:0.50212
# [617]	train-auc:0.81534	test-auc:0.50204
# [618]	train-auc:0.81574	test-auc:0.50197
# [619]	train-auc:0.81592	test-auc:0.50187
# [620]	train-auc:0.81614	test-auc:0.50184
# [621]	train-auc:0.81622	test-auc:0.50187
# [622]	train-auc:0.81628	test-auc:0.50183
# [623]	train-auc:0.81631	test-auc:0.50182
# [624]	train-auc:0.81632	test-auc:0.50188
# [625]	train-auc:0.81657	test-auc:0.50178
# [626]	train-auc:0.81669	test-auc:0.50178
# [627]	train-auc:0.81670	test-auc:0.50178
# [628]	train-auc:0.81673	test-auc:0.50178
# [629]	train-auc:0.81676	test-auc:0.50178
# [630]	train-auc:0.81709	test-auc:0.50184
# [631]	train-auc:0.81707	test-auc:0.50185
# [632]	train-auc:0.81710	test-auc:0.50185
# [633]	train-auc:0.81707	test-auc:0.50190
# [634]	train-auc:0.81711	test-auc:0.50191
# [635]	train-auc:0.81742	test-auc:0.50181
# [636]	train-auc:0.81742	test-auc:0.50182
# [637]	train-auc:0.81770	test-auc:0.50174
# [638]	train-auc:0.81770	test-auc:0.50174
# [639]	train-auc:0.81799	test-auc:0.50175
# [640]	train-auc:0.81801	test-auc:0.50175
# [641]	train-auc:0.81802	test-auc:0.50176
# [642]	train-auc:0.81801	test-auc:0.50181
# [643]	train-auc:0.81811	test-auc:0.50178
# [644]	train-auc:0.81869	test-auc:0.50161
# [645]	train-auc:0.81888	test-auc:0.50158
# [646]	train-auc:0.81891	test-auc:0.50151
# [647]	train-auc:0.81896	test-auc:0.50155
# [648]	train-auc:0.81909	test-auc:0.50152
# [649]	train-auc:0.81906	test-auc:0.50151
# [650]	train-auc:0.81915	test-auc:0.50156
# [651]	train-auc:0.81966	test-auc:0.50142
# [652]	train-auc:0.81970	test-auc:0.50139
# [653]	train-auc:0.81980	test-auc:0.50141
# [654]	train-auc:0.81992	test-auc:0.50138
# [655]	train-auc:0.82001	test-auc:0.50127
# [656]	train-auc:0.82001	test-auc:0.50129
# [657]	train-auc:0.82041	test-auc:0.50133
# [658]	train-auc:0.82046	test-auc:0.50135
# [659]	train-auc:0.82083	test-auc:0.50119
# [660]	train-auc:0.82119	test-auc:0.50127
# [661]	train-auc:0.82123	test-auc:0.50125
# [662]	train-auc:0.82157	test-auc:0.50124
# [663]	train-auc:0.82159	test-auc:0.50123
# [664]	train-auc:0.82172	test-auc:0.50128
# [665]	train-auc:0.82173	test-auc:0.50127
# [666]	train-auc:0.82181	test-auc:0.50114
# [667]	train-auc:0.82180	test-auc:0.50115
# [668]	train-auc:0.82199	test-auc:0.50116
# [669]	train-auc:0.82236	test-auc:0.50112
# [670]	train-auc:0.82244	test-auc:0.50111
# [671]	train-auc:0.82244	test-auc:0.50103
# [672]	train-auc:0.82264	test-auc:0.50098
# [673]	train-auc:0.82319	test-auc:0.50098
# [674]	train-auc:0.82330	test-auc:0.50095
# [675]	train-auc:0.82332	test-auc:0.50087
# [676]	train-auc:0.82336	test-auc:0.50087
# [677]	train-auc:0.82377	test-auc:0.50092
# [678]	train-auc:0.82380	test-auc:0.50092
# [679]	train-auc:0.82408	test-auc:0.50086
# [680]	train-auc:0.82405	test-auc:0.50082
# [681]	train-auc:0.82418	test-auc:0.50085
# [682]	train-auc:0.82419	test-auc:0.50080
# [683]	train-auc:0.82436	test-auc:0.50076
# [684]	train-auc:0.82431	test-auc:0.50078
# [685]	train-auc:0.82434	test-auc:0.50080
# [686]	train-auc:0.82474	test-auc:0.50088
# [687]	train-auc:0.82476	test-auc:0.50087
# [688]	train-auc:0.82511	test-auc:0.50085
# [689]	train-auc:0.82521	test-auc:0.50088
# [690]	train-auc:0.82548	test-auc:0.50087
# [691]	train-auc:0.82595	test-auc:0.50085
# [692]	train-auc:0.82602	test-auc:0.50074
# [693]	train-auc:0.82627	test-auc:0.50073
# [694]	train-auc:0.82641	test-auc:0.50072
# [695]	train-auc:0.82640	test-auc:0.50073
# [696]	train-auc:0.82643	test-auc:0.50075
# [697]	train-auc:0.82674	test-auc:0.50080
# [698]	train-auc:0.82675	test-auc:0.50081
# [699]	train-auc:0.82673	test-auc:0.50081
# [700]	train-auc:0.82669	test-auc:0.50082
# [701]	train-auc:0.82677	test-auc:0.50088
# [702]	train-auc:0.82708	test-auc:0.50091
# [703]	train-auc:0.82720	test-auc:0.50089
# [704]	train-auc:0.82730	test-auc:0.50090
# [705]	train-auc:0.82752	test-auc:0.50084
# [706]	train-auc:0.82797	test-auc:0.50081
# [707]	train-auc:0.82835	test-auc:0.50077
# [708]	train-auc:0.82838	test-auc:0.50077
# [709]	train-auc:0.82871	test-auc:0.50072
# [710]	train-auc:0.82878	test-auc:0.50079
# [711]	train-auc:0.82889	test-auc:0.50074
# [712]	train-auc:0.82894	test-auc:0.50078
# [713]	train-auc:0.82900	test-auc:0.50075
# [714]	train-auc:0.82895	test-auc:0.50072
# [715]	train-auc:0.82919	test-auc:0.50077
# [716]	train-auc:0.82943	test-auc:0.50075
# [717]	train-auc:0.82966	test-auc:0.50069
# [718]	train-auc:0.83000	test-auc:0.50065
# [719]	train-auc:0.83026	test-auc:0.50063
# [720]	train-auc:0.83052	test-auc:0.50058
# [721]	train-auc:0.83053	test-auc:0.50053
# [722]	train-auc:0.83087	test-auc:0.50040
# [723]	train-auc:0.83113	test-auc:0.50048
# [724]	train-auc:0.83165	test-auc:0.50049
# [725]	train-auc:0.83190	test-auc:0.50047
# [726]	train-auc:0.83187	test-auc:0.50045
# [727]	train-auc:0.83227	test-auc:0.50036
# [728]	train-auc:0.83248	test-auc:0.50041
# [729]	train-auc:0.83251	test-auc:0.50039
# [730]	train-auc:0.83268	test-auc:0.50045
# [731]	train-auc:0.83291	test-auc:0.50044
# [732]	train-auc:0.83304	test-auc:0.50042
# [733]	train-auc:0.83316	test-auc:0.50038
# [734]	train-auc:0.83333	test-auc:0.50035
# [735]	train-auc:0.83352	test-auc:0.50035
# [736]	train-auc:0.83364	test-auc:0.50043
# [737]	train-auc:0.83387	test-auc:0.50035
# [738]	train-auc:0.83415	test-auc:0.50025
# [739]	train-auc:0.83415	test-auc:0.50026
# [740]	train-auc:0.83428	test-auc:0.50023
# [741]	train-auc:0.83437	test-auc:0.50025
# [742]	train-auc:0.83436	test-auc:0.50025
# [743]	train-auc:0.83479	test-auc:0.50030
# [744]	train-auc:0.83473	test-auc:0.50030
# [745]	train-auc:0.83505	test-auc:0.50025
# [746]	train-auc:0.83508	test-auc:0.50022
# [747]	train-auc:0.83510	test-auc:0.50024
# [748]	train-auc:0.83533	test-auc:0.50014
# [749]	train-auc:0.83534	test-auc:0.50013
# [750]	train-auc:0.83544	test-auc:0.50013
# [751]	train-auc:0.83571	test-auc:0.50006
# [752]	train-auc:0.83571	test-auc:0.50008
# [753]	train-auc:0.83579	test-auc:0.50010
# [754]	train-auc:0.83599	test-auc:0.50010
# [755]	train-auc:0.83628	test-auc:0.50007
# [756]	train-auc:0.83652	test-auc:0.50002
# [757]	train-auc:0.83656	test-auc:0.50003
# [758]	train-auc:0.83678	test-auc:0.49997
# [759]	train-auc:0.83708	test-auc:0.49996
# [760]	train-auc:0.83708	test-auc:0.49998
# [761]	train-auc:0.83746	test-auc:0.49997
# [762]	train-auc:0.83778	test-auc:0.50001
# [763]	train-auc:0.83778	test-auc:0.50002
# [764]	train-auc:0.83801	test-auc:0.50001
# [765]	train-auc:0.83831	test-auc:0.49996
# [766]	train-auc:0.83863	test-auc:0.50000
# [767]	train-auc:0.83866	test-auc:0.49999
# [768]	train-auc:0.83867	test-auc:0.50002
# [769]	train-auc:0.83866	test-auc:0.50004
# [770]	train-auc:0.83877	test-auc:0.50002
# [771]	train-auc:0.83898	test-auc:0.50007
# [772]	train-auc:0.83900	test-auc:0.50007
# [773]	train-auc:0.83908	test-auc:0.49996
# [774]	train-auc:0.83936	test-auc:0.49998
# [775]	train-auc:0.83938	test-auc:0.49995
# [776]	train-auc:0.83942	test-auc:0.49990
# [777]	train-auc:0.83974	test-auc:0.49998
# [778]	train-auc:0.84002	test-auc:0.49998
# [779]	train-auc:0.84014	test-auc:0.49991
# [780]	train-auc:0.84013	test-auc:0.49992
# [781]	train-auc:0.84030	test-auc:0.49994
# [782]	train-auc:0.84048	test-auc:0.49995
# [783]	train-auc:0.84066	test-auc:0.50000
# [784]	train-auc:0.84073	test-auc:0.49988
# [785]	train-auc:0.84081	test-auc:0.49985
# [786]	train-auc:0.84081	test-auc:0.49984
# [787]	train-auc:0.84102	test-auc:0.49983
# [788]	train-auc:0.84133	test-auc:0.49990
# [789]	train-auc:0.84156	test-auc:0.49994
# [790]	train-auc:0.84167	test-auc:0.49991
# [791]	train-auc:0.84180	test-auc:0.49986
# [792]	train-auc:0.84206	test-auc:0.49982
# [793]	train-auc:0.84246	test-auc:0.49979
# [794]	train-auc:0.84248	test-auc:0.49975
# [795]	train-auc:0.84248	test-auc:0.49981
# [796]	train-auc:0.84256	test-auc:0.49981
# [797]	train-auc:0.84262	test-auc:0.49989
# [798]	train-auc:0.84265	test-auc:0.49983
# [799]	train-auc:0.84266	test-auc:0.49988
# [800]	train-auc:0.84299	test-auc:0.49988
# [801]	train-auc:0.84310	test-auc:0.49993
# [802]	train-auc:0.84335	test-auc:0.49991
# [803]	train-auc:0.84349	test-auc:0.50001
# [804]	train-auc:0.84370	test-auc:0.50007
# [805]	train-auc:0.84377	test-auc:0.50007
# [806]	train-auc:0.84375	test-auc:0.50007
# [807]	train-auc:0.84378	test-auc:0.50007
# [808]	train-auc:0.84376	test-auc:0.50005
# [809]	train-auc:0.84381	test-auc:0.49995
# [810]	train-auc:0.84384	test-auc:0.49997
# [811]	train-auc:0.84382	test-auc:0.50002
# [812]	train-auc:0.84400	test-auc:0.49998
# [813]	train-auc:0.84406	test-auc:0.49999
# [814]	train-auc:0.84423	test-auc:0.49999
# [815]	train-auc:0.84438	test-auc:0.49996
# [816]	train-auc:0.84454	test-auc:0.50000
# [817]	train-auc:0.84452	test-auc:0.50000
# [818]	train-auc:0.84455	test-auc:0.50002
# [819]	train-auc:0.84479	test-auc:0.50007
# [820]	train-auc:0.84480	test-auc:0.50003
# [821]	train-auc:0.84500	test-auc:0.49994
# [822]	train-auc:0.84519	test-auc:0.49991
# [823]	train-auc:0.84523	test-auc:0.49985
# [824]	train-auc:0.84555	test-auc:0.49986
# [825]	train-auc:0.84555	test-auc:0.49987
# [826]	train-auc:0.84576	test-auc:0.49991
# [827]	train-auc:0.84602	test-auc:0.49983
# [828]	train-auc:0.84622	test-auc:0.49980
# [829]	train-auc:0.84648	test-auc:0.49979
# [830]	train-auc:0.84654	test-auc:0.49978
# [831]	train-auc:0.84657	test-auc:0.49974
# [832]	train-auc:0.84667	test-auc:0.49972
# [833]	train-auc:0.84685	test-auc:0.49978
# [834]	train-auc:0.84685	test-auc:0.49972
# [835]	train-auc:0.84706	test-auc:0.49974
# [836]	train-auc:0.84707	test-auc:0.49977
# [837]	train-auc:0.84736	test-auc:0.49979
# [838]	train-auc:0.84757	test-auc:0.49981
# [839]	train-auc:0.84757	test-auc:0.49985
# [840]	train-auc:0.84753	test-auc:0.49987
# [841]	train-auc:0.84762	test-auc:0.49982
# [842]	train-auc:0.84790	test-auc:0.49979
# [843]	train-auc:0.84805	test-auc:0.49976
# [844]	train-auc:0.84809	test-auc:0.49979
# [845]	train-auc:0.84817	test-auc:0.49976
# [846]	train-auc:0.84824	test-auc:0.49976
# [847]	train-auc:0.84828	test-auc:0.49987
# [848]	train-auc:0.84835	test-auc:0.49983
# [849]	train-auc:0.84841	test-auc:0.49983
# [850]	train-auc:0.84865	test-auc:0.49972
# [851]	train-auc:0.84892	test-auc:0.49975
# [852]	train-auc:0.84891	test-auc:0.49980
# [853]	train-auc:0.84892	test-auc:0.49980
# [854]	train-auc:0.84890	test-auc:0.49979
# [855]	train-auc:0.84916	test-auc:0.49978
# [856]	train-auc:0.84930	test-auc:0.49968
# [857]	train-auc:0.84955	test-auc:0.49970
# [858]	train-auc:0.84967	test-auc:0.49973
# [859]	train-auc:0.84976	test-auc:0.49971
# [860]	train-auc:0.84989	test-auc:0.49970
# [861]	train-auc:0.85002	test-auc:0.49976
# [862]	train-auc:0.85019	test-auc:0.49970
# [863]	train-auc:0.85037	test-auc:0.49960
# [864]	train-auc:0.85050	test-auc:0.49959
# [865]	train-auc:0.85076	test-auc:0.49964
# [866]	train-auc:0.85084	test-auc:0.49961
# [867]	train-auc:0.85085	test-auc:0.49960
# [868]	train-auc:0.85086	test-auc:0.49961
# [869]	train-auc:0.85106	test-auc:0.49962
# [870]	train-auc:0.85108	test-auc:0.49968
# [871]	train-auc:0.85115	test-auc:0.49965
# [872]	train-auc:0.85121	test-auc:0.49961
# [873]	train-auc:0.85161	test-auc:0.49955
# [874]	train-auc:0.85163	test-auc:0.49959
# [875]	train-auc:0.85176	test-auc:0.49953
# [876]	train-auc:0.85198	test-auc:0.49950
# [877]	train-auc:0.85214	test-auc:0.49951
# [878]	train-auc:0.85213	test-auc:0.49951
# [879]	train-auc:0.85215	test-auc:0.49949
# [880]	train-auc:0.85234	test-auc:0.49960
# [881]	train-auc:0.85251	test-auc:0.49955
# [882]	train-auc:0.85252	test-auc:0.49955
# [883]	train-auc:0.85250	test-auc:0.49958
# [884]	train-auc:0.85260	test-auc:0.49959
# [885]	train-auc:0.85276	test-auc:0.49949
# [886]	train-auc:0.85287	test-auc:0.49952
# [887]	train-auc:0.85302	test-auc:0.49949
# [888]	train-auc:0.85305	test-auc:0.49947
# [889]	train-auc:0.85319	test-auc:0.49951
# [890]	train-auc:0.85331	test-auc:0.49945
# [891]	train-auc:0.85329	test-auc:0.49949
# [892]	train-auc:0.85326	test-auc:0.49947
# [893]	train-auc:0.85324	test-auc:0.49949
# [894]	train-auc:0.85337	test-auc:0.49954
# [895]	train-auc:0.85342	test-auc:0.49958
# [896]	train-auc:0.85359	test-auc:0.49950
# [897]	train-auc:0.85361	test-auc:0.49946
# [898]	train-auc:0.85406	test-auc:0.49929
# [899]	train-auc:0.85417	test-auc:0.49931
# [900]	train-auc:0.85429	test-auc:0.49937
# [901]	train-auc:0.85435	test-auc:0.49935
# [902]	train-auc:0.85440	test-auc:0.49938
# [903]	train-auc:0.85474	test-auc:0.49937
# [904]	train-auc:0.85488	test-auc:0.49938
# [905]	train-auc:0.85494	test-auc:0.49936
# [906]	train-auc:0.85509	test-auc:0.49930
# [907]	train-auc:0.85524	test-auc:0.49924
# [908]	train-auc:0.85548	test-auc:0.49922
# [909]	train-auc:0.85562	test-auc:0.49924
# [910]	train-auc:0.85565	test-auc:0.49926
# [911]	train-auc:0.85604	test-auc:0.49916
# [912]	train-auc:0.85607	test-auc:0.49914
# [913]	train-auc:0.85613	test-auc:0.49914
# [914]	train-auc:0.85622	test-auc:0.49915
# [915]	train-auc:0.85618	test-auc:0.49916

# %%
df_res=pd.DataFrame({'cust_id':X_test['cust_id'],'p_test':bst.predict(dtest)})
df_res1=pd.DataFrame({'cust_id':X_train['cust_id'],'p_test':bst1.predict(dtrain)})

df=pd.concat([df_res,df_res1],axis=0,ignore_index=True)

df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))

# %%
temp=len(df_train)
df_train.to_csv("train_input.csv", encoding='utf-8')

df_train=df_train[df_train['p_test']>=0.1]


print("经过对抗验证，有",len(df_train),"条数据被保留，",temp-len(df_train),"条数据被抛弃",sep="")
# Out:
# 经过对抗验证，有17992条数据被保留，7条数据被抛弃

# %% [markdown]
# # 训练模型

# %% [markdown]
# ## 超参数

# %%
N = 60
num_round = 3000
local_test_size = 2000

# 共用
test_size = [0.2, 0.25, 0.3]
max_depth = [3, 4, 5]
subsample = [0.8, 0.75, 0.7, 0.65, 0.6]
early_stopping_rounds = 150

# XGB
eta = [0.007, 0.01]

# LGB
learning_rate = [0.03, 0.02, 0.025]

# %% [markdown]
# ### train划分为
# * 本地测试集（固定）d_localtest
# * 训练集（固定）
#   * 评估集（每次的模型不同）dtest
#   * 真正的训练集（每次的模型不同）dtrain

# %%
import copy
import xgboost as xgb
import random
from sklearn import model_selection
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from catboost import CatBoostClassifier


pred_labels = []
local_test_labels = []
loss_seq = []
max_auc_loss = 0
flag = 0
important_x_seq = []


d_full = xgb.DMatrix(df_train[x_col], label=df_train['label'])
X = df_train[x_col]
Y = df_train['label']

X, X_local_test, Y, Y_local_test = model_selection.train_test_split(
    X, Y, test_size=local_test_size, stratify=Y, random_state=2022)

d_localtest = xgb.DMatrix(X_local_test, label=Y_local_test)
x_perd = xgb.DMatrix(df_test[x_col])

d_localtest1 = lgb.Dataset(X_local_test, Y_local_test)
x_perd1 = lgb.Dataset(df_test[x_col])


lgbcallback = [early_stopping(early_stopping_rounds), log_evaluation(10000)]

# %%
for i in range(N):

    test_size_this_round = random.choice(test_size)
    X_train, X_test, y_train, y_test = model_selection.train_test_split(
        X, Y, test_size=test_size_this_round, stratify=Y)

    #XGB-----------------------------------------------
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    evallist = [(dtest, 'eval')]
    param = {
        'max_depth': random.choice(max_depth),
        'eta': random.choice(eta),
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'subsample': random.choice(subsample),
        'tree_method': 'gpu_hist',
        'gpu_id': 0,
    }

    bst = xgb.train(param, dtrain, num_round, evals=evallist,
                    early_stopping_rounds=early_stopping_rounds, verbose_eval=False)

    loss = roc_auc_score(y_test, bst.predict(dtest))
    train_loss = roc_auc_score(y_train, bst.predict(dtrain))
    local_test_loss = roc_auc_score(Y_local_test, bst.predict(d_localtest))
    global_auc = roc_auc_score(df_train['label'], bst.predict(d_full))

    pred_label = list(bst.predict(x_perd))
    test_label = list(bst.predict(d_localtest))


    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'xgb'}

    if flag == 0:
        info_df = pd.DataFrame(temp_dict, index=[i])
        flag = 1
    else:
        info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])

    # if loss > max_auc_loss:
    #     best_bst = copy.deepcopy(bst)
    #     max_auc_loss = loss

    # if False:
    #     pic = xgb.plot_importance(bst, max_num_features=50)
    #     temp = pic.get_ymajorticklabels()
    #     important_x = [str(i).split("\'")[1] for i in temp]
    #     important_x.reverse()
    #     important_x_seq += important_x

    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))


    #LGB--------------------------------------------------------
    param = {
        'task': 'train',
        "max_depth": random.choice(max_depth),
        'max_bin':128,
        'boosting_type': 'gbdt',  # 设置提升类型
        'objective': 'binary',  # 目标函数
        'metric': 'auc',  # 评估函数
        'learning_rate': random.choice(learning_rate),  # 学习速率
        'bagging_fraction': random.choice(subsample),  # 建树的样本采样比例
        'bagging_freq': 1,  # k 意味着每 k 次迭代执行bagging
        'min_data_in_leaf': 1,
        'verbose': -1,  # <0 显示致命的, =0 显示错误 (警告), >0 显示信息
        'device_type': 'gpu',
    }

    dtrain = lgb.Dataset(X_train, y_train)
    dtest = lgb.Dataset(X_test, y_test)

    if cat_way == "auto":
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback, categorical_feature=type_col)
    else:
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback)

    loss = roc_auc_score(y_test, bst1.predict(X_test))
    train_loss = roc_auc_score(y_train, bst1.predict(X_train))
    local_test_loss = roc_auc_score(Y_local_test, bst1.predict(X_local_test))
    global_auc = roc_auc_score(
        df_train['label'], bst1.predict(df_train[x_col]))

    pred_label = list(bst1.predict(df_test[x_col]))
    test_label = list(bst1.predict(X_local_test))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'lgb'}

    info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    #CAT-----------------------------------------------------------
    # bst2 = CatBoostClassifier(iterations=num_round,
    #                        depth=random.choice(max_depth),
    #                        learning_rate=random.choice(learning_rate),
    #                        loss_function='Logloss',
    #                        subsample=random.choice(subsample),
    #                        early_stopping_rounds=early_stopping_rounds,
    #                        verbose=False)
    # bst2.fit(X_train, y_train,eval_set=(X_test,y_test))

    # loss = roc_auc_score(y_test, bst2.predict_proba(X_test)[:,1])
    # train_loss = roc_auc_score(y_train, bst2.predict_proba(X_train)[:,1])
    # local_test_loss = roc_auc_score(Y_local_test, bst2.predict_proba(X_local_test)[:,1])
    # global_auc = roc_auc_score(df_train['label'], bst2.predict_proba(df_train[x_col])[:,1])

    # pred_label = list(bst2.predict_proba(df_test[x_col])[:,1])
    # test_label = list(bst2.predict_proba(X_local_test)[:,1])

    # temp_dict = {"test_auc": loss, "train_auc": train_loss,
    #              'local_test_auc': local_test_loss,
    #              'model': 'cat'}

    # info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    # pred_labels.append(copy.deepcopy(pred_label))
    # local_test_labels.append(copy.deepcopy(test_label))


print('最大AUC:', max(info_df['local_test_auc']), sep="")
# Out:
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [570]	valid_0's auc: 0.754578
# Early stopping, best iteration is:
# [587]	valid_0's auc: 0.764463
# Early stopping, best iteration is:
# [587]	valid_0's auc: 0.764463
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.764936
# 最大AUC:0.7615470101083911

# %%
info_df.to_csv("info.csv", encoding="utf-8", index=False)

# %%
# pic = xgb.plot_importance(bst, max_num_features=50)
# temp = pic.get_ymajorticklabels()
# important_x = [str(i).split("\'")[1] for i in temp]
# important_x.reverse()

# %%
# important_x

# %%
# pd.value_counts(important_x_seq)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6.5, 6), dpi=200)


plt.scatter(info_df[info_df['model'] == 'xgb']['local_test_auc'], info_df[info_df['model'] == 'xgb']['test_auc'],
            c='r', s=4,label="xgb")
plt.scatter(info_df[info_df['model'] == 'lgb']['local_test_auc'], info_df[info_df['model'] == 'lgb']['test_auc'],
            c='g', s=4,label="lgb")
# plt.scatter(info_df[info_df['model'] == 'cat']['local_test_auc'], info_df[info_df['model'] == 'cat']['test_auc'],
#             c='b', s=4,label="cat")
plt.legend()
plt.xlabel('local_test_auc')
plt.ylabel('test_auc')
plt.plot([0.6, 0.85], [0.6, 0.85])
plt.xlim(0.6, 0.85)
plt.ylim(0.6, 0.85)
plt.grid()
plt.show()

# %% [markdown]
# # 输出模块

# %%
import time
import numpy as np
from sklearn.metrics import roc_auc_score

date = time.strftime("%Y%m%d-%H%M%S", time.localtime())
res_num = np.argsort([-i for i in (info_df['local_test_auc']+info_df['test_auc'])])

# 选择前n个结果进行平均（手动指定or在本地测试集排序选出）
if True:
    max_auc = -1
    list_temp = []
    auc_seq = []
    for i in range(N*2):
        list_temp.append(local_test_labels[res_num[i]])
        # 算数平均
        # temp = np.mean(list_temp, axis=0)
        # 几何平均(better)
        temp = np.exp(np.mean(np.log(list_temp), axis=0))
        temp_auc = roc_auc_score(Y_local_test, temp)
        # print(i, temp_auc)
        auc_seq.append(temp_auc)
        if temp_auc > max_auc:
            max_auc = temp_auc
            n = i+1
else:
    n = 40
    n = min(N, n)

res_num = res_num[0:n]

#final_pred_label = np.mean([pred_labels[i] for i in res_num], axis=0)
final_pred_label = np.exp(
    np.mean(np.log([pred_labels[i] for i in res_num]), axis=0))
#local_auc = roc_auc_score(y_test, final_pred_label)
print("本地测试集前", n, "个auc为", [
      list(info_df['local_test_auc'])[i] for i in res_num], sep="")
print("平均之后local_test_AUC为", max_auc, sep="")

res = pd.DataFrame({
    'cust_id': list(df_test["cust_id"]),
    'label': final_pred_label,
})
res.to_csv("./output/result"+date+".csv", encoding="utf-8", index=False)
# Out:
# 本地测试集前12个auc为[0.7432788332724394, 0.7445576056509561, 0.7533720009743027, 0.7419467787114847, 0.7605727073438071, 0.7562111801242236, 0.7467802338326635, 0.7416118621361589, 0.7340305687492388, 0.7615470101083911, 0.7466508342467422, 0.7533415540129095]
# 平均之后local_test_AUC为0.7603900255754475

# %%
from sklearn.linear_model import LogisticRegression
res_df=pd.DataFrame()
pred_df=pd.DataFrame()
model_name=[]

for i in res_num:
    res_df['model'+str(i)]=local_test_labels[i]
    pred_df['model'+str(i)]=pred_labels[i]

logreg=LogisticRegression()
logreg.fit(res_df,Y_local_test)

print(roc_auc_score(Y_local_test,logreg.predict_proba(res_df)[:,1]))

log_pred=logreg.predict_proba(pred_df)[:,1]


res = pd.DataFrame({
    'cust_id': list(df_test["cust_id"]),
    'label': log_pred,
})
res.to_csv("./output/result"+date+"_stacking.csv", encoding="utf-8", index=False)
# Out:
# 0.7602986846912678

# %%
plt.figure(figsize=(10, 6), dpi=200)
plt.plot(list(range(len(auc_seq))), auc_seq)

# %% [markdown]
# # 一些tips
#
# * 提升n有一定提升(如何确定n？)
#   * n=40 0.6763
#   * n=10 0.6728
#   * n=100 0.6774
#   * 太大也不好
#
# # 一些进展
#
# * 随机参数
# * XGB模型
# * 本地测试集auc较高（0.75+）
# * 部分类型变量进行了one-hot处理
# * 把细分表除了loan与主表合并
#
# # tbd
#
# * 处理细分表的loan，给出指标
# * 确定变量类型，以便对所有（or重要）分类变量进行one-hot处理
# * 新模型？

# %% [markdown]
# ## 10-12
# * 0.6824（这次我留了代码\doge）
# * 把-99变为-1，本地有提升
# * 划出了一个本地测试集
#   * 本地测试集（固定）d_localtest
#   * 训练集（固定）
#     * 评估集（每次的模型不同）dtest
#     * 真正的训练集（每次的模型不同）dtrain
# * 添加参数nan_num（然并卵）
# * tbd
#   * 找特征
#   * 加x
#   * 分析一下参数作用
# ## 10-18
# * 不能把industry之类种类很多的分类变量做证据权重

# %% [markdown]
# # 记录
# * 1014-4
#   * 0.6823
#   * 证据权重
#   * 未添加贷款记录表
#   * 按test auc排序
# * 1014-5
#   * 0.6925
#   * 按local test auc排序
# * 1015-1
#   * 0.6834
#   * 处理-99
# * 1015-2
#   * 0.6628
#   * 添加贷款记录表
# * 1015-3
#   * 0.6772
#   * 不处理-99
#   * 去除贷款记录表
#   * 添加了type-col
# * 1015-4
#   * 0.6811
#   * 不做证据权重
# * 1015-5
#   * 0.6765
#   * gamma=0
# * 1016-1
#   * 0.6798
#   * 添加gamma
#   * 增大early stop round
# * 1016-2
#   * 0.6858
#   * early stop round=10
#   * 证据权重
# * 1016-3
#   * 0.685799
#   * 使用原始type-col
# * 1017-2
#   * 0.6655
