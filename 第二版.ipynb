# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 数据读入

# %%
import pandas as pd

train_data = pd.read_csv("data\main\df_train_b1.csv", index_col=0)
test_data = pd.read_csv('data\main\df_test_b1.csv', index_col=0)

# %% [markdown]
# ## 要读入除了main之外的数在此处添加

# %%
import os
filenames = ["data\detail\df_basic_b1.csv",
             "data\detail\df_corp_b1.csv",
             "data\detail\df_judicial_b1.csv",
             "data\detail\df_loan2_b1.csv",
             "data\detail\df_query_b1.csv"
             ]
for filename in filenames:
    temp = pd.read_csv(filename)
    train_data = pd.merge(train_data, temp, on="cust_id",
                          how="left", suffixes=("", "_y"))
    test_data = pd.merge(test_data, temp, on="cust_id",
                         how="left", suffixes=("", "_y"))

# %%
train_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in train_data['judicial_reason']]
test_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in test_data['judicial_reason']]

# %%
# train_data['nan_num'] = (train_data == 0).astype(int).sum(axis=1)
# test_data['nan_num'] = (test_data == 0).astype(int).sum(axis=1)

# %%
# drop_col = ['basic_2',
#             'basic_3',
#             'basic_4',
#             'loan1_1',
#             'overdue_19',
#             'basic_8',
#             'basic_9',
#             'basic_11',
#             'basic_15',
#             'loan1_17',
#             'loan1_31', ]

# train_data.drop(drop_col, inplace=True, axis=1)
# test_data.drop(drop_col, inplace=True, axis=1)

# %% [markdown]
# ## loan1表

# %%
if True:

    import pandas as pd
    temp_df = pd.read_csv("./data/detail/df_loan1_b1.csv")

    def chuli_loan(df, colname, ways):
        cust_id = list(range(len(set(df['cust_id']))))
        res_df = pd.DataFrame({'cust_id': cust_id})

        if len(ways) == 0:
            return res_df
        if 'mean' in ways:
            res_df[colname+'_mean'] = df.groupby('cust_id')[colname].mean()
        if 'sum' in ways:
            res_df[colname+'_sum'] = df.groupby('cust_id')[colname].sum()
        if 'count' in ways:
            res_df[colname+'_count'] = df.groupby('cust_id')[colname].count()
        if 'std' in ways:
            res_df[colname+'_std'] = df.groupby('cust_id')[colname].std()
        if 'diff_std' in ways:
            res_df[colname+'_diff_std'] = df.groupby('cust_id')[colname].apply(
                lambda x: x.sort_values(ascending=True).diff()[2:].std())
        return res_df

    for colname in ['loan1_2', 'loan1_3', 'loan1_7', 'loan1_9']:
        df = chuli_loan(temp_df, colname, ('sum', 'std'))
        train_data = pd.merge(train_data, df, on="cust_id",
                              how="left", suffixes=("", "_y"))
        test_data = pd.merge(test_data, df, on="cust_id",
                             how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_3', ('count',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_1', ('std', 'diff_std'))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_10', ('mean',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_11', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_12', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    train_data.to_csv('./data/df_train.csv')
    test_data.to_csv('./data/df_test.csv')

# %%
# data = temp_df.dropna(axis=0,subset = ["date_1"])
# data['date2-date1'] = data['date_2'] - data['date_1']
# data['date3-date2'] = data['date_3'] - data['date_2']
# data['dateinterval_max'] = data[['date2-date1','date3-date2']].max(axis=1)
# data = data.groupby('cust_id').agg({'date_2':['count'],'date_3':['count'],'dateinterval_max':['mean']})
# train_data = pd.merge(train_data, data, on="cust_id",
#                           how="left", suffixes=("", "_y"))
# test_data = pd.merge(test_data, data, on="cust_id",
#                          how="left", suffixes=("", "_y"))

# %% [markdown]
# ## 处理NAN

# %%
def delnan(df):
    df = df.dropna(how="all", axis=1)  # 删除全是空值的列
    df = df.fillna(-99)
    return df

# %%
df_train = delnan(train_data)
df_test = delnan(test_data)

# %% [markdown]
# ## 处理-99

# %%
# df_train.replace(-99, -1, inplace=True)
# df_test.replace(-99, -1, inplace=True)

# %% [markdown]
# ## 主成分分析（效果不好）

# %%
# from sklearn.decomposition import PCA

# full_col_name = list(df_train.columns)
# pca_col=[i for i in full_col_name if "loan" in i]

# modelPCA=PCA(n_components=0.9)
# temp=modelPCA.fit_transform(df_train[pca_col])
# temp1=modelPCA.transform(df_test[pca_col])
# for i in range(temp.shape[1]):
#     df_train['loan_pca'+str(i)]=temp[:,i]
#     df_test['loan_pca'+str(i)]=temp1[:,i]

# %% [markdown]
# ## 处理分类变量

# %%
cat_way = "no"

# %% [markdown]
# ## 转化为one-hot编码（不宜采用）

# %%
def to_one_hot(df, colnames):
    df = pd.get_dummies(df, columns=colnames)
    return df

# %% [markdown]
# ## 类型计数

# %%
type_count_cols = ['industry', 'scope', 'basic_13']

# %%
# def type_count(cols):
#     global df_train, df_test
#     df1 = df_train[['cust_id']+cols]
#     df2 = df_test[['cust_id']+cols]
#     df = pd.concat([df1, df2], axis=0, ignore_index=True)
#     for i in cols:
#         temp_df = df.groupby(i)['cust_id'].count()
#         temp_df = pd.DataFrame({(i+"_num"): temp_df})
#         df = pd.merge(df, temp_df, on=i, how="left")
#         del df[i], df1[i], df2[i]
#     df_train = pd.merge(df_train, df, on="cust_id",
#                         how="left", suffixes=("", "_y"))
#     df_test = pd.merge(df_test, df, on="cust_id",
#                        how="left", suffixes=("", "_y"))


# type_count(type_count_cols)

# %% [markdown]
# ## 证据权重

# %%
import pandas as pd
import numpy as np


def cal_woe(df, df_no_label, x_cols, y_col):
    for i in x_cols:
        x_set = pd.unique(df[i])
        x1_set = pd.unique(df_no_label[i])
        for j in x1_set:
            if j not in x_set:
                df_no_label[i].replace(j, 0.03, inplace=True)
                print(i, j, '不存在')
        for j in x_set:
            woe = np.mean(df[df[i] == j][y_col])
            if woe >= 0.1:
                n = np.sum(df[df[i] == j][y_col])
                print(i, '列：', j, ' 共有', int(n/woe), '个,其中',
                      int(n), '个label为1,woe为', woe, sep="")
            df[i].replace(j, woe, inplace=True)
            df_no_label[i].replace(j, woe, inplace=True)
    return df, df_no_label

# %%
type_col = ["basic_1",
            "basic_10",
            "basic_12",
            "basic_14",
            "loan1_16",
            "loan1_20",
            "loan1_23",
            "loan1_25", ]

# df_train,df_test=cal_woe(df_train,df_test,type_col,"label")

# %%
if cat_way == "auto" or cat_way == "no":
    type_col = ["basic_1",
                "basic_10",
                "basic_12",
                "basic_14",
                "loan1_16",
                "loan1_20",
                "loan1_23",
                "loan1_25",
                "loan2_1_y",
                "query_2_y",
                "query_3_y",
                "query_4_y",
                "query_5_y",
                "query_6_y", ]
if cat_way == "manual":
    woe_col = ['basic_1',
               'basic_5',
               'basic_6',
               'basic_10',
               'loan1_16',
               'loan1_20',
               'loan1_25',
               'loan1_23',
               'loan1_32',
               'loan2_4',
               'loan2_6',
               'overdue_2',
               'overdue_20',
               'overdue_21',
               'overdue_26',
               'overdue_27',
               'query_1',
               'query_2',
               'query_3',
               'query_4',
               'query_6',
               'query_7',
               'query_8',
               'query_10',
               'query_11', ]

    onehot_col = ['basic_12',
                  'basic_14',
                  'loan1_8',
                  'loan1_9',
                  'overdue_1',
                  'overdue_3',
                  'overdue_4',
                  'overdue_5',
                  'overdue_6',
                  'overdue_7',
                  'overdue_8',
                  'overdue_9',
                  'overdue_10',
                  'overdue_11',
                  'overdue_12',
                  'overdue_14',
                  'overdue_15',
                  'overdue_16',
                  'overdue_17',
                  'overdue_18',
                  'overdue_22',
                  'overdue_23',
                  'overdue_24',
                  'overdue_25',
                  'overdue_28',
                  'overdue_29',
                  'query_5',
                  'query_9', ]

    df_train, df_test = cal_woe(df_train, df_test, woe_col, "label")
    df_train = to_one_hot(df_train, onehot_col)
    df_test = to_one_hot(df_test, onehot_col)
    for i in df_train.columns:
        if i not in df_test.columns:
            df_test[i] = 0

# %%
full_col_name = list(df_train.columns)
basic_col = [i for i in full_col_name if "basic" in i]
loan_col = [i for i in full_col_name if "loan" in i]
overdue_col = [i for i in full_col_name if "overdue" in i]
query_col = [i for i in full_col_name if "query" in i]
judicial_col = [i for i in full_col_name if "judicial" in i]
date_col = [i for i in full_col_name if "date" in i]
# loan_pca_col = [i for i in full_col_name if "loan_pca" in i]

# for i in judicial_col:
#     df_train[i].astype("float")
#     df_test[i].astype("float")

# %% [markdown]
# ## rank化

# %%
def rank(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = np.argsort(df[i])
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


a = ['loan1_1', 'loan1_3', 'loan1_7', 'loan1_9']
b = ['_sum', '_mean']
c = []
for i in a:
    for j in b:
        c.append(i+j)
# rank(c)

# %% [markdown]
# ## 归一化

# %%
def norm(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.min(df[i]))/(np.max(df[i])-np.min(df[i]))
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# norm([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 标准化

# %%
def stand(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.mean(df[i], axis=0))/np.std(df[i], axis=0)
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# stand([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 设置哪些x作为模型自变量输入

# %%
# x_col = basic_col+loan_col+['nan_num'] + ['is_judicial']+ overdue_col+query_col
# x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col+['scope_num'] + \
#     ['industry_num']+['date_3_count', 'date_1_std', 'date_1_diff_std']

x_col = basic_col+['is_judicial']+loan_col+query_col
x_col = [i for i in x_col if i in full_col_name]

if cat_way == "auto":
    type_col = [i for i in type_col if i in x_col]
# categorize(df_train,type_col)
# categorize(df_test,type_col)

print('自变量个数为', len(x_col))
print(x_col)
# Out:
# 自变量个数为 94
# ['basic_1', 'basic_2', 'basic_3', 'basic_4', 'basic_5', 'basic_6', 'basic_7', 'basic_8', 'basic_9', 'basic_10', 'basic_11', 'basic_12', 'basic_13', 'basic_14', 'basic_15', 'basic_1_y', 'basic_2_y', 'basic_3_y', 'is_judicial', 'loan1_1', 'loan1_2', 'loan1_3', 'loan1_4', 'loan1_5', 'loan1_6', 'loan1_7', 'loan1_8', 'loan1_9', 'loan1_10', 'loan1_11', 'loan1_12', 'loan1_13', 'loan1_14', 'loan1_15', 'loan1_16', 'loan1_17', 'loan1_18', 'loan1_19', 'loan1_20', 'loan1_21', 'loan1_22', 'loan1_23', 'loan1_24', 'loan1_25', 'loan1_26', 'loan1_27', 'loan1_28', 'loan1_29', 'loan1_30', 'loan1_31', 'loan1_32', 'loan1_33', 'loan2_1', 'loan2_2', 'loan2_3', 'loan2_4', 'loan2_5', 'loan2_6', 'loan2_7', 'loan2_8', 'loan2_9', 'loan2_10', 'loan2_11', 'loan2_12', 'loan2_1_y', 'loan2_2_y', 'loan2_3_y', 'loan2_4_y', 'loan2_5_y', 'loan1_2_sum', 'loan1_2_std', 'loan1_3_sum', 'loan1_3_std', 'loan1_7_sum', 'loan1_7_std', 'loan1_9_sum', 'loan1_9_std', 'query_1', 'query_2', 'query_3', 'query_4', 'query_5', 'query_6', 'query_7', 'query_8', 'query_9', 'query_10', 'query_11', 'query_1_y', 'query_2_y', 'query_3_y', 'query_4_y', 'query_5_y', 'query_6_y']

# %%
df_train = df_train[x_col+['label', 'cust_id']]
df_test = df_test[x_col+['cust_id']]

df_test.to_csv("test_input.csv", encoding='utf-8')

# %% [markdown]
# ## 对抗验证

# %%
from sklearn import model_selection
import xgboost as xgb

df_full = pd.concat([df_train[x_col+['cust_id']], df_test],
                    axis=0, ignore_index=True)
df_full['label_test'] = [1 if i in df_test['cust_id']
                         else 0 for i in df_full['cust_id']]

df_full.to_csv("full.csv", encoding='utf-8')

# %%
X = df_full[x_col+['cust_id']]
Y = df_full['label_test']

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(
    X, Y, test_size=0.5, stratify=Y, random_state=2022)

dtrain = xgb.DMatrix(X_train[x_col], label=Y_train)
dtest = xgb.DMatrix(X_test[x_col], label=Y_test)

param = {'max_depth': 5,
         'eta': 0.1,
         'objective': 'binary:logistic',
         "eval_metric": "auc",
         "scale_pos_weight": 1,
         "subsample": 1,
         "min_child_weight": 1,
         'tree_method': 'gpu_hist',
         'gpu_id': 0, }

bst = xgb.train(param, dtrain, 4000, evals=[(dtrain, "train"), (dtest, "test")],
                early_stopping_rounds=300, verbose_eval=True)
bst1 = xgb.train(param, dtest, 4000, evals=[(dtest, "train"), (dtrain, "test")],
                 early_stopping_rounds=300, verbose_eval=False)
# Out:
# [0]	train-auc:0.53583	test-auc:0.49235
# [1]	train-auc:0.54782	test-auc:0.49142
# [2]	train-auc:0.55699	test-auc:0.48995
# [3]	train-auc:0.56871	test-auc:0.49386
# [4]	train-auc:0.57104	test-auc:0.49432
# [5]	train-auc:0.57965	test-auc:0.49297
# [6]	train-auc:0.59991	test-auc:0.49251
# [7]	train-auc:0.61328	test-auc:0.49473
# [8]	train-auc:0.62755	test-auc:0.49355
# [9]	train-auc:0.63645	test-auc:0.49527
# [10]	train-auc:0.64679	test-auc:0.49600
# [11]	train-auc:0.65598	test-auc:0.49534
# [12]	train-auc:0.65812	test-auc:0.49441
# [13]	train-auc:0.67030	test-auc:0.49208
# [14]	train-auc:0.67839	test-auc:0.49195
# [15]	train-auc:0.68601	test-auc:0.49239
# [16]	train-auc:0.69486	test-auc:0.49233
# [17]	train-auc:0.69735	test-auc:0.49024
# [18]	train-auc:0.70062	test-auc:0.49105
# [19]	train-auc:0.71205	test-auc:0.49103
# [20]	train-auc:0.71746	test-auc:0.49241
# [21]	train-auc:0.72901	test-auc:0.49593
# [22]	train-auc:0.73511	test-auc:0.49366
# [23]	train-auc:0.73980	test-auc:0.49384
# [24]	train-auc:0.74102	test-auc:0.49385
# [25]	train-auc:0.74387	test-auc:0.49574
# [26]	train-auc:0.74750	test-auc:0.49847
# [27]	train-auc:0.74934	test-auc:0.50037
# [28]	train-auc:0.75157	test-auc:0.49908
# [29]	train-auc:0.75326	test-auc:0.49979
# [30]	train-auc:0.75460	test-auc:0.49924
# [31]	train-auc:0.75641	test-auc:0.49895
# [32]	train-auc:0.75710	test-auc:0.49907
# [33]	train-auc:0.75761	test-auc:0.49946
# [34]	train-auc:0.75795	test-auc:0.49974
# [35]	train-auc:0.76360	test-auc:0.49939
# [36]	train-auc:0.76676	test-auc:0.50118
# [37]	train-auc:0.77024	test-auc:0.50226
# [38]	train-auc:0.77313	test-auc:0.50252
# [39]	train-auc:0.77390	test-auc:0.50314
# [40]	train-auc:0.78157	test-auc:0.50308
# [41]	train-auc:0.78513	test-auc:0.50381
# [42]	train-auc:0.78800	test-auc:0.50301
# [43]	train-auc:0.79255	test-auc:0.50271
# [44]	train-auc:0.79400	test-auc:0.50324
# [45]	train-auc:0.79530	test-auc:0.50319
# [46]	train-auc:0.79899	test-auc:0.50190
# [47]	train-auc:0.79935	test-auc:0.50179
# [48]	train-auc:0.80065	test-auc:0.50254
# [49]	train-auc:0.80374	test-auc:0.50221
# [50]	train-auc:0.80397	test-auc:0.50237
# [51]	train-auc:0.80455	test-auc:0.50247
# [52]	train-auc:0.80739	test-auc:0.50256
# [53]	train-auc:0.80773	test-auc:0.50274
# [54]	train-auc:0.80907	test-auc:0.50344
# [55]	train-auc:0.81104	test-auc:0.50423
# [56]	train-auc:0.81302	test-auc:0.50360
# [57]	train-auc:0.81541	test-auc:0.50318
# [58]	train-auc:0.81720	test-auc:0.50338
# [59]	train-auc:0.81957	test-auc:0.50327
# [60]	train-auc:0.82040	test-auc:0.50322
# [61]	train-auc:0.82325	test-auc:0.50346
# [62]	train-auc:0.82674	test-auc:0.50259
# [63]	train-auc:0.82687	test-auc:0.50342
# [64]	train-auc:0.83004	test-auc:0.50311
# [65]	train-auc:0.83071	test-auc:0.50319
# [66]	train-auc:0.83333	test-auc:0.50369
# [67]	train-auc:0.83361	test-auc:0.50337
# [68]	train-auc:0.83478	test-auc:0.50319
# [69]	train-auc:0.83788	test-auc:0.50380
# [70]	train-auc:0.84127	test-auc:0.50256
# [71]	train-auc:0.84187	test-auc:0.50287
# [72]	train-auc:0.84212	test-auc:0.50290
# [73]	train-auc:0.84649	test-auc:0.50233
# [74]	train-auc:0.84650	test-auc:0.50256
# [75]	train-auc:0.84759	test-auc:0.50173
# [76]	train-auc:0.85123	test-auc:0.50126
# [77]	train-auc:0.85292	test-auc:0.50141
# [78]	train-auc:0.85420	test-auc:0.50128
# [79]	train-auc:0.85552	test-auc:0.50071
# [80]	train-auc:0.85545	test-auc:0.50083
# [81]	train-auc:0.85837	test-auc:0.50114
# [82]	train-auc:0.85931	test-auc:0.50090
# [83]	train-auc:0.85974	test-auc:0.50090
# [84]	train-auc:0.86006	test-auc:0.50092
# [85]	train-auc:0.86088	test-auc:0.50141
# [86]	train-auc:0.86211	test-auc:0.50170
# [87]	train-auc:0.86241	test-auc:0.50168
# [88]	train-auc:0.86569	test-auc:0.50296
# [89]	train-auc:0.86741	test-auc:0.50245
# [90]	train-auc:0.86820	test-auc:0.50246
# [91]	train-auc:0.86945	test-auc:0.50246
# [92]	train-auc:0.86972	test-auc:0.50238
# [93]	train-auc:0.87023	test-auc:0.50222
# [94]	train-auc:0.87103	test-auc:0.50228
# [95]	train-auc:0.87278	test-auc:0.50171
# [96]	train-auc:0.87329	test-auc:0.50208
# [97]	train-auc:0.87368	test-auc:0.50198
# [98]	train-auc:0.87397	test-auc:0.50192
# [99]	train-auc:0.87611	test-auc:0.50300
# [100]	train-auc:0.87613	test-auc:0.50303
# [101]	train-auc:0.87605	test-auc:0.50293
# [102]	train-auc:0.87628	test-auc:0.50290
# [103]	train-auc:0.87649	test-auc:0.50292
# [104]	train-auc:0.87706	test-auc:0.50299
# [105]	train-auc:0.87799	test-auc:0.50272
# [106]	train-auc:0.87803	test-auc:0.50309
# [107]	train-auc:0.88063	test-auc:0.50335
# [108]	train-auc:0.88205	test-auc:0.50315
# [109]	train-auc:0.88282	test-auc:0.50291
# [110]	train-auc:0.88387	test-auc:0.50309
# [111]	train-auc:0.88455	test-auc:0.50259
# [112]	train-auc:0.88503	test-auc:0.50243
# [113]	train-auc:0.88818	test-auc:0.50351
# [114]	train-auc:0.88887	test-auc:0.50367
# [115]	train-auc:0.88961	test-auc:0.50372
# [116]	train-auc:0.89160	test-auc:0.50360
# [117]	train-auc:0.89314	test-auc:0.50253
# [118]	train-auc:0.89570	test-auc:0.50326
# [119]	train-auc:0.89687	test-auc:0.50340
# [120]	train-auc:0.89755	test-auc:0.50300
# [121]	train-auc:0.89794	test-auc:0.50289
# [122]	train-auc:0.89907	test-auc:0.50240
# [123]	train-auc:0.89957	test-auc:0.50236
# [124]	train-auc:0.90183	test-auc:0.50239
# [125]	train-auc:0.90295	test-auc:0.50246
# [126]	train-auc:0.90397	test-auc:0.50216
# [127]	train-auc:0.90405	test-auc:0.50222
# [128]	train-auc:0.90413	test-auc:0.50259
# [129]	train-auc:0.90513	test-auc:0.50247
# [130]	train-auc:0.90565	test-auc:0.50244
# [131]	train-auc:0.90595	test-auc:0.50254
# [132]	train-auc:0.90782	test-auc:0.50241
# [133]	train-auc:0.90891	test-auc:0.50253
# [134]	train-auc:0.91071	test-auc:0.50268
# [135]	train-auc:0.91272	test-auc:0.50354
# [136]	train-auc:0.91362	test-auc:0.50314
# [137]	train-auc:0.91559	test-auc:0.50370
# [138]	train-auc:0.91557	test-auc:0.50360
# [139]	train-auc:0.91571	test-auc:0.50348
# [140]	train-auc:0.91627	test-auc:0.50348
# [141]	train-auc:0.91793	test-auc:0.50426
# [142]	train-auc:0.91919	test-auc:0.50428
# [143]	train-auc:0.92025	test-auc:0.50414
# [144]	train-auc:0.92033	test-auc:0.50421
# [145]	train-auc:0.92287	test-auc:0.50392
# [146]	train-auc:0.92298	test-auc:0.50385
# [147]	train-auc:0.92346	test-auc:0.50392
# [148]	train-auc:0.92548	test-auc:0.50390
# [149]	train-auc:0.92606	test-auc:0.50365
# [150]	train-auc:0.92622	test-auc:0.50368
# [151]	train-auc:0.92716	test-auc:0.50360
# [152]	train-auc:0.92744	test-auc:0.50377
# [153]	train-auc:0.92884	test-auc:0.50450
# [154]	train-auc:0.92914	test-auc:0.50442
# [155]	train-auc:0.93026	test-auc:0.50535
# [156]	train-auc:0.93100	test-auc:0.50545
# [157]	train-auc:0.93157	test-auc:0.50539
# [158]	train-auc:0.93154	test-auc:0.50545
# [159]	train-auc:0.93146	test-auc:0.50552
# [160]	train-auc:0.93173	test-auc:0.50557
# [161]	train-auc:0.93179	test-auc:0.50553
# [162]	train-auc:0.93246	test-auc:0.50565
# [163]	train-auc:0.93338	test-auc:0.50617
# [164]	train-auc:0.93400	test-auc:0.50566
# [165]	train-auc:0.93399	test-auc:0.50559
# [166]	train-auc:0.93530	test-auc:0.50562
# [167]	train-auc:0.93589	test-auc:0.50472
# [168]	train-auc:0.93617	test-auc:0.50473
# [169]	train-auc:0.93619	test-auc:0.50468
# [170]	train-auc:0.93675	test-auc:0.50479
# [171]	train-auc:0.93686	test-auc:0.50444
# [172]	train-auc:0.93760	test-auc:0.50440
# [173]	train-auc:0.93875	test-auc:0.50435
# [174]	train-auc:0.93884	test-auc:0.50408
# [175]	train-auc:0.93987	test-auc:0.50406
# [176]	train-auc:0.94094	test-auc:0.50353
# [177]	train-auc:0.94127	test-auc:0.50360
# [178]	train-auc:0.94246	test-auc:0.50379
# [179]	train-auc:0.94262	test-auc:0.50401
# [180]	train-auc:0.94308	test-auc:0.50429
# [181]	train-auc:0.94378	test-auc:0.50488
# [182]	train-auc:0.94421	test-auc:0.50478
# [183]	train-auc:0.94421	test-auc:0.50490
# [184]	train-auc:0.94518	test-auc:0.50428
# [185]	train-auc:0.94518	test-auc:0.50419
# [186]	train-auc:0.94538	test-auc:0.50464
# [187]	train-auc:0.94632	test-auc:0.50426
# [188]	train-auc:0.94651	test-auc:0.50459
# [189]	train-auc:0.94734	test-auc:0.50415
# [190]	train-auc:0.94736	test-auc:0.50421
# [191]	train-auc:0.94752	test-auc:0.50476
# [192]	train-auc:0.94771	test-auc:0.50463
# [193]	train-auc:0.94807	test-auc:0.50484
# [194]	train-auc:0.94864	test-auc:0.50438
# [195]	train-auc:0.94979	test-auc:0.50404
# [196]	train-auc:0.95014	test-auc:0.50445
# [197]	train-auc:0.95048	test-auc:0.50435
# [198]	train-auc:0.95051	test-auc:0.50422
# [199]	train-auc:0.95071	test-auc:0.50427
# [200]	train-auc:0.95102	test-auc:0.50472
# [201]	train-auc:0.95106	test-auc:0.50495
# [202]	train-auc:0.95169	test-auc:0.50502
# [203]	train-auc:0.95192	test-auc:0.50536
# [204]	train-auc:0.95218	test-auc:0.50510
# [205]	train-auc:0.95271	test-auc:0.50490
# [206]	train-auc:0.95299	test-auc:0.50526
# [207]	train-auc:0.95300	test-auc:0.50513
# [208]	train-auc:0.95349	test-auc:0.50501
# [209]	train-auc:0.95353	test-auc:0.50507
# [210]	train-auc:0.95377	test-auc:0.50494
# [211]	train-auc:0.95416	test-auc:0.50492
# [212]	train-auc:0.95419	test-auc:0.50497
# [213]	train-auc:0.95427	test-auc:0.50500
# [214]	train-auc:0.95487	test-auc:0.50454
# [215]	train-auc:0.95551	test-auc:0.50463
# [216]	train-auc:0.95655	test-auc:0.50437
# [217]	train-auc:0.95721	test-auc:0.50438
# [218]	train-auc:0.95810	test-auc:0.50431
# [219]	train-auc:0.95849	test-auc:0.50428
# [220]	train-auc:0.95896	test-auc:0.50415
# [221]	train-auc:0.95944	test-auc:0.50457
# [222]	train-auc:0.95975	test-auc:0.50494
# [223]	train-auc:0.96037	test-auc:0.50509
# [224]	train-auc:0.96042	test-auc:0.50508
# [225]	train-auc:0.96132	test-auc:0.50514
# [226]	train-auc:0.96186	test-auc:0.50518
# [227]	train-auc:0.96221	test-auc:0.50569
# [228]	train-auc:0.96290	test-auc:0.50583
# [229]	train-auc:0.96352	test-auc:0.50623
# [230]	train-auc:0.96372	test-auc:0.50598
# [231]	train-auc:0.96394	test-auc:0.50599
# [232]	train-auc:0.96443	test-auc:0.50617
# [233]	train-auc:0.96498	test-auc:0.50620
# [234]	train-auc:0.96505	test-auc:0.50611
# [235]	train-auc:0.96508	test-auc:0.50604
# [236]	train-auc:0.96518	test-auc:0.50585
# [237]	train-auc:0.96521	test-auc:0.50589
# [238]	train-auc:0.96555	test-auc:0.50605
# [239]	train-auc:0.96602	test-auc:0.50676
# [240]	train-auc:0.96653	test-auc:0.50712
# [241]	train-auc:0.96687	test-auc:0.50715
# [242]	train-auc:0.96712	test-auc:0.50725
# [243]	train-auc:0.96735	test-auc:0.50737
# [244]	train-auc:0.96748	test-auc:0.50737
# [245]	train-auc:0.96780	test-auc:0.50795
# [246]	train-auc:0.96785	test-auc:0.50805
# [247]	train-auc:0.96803	test-auc:0.50787
# [248]	train-auc:0.96817	test-auc:0.50773
# [249]	train-auc:0.96824	test-auc:0.50764
# [250]	train-auc:0.96860	test-auc:0.50776
# [251]	train-auc:0.96874	test-auc:0.50751
# [252]	train-auc:0.96885	test-auc:0.50749
# [253]	train-auc:0.96910	test-auc:0.50762
# [254]	train-auc:0.96927	test-auc:0.50731
# [255]	train-auc:0.96963	test-auc:0.50691
# [256]	train-auc:0.96971	test-auc:0.50626
# [257]	train-auc:0.96995	test-auc:0.50656
# [258]	train-auc:0.97004	test-auc:0.50642
# [259]	train-auc:0.97031	test-auc:0.50664
# [260]	train-auc:0.97065	test-auc:0.50607
# [261]	train-auc:0.97053	test-auc:0.50616
# [262]	train-auc:0.97063	test-auc:0.50575
# [263]	train-auc:0.97067	test-auc:0.50539
# [264]	train-auc:0.97068	test-auc:0.50540
# [265]	train-auc:0.97093	test-auc:0.50570
# [266]	train-auc:0.97134	test-auc:0.50549
# [267]	train-auc:0.97159	test-auc:0.50553
# [268]	train-auc:0.97172	test-auc:0.50524
# [269]	train-auc:0.97194	test-auc:0.50529
# [270]	train-auc:0.97215	test-auc:0.50484
# [271]	train-auc:0.97217	test-auc:0.50488
# [272]	train-auc:0.97241	test-auc:0.50464
# [273]	train-auc:0.97330	test-auc:0.50490
# [274]	train-auc:0.97368	test-auc:0.50476
# [275]	train-auc:0.97381	test-auc:0.50514
# [276]	train-auc:0.97399	test-auc:0.50480
# [277]	train-auc:0.97422	test-auc:0.50458
# [278]	train-auc:0.97430	test-auc:0.50454
# [279]	train-auc:0.97453	test-auc:0.50513
# [280]	train-auc:0.97468	test-auc:0.50477
# [281]	train-auc:0.97472	test-auc:0.50445
# [282]	train-auc:0.97478	test-auc:0.50469
# [283]	train-auc:0.97493	test-auc:0.50462
# [284]	train-auc:0.97499	test-auc:0.50459
# [285]	train-auc:0.97548	test-auc:0.50491
# [286]	train-auc:0.97566	test-auc:0.50496
# [287]	train-auc:0.97571	test-auc:0.50499
# [288]	train-auc:0.97585	test-auc:0.50497
# [289]	train-auc:0.97618	test-auc:0.50499
# [290]	train-auc:0.97620	test-auc:0.50496
# [291]	train-auc:0.97644	test-auc:0.50538
# [292]	train-auc:0.97658	test-auc:0.50534
# [293]	train-auc:0.97684	test-auc:0.50521
# [294]	train-auc:0.97701	test-auc:0.50526
# [295]	train-auc:0.97720	test-auc:0.50540
# [296]	train-auc:0.97737	test-auc:0.50534
# [297]	train-auc:0.97750	test-auc:0.50525
# [298]	train-auc:0.97759	test-auc:0.50509
# [299]	train-auc:0.97782	test-auc:0.50515
# [300]	train-auc:0.97814	test-auc:0.50466
# [301]	train-auc:0.97829	test-auc:0.50447
# [302]	train-auc:0.97835	test-auc:0.50430
# [303]	train-auc:0.97851	test-auc:0.50439
# [304]	train-auc:0.97860	test-auc:0.50431
# [305]	train-auc:0.97897	test-auc:0.50429
# [306]	train-auc:0.97905	test-auc:0.50395
# [307]	train-auc:0.97911	test-auc:0.50423
# [308]	train-auc:0.97926	test-auc:0.50423
# [309]	train-auc:0.97926	test-auc:0.50423
# [310]	train-auc:0.97932	test-auc:0.50413
# [311]	train-auc:0.97956	test-auc:0.50395
# [312]	train-auc:0.97957	test-auc:0.50388
# [313]	train-auc:0.97957	test-auc:0.50387
# [314]	train-auc:0.97972	test-auc:0.50391
# [315]	train-auc:0.97978	test-auc:0.50396
# [316]	train-auc:0.97983	test-auc:0.50407
# [317]	train-auc:0.97986	test-auc:0.50431
# [318]	train-auc:0.98002	test-auc:0.50389
# [319]	train-auc:0.98001	test-auc:0.50390
# [320]	train-auc:0.98011	test-auc:0.50406
# [321]	train-auc:0.98020	test-auc:0.50424
# [322]	train-auc:0.98025	test-auc:0.50450
# [323]	train-auc:0.98041	test-auc:0.50455
# [324]	train-auc:0.98044	test-auc:0.50445
# [325]	train-auc:0.98046	test-auc:0.50432
# [326]	train-auc:0.98043	test-auc:0.50408
# [327]	train-auc:0.98045	test-auc:0.50423
# [328]	train-auc:0.98045	test-auc:0.50426
# [329]	train-auc:0.98044	test-auc:0.50433
# [330]	train-auc:0.98081	test-auc:0.50461
# [331]	train-auc:0.98096	test-auc:0.50442
# [332]	train-auc:0.98099	test-auc:0.50439
# [333]	train-auc:0.98118	test-auc:0.50466
# [334]	train-auc:0.98120	test-auc:0.50456
# [335]	train-auc:0.98132	test-auc:0.50465
# [336]	train-auc:0.98158	test-auc:0.50468
# [337]	train-auc:0.98173	test-auc:0.50460
# [338]	train-auc:0.98189	test-auc:0.50491
# [339]	train-auc:0.98235	test-auc:0.50477
# [340]	train-auc:0.98255	test-auc:0.50471
# [341]	train-auc:0.98262	test-auc:0.50464
# [342]	train-auc:0.98263	test-auc:0.50472
# [343]	train-auc:0.98268	test-auc:0.50473
# [344]	train-auc:0.98270	test-auc:0.50455
# [345]	train-auc:0.98283	test-auc:0.50446
# [346]	train-auc:0.98311	test-auc:0.50424
# [347]	train-auc:0.98331	test-auc:0.50408
# [348]	train-auc:0.98342	test-auc:0.50401
# [349]	train-auc:0.98343	test-auc:0.50394
# [350]	train-auc:0.98348	test-auc:0.50382
# [351]	train-auc:0.98355	test-auc:0.50375
# [352]	train-auc:0.98368	test-auc:0.50398
# [353]	train-auc:0.98380	test-auc:0.50388
# [354]	train-auc:0.98384	test-auc:0.50400
# [355]	train-auc:0.98389	test-auc:0.50384
# [356]	train-auc:0.98404	test-auc:0.50372
# [357]	train-auc:0.98414	test-auc:0.50359
# [358]	train-auc:0.98423	test-auc:0.50364
# [359]	train-auc:0.98445	test-auc:0.50365
# [360]	train-auc:0.98445	test-auc:0.50355
# [361]	train-auc:0.98458	test-auc:0.50367
# [362]	train-auc:0.98466	test-auc:0.50349
# [363]	train-auc:0.98477	test-auc:0.50340
# [364]	train-auc:0.98496	test-auc:0.50305
# [365]	train-auc:0.98509	test-auc:0.50293
# [366]	train-auc:0.98516	test-auc:0.50271
# [367]	train-auc:0.98538	test-auc:0.50239
# [368]	train-auc:0.98549	test-auc:0.50269
# [369]	train-auc:0.98549	test-auc:0.50296
# [370]	train-auc:0.98576	test-auc:0.50305
# [371]	train-auc:0.98578	test-auc:0.50308
# [372]	train-auc:0.98583	test-auc:0.50295
# [373]	train-auc:0.98584	test-auc:0.50296
# [374]	train-auc:0.98589	test-auc:0.50303
# [375]	train-auc:0.98599	test-auc:0.50314
# [376]	train-auc:0.98599	test-auc:0.50300
# [377]	train-auc:0.98603	test-auc:0.50295
# [378]	train-auc:0.98622	test-auc:0.50283
# [379]	train-auc:0.98624	test-auc:0.50304
# [380]	train-auc:0.98624	test-auc:0.50306
# [381]	train-auc:0.98651	test-auc:0.50338
# [382]	train-auc:0.98652	test-auc:0.50343
# [383]	train-auc:0.98653	test-auc:0.50352
# [384]	train-auc:0.98677	test-auc:0.50317
# [385]	train-auc:0.98688	test-auc:0.50308
# [386]	train-auc:0.98691	test-auc:0.50251
# [387]	train-auc:0.98691	test-auc:0.50242
# [388]	train-auc:0.98710	test-auc:0.50218
# [389]	train-auc:0.98716	test-auc:0.50198
# [390]	train-auc:0.98719	test-auc:0.50202
# [391]	train-auc:0.98735	test-auc:0.50185
# [392]	train-auc:0.98766	test-auc:0.50173
# [393]	train-auc:0.98775	test-auc:0.50160
# [394]	train-auc:0.98786	test-auc:0.50168
# [395]	train-auc:0.98816	test-auc:0.50189
# [396]	train-auc:0.98826	test-auc:0.50209
# [397]	train-auc:0.98829	test-auc:0.50214
# [398]	train-auc:0.98832	test-auc:0.50200
# [399]	train-auc:0.98834	test-auc:0.50197
# [400]	train-auc:0.98835	test-auc:0.50188
# [401]	train-auc:0.98845	test-auc:0.50201
# [402]	train-auc:0.98859	test-auc:0.50203
# [403]	train-auc:0.98884	test-auc:0.50223
# [404]	train-auc:0.98896	test-auc:0.50228
# [405]	train-auc:0.98920	test-auc:0.50232
# [406]	train-auc:0.98921	test-auc:0.50224
# [407]	train-auc:0.98931	test-auc:0.50234
# [408]	train-auc:0.98960	test-auc:0.50221
# [409]	train-auc:0.98962	test-auc:0.50203
# [410]	train-auc:0.98979	test-auc:0.50216
# [411]	train-auc:0.98981	test-auc:0.50232
# [412]	train-auc:0.98985	test-auc:0.50218
# [413]	train-auc:0.98990	test-auc:0.50240
# [414]	train-auc:0.98994	test-auc:0.50194
# [415]	train-auc:0.98998	test-auc:0.50207
# [416]	train-auc:0.99004	test-auc:0.50186
# [417]	train-auc:0.99013	test-auc:0.50194
# [418]	train-auc:0.99041	test-auc:0.50183
# [419]	train-auc:0.99043	test-auc:0.50206
# [420]	train-auc:0.99054	test-auc:0.50213
# [421]	train-auc:0.99063	test-auc:0.50202
# [422]	train-auc:0.99077	test-auc:0.50191
# [423]	train-auc:0.99078	test-auc:0.50167
# [424]	train-auc:0.99085	test-auc:0.50151
# [425]	train-auc:0.99098	test-auc:0.50157
# [426]	train-auc:0.99114	test-auc:0.50168
# [427]	train-auc:0.99121	test-auc:0.50191
# [428]	train-auc:0.99121	test-auc:0.50189
# [429]	train-auc:0.99131	test-auc:0.50160
# [430]	train-auc:0.99151	test-auc:0.50134
# [431]	train-auc:0.99164	test-auc:0.50142
# [432]	train-auc:0.99170	test-auc:0.50173
# [433]	train-auc:0.99172	test-auc:0.50183
# [434]	train-auc:0.99177	test-auc:0.50194
# [435]	train-auc:0.99180	test-auc:0.50164
# [436]	train-auc:0.99183	test-auc:0.50146
# [437]	train-auc:0.99189	test-auc:0.50144
# [438]	train-auc:0.99194	test-auc:0.50142
# [439]	train-auc:0.99199	test-auc:0.50137
# [440]	train-auc:0.99205	test-auc:0.50130
# [441]	train-auc:0.99220	test-auc:0.50136
# [442]	train-auc:0.99226	test-auc:0.50154
# [443]	train-auc:0.99234	test-auc:0.50166
# [444]	train-auc:0.99252	test-auc:0.50180
# [445]	train-auc:0.99259	test-auc:0.50167
# [446]	train-auc:0.99261	test-auc:0.50153
# [447]	train-auc:0.99270	test-auc:0.50171
# [448]	train-auc:0.99271	test-auc:0.50180
# [449]	train-auc:0.99281	test-auc:0.50169
# [450]	train-auc:0.99284	test-auc:0.50197
# [451]	train-auc:0.99284	test-auc:0.50205
# [452]	train-auc:0.99292	test-auc:0.50242
# [453]	train-auc:0.99307	test-auc:0.50235
# [454]	train-auc:0.99321	test-auc:0.50251
# [455]	train-auc:0.99321	test-auc:0.50251
# [456]	train-auc:0.99324	test-auc:0.50245
# [457]	train-auc:0.99324	test-auc:0.50261
# [458]	train-auc:0.99325	test-auc:0.50249
# [459]	train-auc:0.99338	test-auc:0.50209
# [460]	train-auc:0.99338	test-auc:0.50213
# [461]	train-auc:0.99347	test-auc:0.50176
# [462]	train-auc:0.99352	test-auc:0.50183
# [463]	train-auc:0.99358	test-auc:0.50172
# [464]	train-auc:0.99361	test-auc:0.50170
# [465]	train-auc:0.99364	test-auc:0.50185
# [466]	train-auc:0.99370	test-auc:0.50174
# [467]	train-auc:0.99371	test-auc:0.50169
# [468]	train-auc:0.99380	test-auc:0.50158
# [469]	train-auc:0.99383	test-auc:0.50154
# [470]	train-auc:0.99384	test-auc:0.50171
# [471]	train-auc:0.99392	test-auc:0.50148
# [472]	train-auc:0.99392	test-auc:0.50137
# [473]	train-auc:0.99408	test-auc:0.50154
# [474]	train-auc:0.99414	test-auc:0.50162
# [475]	train-auc:0.99414	test-auc:0.50166
# [476]	train-auc:0.99427	test-auc:0.50161
# [477]	train-auc:0.99430	test-auc:0.50183
# [478]	train-auc:0.99430	test-auc:0.50184
# [479]	train-auc:0.99430	test-auc:0.50183
# [480]	train-auc:0.99446	test-auc:0.50214
# [481]	train-auc:0.99452	test-auc:0.50261
# [482]	train-auc:0.99465	test-auc:0.50256
# [483]	train-auc:0.99465	test-auc:0.50266
# [484]	train-auc:0.99474	test-auc:0.50263
# [485]	train-auc:0.99483	test-auc:0.50260
# [486]	train-auc:0.99497	test-auc:0.50290
# [487]	train-auc:0.99501	test-auc:0.50267
# [488]	train-auc:0.99508	test-auc:0.50257
# [489]	train-auc:0.99511	test-auc:0.50243
# [490]	train-auc:0.99512	test-auc:0.50259
# [491]	train-auc:0.99518	test-auc:0.50267
# [492]	train-auc:0.99523	test-auc:0.50274
# [493]	train-auc:0.99525	test-auc:0.50281
# [494]	train-auc:0.99526	test-auc:0.50299
# [495]	train-auc:0.99526	test-auc:0.50305
# [496]	train-auc:0.99526	test-auc:0.50302
# [497]	train-auc:0.99526	test-auc:0.50311
# [498]	train-auc:0.99533	test-auc:0.50320
# [499]	train-auc:0.99539	test-auc:0.50322
# [500]	train-auc:0.99550	test-auc:0.50300
# [501]	train-auc:0.99551	test-auc:0.50322
# [502]	train-auc:0.99559	test-auc:0.50306
# [503]	train-auc:0.99561	test-auc:0.50312
# [504]	train-auc:0.99567	test-auc:0.50325
# [505]	train-auc:0.99567	test-auc:0.50319
# [506]	train-auc:0.99573	test-auc:0.50318
# [507]	train-auc:0.99574	test-auc:0.50327
# [508]	train-auc:0.99574	test-auc:0.50326
# [509]	train-auc:0.99575	test-auc:0.50314
# [510]	train-auc:0.99575	test-auc:0.50296
# [511]	train-auc:0.99575	test-auc:0.50289
# [512]	train-auc:0.99576	test-auc:0.50294
# [513]	train-auc:0.99576	test-auc:0.50308
# [514]	train-auc:0.99585	test-auc:0.50286
# [515]	train-auc:0.99591	test-auc:0.50309
# [516]	train-auc:0.99598	test-auc:0.50313
# [517]	train-auc:0.99600	test-auc:0.50284
# [518]	train-auc:0.99600	test-auc:0.50292
# [519]	train-auc:0.99606	test-auc:0.50306
# [520]	train-auc:0.99613	test-auc:0.50332
# [521]	train-auc:0.99614	test-auc:0.50339
# [522]	train-auc:0.99619	test-auc:0.50354
# [523]	train-auc:0.99622	test-auc:0.50345
# [524]	train-auc:0.99628	test-auc:0.50343
# [525]	train-auc:0.99629	test-auc:0.50345
# [526]	train-auc:0.99631	test-auc:0.50342
# [527]	train-auc:0.99640	test-auc:0.50335
# [528]	train-auc:0.99643	test-auc:0.50328
# [529]	train-auc:0.99647	test-auc:0.50317
# [530]	train-auc:0.99646	test-auc:0.50316
# [531]	train-auc:0.99651	test-auc:0.50307
# [532]	train-auc:0.99651	test-auc:0.50304
# [533]	train-auc:0.99652	test-auc:0.50320
# [534]	train-auc:0.99655	test-auc:0.50321
# [535]	train-auc:0.99664	test-auc:0.50291
# [536]	train-auc:0.99666	test-auc:0.50296
# [537]	train-auc:0.99665	test-auc:0.50280
# [538]	train-auc:0.99665	test-auc:0.50277
# [539]	train-auc:0.99670	test-auc:0.50286
# [540]	train-auc:0.99671	test-auc:0.50302
# [541]	train-auc:0.99671	test-auc:0.50312
# [542]	train-auc:0.99680	test-auc:0.50346
# [543]	train-auc:0.99680	test-auc:0.50364
# [544]	train-auc:0.99680	test-auc:0.50364
# [545]	train-auc:0.99681	test-auc:0.50355
# [546]	train-auc:0.99684	test-auc:0.50358

# %%
df_res = pd.DataFrame(
    {'cust_id': X_test['cust_id'], 'p_test': bst.predict(dtest)})
df_res1 = pd.DataFrame(
    {'cust_id': X_train['cust_id'], 'p_test': bst1.predict(dtrain)})

df = pd.concat([df_res, df_res1], axis=0, ignore_index=True)

df_train = pd.merge(df_train, df, on="cust_id",
                    how="left", suffixes=("", "_y"))

# %%
temp = len(df_train)
df_train.to_csv("train_input.csv", encoding='utf-8')

df_train = df_train[df_train['p_test'] >= 0.1]


print("经过对抗验证，有", len(df_train), "条数据被保留，",
      temp-len(df_train), "条数据被抛弃", sep="")
# Out:
# 经过对抗验证，有16775条数据被保留，1224条数据被抛弃

# %% [markdown]
# # 训练模型

# %% [markdown]
# ## 超参数

# %%
N = 60
num_round = 3000
local_test_size = 2000

# 共用
test_size = [0.2, 0.25, 0.3]
max_depth = [3, 4, 5]
subsample = [0.8, 0.75, 0.7, 0.65, 0.6]
early_stopping_rounds = 150

# XGB
eta = [0.007, 0.01]

# LGB
learning_rate = [0.03, 0.02, 0.025]

# %% [markdown]
# ### train划分为
# * 本地测试集（固定）d_localtest
# * 训练集（固定）
#   * 评估集（每次的模型不同）dtest
#   * 真正的训练集（每次的模型不同）dtrain

# %%
import copy
import xgboost as xgb
import random
from sklearn import model_selection
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from catboost import CatBoostClassifier


pred_labels = []
local_test_labels = []
loss_seq = []
max_auc_loss = 0
flag = 0
important_x_seq = []


d_full = xgb.DMatrix(df_train[x_col], label=df_train['label'])
X = df_train[x_col]
Y = df_train['label']

X, X_local_test, Y, Y_local_test = model_selection.train_test_split(
    X, Y, test_size=local_test_size, stratify=Y, random_state=2022)

d_localtest = xgb.DMatrix(X_local_test, label=Y_local_test)
x_perd = xgb.DMatrix(df_test[x_col])

d_localtest1 = lgb.Dataset(X_local_test, Y_local_test)
x_perd1 = lgb.Dataset(df_test[x_col])


lgbcallback = [early_stopping(early_stopping_rounds), log_evaluation(10000)]

# %%
for i in range(N):

    test_size_this_round = random.choice(test_size)
    X_train, X_test, y_train, y_test = model_selection.train_test_split(
        X, Y, test_size=test_size_this_round, stratify=Y)

    # XGB-----------------------------------------------
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    evallist = [(dtest, 'eval')]
    param = {
        'max_depth': random.choice(max_depth),
        'eta': random.choice(eta),
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'subsample': random.choice(subsample),
        'tree_method': 'gpu_hist',
        'gpu_id': 0,
    }

    bst = xgb.train(param, dtrain, num_round, evals=evallist,
                    early_stopping_rounds=early_stopping_rounds, verbose_eval=False)

    loss = roc_auc_score(y_test, bst.predict(dtest))
    train_loss = roc_auc_score(y_train, bst.predict(dtrain))
    local_test_loss = roc_auc_score(Y_local_test, bst.predict(d_localtest))
    global_auc = roc_auc_score(df_train['label'], bst.predict(d_full))

    pred_label = list(bst.predict(x_perd))
    test_label = list(bst.predict(d_localtest))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'xgb'}

    if flag == 0:
        info_df = pd.DataFrame(temp_dict, index=[i])
        flag = 1
    else:
        info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])

    # if loss > max_auc_loss:
    #     best_bst = copy.deepcopy(bst)
    #     max_auc_loss = loss

    # if False:
    #     pic = xgb.plot_importance(bst, max_num_features=50)
    #     temp = pic.get_ymajorticklabels()
    #     important_x = [str(i).split("\'")[1] for i in temp]
    #     important_x.reverse()
    #     important_x_seq += important_x

    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    # LGB--------------------------------------------------------
    param = {
        'task': 'train',
        "max_depth": random.choice(max_depth),
        'max_bin': 128,
        'boosting_type': 'gbdt',  # 设置提升类型
        'objective': 'binary',  # 目标函数
        'metric': 'auc',  # 评估函数
        'learning_rate': random.choice(learning_rate),  # 学习速率
        'bagging_fraction': random.choice(subsample),  # 建树的样本采样比例
        'bagging_freq': 1,  # k 意味着每 k 次迭代执行bagging
        'min_data_in_leaf': 1,
        'verbose': -1,  # <0 显示致命的, =0 显示错误 (警告), >0 显示信息
        'device_type': 'gpu',
    }

    dtrain = lgb.Dataset(X_train, y_train)
    dtest = lgb.Dataset(X_test, y_test)

    if cat_way == "auto":
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback, categorical_feature=type_col)
    else:
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback)

    loss = roc_auc_score(y_test, bst1.predict(X_test))
    train_loss = roc_auc_score(y_train, bst1.predict(X_train))
    local_test_loss = roc_auc_score(Y_local_test, bst1.predict(X_local_test))
    global_auc = roc_auc_score(
        df_train['label'], bst1.predict(df_train[x_col]))

    pred_label = list(bst1.predict(df_test[x_col]))
    test_label = list(bst1.predict(X_local_test))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'lgb'}

    info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    # CAT-----------------------------------------------------------
    # bst2 = CatBoostClassifier(iterations=num_round,
    #                        depth=random.choice(max_depth),
    #                        learning_rate=random.choice(learning_rate),
    #                        loss_function='Logloss',
    #                        subsample=random.choice(subsample),
    #                        early_stopping_rounds=early_stopping_rounds,
    #                        verbose=False)
    # bst2.fit(X_train, y_train,eval_set=(X_test,y_test))

    # loss = roc_auc_score(y_test, bst2.predict_proba(X_test)[:,1])
    # train_loss = roc_auc_score(y_train, bst2.predict_proba(X_train)[:,1])
    # local_test_loss = roc_auc_score(Y_local_test, bst2.predict_proba(X_local_test)[:,1])
    # global_auc = roc_auc_score(df_train['label'], bst2.predict_proba(df_train[x_col])[:,1])

    # pred_label = list(bst2.predict_proba(df_test[x_col])[:,1])
    # test_label = list(bst2.predict_proba(X_local_test)[:,1])

    # temp_dict = {"test_auc": loss, "train_auc": train_loss,
    #              'local_test_auc': local_test_loss,
    #              'model': 'cat'}

    # info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    # pred_labels.append(copy.deepcopy(pred_label))
    # local_test_labels.append(copy.deepcopy(test_label))


print('最大AUC:', max(info_df['local_test_auc']), sep="")
# Out:
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [180]	valid_0's auc: 0.765223
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [420]	valid_0's auc: 0.771552
# Early stopping, best iteration is:
# [286]	valid_0's auc: 0.79832
# Early stopping, best iteration is:
# [286]	valid_0's auc: 0.79832
# Early stopping, best iteration is:
# [286]	valid_0's auc: 0.79832
# Early stopping, best iteration is:
# [286]	valid_0's auc: 0.79832
# Early stopping, best iteration is:
# [286]	valid_0's auc: 0.79832
# Early stopping, best iteration is:
# [286]	valid_0's auc: 0.79832
# Early stopping, best iteration is:
# [286]	valid_0's auc: 0.79832
# 最大AUC:0.7728808914870297

# %%
info_df.to_csv("info.csv", encoding="utf-8", index=False)

# %%
# pic = xgb.plot_importance(bst, max_num_features=50)
# temp = pic.get_ymajorticklabels()
# important_x = [str(i).split("\'")[1] for i in temp]
# important_x.reverse()

# %%
# important_x

# %%
# pd.value_counts(important_x_seq)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6.5, 6), dpi=200)


plt.scatter(info_df[info_df['model'] == 'xgb']['local_test_auc'], info_df[info_df['model'] == 'xgb']['test_auc'],
            c='r', s=4, label="xgb")
plt.scatter(info_df[info_df['model'] == 'lgb']['local_test_auc'], info_df[info_df['model'] == 'lgb']['test_auc'],
            c='g', s=4, label="lgb")
# plt.scatter(info_df[info_df['model'] == 'cat']['local_test_auc'], info_df[info_df['model'] == 'cat']['test_auc'],
#             c='b', s=4,label="cat")
plt.legend()
plt.xlabel('local_test_auc')
plt.ylabel('test_auc')
plt.plot([0.6, 0.85], [0.6, 0.85])
plt.xlim(0.6, 0.85)
plt.ylim(0.6, 0.85)
plt.grid()
plt.show()

# %% [markdown]
# # 输出模块

# %%
import time
import numpy as np
from sklearn.metrics import roc_auc_score

date = time.strftime("%Y%m%d-%H%M%S", time.localtime())
res_num = np.argsort(
    [-i for i in (info_df['local_test_auc']+info_df['test_auc'])])

# 选择前n个结果进行平均（手动指定or在本地测试集排序选出）
if True:
    max_auc = -1
    list_temp = []
    auc_seq = []
    for i in range(N*2):
        list_temp.append(local_test_labels[res_num[i]])
        # 算数平均
        # temp = np.mean(list_temp, axis=0)
        # 几何平均(better)
        temp = np.exp(np.mean(np.log(list_temp), axis=0))
        temp_auc = roc_auc_score(Y_local_test, temp)
        # print(i, temp_auc)
        auc_seq.append(temp_auc)
        if temp_auc > max_auc:
            max_auc = temp_auc
            n = i+1
else:
    n = 40
    n = min(N, n)

res_num = res_num[0:n]

#final_pred_label = np.mean([pred_labels[i] for i in res_num], axis=0)
final_pred_label = np.exp(
    np.mean(np.log([pred_labels[i] for i in res_num]), axis=0))
#local_auc = roc_auc_score(y_test, final_pred_label)
print("本地测试集前", n, "个auc为", [
      list(info_df['local_test_auc'])[i] for i in res_num], sep="")
print("平均之后local_test_AUC为", max_auc, sep="")

res = pd.DataFrame({
    'cust_id': list(df_test["cust_id"]),
    'label': final_pred_label,
})
res.to_csv("./output/result"+date+".csv", encoding="utf-8", index=False)
# Out:
# 本地测试集前12个auc为[0.7457678723663378, 0.7461865180854951, 0.7483710875654609, 0.748713615881135, 0.7484548167092926, 0.7541179515284375, 0.7679865424430643, 0.7599409328948971, 0.7527173913043479, 0.7494900133966631, 0.7659085373279748, 0.7728808914870297]
# 平均之后local_test_AUC为0.7686792108147608

# %%
plt.figure(figsize=(10, 6), dpi=200)
plt.plot(list(range(len(auc_seq))), auc_seq)

# %% [markdown]
# # 一些tips
#
# * 提升n有一定提升(如何确定n？)
#   * n=40 0.6763
#   * n=10 0.6728
#   * n=100 0.6774
#   * 太大也不好
#
# # 一些进展
#
# * 随机参数
# * XGB模型
# * 本地测试集auc较高（0.75+）
# * 部分类型变量进行了one-hot处理
# * 把细分表除了loan与主表合并
#
# # tbd
#
# * 处理细分表的loan，给出指标
# * 确定变量类型，以便对所有（or重要）分类变量进行one-hot处理
# * 新模型？

# %% [markdown]
# ## 10-12
# * 0.6824（这次我留了代码\doge）
# * 把-99变为-1，本地有提升
# * 划出了一个本地测试集
#   * 本地测试集（固定）d_localtest
#   * 训练集（固定）
#     * 评估集（每次的模型不同）dtest
#     * 真正的训练集（每次的模型不同）dtrain
# * 添加参数nan_num（然并卵）
# * tbd
#   * 找特征
#   * 加x
#   * 分析一下参数作用
# ## 10-18
# * 不能把industry之类种类很多的分类变量做证据权重

# %% [markdown]
# # 记录
# * 1014-4
#   * 0.6823
#   * 证据权重
#   * 未添加贷款记录表
#   * 按test auc排序
# * 1014-5
#   * 0.6925
#   * 按local test auc排序
# * 1015-1
#   * 0.6834
#   * 处理-99
# * 1015-2
#   * 0.6628
#   * 添加贷款记录表
# * 1015-3
#   * 0.6772
#   * 不处理-99
#   * 去除贷款记录表
#   * 添加了type-col
# * 1015-4
#   * 0.6811
#   * 不做证据权重
# * 1015-5
#   * 0.6765
#   * gamma=0
# * 1016-1
#   * 0.6798
#   * 添加gamma
#   * 增大early stop round
# * 1016-2
#   * 0.6858
#   * early stop round=10
#   * 证据权重
# * 1016-3
#   * 0.685799
#   * 使用原始type-col
# * 1017-2
#   * 0.6655
