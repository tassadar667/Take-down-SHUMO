# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 数据读入

# %%
import pandas as pd

train_data = pd.read_csv("data\main\df_train_b1.csv", index_col=0)
test_data = pd.read_csv('data\main\df_test_b1.csv', index_col=0)

# %% [markdown]
# ## 要读入除了main之外的数在此处添加

# %%
import os
filenames = ["data\detail\df_basic_b1.csv",
             "data\detail\df_corp_b1.csv",
             "data\detail\df_judicial_b1.csv",
             "data\detail\df_loan2_b1.csv",
             "data\detail\df_query_b1.csv"
             ]
for filename in filenames:
    temp = pd.read_csv(filename)
    train_data = pd.merge(train_data, temp, on="cust_id",
                          how="left", suffixes=("", "_y"))
    test_data = pd.merge(test_data, temp, on="cust_id",
                         how="left", suffixes=("", "_y"))

# %%
train_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in train_data['judicial_reason']]
test_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in test_data['judicial_reason']]

# %%
# train_data['nan_num'] = (train_data == 0).astype(int).sum(axis=1)
# test_data['nan_num'] = (test_data == 0).astype(int).sum(axis=1)

# %%
# drop_col = ['basic_2',
#             'basic_3',
#             'basic_4',
#             'loan1_1',
#             'overdue_19',
#             'basic_8',
#             'basic_9',
#             'basic_11',
#             'basic_15',
#             'loan1_17',
#             'loan1_31', ]

# train_data.drop(drop_col, inplace=True, axis=1)
# test_data.drop(drop_col, inplace=True, axis=1)

# %% [markdown]
# ## loan1表

# %%
if True:

    import pandas as pd
    temp_df = pd.read_csv("./data/detail/df_loan1_b1.csv")

    def chuli_loan(df, colname, ways):
        cust_id = list(range(len(set(df['cust_id']))))
        res_df = pd.DataFrame({'cust_id': cust_id})

        if len(ways) == 0:
            return res_df
        if 'mean' in ways:
            res_df[colname+'_mean'] = df.groupby('cust_id')[colname].mean()
        if 'sum' in ways:
            res_df[colname+'_sum'] = df.groupby('cust_id')[colname].sum()
        if 'count' in ways:
            res_df[colname+'_count'] = df.groupby('cust_id')[colname].count()
        if 'std' in ways:
            res_df[colname+'_std'] = df.groupby('cust_id')[colname].std()
        if 'diff_std' in ways:
            res_df[colname+'_diff_std'] = df.groupby('cust_id')[colname].apply(
                lambda x: x.sort_values(ascending=True).diff()[2:].std())
        return res_df

    for colname in ['loan1_2', 'loan1_3', 'loan1_7', 'loan1_9']:
        df = chuli_loan(temp_df, colname, ('sum', 'std','mean'))
        train_data = pd.merge(train_data, df, on="cust_id",
                              how="left", suffixes=("", "_y"))
        test_data = pd.merge(test_data, df, on="cust_id",
                             how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_3', ('count',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_1', ('std', 'diff_std'))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_10', ('mean',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_11', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_12', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    train_data.to_csv('./data/df_train.csv')
    test_data.to_csv('./data/df_test.csv')

# %%
# data = temp_df.dropna(axis=0,subset = ["date_1"])
# data['date2-date1'] = data['date_2'] - data['date_1']
# data['date3-date2'] = data['date_3'] - data['date_2']
# data['dateinterval_max'] = data[['date2-date1','date3-date2']].max(axis=1)
# data = data.groupby('cust_id').agg({'date_2':['count'],'date_3':['count'],'dateinterval_max':['mean']})
# train_data = pd.merge(train_data, data, on="cust_id",
#                           how="left", suffixes=("", "_y"))
# test_data = pd.merge(test_data, data, on="cust_id",
#                          how="left", suffixes=("", "_y"))

# %% [markdown]
# ## 处理NAN

# %%
def delnan(df):
    df = df.dropna(how="all", axis=1)  # 删除全是空值的列
    df = df.fillna(-99)
    return df

# %%
df_train = delnan(train_data)
df_test = delnan(test_data)

# %% [markdown]
# ## 处理-99

# %%
# df_train.replace(-99, -1, inplace=True)
# df_test.replace(-99, -1, inplace=True)

# %% [markdown]
# ## 主成分分析（效果不好）

# %%
# from sklearn.decomposition import PCA

# full_col_name = list(df_train.columns)
# pca_col=[i for i in full_col_name if "loan" in i]

# modelPCA=PCA(n_components=0.9)
# temp=modelPCA.fit_transform(df_train[pca_col])
# temp1=modelPCA.transform(df_test[pca_col])
# for i in range(temp.shape[1]):
#     df_train['loan_pca'+str(i)]=temp[:,i]
#     df_test['loan_pca'+str(i)]=temp1[:,i]

# %% [markdown]
# ## 处理分类变量

# %%
cat_way = "no"

# %% [markdown]
# ## 转化为one-hot编码（不宜采用）

# %%
def to_one_hot(df, colnames):
    df = pd.get_dummies(df, columns=colnames)
    return df

# %% [markdown]
# ## 类型计数

# %%
type_count_cols = ['industry', 'scope', 'basic_13']

# %%
# def type_count(cols):
#     global df_train, df_test
#     df1 = df_train[['cust_id']+cols]
#     df2 = df_test[['cust_id']+cols]
#     df = pd.concat([df1, df2], axis=0, ignore_index=True)
#     for i in cols:
#         temp_df = df.groupby(i)['cust_id'].count()
#         temp_df = pd.DataFrame({(i+"_num"): temp_df})
#         df = pd.merge(df, temp_df, on=i, how="left")
#         del df[i], df1[i], df2[i]
#     df_train = pd.merge(df_train, df, on="cust_id",
#                         how="left", suffixes=("", "_y"))
#     df_test = pd.merge(df_test, df, on="cust_id",
#                        how="left", suffixes=("", "_y"))


# type_count(type_count_cols)

# %% [markdown]
# ## 证据权重

# %%
import pandas as pd
import numpy as np


def cal_woe(df, df_no_label, x_cols, y_col):
    for i in x_cols:
        x_set = pd.unique(df[i])
        x1_set = pd.unique(df_no_label[i])
        for j in x1_set:
            if j not in x_set:
                df_no_label[i].replace(j, 0.03, inplace=True)
                print(i, j, '不存在')
        for j in x_set:
            woe = np.mean(df[df[i] == j][y_col])
            if woe >= 0.1:
                n = np.sum(df[df[i] == j][y_col])
                print(i, '列：', j, ' 共有', int(n/woe), '个,其中',
                      int(n), '个label为1,woe为', woe, sep="")
            df[i].replace(j, woe, inplace=True)
            df_no_label[i].replace(j, woe, inplace=True)
    return df, df_no_label

# %%
type_col = ["basic_1",
            "basic_10",
            "basic_12",
            "basic_14",
            "loan1_16",
            "loan1_20",
            "loan1_23",
            "loan1_25", ]

# df_train,df_test=cal_woe(df_train,df_test,type_col,"label")

# %%
if cat_way == "auto" or cat_way == "no":
    type_col = ["basic_1",
                "basic_10",
                "basic_12",
                "basic_14",
                "loan1_16",
                "loan1_20",
                "loan1_23",
                "loan1_25",
                "loan2_1_y",
                "query_2_y",
                "query_3_y",
                "query_4_y",
                "query_5_y",
                "query_6_y", ]
if cat_way == "manual":
    woe_col = ['basic_1',
               'basic_5',
               'basic_6',
               'basic_10',
               'loan1_16',
               'loan1_20',
               'loan1_25',
               'loan1_23',
               'loan1_32',
               'loan2_4',
               'loan2_6',
               'overdue_2',
               'overdue_20',
               'overdue_21',
               'overdue_26',
               'overdue_27',
               'query_1',
               'query_2',
               'query_3',
               'query_4',
               'query_6',
               'query_7',
               'query_8',
               'query_10',
               'query_11', ]

    onehot_col = ['basic_12',
                  'basic_14',
                  'loan1_8',
                  'loan1_9',
                  'overdue_1',
                  'overdue_3',
                  'overdue_4',
                  'overdue_5',
                  'overdue_6',
                  'overdue_7',
                  'overdue_8',
                  'overdue_9',
                  'overdue_10',
                  'overdue_11',
                  'overdue_12',
                  'overdue_14',
                  'overdue_15',
                  'overdue_16',
                  'overdue_17',
                  'overdue_18',
                  'overdue_22',
                  'overdue_23',
                  'overdue_24',
                  'overdue_25',
                  'overdue_28',
                  'overdue_29',
                  'query_5',
                  'query_9', ]

    df_train, df_test = cal_woe(df_train, df_test, woe_col, "label")
    df_train = to_one_hot(df_train, onehot_col)
    df_test = to_one_hot(df_test, onehot_col)
    for i in df_train.columns:
        if i not in df_test.columns:
            df_test[i] = 0

# %%
full_col_name = list(df_train.columns)
basic_col = [i for i in full_col_name if "basic" in i]
loan_col = [i for i in full_col_name if "loan" in i]
overdue_col = [i for i in full_col_name if "overdue" in i]
query_col = [i for i in full_col_name if "query" in i]
judicial_col = [i for i in full_col_name if "judicial" in i]
date_col = [i for i in full_col_name if "date" in i]
# loan_pca_col = [i for i in full_col_name if "loan_pca" in i]

# for i in judicial_col:
#     df_train[i].astype("float")
#     df_test[i].astype("float")

# %% [markdown]
# ## rank化

# %%
def rank(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = np.argsort(df[i])
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


a = ['loan1_1', 'loan1_3', 'loan1_7', 'loan1_9']
b = ['_sum', '_mean']
c = []
for i in a:
    for j in b:
        c.append(i+j)
# rank(c)

# %% [markdown]
# ## 归一化

# %%
def norm(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.min(df[i]))/(np.max(df[i])-np.min(df[i]))
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# norm([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 标准化

# %%
def stand(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.mean(df[i], axis=0))/np.std(df[i], axis=0)
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# stand([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 设置哪些x作为模型自变量输入

# %%
# x_col = basic_col+loan_col+['nan_num'] + ['is_judicial']+ overdue_col+query_col
# x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col+['scope_num'] + \
#     ['industry_num']+['date_3_count', 'date_1_std', 'date_1_diff_std']

x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col
x_col = [i for i in x_col if i in full_col_name]

if cat_way == "auto":
    type_col = [i for i in type_col if i in x_col]
# categorize(df_train,type_col)
# categorize(df_test,type_col)

print('自变量个数为', len(x_col))
print(x_col)
# Out:
# 自变量个数为 130
# ['basic_1', 'basic_2', 'basic_3', 'basic_4', 'basic_5', 'basic_6', 'basic_7', 'basic_8', 'basic_9', 'basic_10', 'basic_11', 'basic_12', 'basic_13', 'basic_14', 'basic_15', 'basic_1_y', 'basic_2_y', 'basic_3_y', 'is_judicial', 'loan1_1', 'loan1_2', 'loan1_3', 'loan1_4', 'loan1_5', 'loan1_6', 'loan1_7', 'loan1_8', 'loan1_9', 'loan1_10', 'loan1_11', 'loan1_12', 'loan1_13', 'loan1_14', 'loan1_15', 'loan1_16', 'loan1_17', 'loan1_18', 'loan1_19', 'loan1_20', 'loan1_21', 'loan1_22', 'loan1_23', 'loan1_24', 'loan1_25', 'loan1_26', 'loan1_27', 'loan1_28', 'loan1_29', 'loan1_30', 'loan1_31', 'loan1_32', 'loan1_33', 'loan2_1', 'loan2_2', 'loan2_3', 'loan2_4', 'loan2_5', 'loan2_6', 'loan2_7', 'loan2_8', 'loan2_9', 'loan2_10', 'loan2_11', 'loan2_12', 'loan2_1_y', 'loan2_2_y', 'loan2_3_y', 'loan2_4_y', 'loan2_5_y', 'loan1_2_mean', 'loan1_2_sum', 'loan1_2_std', 'loan1_3_mean', 'loan1_3_sum', 'loan1_3_std', 'loan1_7_mean', 'loan1_7_sum', 'loan1_7_std', 'loan1_9_mean', 'loan1_9_sum', 'loan1_9_std', 'loan1_10_mean', 'loan1_11_sum', 'loan1_12_sum', 'query_1', 'query_2', 'query_3', 'query_4', 'query_5', 'query_6', 'query_7', 'query_8', 'query_9', 'query_10', 'query_11', 'query_1_y', 'query_2_y', 'query_3_y', 'query_4_y', 'query_5_y', 'query_6_y', 'overdue_1', 'overdue_2', 'overdue_3', 'overdue_4', 'overdue_5', 'overdue_6', 'overdue_7', 'overdue_8', 'overdue_9', 'overdue_10', 'overdue_11', 'overdue_12', 'overdue_13', 'overdue_14', 'overdue_15', 'overdue_16', 'overdue_17', 'overdue_18', 'overdue_19', 'overdue_20', 'overdue_21', 'overdue_22', 'overdue_23', 'overdue_24', 'overdue_25', 'overdue_26', 'overdue_27', 'overdue_28', 'overdue_29']

# %%
df_train = df_train[x_col+['label', 'cust_id']]
df_test = df_test[x_col+['cust_id']]

df_test.to_csv("test_input.csv", encoding='utf-8')

# %% [markdown]
# ## 对抗验证

# %%
from sklearn import model_selection
import xgboost as xgb

df_full = pd.concat([df_train[x_col+['cust_id']], df_test],
                    axis=0, ignore_index=True)
df_full['label_test'] = [1 if i in df_test['cust_id']
                         else 0 for i in df_full['cust_id']]

df_full.to_csv("full.csv", encoding='utf-8')

# %%
X = df_full[x_col+['cust_id']]
Y = df_full['label_test']

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(
    X, Y, test_size=0.5, stratify=Y, random_state=2022)

dtrain = xgb.DMatrix(X_train[x_col], label=Y_train)
dtest = xgb.DMatrix(X_test[x_col], label=Y_test)

param = {'max_depth': 5,
         'eta': 0.1,
         'objective': 'binary:logistic',
         "eval_metric": "auc",
         "scale_pos_weight": 1,
         "subsample": 1,
         "min_child_weight": 1,
         'tree_method': 'gpu_hist',
         'gpu_id': 0, }

bst = xgb.train(param, dtrain, 4000, evals=[(dtrain, "train"), (dtest, "test")],
                early_stopping_rounds=300, verbose_eval=True)
bst1 = xgb.train(param, dtest, 4000, evals=[(dtest, "train"), (dtrain, "test")],
                 early_stopping_rounds=300, verbose_eval=False)
# Out:
# [0]	train-auc:0.54199	test-auc:0.49115
# [1]	train-auc:0.54641	test-auc:0.48996
# [2]	train-auc:0.56949	test-auc:0.48613
# [3]	train-auc:0.57531	test-auc:0.48519
# [4]	train-auc:0.58869	test-auc:0.48606
# [5]	train-auc:0.60283	test-auc:0.48650
# [6]	train-auc:0.62090	test-auc:0.48883
# [7]	train-auc:0.62517	test-auc:0.48985
# [8]	train-auc:0.62592	test-auc:0.49073
# [9]	train-auc:0.63986	test-auc:0.49070
# [10]	train-auc:0.65440	test-auc:0.48923
# [11]	train-auc:0.66912	test-auc:0.48973
# [12]	train-auc:0.67621	test-auc:0.48920
# [13]	train-auc:0.68088	test-auc:0.48808
# [14]	train-auc:0.68273	test-auc:0.48799
# [15]	train-auc:0.68769	test-auc:0.48812
# [16]	train-auc:0.69439	test-auc:0.48852
# [17]	train-auc:0.70060	test-auc:0.49152
# [18]	train-auc:0.70925	test-auc:0.48875
# [19]	train-auc:0.71151	test-auc:0.48830
# [20]	train-auc:0.71698	test-auc:0.48875
# [21]	train-auc:0.72058	test-auc:0.48953
# [22]	train-auc:0.72367	test-auc:0.49086
# [23]	train-auc:0.72846	test-auc:0.49163
# [24]	train-auc:0.72985	test-auc:0.49215
# [25]	train-auc:0.73380	test-auc:0.49346
# [26]	train-auc:0.73631	test-auc:0.49362
# [27]	train-auc:0.74125	test-auc:0.49351
# [28]	train-auc:0.74309	test-auc:0.49383
# [29]	train-auc:0.74601	test-auc:0.49338
# [30]	train-auc:0.74947	test-auc:0.49398
# [31]	train-auc:0.75483	test-auc:0.49513
# [32]	train-auc:0.75695	test-auc:0.49606
# [33]	train-auc:0.76295	test-auc:0.49432
# [34]	train-auc:0.76610	test-auc:0.49456
# [35]	train-auc:0.76718	test-auc:0.49529
# [36]	train-auc:0.76947	test-auc:0.49475
# [37]	train-auc:0.76985	test-auc:0.49495
# [38]	train-auc:0.77698	test-auc:0.49443
# [39]	train-auc:0.78148	test-auc:0.49258
# [40]	train-auc:0.78301	test-auc:0.49302
# [41]	train-auc:0.78761	test-auc:0.49400
# [42]	train-auc:0.78883	test-auc:0.49444
# [43]	train-auc:0.78978	test-auc:0.49454
# [44]	train-auc:0.78989	test-auc:0.49458
# [45]	train-auc:0.79146	test-auc:0.49442
# [46]	train-auc:0.79258	test-auc:0.49456
# [47]	train-auc:0.79407	test-auc:0.49503
# [48]	train-auc:0.79723	test-auc:0.49411
# [49]	train-auc:0.80026	test-auc:0.49307
# [50]	train-auc:0.80778	test-auc:0.49317
# [51]	train-auc:0.81063	test-auc:0.49428
# [52]	train-auc:0.81483	test-auc:0.49479
# [53]	train-auc:0.81526	test-auc:0.49551
# [54]	train-auc:0.81610	test-auc:0.49619
# [55]	train-auc:0.81821	test-auc:0.49611
# [56]	train-auc:0.81851	test-auc:0.49675
# [57]	train-auc:0.82056	test-auc:0.49637
# [58]	train-auc:0.82148	test-auc:0.49614
# [59]	train-auc:0.82335	test-auc:0.49606
# [60]	train-auc:0.82640	test-auc:0.49707
# [61]	train-auc:0.82760	test-auc:0.49633
# [62]	train-auc:0.82848	test-auc:0.49630
# [63]	train-auc:0.82928	test-auc:0.49576
# [64]	train-auc:0.82900	test-auc:0.49552
# [65]	train-auc:0.83015	test-auc:0.49553
# [66]	train-auc:0.83031	test-auc:0.49555
# [67]	train-auc:0.83109	test-auc:0.49616
# [68]	train-auc:0.83182	test-auc:0.49633
# [69]	train-auc:0.83375	test-auc:0.49642
# [70]	train-auc:0.83438	test-auc:0.49674
# [71]	train-auc:0.83513	test-auc:0.49617
# [72]	train-auc:0.83565	test-auc:0.49648
# [73]	train-auc:0.83864	test-auc:0.49505
# [74]	train-auc:0.83938	test-auc:0.49507
# [75]	train-auc:0.84275	test-auc:0.49627
# [76]	train-auc:0.84458	test-auc:0.49689
# [77]	train-auc:0.84457	test-auc:0.49694
# [78]	train-auc:0.84696	test-auc:0.49716
# [79]	train-auc:0.84739	test-auc:0.49723
# [80]	train-auc:0.84783	test-auc:0.49710
# [81]	train-auc:0.84942	test-auc:0.49763
# [82]	train-auc:0.85036	test-auc:0.49777
# [83]	train-auc:0.85171	test-auc:0.49828
# [84]	train-auc:0.85287	test-auc:0.49824
# [85]	train-auc:0.85311	test-auc:0.49836
# [86]	train-auc:0.85311	test-auc:0.49841
# [87]	train-auc:0.85469	test-auc:0.49888
# [88]	train-auc:0.85791	test-auc:0.49897
# [89]	train-auc:0.85857	test-auc:0.49895
# [90]	train-auc:0.85909	test-auc:0.49899
# [91]	train-auc:0.85946	test-auc:0.49836
# [92]	train-auc:0.86167	test-auc:0.49849
# [93]	train-auc:0.86527	test-auc:0.49721
# [94]	train-auc:0.86751	test-auc:0.49601
# [95]	train-auc:0.86770	test-auc:0.49648
# [96]	train-auc:0.86829	test-auc:0.49696
# [97]	train-auc:0.87081	test-auc:0.49710
# [98]	train-auc:0.87176	test-auc:0.49695
# [99]	train-auc:0.87502	test-auc:0.49705
# [100]	train-auc:0.87601	test-auc:0.49711
# [101]	train-auc:0.87678	test-auc:0.49724
# [102]	train-auc:0.87718	test-auc:0.49722
# [103]	train-auc:0.87751	test-auc:0.49693
# [104]	train-auc:0.87837	test-auc:0.49688
# [105]	train-auc:0.87842	test-auc:0.49687
# [106]	train-auc:0.87993	test-auc:0.49672
# [107]	train-auc:0.88214	test-auc:0.49658
# [108]	train-auc:0.88387	test-auc:0.49710
# [109]	train-auc:0.88444	test-auc:0.49684
# [110]	train-auc:0.88511	test-auc:0.49696
# [111]	train-auc:0.88640	test-auc:0.49759
# [112]	train-auc:0.88967	test-auc:0.49738
# [113]	train-auc:0.89197	test-auc:0.49694
# [114]	train-auc:0.89269	test-auc:0.49696
# [115]	train-auc:0.89375	test-auc:0.49642
# [116]	train-auc:0.89485	test-auc:0.49655
# [117]	train-auc:0.89757	test-auc:0.49628
# [118]	train-auc:0.89936	test-auc:0.49605
# [119]	train-auc:0.90015	test-auc:0.49596
# [120]	train-auc:0.90291	test-auc:0.49631
# [121]	train-auc:0.90342	test-auc:0.49575
# [122]	train-auc:0.90367	test-auc:0.49619
# [123]	train-auc:0.90467	test-auc:0.49646
# [124]	train-auc:0.90509	test-auc:0.49644
# [125]	train-auc:0.90502	test-auc:0.49648
# [126]	train-auc:0.90549	test-auc:0.49646
# [127]	train-auc:0.90643	test-auc:0.49660
# [128]	train-auc:0.90676	test-auc:0.49626
# [129]	train-auc:0.90750	test-auc:0.49664
# [130]	train-auc:0.90870	test-auc:0.49663
# [131]	train-auc:0.91040	test-auc:0.49691
# [132]	train-auc:0.91108	test-auc:0.49705
# [133]	train-auc:0.91139	test-auc:0.49720
# [134]	train-auc:0.91242	test-auc:0.49680
# [135]	train-auc:0.91435	test-auc:0.49678
# [136]	train-auc:0.91493	test-auc:0.49674
# [137]	train-auc:0.91704	test-auc:0.49663
# [138]	train-auc:0.91771	test-auc:0.49726
# [139]	train-auc:0.91776	test-auc:0.49775
# [140]	train-auc:0.91857	test-auc:0.49743
# [141]	train-auc:0.91909	test-auc:0.49753
# [142]	train-auc:0.92000	test-auc:0.49785
# [143]	train-auc:0.92079	test-auc:0.49801
# [144]	train-auc:0.92121	test-auc:0.49837
# [145]	train-auc:0.92165	test-auc:0.49811
# [146]	train-auc:0.92330	test-auc:0.49830
# [147]	train-auc:0.92475	test-auc:0.49801
# [148]	train-auc:0.92596	test-auc:0.49859
# [149]	train-auc:0.92620	test-auc:0.49872
# [150]	train-auc:0.92632	test-auc:0.49871
# [151]	train-auc:0.92660	test-auc:0.49867
# [152]	train-auc:0.92657	test-auc:0.49879
# [153]	train-auc:0.92687	test-auc:0.49924
# [154]	train-auc:0.92788	test-auc:0.49950
# [155]	train-auc:0.92874	test-auc:0.49932
# [156]	train-auc:0.92886	test-auc:0.49936
# [157]	train-auc:0.92954	test-auc:0.49989
# [158]	train-auc:0.93007	test-auc:0.49931
# [159]	train-auc:0.93046	test-auc:0.49910
# [160]	train-auc:0.93078	test-auc:0.49893
# [161]	train-auc:0.93133	test-auc:0.49929
# [162]	train-auc:0.93266	test-auc:0.49935
# [163]	train-auc:0.93273	test-auc:0.49926
# [164]	train-auc:0.93286	test-auc:0.49924
# [165]	train-auc:0.93367	test-auc:0.49941
# [166]	train-auc:0.93410	test-auc:0.49889
# [167]	train-auc:0.93441	test-auc:0.49901
# [168]	train-auc:0.93452	test-auc:0.49898
# [169]	train-auc:0.93447	test-auc:0.49887
# [170]	train-auc:0.93471	test-auc:0.49872
# [171]	train-auc:0.93606	test-auc:0.49886
# [172]	train-auc:0.93782	test-auc:0.49930
# [173]	train-auc:0.93901	test-auc:0.49881
# [174]	train-auc:0.93953	test-auc:0.49858
# [175]	train-auc:0.94034	test-auc:0.49871
# [176]	train-auc:0.94028	test-auc:0.49835
# [177]	train-auc:0.94144	test-auc:0.49849
# [178]	train-auc:0.94166	test-auc:0.49858
# [179]	train-auc:0.94298	test-auc:0.49863
# [180]	train-auc:0.94391	test-auc:0.49880
# [181]	train-auc:0.94432	test-auc:0.49867
# [182]	train-auc:0.94474	test-auc:0.49916
# [183]	train-auc:0.94500	test-auc:0.49920
# [184]	train-auc:0.94598	test-auc:0.49865
# [185]	train-auc:0.94628	test-auc:0.49835
# [186]	train-auc:0.94703	test-auc:0.49855
# [187]	train-auc:0.94733	test-auc:0.49875
# [188]	train-auc:0.94761	test-auc:0.49877
# [189]	train-auc:0.94789	test-auc:0.49888
# [190]	train-auc:0.94801	test-auc:0.49897
# [191]	train-auc:0.94835	test-auc:0.49880
# [192]	train-auc:0.94836	test-auc:0.49899
# [193]	train-auc:0.94866	test-auc:0.49846
# [194]	train-auc:0.94913	test-auc:0.49806
# [195]	train-auc:0.94919	test-auc:0.49808
# [196]	train-auc:0.95015	test-auc:0.49832
# [197]	train-auc:0.95055	test-auc:0.49821
# [198]	train-auc:0.95117	test-auc:0.49804
# [199]	train-auc:0.95137	test-auc:0.49827
# [200]	train-auc:0.95198	test-auc:0.49831
# [201]	train-auc:0.95261	test-auc:0.49866
# [202]	train-auc:0.95263	test-auc:0.49862
# [203]	train-auc:0.95296	test-auc:0.49859
# [204]	train-auc:0.95360	test-auc:0.49871
# [205]	train-auc:0.95397	test-auc:0.49876
# [206]	train-auc:0.95476	test-auc:0.49900
# [207]	train-auc:0.95503	test-auc:0.49914
# [208]	train-auc:0.95541	test-auc:0.49914
# [209]	train-auc:0.95561	test-auc:0.49922
# [210]	train-auc:0.95563	test-auc:0.49923
# [211]	train-auc:0.95587	test-auc:0.49905
# [212]	train-auc:0.95644	test-auc:0.49898
# [213]	train-auc:0.95654	test-auc:0.49914
# [214]	train-auc:0.95717	test-auc:0.49908
# [215]	train-auc:0.95719	test-auc:0.49943
# [216]	train-auc:0.95736	test-auc:0.49945
# [217]	train-auc:0.95779	test-auc:0.49932
# [218]	train-auc:0.95786	test-auc:0.49946
# [219]	train-auc:0.95858	test-auc:0.49985
# [220]	train-auc:0.95918	test-auc:0.50019
# [221]	train-auc:0.95960	test-auc:0.50040
# [222]	train-auc:0.95961	test-auc:0.50050
# [223]	train-auc:0.95965	test-auc:0.50054
# [224]	train-auc:0.95988	test-auc:0.50045
# [225]	train-auc:0.96007	test-auc:0.50066
# [226]	train-auc:0.96059	test-auc:0.50075
# [227]	train-auc:0.96098	test-auc:0.50102
# [228]	train-auc:0.96102	test-auc:0.50110
# [229]	train-auc:0.96136	test-auc:0.50092
# [230]	train-auc:0.96143	test-auc:0.50098
# [231]	train-auc:0.96144	test-auc:0.50092
# [232]	train-auc:0.96155	test-auc:0.50096
# [233]	train-auc:0.96154	test-auc:0.50104
# [234]	train-auc:0.96193	test-auc:0.50123
# [235]	train-auc:0.96241	test-auc:0.50112
# [236]	train-auc:0.96265	test-auc:0.50114
# [237]	train-auc:0.96343	test-auc:0.50134
# [238]	train-auc:0.96389	test-auc:0.50060
# [239]	train-auc:0.96476	test-auc:0.50074
# [240]	train-auc:0.96539	test-auc:0.50051
# [241]	train-auc:0.96586	test-auc:0.50030
# [242]	train-auc:0.96607	test-auc:0.50030
# [243]	train-auc:0.96653	test-auc:0.50037
# [244]	train-auc:0.96659	test-auc:0.50054
# [245]	train-auc:0.96660	test-auc:0.50061
# [246]	train-auc:0.96741	test-auc:0.50103
# [247]	train-auc:0.96762	test-auc:0.50125
# [248]	train-auc:0.96789	test-auc:0.50134
# [249]	train-auc:0.96804	test-auc:0.50139
# [250]	train-auc:0.96843	test-auc:0.50143
# [251]	train-auc:0.96926	test-auc:0.50139
# [252]	train-auc:0.96940	test-auc:0.50142
# [253]	train-auc:0.96955	test-auc:0.50150
# [254]	train-auc:0.96958	test-auc:0.50148
# [255]	train-auc:0.96956	test-auc:0.50150
# [256]	train-auc:0.96964	test-auc:0.50144
# [257]	train-auc:0.97025	test-auc:0.50127
# [258]	train-auc:0.97036	test-auc:0.50131
# [259]	train-auc:0.97062	test-auc:0.50133
# [260]	train-auc:0.97066	test-auc:0.50113
# [261]	train-auc:0.97078	test-auc:0.50084
# [262]	train-auc:0.97090	test-auc:0.50096
# [263]	train-auc:0.97102	test-auc:0.50128
# [264]	train-auc:0.97111	test-auc:0.50171
# [265]	train-auc:0.97150	test-auc:0.50135
# [266]	train-auc:0.97201	test-auc:0.50121
# [267]	train-auc:0.97208	test-auc:0.50094
# [268]	train-auc:0.97225	test-auc:0.50077
# [269]	train-auc:0.97236	test-auc:0.50059
# [270]	train-auc:0.97266	test-auc:0.50060
# [271]	train-auc:0.97264	test-auc:0.50083
# [272]	train-auc:0.97297	test-auc:0.50080
# [273]	train-auc:0.97366	test-auc:0.50102
# [274]	train-auc:0.97376	test-auc:0.50132
# [275]	train-auc:0.97396	test-auc:0.50168
# [276]	train-auc:0.97400	test-auc:0.50172
# [277]	train-auc:0.97402	test-auc:0.50165
# [278]	train-auc:0.97405	test-auc:0.50164
# [279]	train-auc:0.97409	test-auc:0.50135
# [280]	train-auc:0.97412	test-auc:0.50122
# [281]	train-auc:0.97413	test-auc:0.50107
# [282]	train-auc:0.97415	test-auc:0.50099
# [283]	train-auc:0.97423	test-auc:0.50096
# [284]	train-auc:0.97447	test-auc:0.50128
# [285]	train-auc:0.97458	test-auc:0.50120
# [286]	train-auc:0.97467	test-auc:0.50141
# [287]	train-auc:0.97468	test-auc:0.50130
# [288]	train-auc:0.97492	test-auc:0.50145
# [289]	train-auc:0.97494	test-auc:0.50137
# [290]	train-auc:0.97533	test-auc:0.50129
# [291]	train-auc:0.97580	test-auc:0.50103
# [292]	train-auc:0.97599	test-auc:0.50096
# [293]	train-auc:0.97638	test-auc:0.50109
# [294]	train-auc:0.97649	test-auc:0.50109
# [295]	train-auc:0.97671	test-auc:0.50122
# [296]	train-auc:0.97701	test-auc:0.50121
# [297]	train-auc:0.97718	test-auc:0.50096
# [298]	train-auc:0.97766	test-auc:0.50080
# [299]	train-auc:0.97781	test-auc:0.50067
# [300]	train-auc:0.97798	test-auc:0.50072
# [301]	train-auc:0.97833	test-auc:0.50042
# [302]	train-auc:0.97884	test-auc:0.50074
# [303]	train-auc:0.97909	test-auc:0.50063
# [304]	train-auc:0.97939	test-auc:0.50060
# [305]	train-auc:0.97971	test-auc:0.50078
# [306]	train-auc:0.97991	test-auc:0.50082
# [307]	train-auc:0.98016	test-auc:0.50118
# [308]	train-auc:0.98040	test-auc:0.50079
# [309]	train-auc:0.98052	test-auc:0.50047
# [310]	train-auc:0.98093	test-auc:0.50068
# [311]	train-auc:0.98096	test-auc:0.50070
# [312]	train-auc:0.98126	test-auc:0.50056
# [313]	train-auc:0.98133	test-auc:0.50045
# [314]	train-auc:0.98146	test-auc:0.50035
# [315]	train-auc:0.98180	test-auc:0.50037
# [316]	train-auc:0.98192	test-auc:0.50049
# [317]	train-auc:0.98210	test-auc:0.50066
# [318]	train-auc:0.98219	test-auc:0.50046
# [319]	train-auc:0.98231	test-auc:0.50034
# [320]	train-auc:0.98241	test-auc:0.50019
# [321]	train-auc:0.98270	test-auc:0.50014
# [322]	train-auc:0.98292	test-auc:0.49988
# [323]	train-auc:0.98295	test-auc:0.49997
# [324]	train-auc:0.98298	test-auc:0.49972
# [325]	train-auc:0.98326	test-auc:0.49988
# [326]	train-auc:0.98347	test-auc:0.49968
# [327]	train-auc:0.98368	test-auc:0.49986
# [328]	train-auc:0.98368	test-auc:0.49996
# [329]	train-auc:0.98384	test-auc:0.49971
# [330]	train-auc:0.98426	test-auc:0.49937
# [331]	train-auc:0.98430	test-auc:0.49944
# [332]	train-auc:0.98443	test-auc:0.49976
# [333]	train-auc:0.98442	test-auc:0.49944
# [334]	train-auc:0.98453	test-auc:0.49949
# [335]	train-auc:0.98459	test-auc:0.49938
# [336]	train-auc:0.98469	test-auc:0.49928
# [337]	train-auc:0.98468	test-auc:0.49914
# [338]	train-auc:0.98483	test-auc:0.49910
# [339]	train-auc:0.98491	test-auc:0.49901
# [340]	train-auc:0.98512	test-auc:0.49890
# [341]	train-auc:0.98546	test-auc:0.49881
# [342]	train-auc:0.98577	test-auc:0.49891
# [343]	train-auc:0.98576	test-auc:0.49898
# [344]	train-auc:0.98599	test-auc:0.49910
# [345]	train-auc:0.98614	test-auc:0.49900
# [346]	train-auc:0.98614	test-auc:0.49914
# [347]	train-auc:0.98615	test-auc:0.49917
# [348]	train-auc:0.98637	test-auc:0.49889
# [349]	train-auc:0.98644	test-auc:0.49877
# [350]	train-auc:0.98666	test-auc:0.49857
# [351]	train-auc:0.98686	test-auc:0.49834
# [352]	train-auc:0.98705	test-auc:0.49822
# [353]	train-auc:0.98713	test-auc:0.49804
# [354]	train-auc:0.98715	test-auc:0.49819
# [355]	train-auc:0.98715	test-auc:0.49819
# [356]	train-auc:0.98725	test-auc:0.49861
# [357]	train-auc:0.98725	test-auc:0.49877
# [358]	train-auc:0.98727	test-auc:0.49867
# [359]	train-auc:0.98735	test-auc:0.49844
# [360]	train-auc:0.98744	test-auc:0.49845
# [361]	train-auc:0.98747	test-auc:0.49838
# [362]	train-auc:0.98762	test-auc:0.49845
# [363]	train-auc:0.98768	test-auc:0.49852
# [364]	train-auc:0.98763	test-auc:0.49846
# [365]	train-auc:0.98783	test-auc:0.49833
# [366]	train-auc:0.98794	test-auc:0.49826
# [367]	train-auc:0.98795	test-auc:0.49825
# [368]	train-auc:0.98805	test-auc:0.49810
# [369]	train-auc:0.98804	test-auc:0.49807
# [370]	train-auc:0.98817	test-auc:0.49814
# [371]	train-auc:0.98822	test-auc:0.49828
# [372]	train-auc:0.98832	test-auc:0.49851
# [373]	train-auc:0.98838	test-auc:0.49856
# [374]	train-auc:0.98851	test-auc:0.49894
# [375]	train-auc:0.98856	test-auc:0.49897
# [376]	train-auc:0.98871	test-auc:0.49875
# [377]	train-auc:0.98883	test-auc:0.49875
# [378]	train-auc:0.98889	test-auc:0.49873
# [379]	train-auc:0.98905	test-auc:0.49872
# [380]	train-auc:0.98927	test-auc:0.49896
# [381]	train-auc:0.98943	test-auc:0.49890
# [382]	train-auc:0.98942	test-auc:0.49863
# [383]	train-auc:0.98944	test-auc:0.49877
# [384]	train-auc:0.98948	test-auc:0.49895
# [385]	train-auc:0.98964	test-auc:0.49892
# [386]	train-auc:0.98978	test-auc:0.49873
# [387]	train-auc:0.98985	test-auc:0.49876
# [388]	train-auc:0.98988	test-auc:0.49901
# [389]	train-auc:0.98995	test-auc:0.49917
# [390]	train-auc:0.99006	test-auc:0.49922
# [391]	train-auc:0.99015	test-auc:0.49898
# [392]	train-auc:0.99041	test-auc:0.49871
# [393]	train-auc:0.99041	test-auc:0.49892
# [394]	train-auc:0.99059	test-auc:0.49854
# [395]	train-auc:0.99063	test-auc:0.49874
# [396]	train-auc:0.99081	test-auc:0.49869
# [397]	train-auc:0.99086	test-auc:0.49882
# [398]	train-auc:0.99093	test-auc:0.49899
# [399]	train-auc:0.99093	test-auc:0.49894
# [400]	train-auc:0.99093	test-auc:0.49894
# [401]	train-auc:0.99099	test-auc:0.49895
# [402]	train-auc:0.99103	test-auc:0.49902
# [403]	train-auc:0.99114	test-auc:0.49894
# [404]	train-auc:0.99127	test-auc:0.49898
# [405]	train-auc:0.99143	test-auc:0.49857
# [406]	train-auc:0.99161	test-auc:0.49862
# [407]	train-auc:0.99171	test-auc:0.49867
# [408]	train-auc:0.99174	test-auc:0.49890
# [409]	train-auc:0.99182	test-auc:0.49897
# [410]	train-auc:0.99183	test-auc:0.49899
# [411]	train-auc:0.99191	test-auc:0.49902
# [412]	train-auc:0.99201	test-auc:0.49919
# [413]	train-auc:0.99211	test-auc:0.49910
# [414]	train-auc:0.99211	test-auc:0.49904
# [415]	train-auc:0.99212	test-auc:0.49925
# [416]	train-auc:0.99217	test-auc:0.49909
# [417]	train-auc:0.99227	test-auc:0.49940
# [418]	train-auc:0.99229	test-auc:0.49952
# [419]	train-auc:0.99234	test-auc:0.49974
# [420]	train-auc:0.99235	test-auc:0.49959
# [421]	train-auc:0.99246	test-auc:0.49960
# [422]	train-auc:0.99254	test-auc:0.49992
# [423]	train-auc:0.99256	test-auc:0.50000
# [424]	train-auc:0.99257	test-auc:0.49996
# [425]	train-auc:0.99271	test-auc:0.49971
# [426]	train-auc:0.99297	test-auc:0.50007
# [427]	train-auc:0.99301	test-auc:0.50004
# [428]	train-auc:0.99304	test-auc:0.50021
# [429]	train-auc:0.99318	test-auc:0.49997
# [430]	train-auc:0.99325	test-auc:0.49998
# [431]	train-auc:0.99329	test-auc:0.49988
# [432]	train-auc:0.99340	test-auc:0.50015
# [433]	train-auc:0.99344	test-auc:0.49985
# [434]	train-auc:0.99353	test-auc:0.49967
# [435]	train-auc:0.99361	test-auc:0.50002
# [436]	train-auc:0.99366	test-auc:0.49969
# [437]	train-auc:0.99367	test-auc:0.49954
# [438]	train-auc:0.99369	test-auc:0.49964
# [439]	train-auc:0.99371	test-auc:0.49953
# [440]	train-auc:0.99373	test-auc:0.49973
# [441]	train-auc:0.99373	test-auc:0.49987
# [442]	train-auc:0.99374	test-auc:0.49981
# [443]	train-auc:0.99376	test-auc:0.49984
# [444]	train-auc:0.99377	test-auc:0.49985
# [445]	train-auc:0.99395	test-auc:0.50003
# [446]	train-auc:0.99404	test-auc:0.50004
# [447]	train-auc:0.99405	test-auc:0.49997
# [448]	train-auc:0.99406	test-auc:0.50006
# [449]	train-auc:0.99412	test-auc:0.49979
# [450]	train-auc:0.99416	test-auc:0.49977
# [451]	train-auc:0.99417	test-auc:0.49975
# [452]	train-auc:0.99418	test-auc:0.49979
# [453]	train-auc:0.99423	test-auc:0.50006
# [454]	train-auc:0.99440	test-auc:0.49988
# [455]	train-auc:0.99442	test-auc:0.49981
# [456]	train-auc:0.99445	test-auc:0.49963
# [457]	train-auc:0.99450	test-auc:0.49973
# [458]	train-auc:0.99453	test-auc:0.49951
# [459]	train-auc:0.99453	test-auc:0.49957
# [460]	train-auc:0.99458	test-auc:0.49937
# [461]	train-auc:0.99461	test-auc:0.49946
# [462]	train-auc:0.99462	test-auc:0.49933
# [463]	train-auc:0.99470	test-auc:0.49938
# [464]	train-auc:0.99479	test-auc:0.49951
# [465]	train-auc:0.99485	test-auc:0.49961
# [466]	train-auc:0.99485	test-auc:0.49962
# [467]	train-auc:0.99490	test-auc:0.49970
# [468]	train-auc:0.99492	test-auc:0.49977
# [469]	train-auc:0.99492	test-auc:0.49978
# [470]	train-auc:0.99497	test-auc:0.49994
# [471]	train-auc:0.99499	test-auc:0.50000
# [472]	train-auc:0.99510	test-auc:0.49995
# [473]	train-auc:0.99513	test-auc:0.50005
# [474]	train-auc:0.99516	test-auc:0.50028
# [475]	train-auc:0.99516	test-auc:0.50018
# [476]	train-auc:0.99517	test-auc:0.50020
# [477]	train-auc:0.99523	test-auc:0.49986
# [478]	train-auc:0.99527	test-auc:0.49974
# [479]	train-auc:0.99528	test-auc:0.49938
# [480]	train-auc:0.99529	test-auc:0.49925
# [481]	train-auc:0.99531	test-auc:0.49926
# [482]	train-auc:0.99531	test-auc:0.49909
# [483]	train-auc:0.99530	test-auc:0.49888
# [484]	train-auc:0.99535	test-auc:0.49874
# [485]	train-auc:0.99544	test-auc:0.49866
# [486]	train-auc:0.99549	test-auc:0.49852
# [487]	train-auc:0.99559	test-auc:0.49837
# [488]	train-auc:0.99564	test-auc:0.49823
# [489]	train-auc:0.99570	test-auc:0.49819
# [490]	train-auc:0.99578	test-auc:0.49837
# [491]	train-auc:0.99582	test-auc:0.49844
# [492]	train-auc:0.99582	test-auc:0.49830
# [493]	train-auc:0.99583	test-auc:0.49823
# [494]	train-auc:0.99584	test-auc:0.49833
# [495]	train-auc:0.99585	test-auc:0.49850
# [496]	train-auc:0.99585	test-auc:0.49846
# [497]	train-auc:0.99586	test-auc:0.49826
# [498]	train-auc:0.99587	test-auc:0.49813
# [499]	train-auc:0.99594	test-auc:0.49850
# [500]	train-auc:0.99595	test-auc:0.49836
# [501]	train-auc:0.99604	test-auc:0.49835
# [502]	train-auc:0.99608	test-auc:0.49831
# [503]	train-auc:0.99613	test-auc:0.49831
# [504]	train-auc:0.99615	test-auc:0.49839
# [505]	train-auc:0.99619	test-auc:0.49831
# [506]	train-auc:0.99619	test-auc:0.49819
# [507]	train-auc:0.99621	test-auc:0.49832
# [508]	train-auc:0.99621	test-auc:0.49828
# [509]	train-auc:0.99628	test-auc:0.49797
# [510]	train-auc:0.99629	test-auc:0.49798
# [511]	train-auc:0.99630	test-auc:0.49795
# [512]	train-auc:0.99634	test-auc:0.49792
# [513]	train-auc:0.99634	test-auc:0.49794
# [514]	train-auc:0.99642	test-auc:0.49788
# [515]	train-auc:0.99644	test-auc:0.49767
# [516]	train-auc:0.99652	test-auc:0.49775
# [517]	train-auc:0.99653	test-auc:0.49785
# [518]	train-auc:0.99657	test-auc:0.49781
# [519]	train-auc:0.99656	test-auc:0.49778
# [520]	train-auc:0.99658	test-auc:0.49776
# [521]	train-auc:0.99660	test-auc:0.49767
# [522]	train-auc:0.99666	test-auc:0.49760
# [523]	train-auc:0.99666	test-auc:0.49762
# [524]	train-auc:0.99667	test-auc:0.49775
# [525]	train-auc:0.99672	test-auc:0.49765
# [526]	train-auc:0.99676	test-auc:0.49768
# [527]	train-auc:0.99676	test-auc:0.49761
# [528]	train-auc:0.99676	test-auc:0.49752
# [529]	train-auc:0.99676	test-auc:0.49756
# [530]	train-auc:0.99684	test-auc:0.49737
# [531]	train-auc:0.99688	test-auc:0.49737
# [532]	train-auc:0.99690	test-auc:0.49752
# [533]	train-auc:0.99693	test-auc:0.49744
# [534]	train-auc:0.99696	test-auc:0.49736
# [535]	train-auc:0.99698	test-auc:0.49743
# [536]	train-auc:0.99703	test-auc:0.49735
# [537]	train-auc:0.99703	test-auc:0.49728
# [538]	train-auc:0.99708	test-auc:0.49717
# [539]	train-auc:0.99708	test-auc:0.49729
# [540]	train-auc:0.99711	test-auc:0.49715
# [541]	train-auc:0.99719	test-auc:0.49698
# [542]	train-auc:0.99719	test-auc:0.49693
# [543]	train-auc:0.99722	test-auc:0.49681
# [544]	train-auc:0.99722	test-auc:0.49671
# [545]	train-auc:0.99722	test-auc:0.49689
# [546]	train-auc:0.99732	test-auc:0.49686
# [547]	train-auc:0.99735	test-auc:0.49676
# [548]	train-auc:0.99735	test-auc:0.49656
# [549]	train-auc:0.99737	test-auc:0.49648
# [550]	train-auc:0.99737	test-auc:0.49661
# [551]	train-auc:0.99737	test-auc:0.49642
# [552]	train-auc:0.99738	test-auc:0.49660
# [553]	train-auc:0.99740	test-auc:0.49633
# [554]	train-auc:0.99746	test-auc:0.49659
# [555]	train-auc:0.99750	test-auc:0.49647
# [556]	train-auc:0.99755	test-auc:0.49662
# [557]	train-auc:0.99758	test-auc:0.49679
# [558]	train-auc:0.99766	test-auc:0.49712
# [559]	train-auc:0.99767	test-auc:0.49698
# [560]	train-auc:0.99769	test-auc:0.49688
# [561]	train-auc:0.99772	test-auc:0.49693
# [562]	train-auc:0.99774	test-auc:0.49694
# [563]	train-auc:0.99775	test-auc:0.49692
# [564]	train-auc:0.99777	test-auc:0.49666
# [565]	train-auc:0.99783	test-auc:0.49675
# [566]	train-auc:0.99783	test-auc:0.49684
# [567]	train-auc:0.99784	test-auc:0.49671
# [568]	train-auc:0.99783	test-auc:0.49679
# [569]	train-auc:0.99785	test-auc:0.49685
# [570]	train-auc:0.99785	test-auc:0.49690
# [571]	train-auc:0.99787	test-auc:0.49685
# [572]	train-auc:0.99789	test-auc:0.49687
# [573]	train-auc:0.99789	test-auc:0.49694
# [574]	train-auc:0.99790	test-auc:0.49706
# [575]	train-auc:0.99790	test-auc:0.49708
# [576]	train-auc:0.99790	test-auc:0.49723

# %%
df_res = pd.DataFrame(
    {'cust_id': X_test['cust_id'], 'p_test': bst.predict(dtest)})
df_res1 = pd.DataFrame(
    {'cust_id': X_train['cust_id'], 'p_test': bst1.predict(dtrain)})

df = pd.concat([df_res, df_res1], axis=0, ignore_index=True)

df_train = pd.merge(df_train, df, on="cust_id",
                    how="left", suffixes=("", "_y"))

# %%
temp = len(df_train)
df_train.to_csv("train_input.csv", encoding='utf-8')

df_train = df_train[df_train['p_test'] >= 0.1]


print("经过对抗验证，有", len(df_train), "条数据被保留，",
      temp-len(df_train), "条数据被抛弃", sep="")
# Out:
# 经过对抗验证，有17091条数据被保留，908条数据被抛弃

# %% [markdown]
# # 训练模型

# %% [markdown]
# ## 超参数

# %%
N = 60
num_round = 3000
local_test_size = 2000

# 共用
test_size = [0.2, 0.25, 0.3]
max_depth = [3, 4, 5]
subsample = [0.8, 0.75, 0.7, 0.65, 0.6]
early_stopping_rounds = 150

# XGB
eta = [0.007, 0.01]

# LGB
learning_rate = [0.03, 0.02, 0.025]

# %% [markdown]
# ### train划分为
# * 本地测试集（固定）d_localtest
# * 训练集（固定）
#   * 评估集（每次的模型不同）dtest
#   * 真正的训练集（每次的模型不同）dtrain

# %%
import copy
import xgboost as xgb
import random
from sklearn import model_selection
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from catboost import CatBoostClassifier


pred_labels = []
local_test_labels = []
loss_seq = []
max_auc_loss = 0
flag = 0
important_x_seq = []


d_full = xgb.DMatrix(df_train[x_col], label=df_train['label'])
X = df_train[x_col]
Y = df_train['label']

X, X_local_test, Y, Y_local_test = model_selection.train_test_split(
    X, Y, test_size=local_test_size, stratify=Y, random_state=2022)

d_localtest = xgb.DMatrix(X_local_test, label=Y_local_test)
x_perd = xgb.DMatrix(df_test[x_col])

d_localtest1 = lgb.Dataset(X_local_test, Y_local_test)
x_perd1 = lgb.Dataset(df_test[x_col])


lgbcallback = [early_stopping(early_stopping_rounds), log_evaluation(10000)]

# %%
for i in range(N):

    test_size_this_round = random.choice(test_size)
    X_train, X_test, y_train, y_test = model_selection.train_test_split(
        X, Y, test_size=test_size_this_round, stratify=Y)

    # XGB-----------------------------------------------
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    evallist = [(dtest, 'eval')]
    param = {
        'max_depth': random.choice(max_depth),
        'eta': random.choice(eta),
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'subsample': random.choice(subsample),
        'tree_method': 'gpu_hist',
        'gpu_id': 0,
    }

    bst = xgb.train(param, dtrain, num_round, evals=evallist,
                    early_stopping_rounds=early_stopping_rounds, verbose_eval=False)

    loss = roc_auc_score(y_test, bst.predict(dtest))
    train_loss = roc_auc_score(y_train, bst.predict(dtrain))
    local_test_loss = roc_auc_score(Y_local_test, bst.predict(d_localtest))
    global_auc = roc_auc_score(df_train['label'], bst.predict(d_full))

    pred_label = list(bst.predict(x_perd))
    test_label = list(bst.predict(d_localtest))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'xgb'}

    if flag == 0:
        info_df = pd.DataFrame(temp_dict, index=[i])
        flag = 1
    else:
        info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])

    # if loss > max_auc_loss:
    #     best_bst = copy.deepcopy(bst)
    #     max_auc_loss = loss

    # if False:
    #     pic = xgb.plot_importance(bst, max_num_features=50)
    #     temp = pic.get_ymajorticklabels()
    #     important_x = [str(i).split("\'")[1] for i in temp]
    #     important_x.reverse()
    #     important_x_seq += important_x

    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    # LGB--------------------------------------------------------
    param = {
        'task': 'train',
        "max_depth": random.choice(max_depth),
        'max_bin': 128,
        'boosting_type': 'gbdt',  # 设置提升类型
        'objective': 'binary',  # 目标函数
        'metric': 'auc',  # 评估函数
        'learning_rate': random.choice(learning_rate),  # 学习速率
        'bagging_fraction': random.choice(subsample),  # 建树的样本采样比例
        'bagging_freq': 1,  # k 意味着每 k 次迭代执行bagging
        'min_data_in_leaf': 1,
        'verbose': -1,  # <0 显示致命的, =0 显示错误 (警告), >0 显示信息
        'device_type': 'gpu',
    }

    dtrain = lgb.Dataset(X_train, y_train)
    dtest = lgb.Dataset(X_test, y_test)

    if cat_way == "auto":
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback, categorical_feature=type_col)
    else:
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback)

    loss = roc_auc_score(y_test, bst1.predict(X_test))
    train_loss = roc_auc_score(y_train, bst1.predict(X_train))
    local_test_loss = roc_auc_score(Y_local_test, bst1.predict(X_local_test))
    global_auc = roc_auc_score(
        df_train['label'], bst1.predict(df_train[x_col]))

    pred_label = list(bst1.predict(df_test[x_col]))
    test_label = list(bst1.predict(X_local_test))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'lgb'}

    info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    # CAT-----------------------------------------------------------
    # bst2 = CatBoostClassifier(iterations=num_round,
    #                        depth=random.choice(max_depth),
    #                        learning_rate=random.choice(learning_rate),
    #                        loss_function='Logloss',
    #                        subsample=random.choice(subsample),
    #                        early_stopping_rounds=early_stopping_rounds,
    #                        verbose=False)
    # bst2.fit(X_train, y_train,eval_set=(X_test,y_test))

    # loss = roc_auc_score(y_test, bst2.predict_proba(X_test)[:,1])
    # train_loss = roc_auc_score(y_train, bst2.predict_proba(X_train)[:,1])
    # local_test_loss = roc_auc_score(Y_local_test, bst2.predict_proba(X_local_test)[:,1])
    # global_auc = roc_auc_score(df_train['label'], bst2.predict_proba(df_train[x_col])[:,1])

    # pred_label = list(bst2.predict_proba(df_test[x_col])[:,1])
    # test_label = list(bst2.predict_proba(X_local_test)[:,1])

    # temp_dict = {"test_auc": loss, "train_auc": train_loss,
    #              'local_test_auc': local_test_loss,
    #              'model': 'cat'}

    # info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    # pred_labels.append(copy.deepcopy(pred_label))
    # local_test_labels.append(copy.deepcopy(test_label))


print('最大AUC:', max(info_df['local_test_auc']), sep="")
# Out:
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [369]	valid_0's auc: 0.71519
# Early stopping, best iteration is:
# [438]	valid_0's auc: 0.721092
# Early stopping, best iteration is:
# [586]	valid_0's auc: 0.728589
# Early stopping, best iteration is:
# [352]	valid_0's auc: 0.738154
# Early stopping, best iteration is:
# [352]	valid_0's auc: 0.738154
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.770313
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# Early stopping, best iteration is:
# [172]	valid_0's auc: 0.774512
# 最大AUC:0.7807514310071854

# %%
info_df.to_csv("info.csv", encoding="utf-8", index=False)

# %%
# pic = xgb.plot_importance(bst, max_num_features=50)
# temp = pic.get_ymajorticklabels()
# important_x = [str(i).split("\'")[1] for i in temp]
# important_x.reverse()

# %%
# important_x

# %%
# pd.value_counts(important_x_seq)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6.5, 6), dpi=200)


plt.scatter(info_df[info_df['model'] == 'xgb']['local_test_auc'], info_df[info_df['model'] == 'xgb']['test_auc'],
            c='r', s=4, label="xgb")
plt.scatter(info_df[info_df['model'] == 'lgb']['local_test_auc'], info_df[info_df['model'] == 'lgb']['test_auc'],
            c='g', s=4, label="lgb")
# plt.scatter(info_df[info_df['model'] == 'cat']['local_test_auc'], info_df[info_df['model'] == 'cat']['test_auc'],
#             c='b', s=4,label="cat")
plt.legend()
plt.xlabel('local_test_auc')
plt.ylabel('test_auc')
plt.plot([0.6, 0.85], [0.6, 0.85])
plt.xlim(0.6, 0.85)
plt.ylim(0.6, 0.85)
plt.grid()
plt.show()

# %% [markdown]
# # 输出模块

# %%
import time
import numpy as np
from sklearn.metrics import roc_auc_score

date = time.strftime("%Y%m%d-%H%M%S", time.localtime())
res_num = np.argsort(
    [-i for i in (info_df['local_test_auc']+info_df['test_auc'])])

# 选择前n个结果进行平均（手动指定or在本地测试集排序选出）
if True:
    max_auc = -1
    list_temp = []
    auc_seq = []
    for i in range(N*2):
        list_temp.append(local_test_labels[res_num[i]])
        # 算数平均
        # temp = np.mean(list_temp, axis=0)
        # 几何平均(better)
        temp = np.exp(np.mean(np.log(list_temp), axis=0))
        temp_auc = roc_auc_score(Y_local_test, temp)
        # print(i, temp_auc)
        auc_seq.append(temp_auc)
        if temp_auc > max_auc:
            max_auc = temp_auc
            n = i+1
else:
    n = 40
    n = min(N, n)

res_num = res_num[0:n]

#final_pred_label = np.mean([pred_labels[i] for i in res_num], axis=0)
final_pred_label = np.exp(
    np.mean(np.log([pred_labels[i] for i in res_num]), axis=0))
#local_auc = roc_auc_score(y_test, final_pred_label)
print("本地测试集前", n, "个auc为", [
      list(info_df['local_test_auc'])[i] for i in res_num], sep="")
print("平均之后local_test_AUC为", max_auc, sep="")

res = pd.DataFrame({
    'cust_id': list(df_test["cust_id"]),
    'label': final_pred_label,
})
res.to_csv("./output/result"+date+".csv", encoding="utf-8", index=False)
# Out:
# 本地测试集前1个auc为[0.7807514310071854]
# 平均之后local_test_AUC为0.7807514310071854

# %%
plt.figure(figsize=(10, 6), dpi=200)
plt.plot(list(range(len(auc_seq))), auc_seq)

# %% [markdown]
# # 一些tips
#
# * 提升n有一定提升(如何确定n？)
#   * n=40 0.6763
#   * n=10 0.6728
#   * n=100 0.6774
#   * 太大也不好
#
# # 一些进展
#
# * 随机参数
# * XGB模型
# * 本地测试集auc较高（0.75+）
# * 部分类型变量进行了one-hot处理
# * 把细分表除了loan与主表合并
#
# # tbd
#
# * 处理细分表的loan，给出指标
# * 确定变量类型，以便对所有（or重要）分类变量进行one-hot处理
# * 新模型？

# %% [markdown]
# ## 10-12
# * 0.6824（这次我留了代码\doge）
# * 把-99变为-1，本地有提升
# * 划出了一个本地测试集
#   * 本地测试集（固定）d_localtest
#   * 训练集（固定）
#     * 评估集（每次的模型不同）dtest
#     * 真正的训练集（每次的模型不同）dtrain
# * 添加参数nan_num（然并卵）
# * tbd
#   * 找特征
#   * 加x
#   * 分析一下参数作用
# ## 10-18
# * 不能把industry之类种类很多的分类变量做证据权重

# %% [markdown]
# # 记录
# * 1014-4
#   * 0.6823
#   * 证据权重
#   * 未添加贷款记录表
#   * 按test auc排序
# * 1014-5
#   * 0.6925
#   * 按local test auc排序
# * 1015-1
#   * 0.6834
#   * 处理-99
# * 1015-2
#   * 0.6628
#   * 添加贷款记录表
# * 1015-3
#   * 0.6772
#   * 不处理-99
#   * 去除贷款记录表
#   * 添加了type-col
# * 1015-4
#   * 0.6811
#   * 不做证据权重
# * 1015-5
#   * 0.6765
#   * gamma=0
# * 1016-1
#   * 0.6798
#   * 添加gamma
#   * 增大early stop round
# * 1016-2
#   * 0.6858
#   * early stop round=10
#   * 证据权重
# * 1016-3
#   * 0.685799
#   * 使用原始type-col
# * 1017-2
#   * 0.6655
