# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 数据读入

# %%
import pandas as pd

train_data = pd.read_csv("data\main\df_train_b1.csv", index_col=0)
test_data = pd.read_csv('data\main\df_test_b1.csv', index_col=0)

# %% [markdown]
# ## 要读入除了main之外的数在此处添加

# %%
import os
filenames = ["data\detail\df_basic_b1.csv",
             "data\detail\df_corp_b1.csv",
             "data\detail\df_judicial_b1.csv",
             "data\detail\df_loan2_b1.csv",
             "data\detail\df_query_b1.csv"
             ]
for filename in filenames:
    temp = pd.read_csv(filename)
    train_data = pd.merge(train_data, temp, on="cust_id",
                          how="left", suffixes=("", "_y"))
    test_data = pd.merge(test_data, temp, on="cust_id",
                         how="left", suffixes=("", "_y"))

# %%
train_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in train_data['judicial_reason']]
test_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in test_data['judicial_reason']]

# %%
# train_data['nan_num'] = (train_data == 0).astype(int).sum(axis=1)
# test_data['nan_num'] = (test_data == 0).astype(int).sum(axis=1)

# %%
# drop_col = ['basic_2',
#             'basic_3',
#             'basic_4',
#             'loan1_1',
#             'overdue_19',
#             'basic_8',
#             'basic_9',
#             'basic_11',
#             'basic_15',
#             'loan1_17',
#             'loan1_31', ]

# train_data.drop(drop_col, inplace=True, axis=1)
# test_data.drop(drop_col, inplace=True, axis=1)

# %% [markdown]
# ## loan1表

# %%
if True:

    import pandas as pd
    temp_df = pd.read_csv("./data/detail/df_loan1_b1.csv")

    def chuli_loan(df, colname, ways):
        cust_id = list(range(len(set(df['cust_id']))))
        res_df = pd.DataFrame({'cust_id': cust_id})

        if len(ways) == 0:
            return res_df
        if 'mean' in ways:
            res_df[colname+'_mean'] = df.groupby('cust_id')[colname].mean()
        if 'sum' in ways:
            res_df[colname+'_sum'] = df.groupby('cust_id')[colname].sum()
        if 'count' in ways:
            res_df[colname+'_count'] = df.groupby('cust_id')[colname].count()
        if 'std' in ways:
            res_df[colname+'_std'] = df.groupby('cust_id')[colname].std()
        if 'diff_std' in ways:
            res_df[colname+'_diff_std'] = df.groupby('cust_id')[colname].apply(
                lambda x: x.sort_values(ascending=True).diff()[2:].std())
        return res_df

    for colname in ['loan1_2', 'loan1_3', 'loan1_7', 'loan1_9']:
        df = chuli_loan(temp_df, colname, ('sum', 'std'))
        train_data = pd.merge(train_data, df, on="cust_id",
                              how="left", suffixes=("", "_y"))
        test_data = pd.merge(test_data, df, on="cust_id",
                             how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_3', ('count',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_1', ('std', 'diff_std'))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_10', ('mean',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_11', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_12', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    train_data.to_csv('./data/df_train.csv')
    test_data.to_csv('./data/df_test.csv')

# %%
# data = temp_df.dropna(axis=0,subset = ["date_1"])
# data['date2-date1'] = data['date_2'] - data['date_1']
# data['date3-date2'] = data['date_3'] - data['date_2']
# data['dateinterval_max'] = data[['date2-date1','date3-date2']].max(axis=1)
# data = data.groupby('cust_id').agg({'date_2':['count'],'date_3':['count'],'dateinterval_max':['mean']})
# train_data = pd.merge(train_data, data, on="cust_id",
#                           how="left", suffixes=("", "_y"))
# test_data = pd.merge(test_data, data, on="cust_id",
#                          how="left", suffixes=("", "_y"))

# %% [markdown]
# ## 处理NAN

# %%
def delnan(df):
    df = df.dropna(how="all", axis=1)  # 删除全是空值的列
    df = df.fillna(-99)
    return df

# %%
df_train = delnan(train_data)
df_test = delnan(test_data)

# %% [markdown]
# ## 处理-99

# %%
df_train.replace(-99, -1, inplace=True)
df_test.replace(-99, -1, inplace=True)

# %% [markdown]
# ## 主成分分析（效果不好）

# %%
# from sklearn.decomposition import PCA

# full_col_name = list(df_train.columns)
# pca_col=[i for i in full_col_name if "loan" in i]

# modelPCA=PCA(n_components=0.9)
# temp=modelPCA.fit_transform(df_train[pca_col])
# temp1=modelPCA.transform(df_test[pca_col])
# for i in range(temp.shape[1]):
#     df_train['loan_pca'+str(i)]=temp[:,i]
#     df_test['loan_pca'+str(i)]=temp1[:,i]

# %% [markdown]
# ## 处理分类变量

# %%
cat_way = "no"

# %% [markdown]
# ## 转化为one-hot编码（不宜采用）

# %%
def to_one_hot(df, colnames):
    df = pd.get_dummies(df, columns=colnames)
    return df

# %% [markdown]
# ## 类型计数

# %%
type_count_cols = ['industry', 'scope', 'basic_13']

# %%
# def type_count(cols):
#     global df_train, df_test
#     df1 = df_train[['cust_id']+cols]
#     df2 = df_test[['cust_id']+cols]
#     df = pd.concat([df1, df2], axis=0, ignore_index=True)
#     for i in cols:
#         temp_df = df.groupby(i)['cust_id'].count()
#         temp_df = pd.DataFrame({(i+"_num"): temp_df})
#         df = pd.merge(df, temp_df, on=i, how="left")
#         del df[i], df1[i], df2[i]
#     df_train = pd.merge(df_train, df, on="cust_id",
#                         how="left", suffixes=("", "_y"))
#     df_test = pd.merge(df_test, df, on="cust_id",
#                        how="left", suffixes=("", "_y"))


# type_count(type_count_cols)

# %% [markdown]
# ## 证据权重

# %%
import pandas as pd
import numpy as np


def cal_woe(df, df_no_label, x_cols, y_col):
    for i in x_cols:
        x_set = pd.unique(df[i])
        x1_set = pd.unique(df_no_label[i])
        for j in x1_set:
            if j not in x_set:
                df_no_label[i].replace(j, 0.03, inplace=True)
                print(i, j, '不存在')
        for j in x_set:
            woe = np.mean(df[df[i] == j][y_col])
            if woe >= 0.1:
                n = np.sum(df[df[i] == j][y_col])
                print(i, '列：', j, ' 共有', int(n/woe), '个,其中',
                      int(n), '个label为1,woe为', woe, sep="")
            df[i].replace(j, woe, inplace=True)
            df_no_label[i].replace(j, woe, inplace=True)
    return df, df_no_label

# %%
type_col = ["basic_1",
            "basic_10",
            "basic_12",
            "basic_14",
            "loan1_16",
            "loan1_20",
            "loan1_23",
            "loan1_25", ]

df_train,df_test=cal_woe(df_train,df_test,type_col,"label")
# Out:
# basic_1 12 不存在
# basic_12列：1 共有10个,其中2个label为1,woe为0.2
# loan1_16列：6 共有20个,其中2个label为1,woe为0.1
# loan1_23 8 不存在
# loan1_23列：4 共有4个,其中1个label为1,woe为0.25

# %%
if cat_way == "auto" or cat_way == "no":
    type_col = ["basic_1",
                "basic_10",
                "basic_12",
                "basic_14",
                "loan1_16",
                "loan1_20",
                "loan1_23",
                "loan1_25",
                "loan2_1_y",
                "query_2_y",
                "query_3_y",
                "query_4_y",
                "query_5_y",
                "query_6_y", ]
if cat_way == "manual":
    woe_col = ['basic_1',
               'basic_5',
               'basic_6',
               'basic_10',
               'loan1_16',
               'loan1_20',
               'loan1_25',
               'loan1_23',
               'loan1_32',
               'loan2_4',
               'loan2_6',
               'overdue_2',
               'overdue_20',
               'overdue_21',
               'overdue_26',
               'overdue_27',
               'query_1',
               'query_2',
               'query_3',
               'query_4',
               'query_6',
               'query_7',
               'query_8',
               'query_10',
               'query_11', ]

    onehot_col = ['basic_12',
                  'basic_14',
                  'loan1_8',
                  'loan1_9',
                  'overdue_1',
                  'overdue_3',
                  'overdue_4',
                  'overdue_5',
                  'overdue_6',
                  'overdue_7',
                  'overdue_8',
                  'overdue_9',
                  'overdue_10',
                  'overdue_11',
                  'overdue_12',
                  'overdue_14',
                  'overdue_15',
                  'overdue_16',
                  'overdue_17',
                  'overdue_18',
                  'overdue_22',
                  'overdue_23',
                  'overdue_24',
                  'overdue_25',
                  'overdue_28',
                  'overdue_29',
                  'query_5',
                  'query_9', ]

    df_train, df_test = cal_woe(df_train, df_test, woe_col, "label")
    df_train = to_one_hot(df_train, onehot_col)
    df_test = to_one_hot(df_test, onehot_col)
    for i in df_train.columns:
        if i not in df_test.columns:
            df_test[i] = 0

# %%
full_col_name = list(df_train.columns)
basic_col = [i for i in full_col_name if "basic" in i]
loan_col = [i for i in full_col_name if "loan" in i]
overdue_col = [i for i in full_col_name if "overdue" in i]
query_col = [i for i in full_col_name if "query" in i]
judicial_col = [i for i in full_col_name if "judicial" in i]
date_col = [i for i in full_col_name if "date" in i]
# loan_pca_col = [i for i in full_col_name if "loan_pca" in i]

# for i in judicial_col:
#     df_train[i].astype("float")
#     df_test[i].astype("float")

# %% [markdown]
# ## rank化

# %%
def rank(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = np.argsort(df[i])
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


a = ['loan1_1', 'loan1_3', 'loan1_7', 'loan1_9']
b = ['_sum', '_mean']
c = []
for i in a:
    for j in b:
        c.append(i+j)
# rank(c)

# %% [markdown]
# ## 归一化

# %%
def norm(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.min(df[i]))/(np.max(df[i])-np.min(df[i]))
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# norm([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 标准化

# %%
def stand(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.mean(df[i], axis=0))/np.std(df[i], axis=0)
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# stand([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 设置哪些x作为模型自变量输入

# %%
# x_col = basic_col+loan_col+['nan_num'] + ['is_judicial']+ overdue_col+query_col
# x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col+['scope_num'] + \
#     ['industry_num']+['date_3_count', 'date_1_std', 'date_1_diff_std']

x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col
x_col = [i for i in x_col if i in full_col_name]

if cat_way == "auto":
    type_col = [i for i in type_col if i in x_col]
# categorize(df_train,type_col)
# categorize(df_test,type_col)

print('自变量个数为', len(x_col))
print(x_col)
# Out:
# 自变量个数为 123
# ['basic_1', 'basic_2', 'basic_3', 'basic_4', 'basic_5', 'basic_6', 'basic_7', 'basic_8', 'basic_9', 'basic_10', 'basic_11', 'basic_12', 'basic_13', 'basic_14', 'basic_15', 'basic_1_y', 'basic_2_y', 'basic_3_y', 'is_judicial', 'loan1_1', 'loan1_2', 'loan1_3', 'loan1_4', 'loan1_5', 'loan1_6', 'loan1_7', 'loan1_8', 'loan1_9', 'loan1_10', 'loan1_11', 'loan1_12', 'loan1_13', 'loan1_14', 'loan1_15', 'loan1_16', 'loan1_17', 'loan1_18', 'loan1_19', 'loan1_20', 'loan1_21', 'loan1_22', 'loan1_23', 'loan1_24', 'loan1_25', 'loan1_26', 'loan1_27', 'loan1_28', 'loan1_29', 'loan1_30', 'loan1_31', 'loan1_32', 'loan1_33', 'loan2_1', 'loan2_2', 'loan2_3', 'loan2_4', 'loan2_5', 'loan2_6', 'loan2_7', 'loan2_8', 'loan2_9', 'loan2_10', 'loan2_11', 'loan2_12', 'loan2_1_y', 'loan2_2_y', 'loan2_3_y', 'loan2_4_y', 'loan2_5_y', 'loan1_2_sum', 'loan1_2_std', 'loan1_3_sum', 'loan1_3_std', 'loan1_7_sum', 'loan1_7_std', 'loan1_9_sum', 'loan1_9_std', 'query_1', 'query_2', 'query_3', 'query_4', 'query_5', 'query_6', 'query_7', 'query_8', 'query_9', 'query_10', 'query_11', 'query_1_y', 'query_2_y', 'query_3_y', 'query_4_y', 'query_5_y', 'query_6_y', 'overdue_1', 'overdue_2', 'overdue_3', 'overdue_4', 'overdue_5', 'overdue_6', 'overdue_7', 'overdue_8', 'overdue_9', 'overdue_10', 'overdue_11', 'overdue_12', 'overdue_13', 'overdue_14', 'overdue_15', 'overdue_16', 'overdue_17', 'overdue_18', 'overdue_19', 'overdue_20', 'overdue_21', 'overdue_22', 'overdue_23', 'overdue_24', 'overdue_25', 'overdue_26', 'overdue_27', 'overdue_28', 'overdue_29']

# %%
df_train = df_train[x_col+['label', 'cust_id']]
df_test = df_test[x_col+['cust_id']]

df_test.to_csv("test_input.csv", encoding='utf-8')

# %% [markdown]
# ## 对抗验证

# %%
from sklearn import model_selection
import xgboost as xgb

df_full = pd.concat([df_train[x_col+['cust_id']], df_test],
                    axis=0, ignore_index=True)
df_full['label_test'] = [1 if i in df_test['cust_id']
                         else 0 for i in df_full['cust_id']]

df_full.to_csv("full.csv", encoding='utf-8')

# %%
X = df_full[x_col+['cust_id']]
Y = df_full['label_test']

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(
    X, Y, test_size=0.5, stratify=Y, random_state=2022)

dtrain = xgb.DMatrix(X_train[x_col], label=Y_train)
dtest = xgb.DMatrix(X_test[x_col], label=Y_test)

param = {'max_depth': 5,
         'eta': 0.1,
         'objective': 'binary:logistic',
         "eval_metric": "auc",
         "scale_pos_weight": 1,
         "subsample": 1,
         "min_child_weight": 1,
         'tree_method': 'gpu_hist',
         'gpu_id': 0, }

bst = xgb.train(param, dtrain, 4000, evals=[(dtrain, "train"), (dtest, "test")],
                early_stopping_rounds=300, verbose_eval=True)
bst1 = xgb.train(param, dtest, 4000, evals=[(dtest, "train"), (dtrain, "test")],
                 early_stopping_rounds=300, verbose_eval=False)
# Out:
# [0]	train-auc:0.54530	test-auc:0.49002
# [1]	train-auc:0.55066	test-auc:0.48869
# [2]	train-auc:0.56629	test-auc:0.48812
# [3]	train-auc:0.57194	test-auc:0.48800
# [4]	train-auc:0.58052	test-auc:0.48887
# [5]	train-auc:0.58617	test-auc:0.48995
# [6]	train-auc:0.59010	test-auc:0.49048
# [7]	train-auc:0.61509	test-auc:0.48807
# [8]	train-auc:0.62182	test-auc:0.48679
# [9]	train-auc:0.63410	test-auc:0.48326
# [10]	train-auc:0.63660	test-auc:0.48330
# [11]	train-auc:0.65149	test-auc:0.48115
# [12]	train-auc:0.66151	test-auc:0.48008
# [13]	train-auc:0.68306	test-auc:0.48590
# [14]	train-auc:0.69250	test-auc:0.48812
# [15]	train-auc:0.69763	test-auc:0.48564
# [16]	train-auc:0.70512	test-auc:0.48731
# [17]	train-auc:0.71044	test-auc:0.48998
# [18]	train-auc:0.71748	test-auc:0.49045
# [19]	train-auc:0.71730	test-auc:0.49063
# [20]	train-auc:0.71940	test-auc:0.49273
# [21]	train-auc:0.72207	test-auc:0.49323
# [22]	train-auc:0.72623	test-auc:0.49364
# [23]	train-auc:0.73504	test-auc:0.49685
# [24]	train-auc:0.74113	test-auc:0.49653
# [25]	train-auc:0.74898	test-auc:0.49467
# [26]	train-auc:0.75116	test-auc:0.49437
# [27]	train-auc:0.75168	test-auc:0.49492
# [28]	train-auc:0.75304	test-auc:0.49579
# [29]	train-auc:0.75660	test-auc:0.49566
# [30]	train-auc:0.76083	test-auc:0.49623
# [31]	train-auc:0.76878	test-auc:0.49845
# [32]	train-auc:0.77083	test-auc:0.49779
# [33]	train-auc:0.77249	test-auc:0.49716
# [34]	train-auc:0.77751	test-auc:0.49556
# [35]	train-auc:0.77786	test-auc:0.49575
# [36]	train-auc:0.78015	test-auc:0.49480
# [37]	train-auc:0.78107	test-auc:0.49585
# [38]	train-auc:0.78367	test-auc:0.49644
# [39]	train-auc:0.78544	test-auc:0.49572
# [40]	train-auc:0.78648	test-auc:0.49570
# [41]	train-auc:0.78825	test-auc:0.49652
# [42]	train-auc:0.78795	test-auc:0.49696
# [43]	train-auc:0.79118	test-auc:0.49686
# [44]	train-auc:0.79485	test-auc:0.49555
# [45]	train-auc:0.79882	test-auc:0.49629
# [46]	train-auc:0.80300	test-auc:0.49571
# [47]	train-auc:0.80487	test-auc:0.49569
# [48]	train-auc:0.80507	test-auc:0.49603
# [49]	train-auc:0.80576	test-auc:0.49614
# [50]	train-auc:0.80679	test-auc:0.49645
# [51]	train-auc:0.80779	test-auc:0.49581
# [52]	train-auc:0.80918	test-auc:0.49576
# [53]	train-auc:0.81100	test-auc:0.49628
# [54]	train-auc:0.81249	test-auc:0.49622
# [55]	train-auc:0.81641	test-auc:0.49596
# [56]	train-auc:0.81651	test-auc:0.49592
# [57]	train-auc:0.81663	test-auc:0.49610
# [58]	train-auc:0.81675	test-auc:0.49637
# [59]	train-auc:0.82108	test-auc:0.49563
# [60]	train-auc:0.82159	test-auc:0.49596
# [61]	train-auc:0.82247	test-auc:0.49523
# [62]	train-auc:0.82375	test-auc:0.49474
# [63]	train-auc:0.82456	test-auc:0.49416
# [64]	train-auc:0.82738	test-auc:0.49441
# [65]	train-auc:0.82785	test-auc:0.49467
# [66]	train-auc:0.83295	test-auc:0.49658
# [67]	train-auc:0.83581	test-auc:0.49602
# [68]	train-auc:0.83754	test-auc:0.49644
# [69]	train-auc:0.83948	test-auc:0.49676
# [70]	train-auc:0.84254	test-auc:0.49709
# [71]	train-auc:0.84466	test-auc:0.49684
# [72]	train-auc:0.84646	test-auc:0.49731
# [73]	train-auc:0.84849	test-auc:0.49691
# [74]	train-auc:0.84985	test-auc:0.49664
# [75]	train-auc:0.85434	test-auc:0.49580
# [76]	train-auc:0.85655	test-auc:0.49573
# [77]	train-auc:0.85938	test-auc:0.49708
# [78]	train-auc:0.86269	test-auc:0.49818
# [79]	train-auc:0.86512	test-auc:0.49821
# [80]	train-auc:0.86544	test-auc:0.49824
# [81]	train-auc:0.86557	test-auc:0.49838
# [82]	train-auc:0.86753	test-auc:0.49875
# [83]	train-auc:0.86934	test-auc:0.49887
# [84]	train-auc:0.87006	test-auc:0.49872
# [85]	train-auc:0.87066	test-auc:0.49877
# [86]	train-auc:0.87156	test-auc:0.49902
# [87]	train-auc:0.87489	test-auc:0.49865
# [88]	train-auc:0.87503	test-auc:0.49872
# [89]	train-auc:0.87600	test-auc:0.49814
# [90]	train-auc:0.87643	test-auc:0.49766
# [91]	train-auc:0.87706	test-auc:0.49779
# [92]	train-auc:0.87959	test-auc:0.49713
# [93]	train-auc:0.88030	test-auc:0.49742
# [94]	train-auc:0.88324	test-auc:0.49744
# [95]	train-auc:0.88468	test-auc:0.49668
# [96]	train-auc:0.88582	test-auc:0.49711
# [97]	train-auc:0.88688	test-auc:0.49670
# [98]	train-auc:0.88725	test-auc:0.49607
# [99]	train-auc:0.88765	test-auc:0.49583
# [100]	train-auc:0.88785	test-auc:0.49569
# [101]	train-auc:0.88835	test-auc:0.49627
# [102]	train-auc:0.89069	test-auc:0.49709
# [103]	train-auc:0.89167	test-auc:0.49774
# [104]	train-auc:0.89199	test-auc:0.49743
# [105]	train-auc:0.89209	test-auc:0.49700
# [106]	train-auc:0.89315	test-auc:0.49770
# [107]	train-auc:0.89323	test-auc:0.49785
# [108]	train-auc:0.89389	test-auc:0.49777
# [109]	train-auc:0.89400	test-auc:0.49811
# [110]	train-auc:0.89488	test-auc:0.49786
# [111]	train-auc:0.89635	test-auc:0.49850
# [112]	train-auc:0.89794	test-auc:0.49758
# [113]	train-auc:0.89983	test-auc:0.49822
# [114]	train-auc:0.90139	test-auc:0.49796
# [115]	train-auc:0.90190	test-auc:0.49833
# [116]	train-auc:0.90382	test-auc:0.49779
# [117]	train-auc:0.90414	test-auc:0.49755
# [118]	train-auc:0.90428	test-auc:0.49745
# [119]	train-auc:0.90516	test-auc:0.49760
# [120]	train-auc:0.90580	test-auc:0.49825
# [121]	train-auc:0.90604	test-auc:0.49830
# [122]	train-auc:0.90637	test-auc:0.49823
# [123]	train-auc:0.90656	test-auc:0.49797
# [185]	train-auc:0.94561	test-auc:0.49845
# [186]	train-auc:0.94564	test-auc:0.49829
# [187]	train-auc:0.94599	test-auc:0.49797
# [188]	train-auc:0.94606	test-auc:0.49772
# [189]	train-auc:0.94607	test-auc:0.49775
# [190]	train-auc:0.94616	test-auc:0.49785
# [191]	train-auc:0.94623	test-auc:0.49757
# [192]	train-auc:0.94684	test-auc:0.49752
# [193]	train-auc:0.94709	test-auc:0.49720
# [194]	train-auc:0.94716	test-auc:0.49706
# [195]	train-auc:0.94718	test-auc:0.49681
# [196]	train-auc:0.94833	test-auc:0.49628
# [197]	train-auc:0.94914	test-auc:0.49607
# [198]	train-auc:0.94967	test-auc:0.49598
# [199]	train-auc:0.95009	test-auc:0.49612
# [200]	train-auc:0.95012	test-auc:0.49626
# [201]	train-auc:0.95090	test-auc:0.49608
# [202]	train-auc:0.95178	test-auc:0.49611
# [203]	train-auc:0.95179	test-auc:0.49629
# [204]	train-auc:0.95204	test-auc:0.49664
# [205]	train-auc:0.95312	test-auc:0.49594
# [206]	train-auc:0.95377	test-auc:0.49623
# [207]	train-auc:0.95401	test-auc:0.49662
# [208]	train-auc:0.95464	test-auc:0.49667
# [209]	train-auc:0.95473	test-auc:0.49677
# [210]	train-auc:0.95474	test-auc:0.49664
# [211]	train-auc:0.95540	test-auc:0.49670
# [212]	train-auc:0.95595	test-auc:0.49683
# [213]	train-auc:0.95633	test-auc:0.49673
# [214]	train-auc:0.95650	test-auc:0.49647
# [215]	train-auc:0.95663	test-auc:0.49618
# [216]	train-auc:0.95694	test-auc:0.49621
# [217]	train-auc:0.95791	test-auc:0.49665
# [218]	train-auc:0.95841	test-auc:0.49639
# [219]	train-auc:0.95923	test-auc:0.49621
# [220]	train-auc:0.95973	test-auc:0.49620
# [221]	train-auc:0.95994	test-auc:0.49642
# [222]	train-auc:0.96039	test-auc:0.49628
# [223]	train-auc:0.96082	test-auc:0.49649
# [224]	train-auc:0.96104	test-auc:0.49645
# [225]	train-auc:0.96161	test-auc:0.49585
# [226]	train-auc:0.96174	test-auc:0.49558
# [227]	train-auc:0.96242	test-auc:0.49631
# [228]	train-auc:0.96325	test-auc:0.49664
# [229]	train-auc:0.96348	test-auc:0.49691
# [230]	train-auc:0.96364	test-auc:0.49711
# [231]	train-auc:0.96375	test-auc:0.49704
# [232]	train-auc:0.96386	test-auc:0.49734
# [233]	train-auc:0.96393	test-auc:0.49755
# [234]	train-auc:0.96395	test-auc:0.49762
# [235]	train-auc:0.96409	test-auc:0.49745
# [236]	train-auc:0.96435	test-auc:0.49730
# [237]	train-auc:0.96461	test-auc:0.49767
# [238]	train-auc:0.96469	test-auc:0.49768
# [239]	train-auc:0.96527	test-auc:0.49800
# [240]	train-auc:0.96540	test-auc:0.49777
# [241]	train-auc:0.96575	test-auc:0.49831
# [242]	train-auc:0.96638	test-auc:0.49752
# [243]	train-auc:0.96697	test-auc:0.49736
# [244]	train-auc:0.96705	test-auc:0.49722
# [245]	train-auc:0.96736	test-auc:0.49676
# [246]	train-auc:0.96743	test-auc:0.49680
# [247]	train-auc:0.96793	test-auc:0.49682
# [248]	train-auc:0.96816	test-auc:0.49712
# [249]	train-auc:0.96818	test-auc:0.49714
# [250]	train-auc:0.96837	test-auc:0.49696
# [251]	train-auc:0.96840	test-auc:0.49688
# [252]	train-auc:0.96888	test-auc:0.49702
# [253]	train-auc:0.96898	test-auc:0.49713
# [254]	train-auc:0.96919	test-auc:0.49755
# [255]	train-auc:0.96954	test-auc:0.49713
# [256]	train-auc:0.97012	test-auc:0.49686
# [257]	train-auc:0.97057	test-auc:0.49695
# [258]	train-auc:0.97076	test-auc:0.49726
# [259]	train-auc:0.97077	test-auc:0.49701
# [260]	train-auc:0.97077	test-auc:0.49698
# [261]	train-auc:0.97089	test-auc:0.49724
# [262]	train-auc:0.97106	test-auc:0.49721
# [263]	train-auc:0.97138	test-auc:0.49753
# [264]	train-auc:0.97151	test-auc:0.49755
# [265]	train-auc:0.97181	test-auc:0.49758
# [266]	train-auc:0.97198	test-auc:0.49761
# [267]	train-auc:0.97196	test-auc:0.49765
# [268]	train-auc:0.97225	test-auc:0.49830
# [269]	train-auc:0.97228	test-auc:0.49842
# [270]	train-auc:0.97233	test-auc:0.49866
# [271]	train-auc:0.97240	test-auc:0.49869
# [272]	train-auc:0.97302	test-auc:0.49866
# [273]	train-auc:0.97303	test-auc:0.49853
# [274]	train-auc:0.97316	test-auc:0.49863
# [275]	train-auc:0.97363	test-auc:0.49849
# [276]	train-auc:0.97396	test-auc:0.49828
# [277]	train-auc:0.97448	test-auc:0.49832
# [278]	train-auc:0.97495	test-auc:0.49838
# [279]	train-auc:0.97522	test-auc:0.49821
# [280]	train-auc:0.97557	test-auc:0.49821
# [281]	train-auc:0.97583	test-auc:0.49850
# [282]	train-auc:0.97612	test-auc:0.49812
# [283]	train-auc:0.97634	test-auc:0.49810
# [284]	train-auc:0.97652	test-auc:0.49763
# [285]	train-auc:0.97657	test-auc:0.49744
# [286]	train-auc:0.97659	test-auc:0.49736
# [287]	train-auc:0.97661	test-auc:0.49735
# [288]	train-auc:0.97685	test-auc:0.49745
# [289]	train-auc:0.97684	test-auc:0.49742
# [290]	train-auc:0.97684	test-auc:0.49744
# [291]	train-auc:0.97700	test-auc:0.49748
# [292]	train-auc:0.97717	test-auc:0.49773
# [293]	train-auc:0.97726	test-auc:0.49758
# [294]	train-auc:0.97737	test-auc:0.49748
# [295]	train-auc:0.97750	test-auc:0.49706
# [296]	train-auc:0.97770	test-auc:0.49705
# [297]	train-auc:0.97772	test-auc:0.49712
# [298]	train-auc:0.97781	test-auc:0.49724
# [299]	train-auc:0.97781	test-auc:0.49722
# [300]	train-auc:0.97810	test-auc:0.49722
# [301]	train-auc:0.97828	test-auc:0.49676
# [302]	train-auc:0.97831	test-auc:0.49665
# [303]	train-auc:0.97839	test-auc:0.49677
# [304]	train-auc:0.97848	test-auc:0.49701
# [305]	train-auc:0.97850	test-auc:0.49708
# [306]	train-auc:0.97896	test-auc:0.49654
# [307]	train-auc:0.97918	test-auc:0.49617
# [308]	train-auc:0.97940	test-auc:0.49653
# [309]	train-auc:0.97998	test-auc:0.49639
# [310]	train-auc:0.98025	test-auc:0.49663
# [311]	train-auc:0.98039	test-auc:0.49684
# [312]	train-auc:0.98053	test-auc:0.49702
# [313]	train-auc:0.98068	test-auc:0.49689
# [314]	train-auc:0.98079	test-auc:0.49682
# [315]	train-auc:0.98079	test-auc:0.49686
# [316]	train-auc:0.98081	test-auc:0.49676
# [317]	train-auc:0.98087	test-auc:0.49698
# [318]	train-auc:0.98100	test-auc:0.49704
# [319]	train-auc:0.98101	test-auc:0.49731
# [320]	train-auc:0.98138	test-auc:0.49739
# [321]	train-auc:0.98145	test-auc:0.49714
# [322]	train-auc:0.98168	test-auc:0.49736
# [323]	train-auc:0.98182	test-auc:0.49709
# [324]	train-auc:0.98182	test-auc:0.49694
# [325]	train-auc:0.98187	test-auc:0.49698
# [326]	train-auc:0.98188	test-auc:0.49696
# [327]	train-auc:0.98192	test-auc:0.49695
# [328]	train-auc:0.98205	test-auc:0.49688
# [329]	train-auc:0.98211	test-auc:0.49695
# [330]	train-auc:0.98216	test-auc:0.49704
# [331]	train-auc:0.98252	test-auc:0.49712
# [332]	train-auc:0.98273	test-auc:0.49691
# [333]	train-auc:0.98282	test-auc:0.49681
# [334]	train-auc:0.98285	test-auc:0.49682
# [335]	train-auc:0.98315	test-auc:0.49685
# [336]	train-auc:0.98352	test-auc:0.49708
# [337]	train-auc:0.98366	test-auc:0.49752
# [338]	train-auc:0.98392	test-auc:0.49731
# [339]	train-auc:0.98392	test-auc:0.49747
# [340]	train-auc:0.98409	test-auc:0.49753
# [341]	train-auc:0.98430	test-auc:0.49754
# [342]	train-auc:0.98449	test-auc:0.49783
# [343]	train-auc:0.98448	test-auc:0.49806
# [344]	train-auc:0.98451	test-auc:0.49824
# [345]	train-auc:0.98453	test-auc:0.49835
# [346]	train-auc:0.98475	test-auc:0.49848
# [347]	train-auc:0.98484	test-auc:0.49846
# [348]	train-auc:0.98494	test-auc:0.49876
# [349]	train-auc:0.98495	test-auc:0.49881
# [350]	train-auc:0.98499	test-auc:0.49889
# [351]	train-auc:0.98499	test-auc:0.49891
# [352]	train-auc:0.98511	test-auc:0.49861
# [353]	train-auc:0.98538	test-auc:0.49870
# [354]	train-auc:0.98566	test-auc:0.49878
# [355]	train-auc:0.98573	test-auc:0.49865
# [356]	train-auc:0.98588	test-auc:0.49867
# [357]	train-auc:0.98590	test-auc:0.49873
# [358]	train-auc:0.98595	test-auc:0.49864
# [359]	train-auc:0.98622	test-auc:0.49865
# [360]	train-auc:0.98629	test-auc:0.49880
# [361]	train-auc:0.98645	test-auc:0.49876
# [362]	train-auc:0.98651	test-auc:0.49886
# [363]	train-auc:0.98685	test-auc:0.49876
# [364]	train-auc:0.98687	test-auc:0.49879
# [365]	train-auc:0.98702	test-auc:0.49899
# [366]	train-auc:0.98722	test-auc:0.49920
# [792]	train-auc:0.99949	test-auc:0.50133
# [793]	train-auc:0.99950	test-auc:0.50141
# [794]	train-auc:0.99950	test-auc:0.50137
# [795]	train-auc:0.99950	test-auc:0.50138
# [796]	train-auc:0.99950	test-auc:0.50152
# [797]	train-auc:0.99951	test-auc:0.50153
# [798]	train-auc:0.99951	test-auc:0.50151
# [799]	train-auc:0.99951	test-auc:0.50153
# [800]	train-auc:0.99951	test-auc:0.50148
# [801]	train-auc:0.99952	test-auc:0.50139
# [802]	train-auc:0.99952	test-auc:0.50142
# [803]	train-auc:0.99952	test-auc:0.50134
# [804]	train-auc:0.99952	test-auc:0.50130
# [805]	train-auc:0.99953	test-auc:0.50131
# [806]	train-auc:0.99953	test-auc:0.50101
# [807]	train-auc:0.99953	test-auc:0.50100
# [808]	train-auc:0.99953	test-auc:0.50108
# [809]	train-auc:0.99954	test-auc:0.50112
# [810]	train-auc:0.99954	test-auc:0.50117
# [811]	train-auc:0.99954	test-auc:0.50114
# [812]	train-auc:0.99954	test-auc:0.50101
# [813]	train-auc:0.99954	test-auc:0.50119
# [814]	train-auc:0.99954	test-auc:0.50125
# [815]	train-auc:0.99954	test-auc:0.50121
# [816]	train-auc:0.99955	test-auc:0.50106
# [817]	train-auc:0.99955	test-auc:0.50097
# [818]	train-auc:0.99955	test-auc:0.50095
# [819]	train-auc:0.99955	test-auc:0.50093
# [820]	train-auc:0.99955	test-auc:0.50095
# [821]	train-auc:0.99955	test-auc:0.50089
# [822]	train-auc:0.99956	test-auc:0.50089
# [823]	train-auc:0.99956	test-auc:0.50083
# [824]	train-auc:0.99956	test-auc:0.50091
# [825]	train-auc:0.99956	test-auc:0.50085
# [826]	train-auc:0.99956	test-auc:0.50081
# [827]	train-auc:0.99956	test-auc:0.50064
# [828]	train-auc:0.99956	test-auc:0.50060
# [829]	train-auc:0.99956	test-auc:0.50059
# [830]	train-auc:0.99957	test-auc:0.50041
# [831]	train-auc:0.99957	test-auc:0.50041
# [832]	train-auc:0.99958	test-auc:0.50026
# [833]	train-auc:0.99958	test-auc:0.50035
# [834]	train-auc:0.99958	test-auc:0.50035
# [835]	train-auc:0.99960	test-auc:0.50043

# %%
df_res = pd.DataFrame(
    {'cust_id': X_test['cust_id'], 'p_test': bst.predict(dtest)})
df_res1 = pd.DataFrame(
    {'cust_id': X_train['cust_id'], 'p_test': bst1.predict(dtrain)})

df = pd.concat([df_res, df_res1], axis=0, ignore_index=True)

df_train = pd.merge(df_train, df, on="cust_id",
                    how="left", suffixes=("", "_y"))

# %%
temp = len(df_train)
df_train.to_csv("train_input.csv", encoding='utf-8')

df_train = df_train[df_train['p_test'] >= 0.1]


print("经过对抗验证，有", len(df_train), "条数据被保留，",
      temp-len(df_train), "条数据被抛弃", sep="")
# Out:
# 经过对抗验证，有16491条数据被保留，1508条数据被抛弃

# %% [markdown]
# # 训练模型

# %% [markdown]
# ## 超参数

# %%
N = 60
num_round = 3000
local_test_size = 2000

# 共用
test_size = [0.2, 0.25, 0.3]
max_depth = [3, 4, 5]
subsample = [0.8, 0.75, 0.7, 0.65, 0.6]
early_stopping_rounds = 150

# XGB
eta = [0.007, 0.01]

# LGB
learning_rate = [0.03, 0.02, 0.025]

# %% [markdown]
# ### train划分为
# * 本地测试集（固定）d_localtest
# * 训练集（固定）
#   * 评估集（每次的模型不同）dtest
#   * 真正的训练集（每次的模型不同）dtrain

# %%
import copy
import xgboost as xgb
import random
from sklearn import model_selection
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from catboost import CatBoostClassifier


pred_labels = []
local_test_labels = []
loss_seq = []
max_auc_loss = 0
flag = 0
important_x_seq = []


d_full = xgb.DMatrix(df_train[x_col], label=df_train['label'])
X = df_train[x_col]
Y = df_train['label']

X, X_local_test, Y, Y_local_test = model_selection.train_test_split(
    X, Y, test_size=local_test_size, stratify=Y, random_state=2022)

d_localtest = xgb.DMatrix(X_local_test, label=Y_local_test)
x_perd = xgb.DMatrix(df_test[x_col])

d_localtest1 = lgb.Dataset(X_local_test, Y_local_test)
x_perd1 = lgb.Dataset(df_test[x_col])


lgbcallback = [early_stopping(early_stopping_rounds), log_evaluation(10000)]

# %%
for i in range(N):

    test_size_this_round = random.choice(test_size)
    X_train, X_test, y_train, y_test = model_selection.train_test_split(
        X, Y, test_size=test_size_this_round, stratify=Y)

    # XGB-----------------------------------------------
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    evallist = [(dtest, 'eval')]
    param = {
        'max_depth': random.choice(max_depth),
        'eta': random.choice(eta),
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'subsample': random.choice(subsample),
        'tree_method': 'gpu_hist',
        'gpu_id': 0,
    }

    bst = xgb.train(param, dtrain, num_round, evals=evallist,
                    early_stopping_rounds=early_stopping_rounds, verbose_eval=False)

    loss = roc_auc_score(y_test, bst.predict(dtest))
    train_loss = roc_auc_score(y_train, bst.predict(dtrain))
    local_test_loss = roc_auc_score(Y_local_test, bst.predict(d_localtest))
    global_auc = roc_auc_score(df_train['label'], bst.predict(d_full))

    pred_label = list(bst.predict(x_perd))
    test_label = list(bst.predict(d_localtest))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'xgb'}

    if flag == 0:
        info_df = pd.DataFrame(temp_dict, index=[i])
        flag = 1
    else:
        info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])

    # if loss > max_auc_loss:
    #     best_bst = copy.deepcopy(bst)
    #     max_auc_loss = loss

    # if False:
    #     pic = xgb.plot_importance(bst, max_num_features=50)
    #     temp = pic.get_ymajorticklabels()
    #     important_x = [str(i).split("\'")[1] for i in temp]
    #     important_x.reverse()
    #     important_x_seq += important_x

    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    # LGB--------------------------------------------------------
    param = {
        'task': 'train',
        "max_depth": random.choice(max_depth),
        'max_bin': 128,
        'boosting_type': 'gbdt',  # 设置提升类型
        'objective': 'binary',  # 目标函数
        'metric': 'auc',  # 评估函数
        'learning_rate': random.choice(learning_rate),  # 学习速率
        'bagging_fraction': random.choice(subsample),  # 建树的样本采样比例
        'bagging_freq': 1,  # k 意味着每 k 次迭代执行bagging
        'min_data_in_leaf': 1,
        'verbose': -1,  # <0 显示致命的, =0 显示错误 (警告), >0 显示信息
        'device_type': 'gpu',
    }

    dtrain = lgb.Dataset(X_train, y_train)
    dtest = lgb.Dataset(X_test, y_test)

    if cat_way == "auto":
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback, categorical_feature=type_col)
    else:
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback)

    loss = roc_auc_score(y_test, bst1.predict(X_test))
    train_loss = roc_auc_score(y_train, bst1.predict(X_train))
    local_test_loss = roc_auc_score(Y_local_test, bst1.predict(X_local_test))
    global_auc = roc_auc_score(
        df_train['label'], bst1.predict(df_train[x_col]))

    pred_label = list(bst1.predict(df_test[x_col]))
    test_label = list(bst1.predict(X_local_test))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'lgb'}

    info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    # CAT-----------------------------------------------------------
    # bst2 = CatBoostClassifier(iterations=num_round,
    #                        depth=random.choice(max_depth),
    #                        learning_rate=random.choice(learning_rate),
    #                        loss_function='Logloss',
    #                        subsample=random.choice(subsample),
    #                        early_stopping_rounds=early_stopping_rounds,
    #                        verbose=False)
    # bst2.fit(X_train, y_train,eval_set=(X_test,y_test))

    # loss = roc_auc_score(y_test, bst2.predict_proba(X_test)[:,1])
    # train_loss = roc_auc_score(y_train, bst2.predict_proba(X_train)[:,1])
    # local_test_loss = roc_auc_score(Y_local_test, bst2.predict_proba(X_local_test)[:,1])
    # global_auc = roc_auc_score(df_train['label'], bst2.predict_proba(df_train[x_col])[:,1])

    # pred_label = list(bst2.predict_proba(df_test[x_col])[:,1])
    # test_label = list(bst2.predict_proba(X_local_test)[:,1])

    # temp_dict = {"test_auc": loss, "train_auc": train_loss,
    #              'local_test_auc': local_test_loss,
    #              'model': 'cat'}

    # info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    # pred_labels.append(copy.deepcopy(pred_label))
    # local_test_labels.append(copy.deepcopy(test_label))


print('最大AUC:', max(info_df['local_test_auc']), sep="")
# Out:
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [408]	valid_0's auc: 0.767903
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# Early stopping, best iteration is:
# [506]	valid_0's auc: 0.783077
# 最大AUC:0.799585706887623

# %%
info_df.to_csv("info.csv", encoding="utf-8", index=False)

# %%
# pic = xgb.plot_importance(bst, max_num_features=50)
# temp = pic.get_ymajorticklabels()
# important_x = [str(i).split("\'")[1] for i in temp]
# important_x.reverse()

# %%
# important_x

# %%
# pd.value_counts(important_x_seq)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6.5, 6), dpi=200)


plt.scatter(info_df[info_df['model'] == 'xgb']['local_test_auc'], info_df[info_df['model'] == 'xgb']['test_auc'],
            c='r', s=4, label="xgb")
plt.scatter(info_df[info_df['model'] == 'lgb']['local_test_auc'], info_df[info_df['model'] == 'lgb']['test_auc'],
            c='g', s=4, label="lgb")
# plt.scatter(info_df[info_df['model'] == 'cat']['local_test_auc'], info_df[info_df['model'] == 'cat']['test_auc'],
#             c='b', s=4,label="cat")
plt.legend()
plt.xlabel('local_test_auc')
plt.ylabel('test_auc')
plt.plot([0.6, 0.85], [0.6, 0.85])
plt.xlim(0.6, 0.85)
plt.ylim(0.6, 0.85)
plt.grid()
plt.show()

# %% [markdown]
# # 输出模块

# %%
import time
import numpy as np
from sklearn.metrics import roc_auc_score

date = time.strftime("%Y%m%d-%H%M%S", time.localtime())
res_num = np.argsort(
    [-i for i in (info_df['local_test_auc']+info_df['test_auc'])])

# 选择前n个结果进行平均（手动指定or在本地测试集排序选出）
if True:
    max_auc = -1
    list_temp = []
    auc_seq = []
    for i in range(N*2):
        list_temp.append(local_test_labels[res_num[i]])
        # 算数平均
        # temp = np.mean(list_temp, axis=0)
        # 几何平均(better)
        temp = np.exp(np.mean(np.log(list_temp), axis=0))
        temp_auc = roc_auc_score(Y_local_test, temp)
        # print(i, temp_auc)
        auc_seq.append(temp_auc)
        if temp_auc > max_auc:
            max_auc = temp_auc
            n = i+1
else:
    n = 40
    n = min(N, n)

res_num = res_num[0:n]

#final_pred_label = np.mean([pred_labels[i] for i in res_num], axis=0)
final_pred_label = np.exp(
    np.mean(np.log([pred_labels[i] for i in res_num]), axis=0))
#local_auc = roc_auc_score(y_test, final_pred_label)
print("本地测试集前", n, "个auc为", [
      list(info_df['local_test_auc'])[i] for i in res_num], sep="")
print("平均之后local_test_AUC为", max_auc, sep="")

res = pd.DataFrame({
    'cust_id': list(df_test["cust_id"]),
    'label': final_pred_label,
})
res.to_csv("./output/result"+date+".csv", encoding="utf-8", index=False)
# Out:
# 本地测试集前26个auc为[0.7791712636690459, 0.7822484407718462, 0.779741667229565, 0.7977994431059974, 0.788162625057228, 0.7886129436576378, 0.7911572437499531, 0.7939191978324665, 0.7903091437191814, 0.7784432485983834, 0.7826237062721876, 0.799585706887623, 0.7814528779111222, 0.7824060522819897, 0.7881250985071937, 0.7645884463257754, 0.7915475198703082, 0.771140581961738, 0.7956979563040851, 0.7855057453148102, 0.7862337603854728, 0.7662546251472917, 0.7946246969731086, 0.7850404160943867, 0.79116474905996, 0.7840872417235193]
# 平均之后local_test_AUC为0.8031357185208535

# %%
plt.figure(figsize=(10, 6), dpi=200)
plt.plot(list(range(len(auc_seq))), auc_seq)

# %% [markdown]
# # 一些tips
#
# * 提升n有一定提升(如何确定n？)
#   * n=40 0.6763
#   * n=10 0.6728
#   * n=100 0.6774
#   * 太大也不好
#
# # 一些进展
#
# * 随机参数
# * XGB模型
# * 本地测试集auc较高（0.75+）
# * 部分类型变量进行了one-hot处理
# * 把细分表除了loan与主表合并
#
# # tbd
#
# * 处理细分表的loan，给出指标
# * 确定变量类型，以便对所有（or重要）分类变量进行one-hot处理
# * 新模型？

# %% [markdown]
# ## 10-12
# * 0.6824（这次我留了代码\doge）
# * 把-99变为-1，本地有提升
# * 划出了一个本地测试集
#   * 本地测试集（固定）d_localtest
#   * 训练集（固定）
#     * 评估集（每次的模型不同）dtest
#     * 真正的训练集（每次的模型不同）dtrain
# * 添加参数nan_num（然并卵）
# * tbd
#   * 找特征
#   * 加x
#   * 分析一下参数作用
# ## 10-18
# * 不能把industry之类种类很多的分类变量做证据权重

# %% [markdown]
# # 记录
# * 1014-4
#   * 0.6823
#   * 证据权重
#   * 未添加贷款记录表
#   * 按test auc排序
# * 1014-5
#   * 0.6925
#   * 按local test auc排序
# * 1015-1
#   * 0.6834
#   * 处理-99
# * 1015-2
#   * 0.6628
#   * 添加贷款记录表
# * 1015-3
#   * 0.6772
#   * 不处理-99
#   * 去除贷款记录表
#   * 添加了type-col
# * 1015-4
#   * 0.6811
#   * 不做证据权重
# * 1015-5
#   * 0.6765
#   * gamma=0
# * 1016-1
#   * 0.6798
#   * 添加gamma
#   * 增大early stop round
# * 1016-2
#   * 0.6858
#   * early stop round=10
#   * 证据权重
# * 1016-3
#   * 0.685799
#   * 使用原始type-col
# * 1017-2
#   * 0.6655
