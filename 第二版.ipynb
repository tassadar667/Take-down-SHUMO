# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 数据读入

# %%
import pandas as pd

train_data = pd.read_csv("data\main\df_train_b1.csv", index_col=0)
test_data = pd.read_csv('data\main\df_test_b1.csv', index_col=0)

# %% [markdown]
# ## 要读入除了main之外的数在此处添加

# %%
import os
filenames = ["data\detail\df_basic_b1.csv",
             "data\detail\df_corp_b1.csv",
             "data\detail\df_judicial_b1.csv",
             "data\detail\df_loan2_b1.csv",
             "data\detail\df_query_b1.csv"
             ]
for filename in filenames:
    temp = pd.read_csv(filename)
    train_data = pd.merge(train_data, temp, on="cust_id",
                          how="left", suffixes=("", "_y"))
    test_data = pd.merge(test_data, temp, on="cust_id",
                         how="left", suffixes=("", "_y"))

# %%
train_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in train_data['judicial_reason']]
test_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in test_data['judicial_reason']]

# %%
# train_data['nan_num'] = (train_data == 0).astype(int).sum(axis=1)
# test_data['nan_num'] = (test_data == 0).astype(int).sum(axis=1)

# %%
# drop_col = ['basic_2',
#             'basic_3',
#             'basic_4',
#             'loan1_1',
#             'overdue_19',
#             'basic_8',
#             'basic_9',
#             'basic_11',
#             'basic_15',
#             'loan1_17',
#             'loan1_31', ]

# train_data.drop(drop_col, inplace=True, axis=1)
# test_data.drop(drop_col, inplace=True, axis=1)

# %% [markdown]
# ## loan1表

# %%
if True:

    import pandas as pd
    temp_df = pd.read_csv("./data/detail/df_loan1_b1.csv")

    def chuli_loan(df, colname, ways):
        cust_id = list(range(len(set(df['cust_id']))))
        res_df = pd.DataFrame({'cust_id': cust_id})

        if len(ways) == 0:
            return res_df
        if 'mean' in ways:
            res_df[colname+'_mean'] = df.groupby('cust_id')[colname].mean()
        if 'sum' in ways:
            res_df[colname+'_sum'] = df.groupby('cust_id')[colname].sum()
        if 'count' in ways:
            res_df[colname+'_count'] = df.groupby('cust_id')[colname].count()
        if 'std' in ways:
            res_df[colname+'_std'] = df.groupby('cust_id')[colname].std()
        if 'diff_std' in ways:
            res_df[colname+'_diff_std'] = df.groupby('cust_id')[colname].apply(
                lambda x: x.sort_values(ascending=True).diff()[2:].std())
        return res_df

    for colname in ['loan1_2', 'loan1_3', 'loan1_7', 'loan1_9']:
        df = chuli_loan(temp_df, colname, ('sum', 'std'))
        train_data = pd.merge(train_data, df, on="cust_id",
                              how="left", suffixes=("", "_y"))
        test_data = pd.merge(test_data, df, on="cust_id",
                             how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_3', ('count',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_1', ('std', 'diff_std'))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_10', ('mean',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_11', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_12', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    train_data.to_csv('./data/df_train.csv')
    test_data.to_csv('./data/df_test.csv')

# %%
# data = temp_df.dropna(axis=0,subset = ["date_1"])
# data['date2-date1'] = data['date_2'] - data['date_1']
# data['date3-date2'] = data['date_3'] - data['date_2']
# data['dateinterval_max'] = data[['date2-date1','date3-date2']].max(axis=1)
# data = data.groupby('cust_id').agg({'date_2':['count'],'date_3':['count'],'dateinterval_max':['mean']})
# train_data = pd.merge(train_data, data, on="cust_id",
#                           how="left", suffixes=("", "_y"))
# test_data = pd.merge(test_data, data, on="cust_id",
#                          how="left", suffixes=("", "_y"))

# %% [markdown]
# ## 处理NAN

# %%
def delnan(df):
    df = df.dropna(how="all", axis=1)  # 删除全是空值的列
    df = df.fillna(-99)
    return df

# %%
df_train = delnan(train_data)
df_test = delnan(test_data)

# %% [markdown]
# ## 处理-99

# %%
# df_train.replace(-99, -1, inplace=True)
# df_test.replace(-99, -1, inplace=True)

# %% [markdown]
# ## 主成分分析（效果不好）

# %%
# from sklearn.decomposition import PCA

# full_col_name = list(df_train.columns)
# pca_col=[i for i in full_col_name if "loan" in i]

# modelPCA=PCA(n_components=0.9)
# temp=modelPCA.fit_transform(df_train[pca_col])
# temp1=modelPCA.transform(df_test[pca_col])
# for i in range(temp.shape[1]):
#     df_train['loan_pca'+str(i)]=temp[:,i]
#     df_test['loan_pca'+str(i)]=temp1[:,i]

# %% [markdown]
# ## 处理分类变量

# %%
cat_way = "no"

# %% [markdown]
# ## 转化为one-hot编码（不宜采用）

# %%
def to_one_hot(df, colnames):
    df = pd.get_dummies(df, columns=colnames)
    return df

# %% [markdown]
# ## 类型计数

# %%
type_count_cols = ['industry', 'scope', 'basic_13']

# %%
# def type_count(cols):
#     global df_train, df_test
#     df1 = df_train[['cust_id']+cols]
#     df2 = df_test[['cust_id']+cols]
#     df = pd.concat([df1, df2], axis=0, ignore_index=True)
#     for i in cols:
#         temp_df = df.groupby(i)['cust_id'].count()
#         temp_df = pd.DataFrame({(i+"_num"): temp_df})
#         df = pd.merge(df, temp_df, on=i, how="left")
#         del df[i], df1[i], df2[i]
#     df_train = pd.merge(df_train, df, on="cust_id",
#                         how="left", suffixes=("", "_y"))
#     df_test = pd.merge(df_test, df, on="cust_id",
#                        how="left", suffixes=("", "_y"))


# type_count(type_count_cols)

# %% [markdown]
# ## 证据权重

# %%
import pandas as pd
import numpy as np


def cal_woe(df, df_no_label, x_cols, y_col):
    for i in x_cols:
        x_set = pd.unique(df[i])
        x1_set = pd.unique(df_no_label[i])
        for j in x1_set:
            if j not in x_set:
                df_no_label[i].replace(j, 0.03, inplace=True)
                print(i, j, '不存在')
        for j in x_set:
            woe = np.mean(df[df[i] == j][y_col])
            if woe >= 0.1:
                n = np.sum(df[df[i] == j][y_col])
                print(i, '列：', j, ' 共有', int(n/woe), '个,其中',
                      int(n), '个label为1,woe为', woe, sep="")
            df[i].replace(j, woe, inplace=True)
            df_no_label[i].replace(j, woe, inplace=True)
    return df, df_no_label

# %%
type_col = ["basic_1",
            "basic_10",
            "basic_12",
            "basic_14",
            "loan1_16",
            "loan1_20",
            "loan1_23",
            "loan1_25", ]

# df_train,df_test=cal_woe(df_train,df_test,type_col,"label")

# %%
if cat_way == "auto" or cat_way == "no":
    type_col = ["basic_1",
                "basic_10",
                "basic_12",
                "basic_14",
                "loan1_16",
                "loan1_20",
                "loan1_23",
                "loan1_25",
                "loan2_1_y",
                "query_2_y",
                "query_3_y",
                "query_4_y",
                "query_5_y",
                "query_6_y", ]
if cat_way == "manual":
    woe_col = ['basic_1',
               'basic_5',
               'basic_6',
               'basic_10',
               'loan1_16',
               'loan1_20',
               'loan1_25',
               'loan1_23',
               'loan1_32',
               'loan2_4',
               'loan2_6',
               'overdue_2',
               'overdue_20',
               'overdue_21',
               'overdue_26',
               'overdue_27',
               'query_1',
               'query_2',
               'query_3',
               'query_4',
               'query_6',
               'query_7',
               'query_8',
               'query_10',
               'query_11', ]

    onehot_col = ['basic_12',
                  'basic_14',
                  'loan1_8',
                  'loan1_9',
                  'overdue_1',
                  'overdue_3',
                  'overdue_4',
                  'overdue_5',
                  'overdue_6',
                  'overdue_7',
                  'overdue_8',
                  'overdue_9',
                  'overdue_10',
                  'overdue_11',
                  'overdue_12',
                  'overdue_14',
                  'overdue_15',
                  'overdue_16',
                  'overdue_17',
                  'overdue_18',
                  'overdue_22',
                  'overdue_23',
                  'overdue_24',
                  'overdue_25',
                  'overdue_28',
                  'overdue_29',
                  'query_5',
                  'query_9', ]

    df_train, df_test = cal_woe(df_train, df_test, woe_col, "label")
    df_train = to_one_hot(df_train, onehot_col)
    df_test = to_one_hot(df_test, onehot_col)
    for i in df_train.columns:
        if i not in df_test.columns:
            df_test[i] = 0

# %%
full_col_name = list(df_train.columns)
basic_col = [i for i in full_col_name if "basic" in i]
loan_col = [i for i in full_col_name if "loan" in i]
overdue_col = [i for i in full_col_name if "overdue" in i]
query_col = [i for i in full_col_name if "query" in i]
judicial_col = [i for i in full_col_name if "judicial" in i]
date_col = [i for i in full_col_name if "date" in i]
# loan_pca_col = [i for i in full_col_name if "loan_pca" in i]

# for i in judicial_col:
#     df_train[i].astype("float")
#     df_test[i].astype("float")

# %% [markdown]
# ## rank化

# %%
def rank(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = np.argsort(df[i])
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


a = ['loan1_1', 'loan1_3', 'loan1_7', 'loan1_9']
b = ['_sum', '_mean']
c = []
for i in a:
    for j in b:
        c.append(i+j)
# rank(c)

# %% [markdown]
# ## 归一化

# %%
def norm(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.min(df[i]))/(np.max(df[i])-np.min(df[i]))
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# norm([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 标准化

# %%
def stand(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.mean(df[i], axis=0))/np.std(df[i], axis=0)
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# stand([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 设置哪些x作为模型自变量输入

# %%
# x_col = basic_col+loan_col+['nan_num'] + ['is_judicial']+ overdue_col+query_col
# x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col+['scope_num'] + \
#     ['industry_num']+['date_3_count', 'date_1_std', 'date_1_diff_std']

x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col
x_col = [i for i in x_col if i in full_col_name]

if cat_way == "auto":
    type_col = [i for i in type_col if i in x_col]
# categorize(df_train,type_col)
# categorize(df_test,type_col)

print('自变量个数为', len(x_col))
print(x_col)
# Out:
# 自变量个数为 123
# ['basic_1', 'basic_2', 'basic_3', 'basic_4', 'basic_5', 'basic_6', 'basic_7', 'basic_8', 'basic_9', 'basic_10', 'basic_11', 'basic_12', 'basic_13', 'basic_14', 'basic_15', 'basic_1_y', 'basic_2_y', 'basic_3_y', 'is_judicial', 'loan1_1', 'loan1_2', 'loan1_3', 'loan1_4', 'loan1_5', 'loan1_6', 'loan1_7', 'loan1_8', 'loan1_9', 'loan1_10', 'loan1_11', 'loan1_12', 'loan1_13', 'loan1_14', 'loan1_15', 'loan1_16', 'loan1_17', 'loan1_18', 'loan1_19', 'loan1_20', 'loan1_21', 'loan1_22', 'loan1_23', 'loan1_24', 'loan1_25', 'loan1_26', 'loan1_27', 'loan1_28', 'loan1_29', 'loan1_30', 'loan1_31', 'loan1_32', 'loan1_33', 'loan2_1', 'loan2_2', 'loan2_3', 'loan2_4', 'loan2_5', 'loan2_6', 'loan2_7', 'loan2_8', 'loan2_9', 'loan2_10', 'loan2_11', 'loan2_12', 'loan2_1_y', 'loan2_2_y', 'loan2_3_y', 'loan2_4_y', 'loan2_5_y', 'loan1_2_sum', 'loan1_2_std', 'loan1_3_sum', 'loan1_3_std', 'loan1_7_sum', 'loan1_7_std', 'loan1_9_sum', 'loan1_9_std', 'query_1', 'query_2', 'query_3', 'query_4', 'query_5', 'query_6', 'query_7', 'query_8', 'query_9', 'query_10', 'query_11', 'query_1_y', 'query_2_y', 'query_3_y', 'query_4_y', 'query_5_y', 'query_6_y', 'overdue_1', 'overdue_2', 'overdue_3', 'overdue_4', 'overdue_5', 'overdue_6', 'overdue_7', 'overdue_8', 'overdue_9', 'overdue_10', 'overdue_11', 'overdue_12', 'overdue_13', 'overdue_14', 'overdue_15', 'overdue_16', 'overdue_17', 'overdue_18', 'overdue_19', 'overdue_20', 'overdue_21', 'overdue_22', 'overdue_23', 'overdue_24', 'overdue_25', 'overdue_26', 'overdue_27', 'overdue_28', 'overdue_29']

# %%
df_train = df_train[x_col+['label', 'cust_id']]
df_test = df_test[x_col+['cust_id']]

df_test.to_csv("test_input.csv", encoding='utf-8')

# %% [markdown]
# ## 对抗验证

# %%
from sklearn import model_selection
import xgboost as xgb

df_full = pd.concat([df_train[x_col+['cust_id']], df_test],
                    axis=0, ignore_index=True)
df_full['label_test'] = [1 if i in df_test['cust_id']
                         else 0 for i in df_full['cust_id']]

df_full.to_csv("full.csv", encoding='utf-8')

# %%
X = df_full[x_col+['cust_id']]
Y = df_full['label_test']

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(
    X, Y, test_size=0.5, stratify=Y, random_state=2022)

dtrain = xgb.DMatrix(X_train[x_col], label=Y_train)
dtest = xgb.DMatrix(X_test[x_col], label=Y_test)

param = {'max_depth': 5,
         'eta': 0.1,
         'objective': 'binary:logistic',
         "eval_metric": "auc",
         "scale_pos_weight": 1,
         "subsample": 1,
         "min_child_weight": 1,
         'tree_method': 'gpu_hist',
         'gpu_id': 0, }

bst = xgb.train(param, dtrain, 4000, evals=[(dtrain, "train"), (dtest, "test")],
                early_stopping_rounds=300, verbose_eval=True)
bst1 = xgb.train(param, dtest, 4000, evals=[(dtest, "train"), (dtrain, "test")],
                 early_stopping_rounds=300, verbose_eval=False)
# Out:
# [0]	train-auc:0.54199	test-auc:0.49115
# [1]	train-auc:0.54641	test-auc:0.48996
# [2]	train-auc:0.55736	test-auc:0.48898
# [3]	train-auc:0.56898	test-auc:0.49025
# [4]	train-auc:0.57216	test-auc:0.49097
# [5]	train-auc:0.58084	test-auc:0.49245
# [6]	train-auc:0.61076	test-auc:0.49788
# [7]	train-auc:0.62092	test-auc:0.49896
# [8]	train-auc:0.62901	test-auc:0.49922
# [9]	train-auc:0.63751	test-auc:0.49671
# [10]	train-auc:0.64666	test-auc:0.49628
# [11]	train-auc:0.66433	test-auc:0.50200
# [12]	train-auc:0.66823	test-auc:0.50229
# [13]	train-auc:0.67630	test-auc:0.50317
# [14]	train-auc:0.68294	test-auc:0.50264
# [15]	train-auc:0.69102	test-auc:0.50013
# [16]	train-auc:0.69619	test-auc:0.50097
# [17]	train-auc:0.70326	test-auc:0.50023
# [18]	train-auc:0.70676	test-auc:0.49890
# [19]	train-auc:0.71096	test-auc:0.49815
# [20]	train-auc:0.71642	test-auc:0.49835
# [21]	train-auc:0.72388	test-auc:0.49991
# [22]	train-auc:0.72650	test-auc:0.50024
# [23]	train-auc:0.73699	test-auc:0.49778
# [24]	train-auc:0.74021	test-auc:0.49736
# [25]	train-auc:0.74278	test-auc:0.49814
# [26]	train-auc:0.74592	test-auc:0.49677
# [27]	train-auc:0.75079	test-auc:0.49582
# [28]	train-auc:0.75401	test-auc:0.49596
# [29]	train-auc:0.75865	test-auc:0.49587
# [30]	train-auc:0.76110	test-auc:0.49677
# [31]	train-auc:0.76789	test-auc:0.49837
# [32]	train-auc:0.77104	test-auc:0.49836
# [33]	train-auc:0.77204	test-auc:0.49872
# [34]	train-auc:0.77194	test-auc:0.49885
# [35]	train-auc:0.77778	test-auc:0.49893
# [36]	train-auc:0.78192	test-auc:0.49902
# [37]	train-auc:0.78556	test-auc:0.50001
# [38]	train-auc:0.78695	test-auc:0.50021
# [39]	train-auc:0.79049	test-auc:0.50053
# [40]	train-auc:0.79596	test-auc:0.49990
# [41]	train-auc:0.79825	test-auc:0.49955
# [42]	train-auc:0.80116	test-auc:0.49994
# [43]	train-auc:0.80211	test-auc:0.50068
# [44]	train-auc:0.80273	test-auc:0.50053
# [45]	train-auc:0.80238	test-auc:0.50024
# [46]	train-auc:0.80497	test-auc:0.49971
# [47]	train-auc:0.80548	test-auc:0.49994
# [48]	train-auc:0.80553	test-auc:0.49989
# [49]	train-auc:0.80611	test-auc:0.50024
# [50]	train-auc:0.80719	test-auc:0.50106
# [51]	train-auc:0.81196	test-auc:0.50283
# [52]	train-auc:0.81257	test-auc:0.50213
# [53]	train-auc:0.81481	test-auc:0.50214
# [54]	train-auc:0.81768	test-auc:0.50283
# [55]	train-auc:0.82105	test-auc:0.50242
# [56]	train-auc:0.82149	test-auc:0.50165
# [57]	train-auc:0.82176	test-auc:0.50195
# [58]	train-auc:0.82271	test-auc:0.50239
# [59]	train-auc:0.82369	test-auc:0.50231
# [60]	train-auc:0.82455	test-auc:0.50228
# [61]	train-auc:0.82727	test-auc:0.50320
# [62]	train-auc:0.83109	test-auc:0.50276
# [63]	train-auc:0.83254	test-auc:0.50272
# [64]	train-auc:0.83502	test-auc:0.50167
# [65]	train-auc:0.83632	test-auc:0.50190
# [66]	train-auc:0.83945	test-auc:0.50282
# [67]	train-auc:0.84181	test-auc:0.50347
# [68]	train-auc:0.84203	test-auc:0.50341
# [69]	train-auc:0.84292	test-auc:0.50367
# [70]	train-auc:0.84657	test-auc:0.50444
# [71]	train-auc:0.84839	test-auc:0.50453
# [72]	train-auc:0.84820	test-auc:0.50473
# [73]	train-auc:0.84982	test-auc:0.50424
# [74]	train-auc:0.85418	test-auc:0.50394
# [75]	train-auc:0.85514	test-auc:0.50343
# [76]	train-auc:0.85612	test-auc:0.50373
# [77]	train-auc:0.85718	test-auc:0.50393
# [78]	train-auc:0.85754	test-auc:0.50322
# [79]	train-auc:0.86055	test-auc:0.50167
# [80]	train-auc:0.86237	test-auc:0.50214
# [81]	train-auc:0.86228	test-auc:0.50240
# [82]	train-auc:0.86296	test-auc:0.50184
# [83]	train-auc:0.86339	test-auc:0.50119
# [84]	train-auc:0.86372	test-auc:0.50151
# [85]	train-auc:0.86607	test-auc:0.50063
# [86]	train-auc:0.86657	test-auc:0.50084
# [87]	train-auc:0.86831	test-auc:0.50040
# [88]	train-auc:0.87011	test-auc:0.50133
# [89]	train-auc:0.87029	test-auc:0.50154
# [90]	train-auc:0.87111	test-auc:0.50184
# [91]	train-auc:0.87115	test-auc:0.50191
# [92]	train-auc:0.87146	test-auc:0.50178
# [93]	train-auc:0.87257	test-auc:0.50226
# [94]	train-auc:0.87408	test-auc:0.50168
# [95]	train-auc:0.87431	test-auc:0.50184
# [96]	train-auc:0.87492	test-auc:0.50120
# [97]	train-auc:0.87531	test-auc:0.50139
# [98]	train-auc:0.87579	test-auc:0.50180
# [99]	train-auc:0.87622	test-auc:0.50209
# [100]	train-auc:0.87932	test-auc:0.50224
# [101]	train-auc:0.87985	test-auc:0.50194
# [102]	train-auc:0.88072	test-auc:0.50144
# [103]	train-auc:0.88099	test-auc:0.50132
# [104]	train-auc:0.88122	test-auc:0.50125
# [105]	train-auc:0.88139	test-auc:0.50139
# [106]	train-auc:0.88141	test-auc:0.50122
# [107]	train-auc:0.88216	test-auc:0.50151
# [108]	train-auc:0.88214	test-auc:0.50122
# [109]	train-auc:0.88337	test-auc:0.50145
# [110]	train-auc:0.88562	test-auc:0.50110
# [111]	train-auc:0.88598	test-auc:0.50120
# [112]	train-auc:0.88854	test-auc:0.50132
# [113]	train-auc:0.89123	test-auc:0.50180
# [114]	train-auc:0.89185	test-auc:0.50153
# [115]	train-auc:0.89372	test-auc:0.50151
# [116]	train-auc:0.89608	test-auc:0.50173
# [117]	train-auc:0.89730	test-auc:0.50099
# [118]	train-auc:0.89729	test-auc:0.50067
# [119]	train-auc:0.89792	test-auc:0.50101
# [120]	train-auc:0.89857	test-auc:0.50163
# [121]	train-auc:0.89905	test-auc:0.50149
# [122]	train-auc:0.89913	test-auc:0.50137
# [123]	train-auc:0.90067	test-auc:0.50157
# [124]	train-auc:0.90074	test-auc:0.50182
# [125]	train-auc:0.90106	test-auc:0.50168
# [126]	train-auc:0.90322	test-auc:0.50206
# [127]	train-auc:0.90313	test-auc:0.50243
# [128]	train-auc:0.90449	test-auc:0.50286
# [129]	train-auc:0.90573	test-auc:0.50283
# [130]	train-auc:0.90602	test-auc:0.50244
# [131]	train-auc:0.90625	test-auc:0.50252
# [132]	train-auc:0.90709	test-auc:0.50183
# [133]	train-auc:0.90920	test-auc:0.50155
# [134]	train-auc:0.91101	test-auc:0.50209
# [135]	train-auc:0.91185	test-auc:0.50223
# [136]	train-auc:0.91303	test-auc:0.50176
# [137]	train-auc:0.91303	test-auc:0.50186
# [138]	train-auc:0.91341	test-auc:0.50167
# [139]	train-auc:0.91584	test-auc:0.50149
# [140]	train-auc:0.91603	test-auc:0.50145
# [141]	train-auc:0.91600	test-auc:0.50095
# [142]	train-auc:0.91884	test-auc:0.50104
# [143]	train-auc:0.91980	test-auc:0.50054
# [144]	train-auc:0.91999	test-auc:0.50049
# [145]	train-auc:0.92193	test-auc:0.49979
# [146]	train-auc:0.92316	test-auc:0.49956
# [147]	train-auc:0.92414	test-auc:0.49970
# [148]	train-auc:0.92473	test-auc:0.49965
# [149]	train-auc:0.92520	test-auc:0.49978
# [150]	train-auc:0.92714	test-auc:0.49903
# [151]	train-auc:0.92836	test-auc:0.49994
# [152]	train-auc:0.92842	test-auc:0.49988
# [153]	train-auc:0.92935	test-auc:0.50011
# [154]	train-auc:0.93030	test-auc:0.49996
# [155]	train-auc:0.93027	test-auc:0.49974
# [156]	train-auc:0.93028	test-auc:0.49994
# [157]	train-auc:0.93077	test-auc:0.49957
# [158]	train-auc:0.93107	test-auc:0.49956
# [159]	train-auc:0.93127	test-auc:0.49970
# [160]	train-auc:0.93133	test-auc:0.49954
# [161]	train-auc:0.93303	test-auc:0.50002
# [162]	train-auc:0.93461	test-auc:0.50014
# [163]	train-auc:0.93568	test-auc:0.49963
# [164]	train-auc:0.93628	test-auc:0.49999
# [165]	train-auc:0.93724	test-auc:0.49953
# [166]	train-auc:0.93805	test-auc:0.49987
# [167]	train-auc:0.93902	test-auc:0.49986
# [168]	train-auc:0.93920	test-auc:0.49999
# [169]	train-auc:0.93982	test-auc:0.50010
# [170]	train-auc:0.94070	test-auc:0.50012
# [171]	train-auc:0.94127	test-auc:0.50058
# [172]	train-auc:0.94182	test-auc:0.50083
# [173]	train-auc:0.94228	test-auc:0.50121
# [174]	train-auc:0.94244	test-auc:0.50144
# [175]	train-auc:0.94375	test-auc:0.50100
# [176]	train-auc:0.94474	test-auc:0.50046
# [177]	train-auc:0.94507	test-auc:0.50057
# [178]	train-auc:0.94514	test-auc:0.50026
# [179]	train-auc:0.94556	test-auc:0.50041
# [180]	train-auc:0.94627	test-auc:0.50053
# [181]	train-auc:0.94677	test-auc:0.50044
# [182]	train-auc:0.94758	test-auc:0.50040
# [183]	train-auc:0.94796	test-auc:0.50096
# [184]	train-auc:0.94821	test-auc:0.50146
# [185]	train-auc:0.94894	test-auc:0.50097
# [186]	train-auc:0.94900	test-auc:0.50083
# [187]	train-auc:0.94907	test-auc:0.50070
# [188]	train-auc:0.94939	test-auc:0.50037
# [189]	train-auc:0.94957	test-auc:0.50062
# [190]	train-auc:0.94972	test-auc:0.50055
# [191]	train-auc:0.94977	test-auc:0.50060
# [192]	train-auc:0.95025	test-auc:0.50095
# [193]	train-auc:0.95036	test-auc:0.50102
# [194]	train-auc:0.95044	test-auc:0.50089
# [195]	train-auc:0.95051	test-auc:0.50085
# [196]	train-auc:0.95133	test-auc:0.50052
# [197]	train-auc:0.95143	test-auc:0.50033
# [198]	train-auc:0.95247	test-auc:0.50079
# [199]	train-auc:0.95332	test-auc:0.50133
# [200]	train-auc:0.95391	test-auc:0.50134
# [201]	train-auc:0.95469	test-auc:0.50180
# [202]	train-auc:0.95498	test-auc:0.50107
# [203]	train-auc:0.95560	test-auc:0.50129
# [204]	train-auc:0.95633	test-auc:0.50144
# [205]	train-auc:0.95702	test-auc:0.50141
# [206]	train-auc:0.95710	test-auc:0.50160
# [207]	train-auc:0.95722	test-auc:0.50144
# [208]	train-auc:0.95743	test-auc:0.50198
# [209]	train-auc:0.95753	test-auc:0.50187
# [210]	train-auc:0.95796	test-auc:0.50202
# [211]	train-auc:0.95867	test-auc:0.50167
# [212]	train-auc:0.95913	test-auc:0.50168
# [213]	train-auc:0.95959	test-auc:0.50193
# [214]	train-auc:0.95966	test-auc:0.50195
# [215]	train-auc:0.95961	test-auc:0.50189
# [216]	train-auc:0.95981	test-auc:0.50186
# [217]	train-auc:0.96003	test-auc:0.50200
# [218]	train-auc:0.96025	test-auc:0.50187
# [219]	train-auc:0.96047	test-auc:0.50197
# [220]	train-auc:0.96057	test-auc:0.50188
# [221]	train-auc:0.96072	test-auc:0.50230
# [222]	train-auc:0.96117	test-auc:0.50199
# [223]	train-auc:0.96179	test-auc:0.50198
# [224]	train-auc:0.96182	test-auc:0.50235
# [225]	train-auc:0.96184	test-auc:0.50235
# [226]	train-auc:0.96191	test-auc:0.50254
# [227]	train-auc:0.96246	test-auc:0.50216
# [228]	train-auc:0.96284	test-auc:0.50170
# [229]	train-auc:0.96306	test-auc:0.50187
# [230]	train-auc:0.96319	test-auc:0.50199
# [231]	train-auc:0.96320	test-auc:0.50174
# [232]	train-auc:0.96350	test-auc:0.50217
# [233]	train-auc:0.96379	test-auc:0.50222
# [234]	train-auc:0.96389	test-auc:0.50206
# [235]	train-auc:0.96392	test-auc:0.50208
# [236]	train-auc:0.96460	test-auc:0.50164
# [237]	train-auc:0.96557	test-auc:0.50182
# [238]	train-auc:0.96582	test-auc:0.50187
# [239]	train-auc:0.96614	test-auc:0.50172
# [240]	train-auc:0.96647	test-auc:0.50141
# [241]	train-auc:0.96677	test-auc:0.50128
# [242]	train-auc:0.96741	test-auc:0.50112
# [243]	train-auc:0.96760	test-auc:0.50086
# [244]	train-auc:0.96822	test-auc:0.50114
# [245]	train-auc:0.96879	test-auc:0.50094
# [246]	train-auc:0.96907	test-auc:0.50112
# [247]	train-auc:0.96939	test-auc:0.50102
# [248]	train-auc:0.96939	test-auc:0.50095
# [249]	train-auc:0.96937	test-auc:0.50095
# [250]	train-auc:0.96938	test-auc:0.50104
# [251]	train-auc:0.96949	test-auc:0.50109
# [252]	train-auc:0.96973	test-auc:0.50170
# [253]	train-auc:0.97018	test-auc:0.50207
# [254]	train-auc:0.97022	test-auc:0.50197
# [255]	train-auc:0.97070	test-auc:0.50191
# [256]	train-auc:0.97071	test-auc:0.50195
# [257]	train-auc:0.97094	test-auc:0.50182
# [258]	train-auc:0.97122	test-auc:0.50155
# [259]	train-auc:0.97138	test-auc:0.50186
# [260]	train-auc:0.97161	test-auc:0.50190
# [261]	train-auc:0.97180	test-auc:0.50196
# [262]	train-auc:0.97194	test-auc:0.50215
# [263]	train-auc:0.97214	test-auc:0.50233
# [264]	train-auc:0.97216	test-auc:0.50239
# [265]	train-auc:0.97231	test-auc:0.50225
# [266]	train-auc:0.97229	test-auc:0.50214
# [267]	train-auc:0.97345	test-auc:0.50222
# [268]	train-auc:0.97365	test-auc:0.50174
# [269]	train-auc:0.97369	test-auc:0.50188
# [270]	train-auc:0.97407	test-auc:0.50195
# [271]	train-auc:0.97421	test-auc:0.50179
# [272]	train-auc:0.97437	test-auc:0.50183
# [273]	train-auc:0.97436	test-auc:0.50179
# [274]	train-auc:0.97437	test-auc:0.50173
# [275]	train-auc:0.97451	test-auc:0.50142
# [276]	train-auc:0.97482	test-auc:0.50156
# [277]	train-auc:0.97523	test-auc:0.50205
# [278]	train-auc:0.97528	test-auc:0.50210
# [279]	train-auc:0.97534	test-auc:0.50213
# [280]	train-auc:0.97532	test-auc:0.50226
# [281]	train-auc:0.97552	test-auc:0.50203
# [282]	train-auc:0.97589	test-auc:0.50207
# [283]	train-auc:0.97590	test-auc:0.50214
# [284]	train-auc:0.97591	test-auc:0.50210
# [285]	train-auc:0.97619	test-auc:0.50168
# [286]	train-auc:0.97634	test-auc:0.50190
# [287]	train-auc:0.97646	test-auc:0.50180
# [288]	train-auc:0.97652	test-auc:0.50193
# [289]	train-auc:0.97652	test-auc:0.50189
# [290]	train-auc:0.97670	test-auc:0.50196
# [291]	train-auc:0.97674	test-auc:0.50203
# [292]	train-auc:0.97698	test-auc:0.50193
# [293]	train-auc:0.97698	test-auc:0.50189
# [294]	train-auc:0.97708	test-auc:0.50199
# [295]	train-auc:0.97723	test-auc:0.50232
# [296]	train-auc:0.97725	test-auc:0.50226
# [297]	train-auc:0.97730	test-auc:0.50225
# [298]	train-auc:0.97743	test-auc:0.50195
# [299]	train-auc:0.97747	test-auc:0.50188
# [300]	train-auc:0.97776	test-auc:0.50185
# [301]	train-auc:0.97812	test-auc:0.50157
# [302]	train-auc:0.97816	test-auc:0.50159
# [303]	train-auc:0.97822	test-auc:0.50154
# [304]	train-auc:0.97863	test-auc:0.50148
# [305]	train-auc:0.97888	test-auc:0.50139
# [306]	train-auc:0.97895	test-auc:0.50162
# [307]	train-auc:0.97901	test-auc:0.50151
# [308]	train-auc:0.97905	test-auc:0.50158
# [309]	train-auc:0.97911	test-auc:0.50168
# [310]	train-auc:0.97941	test-auc:0.50196
# [311]	train-auc:0.97949	test-auc:0.50170
# [312]	train-auc:0.97971	test-auc:0.50142
# [313]	train-auc:0.97993	test-auc:0.50139
# [314]	train-auc:0.98030	test-auc:0.50153
# [315]	train-auc:0.98053	test-auc:0.50155
# [316]	train-auc:0.98085	test-auc:0.50146
# [317]	train-auc:0.98138	test-auc:0.50133
# [318]	train-auc:0.98172	test-auc:0.50127
# [319]	train-auc:0.98179	test-auc:0.50122
# [320]	train-auc:0.98198	test-auc:0.50167
# [321]	train-auc:0.98212	test-auc:0.50149
# [322]	train-auc:0.98248	test-auc:0.50165
# [323]	train-auc:0.98262	test-auc:0.50158
# [324]	train-auc:0.98268	test-auc:0.50176
# [325]	train-auc:0.98281	test-auc:0.50170
# [326]	train-auc:0.98291	test-auc:0.50166
# [327]	train-auc:0.98303	test-auc:0.50153
# [328]	train-auc:0.98314	test-auc:0.50200
# [329]	train-auc:0.98343	test-auc:0.50176
# [330]	train-auc:0.98347	test-auc:0.50191
# [331]	train-auc:0.98372	test-auc:0.50184
# [332]	train-auc:0.98379	test-auc:0.50198
# [333]	train-auc:0.98385	test-auc:0.50210
# [334]	train-auc:0.98392	test-auc:0.50194
# [335]	train-auc:0.98418	test-auc:0.50168
# [336]	train-auc:0.98427	test-auc:0.50161
# [337]	train-auc:0.98428	test-auc:0.50150
# [338]	train-auc:0.98450	test-auc:0.50162
# [339]	train-auc:0.98474	test-auc:0.50175
# [340]	train-auc:0.98499	test-auc:0.50194
# [341]	train-auc:0.98504	test-auc:0.50191
# [342]	train-auc:0.98527	test-auc:0.50186
# [343]	train-auc:0.98537	test-auc:0.50207
# [344]	train-auc:0.98548	test-auc:0.50208
# [345]	train-auc:0.98568	test-auc:0.50206
# [346]	train-auc:0.98587	test-auc:0.50209
# [347]	train-auc:0.98599	test-auc:0.50227
# [348]	train-auc:0.98601	test-auc:0.50250
# [349]	train-auc:0.98615	test-auc:0.50287
# [350]	train-auc:0.98618	test-auc:0.50275
# [351]	train-auc:0.98642	test-auc:0.50306
# [352]	train-auc:0.98646	test-auc:0.50299
# [353]	train-auc:0.98666	test-auc:0.50288
# [354]	train-auc:0.98687	test-auc:0.50297
# [355]	train-auc:0.98687	test-auc:0.50290
# [356]	train-auc:0.98682	test-auc:0.50285
# [357]	train-auc:0.98704	test-auc:0.50235
# [358]	train-auc:0.98714	test-auc:0.50245
# [359]	train-auc:0.98721	test-auc:0.50234
# [360]	train-auc:0.98734	test-auc:0.50222
# [361]	train-auc:0.98742	test-auc:0.50176
# [362]	train-auc:0.98765	test-auc:0.50171
# [363]	train-auc:0.98770	test-auc:0.50207
# [364]	train-auc:0.98773	test-auc:0.50204
# [365]	train-auc:0.98791	test-auc:0.50219
# [366]	train-auc:0.98801	test-auc:0.50210
# [367]	train-auc:0.98803	test-auc:0.50206
# [368]	train-auc:0.98804	test-auc:0.50213
# [369]	train-auc:0.98833	test-auc:0.50202
# [370]	train-auc:0.98840	test-auc:0.50191
# [371]	train-auc:0.98844	test-auc:0.50173

# %%
df_res = pd.DataFrame(
    {'cust_id': X_test['cust_id'], 'p_test': bst.predict(dtest)})
df_res1 = pd.DataFrame(
    {'cust_id': X_train['cust_id'], 'p_test': bst1.predict(dtrain)})

df = pd.concat([df_res, df_res1], axis=0, ignore_index=True)

df_train = pd.merge(df_train, df, on="cust_id",
                    how="left", suffixes=("", "_y"))

# %%
temp = len(df_train)
df_train.to_csv("train_input.csv", encoding='utf-8')

df_train = df_train[df_train['p_test'] >= 0.1]


print("经过对抗验证，有", len(df_train), "条数据被保留，",
      temp-len(df_train), "条数据被抛弃", sep="")
# Out:
# 经过对抗验证，有15508条数据被保留，2491条数据被抛弃

# %% [markdown]
# # 训练模型

# %% [markdown]
# ## 超参数

# %%
N = 60
num_round = 3000
local_test_size = 2000

# 共用
test_size = [0.2, 0.25, 0.3]
max_depth = [3, 4, 5]
subsample = [0.8, 0.75, 0.7, 0.65, 0.6]
early_stopping_rounds = 150

# XGB
eta = [0.007, 0.01]

# LGB
learning_rate = [0.03, 0.02, 0.025]

# %% [markdown]
# ### train划分为
# * 本地测试集（固定）d_localtest
# * 训练集（固定）
#   * 评估集（每次的模型不同）dtest
#   * 真正的训练集（每次的模型不同）dtrain

# %%
import copy
import xgboost as xgb
import random
from sklearn import model_selection
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from catboost import CatBoostClassifier


pred_labels = []
local_test_labels = []
loss_seq = []
max_auc_loss = 0
flag = 0
important_x_seq = []


d_full = xgb.DMatrix(df_train[x_col], label=df_train['label'])
X = df_train[x_col]
Y = df_train['label']

X, X_local_test, Y, Y_local_test = model_selection.train_test_split(
    X, Y, test_size=local_test_size, stratify=Y, random_state=2022)

d_localtest = xgb.DMatrix(X_local_test, label=Y_local_test)
x_perd = xgb.DMatrix(df_test[x_col])

d_localtest1 = lgb.Dataset(X_local_test, Y_local_test)
x_perd1 = lgb.Dataset(df_test[x_col])


lgbcallback = [early_stopping(early_stopping_rounds), log_evaluation(10000)]

# %%
for i in range(N):

    test_size_this_round = random.choice(test_size)
    X_train, X_test, y_train, y_test = model_selection.train_test_split(
        X, Y, test_size=test_size_this_round, stratify=Y)

    # XGB-----------------------------------------------
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    evallist = [(dtest, 'eval')]
    param = {
        'max_depth': random.choice(max_depth),
        'eta': random.choice(eta),
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'subsample': random.choice(subsample),
        'tree_method': 'gpu_hist',
        'gpu_id': 0,
    }

    bst = xgb.train(param, dtrain, num_round, evals=evallist,
                    early_stopping_rounds=early_stopping_rounds, verbose_eval=False)

    loss = roc_auc_score(y_test, bst.predict(dtest))
    train_loss = roc_auc_score(y_train, bst.predict(dtrain))
    local_test_loss = roc_auc_score(Y_local_test, bst.predict(d_localtest))
    global_auc = roc_auc_score(df_train['label'], bst.predict(d_full))

    pred_label = list(bst.predict(x_perd))
    test_label = list(bst.predict(d_localtest))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'xgb'}

    if flag == 0:
        info_df = pd.DataFrame(temp_dict, index=[i])
        flag = 1
    else:
        info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])

    # if loss > max_auc_loss:
    #     best_bst = copy.deepcopy(bst)
    #     max_auc_loss = loss

    # if False:
    #     pic = xgb.plot_importance(bst, max_num_features=50)
    #     temp = pic.get_ymajorticklabels()
    #     important_x = [str(i).split("\'")[1] for i in temp]
    #     important_x.reverse()
    #     important_x_seq += important_x

    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    # LGB--------------------------------------------------------
    param = {
        'task': 'train',
        "max_depth": random.choice(max_depth),
        'max_bin': 128,
        'boosting_type': 'gbdt',  # 设置提升类型
        'objective': 'binary',  # 目标函数
        'metric': 'auc',  # 评估函数
        'learning_rate': random.choice(learning_rate),  # 学习速率
        'bagging_fraction': random.choice(subsample),  # 建树的样本采样比例
        'bagging_freq': 1,  # k 意味着每 k 次迭代执行bagging
        'min_data_in_leaf': 1,
        'verbose': -1,  # <0 显示致命的, =0 显示错误 (警告), >0 显示信息
        'device_type': 'gpu',
    }

    dtrain = lgb.Dataset(X_train, y_train)
    dtest = lgb.Dataset(X_test, y_test)

    if cat_way == "auto":
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback, categorical_feature=type_col)
    else:
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback)

    loss = roc_auc_score(y_test, bst1.predict(X_test))
    train_loss = roc_auc_score(y_train, bst1.predict(X_train))
    local_test_loss = roc_auc_score(Y_local_test, bst1.predict(X_local_test))
    global_auc = roc_auc_score(
        df_train['label'], bst1.predict(df_train[x_col]))

    pred_label = list(bst1.predict(df_test[x_col]))
    test_label = list(bst1.predict(X_local_test))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'lgb'}

    info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    # CAT-----------------------------------------------------------
    # bst2 = CatBoostClassifier(iterations=num_round,
    #                        depth=random.choice(max_depth),
    #                        learning_rate=random.choice(learning_rate),
    #                        loss_function='Logloss',
    #                        subsample=random.choice(subsample),
    #                        early_stopping_rounds=early_stopping_rounds,
    #                        verbose=False)
    # bst2.fit(X_train, y_train,eval_set=(X_test,y_test))

    # loss = roc_auc_score(y_test, bst2.predict_proba(X_test)[:,1])
    # train_loss = roc_auc_score(y_train, bst2.predict_proba(X_train)[:,1])
    # local_test_loss = roc_auc_score(Y_local_test, bst2.predict_proba(X_local_test)[:,1])
    # global_auc = roc_auc_score(df_train['label'], bst2.predict_proba(df_train[x_col])[:,1])

    # pred_label = list(bst2.predict_proba(df_test[x_col])[:,1])
    # test_label = list(bst2.predict_proba(X_local_test)[:,1])

    # temp_dict = {"test_auc": loss, "train_auc": train_loss,
    #              'local_test_auc': local_test_loss,
    #              'model': 'cat'}

    # info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    # pred_labels.append(copy.deepcopy(pred_label))
    # local_test_labels.append(copy.deepcopy(test_label))


print('最大AUC:', max(info_df['local_test_auc']), sep="")
# Out:
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [374]	valid_0's auc: 0.747495
# Early stopping, best iteration is:
# [400]	valid_0's auc: 0.762582
# Early stopping, best iteration is:
# [400]	valid_0's auc: 0.762582
# Early stopping, best iteration is:
# [400]	valid_0's auc: 0.762582
# Early stopping, best iteration is:
# [400]	valid_0's auc: 0.762582
# Early stopping, best iteration is:
# [400]	valid_0's auc: 0.762582
# Early stopping, best iteration is:
# [400]	valid_0's auc: 0.762582
# Early stopping, best iteration is:
# [400]	valid_0's auc: 0.762582
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# Early stopping, best iteration is:
# [791]	valid_0's auc: 0.79103
# 最大AUC:0.7597261287934863

# %%
info_df.to_csv("info.csv", encoding="utf-8", index=False)

# %%
# pic = xgb.plot_importance(bst, max_num_features=50)
# temp = pic.get_ymajorticklabels()
# important_x = [str(i).split("\'")[1] for i in temp]
# important_x.reverse()

# %%
# important_x

# %%
# pd.value_counts(important_x_seq)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6.5, 6), dpi=200)


plt.scatter(info_df[info_df['model'] == 'xgb']['local_test_auc'], info_df[info_df['model'] == 'xgb']['test_auc'],
            c='r', s=4, label="xgb")
plt.scatter(info_df[info_df['model'] == 'lgb']['local_test_auc'], info_df[info_df['model'] == 'lgb']['test_auc'],
            c='g', s=4, label="lgb")
# plt.scatter(info_df[info_df['model'] == 'cat']['local_test_auc'], info_df[info_df['model'] == 'cat']['test_auc'],
#             c='b', s=4,label="cat")
plt.legend()
plt.xlabel('local_test_auc')
plt.ylabel('test_auc')
plt.plot([0.6, 0.85], [0.6, 0.85])
plt.xlim(0.6, 0.85)
plt.ylim(0.6, 0.85)
plt.grid()
plt.show()

# %% [markdown]
# # 输出模块

# %%
import time
import numpy as np
from sklearn.metrics import roc_auc_score

date = time.strftime("%Y%m%d-%H%M%S", time.localtime())
res_num = np.argsort(
    [-i for i in (info_df['local_test_auc']+info_df['test_auc'])])

# 选择前n个结果进行平均（手动指定or在本地测试集排序选出）
if True:
    max_auc = -1
    list_temp = []
    auc_seq = []
    for i in range(N*2):
        list_temp.append(local_test_labels[res_num[i]])
        # 算数平均
        # temp = np.mean(list_temp, axis=0)
        # 几何平均(better)
        temp = np.exp(np.mean(np.log(list_temp), axis=0))
        temp_auc = roc_auc_score(Y_local_test, temp)
        # print(i, temp_auc)
        auc_seq.append(temp_auc)
        if temp_auc > max_auc:
            max_auc = temp_auc
            n = i+1
else:
    n = 40
    n = min(N, n)

res_num = res_num[0:n]

#final_pred_label = np.mean([pred_labels[i] for i in res_num], axis=0)
final_pred_label = np.exp(
    np.mean(np.log([pred_labels[i] for i in res_num]), axis=0))
#local_auc = roc_auc_score(y_test, final_pred_label)
print("本地测试集前", n, "个auc为", [
      list(info_df['local_test_auc'])[i] for i in res_num], sep="")
print("平均之后local_test_AUC为", max_auc, sep="")

res = pd.DataFrame({
    'cust_id': list(df_test["cust_id"]),
    'label': final_pred_label,
})
res.to_csv("./output/result"+date+".csv", encoding="utf-8", index=False)
# Out:
# 本地测试集前15个auc为[0.7387786824574389, 0.7360473723168024, 0.7332938564026648, 0.7363582531458178, 0.7597261287934863, 0.7329311621021466, 0.7219985196151, 0.7434344929681718, 0.745721687638786, 0.7382235381199111, 0.7206143597335306, 0.7397779422649889, 0.7403923019985196, 0.7364174685418209, 0.7482457438934123]
# 平均之后local_test_AUC为0.7521687638786084

# %%
from sklearn.linear_model import LogisticRegression
res_df=pd.DataFrame()
pred_df=pd.DataFrame()
model_name=[]

for i in res_num:
    res_df['model'+str(i)]=local_test_labels[i]
    pred_df['model'+str(i)]=pred_labels[i]

logreg=LogisticRegression()
logreg.fit(res_df,Y_local_test)

print(roc_auc_score(Y_local_test,logreg.predict_proba(res_df)[:,1]))

log_pred=logreg.predict_proba(pred_df)[:,1]


res = pd.DataFrame({
    'cust_id': list(df_test["cust_id"]),
    'label': log_pred,
})
res.to_csv("./output/result"+date+"_stacking.csv", encoding="utf-8", index=False)
# Out:
# 0.7540044411547003

# %%
plt.figure(figsize=(10, 6), dpi=200)
plt.plot(list(range(len(auc_seq))), auc_seq)

# %% [markdown]
# # 一些tips
#
# * 提升n有一定提升(如何确定n？)
#   * n=40 0.6763
#   * n=10 0.6728
#   * n=100 0.6774
#   * 太大也不好
#
# # 一些进展
#
# * 随机参数
# * XGB模型
# * 本地测试集auc较高（0.75+）
# * 部分类型变量进行了one-hot处理
# * 把细分表除了loan与主表合并
#
# # tbd
#
# * 处理细分表的loan，给出指标
# * 确定变量类型，以便对所有（or重要）分类变量进行one-hot处理
# * 新模型？

# %% [markdown]
# ## 10-12
# * 0.6824（这次我留了代码\doge）
# * 把-99变为-1，本地有提升
# * 划出了一个本地测试集
#   * 本地测试集（固定）d_localtest
#   * 训练集（固定）
#     * 评估集（每次的模型不同）dtest
#     * 真正的训练集（每次的模型不同）dtrain
# * 添加参数nan_num（然并卵）
# * tbd
#   * 找特征
#   * 加x
#   * 分析一下参数作用
# ## 10-18
# * 不能把industry之类种类很多的分类变量做证据权重

# %% [markdown]
# # 记录
# * 1014-4
#   * 0.6823
#   * 证据权重
#   * 未添加贷款记录表
#   * 按test auc排序
# * 1014-5
#   * 0.6925
#   * 按local test auc排序
# * 1015-1
#   * 0.6834
#   * 处理-99
# * 1015-2
#   * 0.6628
#   * 添加贷款记录表
# * 1015-3
#   * 0.6772
#   * 不处理-99
#   * 去除贷款记录表
#   * 添加了type-col
# * 1015-4
#   * 0.6811
#   * 不做证据权重
# * 1015-5
#   * 0.6765
#   * gamma=0
# * 1016-1
#   * 0.6798
#   * 添加gamma
#   * 增大early stop round
# * 1016-2
#   * 0.6858
#   * early stop round=10
#   * 证据权重
# * 1016-3
#   * 0.685799
#   * 使用原始type-col
# * 1017-2
#   * 0.6655
