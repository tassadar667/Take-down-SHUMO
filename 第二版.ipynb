# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 数据读入

# %%
import pandas as pd

train_data = pd.read_csv("data\main\df_train_b1.csv", index_col=0)
test_data = pd.read_csv('data\main\df_test_b1.csv', index_col=0)

# %% [markdown]
# ## 要读入除了main之外的数在此处添加

# %%
import os
filenames = ["data\detail\df_basic_b1.csv",
             "data\detail\df_corp_b1.csv",
             "data\detail\df_judicial_b1.csv",
             "data\detail\df_loan2_b1.csv",
             "data\detail\df_query_b1.csv"
             ]
for filename in filenames:
    temp = pd.read_csv(filename)
    train_data = pd.merge(train_data, temp, on="cust_id",
                          how="left", suffixes=("", "_y"))
    test_data = pd.merge(test_data, temp, on="cust_id",
                         how="left", suffixes=("", "_y"))

# %%
train_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in train_data['judicial_reason']]
test_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in test_data['judicial_reason']]

# %%
# train_data['nan_num'] = (train_data == 0).astype(int).sum(axis=1)
# test_data['nan_num'] = (test_data == 0).astype(int).sum(axis=1)

# %%
drop_col = ['basic_2',
            'basic_3',
            'basic_4',
            'loan1_1',
            'overdue_19',
            'basic_8',
            'basic_9',
            'basic_11',
            'basic_15',
            'loan1_17',
            'loan1_31', ]

train_data.drop(drop_col, inplace=True, axis=1)
test_data.drop(drop_col, inplace=True, axis=1)

# %% [markdown]
# ## loan1表

# %%
if True:

    import pandas as pd
    temp_df = pd.read_csv("./data/detail/df_loan1_b1.csv")

    def chuli_loan(df, colname, ways):
        cust_id = list(range(len(set(df['cust_id']))))
        res_df = pd.DataFrame({'cust_id': cust_id})

        if len(ways) == 0:
            return res_df
        if 'mean' in ways:
            res_df[colname+'_mean'] = df.groupby('cust_id')[colname].mean()
        if 'sum' in ways:
            res_df[colname+'_sum'] = df.groupby('cust_id')[colname].sum()
        if 'count' in ways:
            res_df[colname+'_count'] = df.groupby('cust_id')[colname].count()
        if 'std' in ways:
            res_df[colname+'_std'] = df.groupby('cust_id')[colname].std()
        if 'diff_std' in ways:
            res_df[colname+'_diff_std'] = df.groupby('cust_id')[colname].apply(
                lambda x: x.sort_values(ascending=True).diff()[2:].std())
        return res_df

    for colname in ['loan1_2', 'loan1_3', 'loan1_7', 'loan1_9']:
        df = chuli_loan(temp_df, colname, ('sum', 'std'))
        train_data = pd.merge(train_data, df, on="cust_id",
                              how="left", suffixes=("", "_y"))
        test_data = pd.merge(test_data, df, on="cust_id",
                             how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_3', ('count',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_1', ('std', 'diff_std'))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_10', ('mean',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_11', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_12', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    train_data.to_csv('./data/df_train.csv')
    test_data.to_csv('./data/df_test.csv')

# %%
# data = temp_df.dropna(axis=0,subset = ["date_1"])
# data['date2-date1'] = data['date_2'] - data['date_1']
# data['date3-date2'] = data['date_3'] - data['date_2']
# data['dateinterval_max'] = data[['date2-date1','date3-date2']].max(axis=1)
# data = data.groupby('cust_id').agg({'date_2':['count'],'date_3':['count'],'dateinterval_max':['mean']})
# train_data = pd.merge(train_data, data, on="cust_id",
#                           how="left", suffixes=("", "_y"))
# test_data = pd.merge(test_data, data, on="cust_id",
#                          how="left", suffixes=("", "_y"))

# %% [markdown]
# ## 处理NAN

# %%
def delnan(df):
    df = df.dropna(how="all", axis=1)  # 删除全是空值的列
    df = df.fillna(-99)
    return df

# %%
df_train = delnan(train_data)
df_test = delnan(test_data)

# %% [markdown]
# ## 处理-99

# %%
# df_train.replace(-99, -1, inplace=True)
# df_test.replace(-99, -1, inplace=True)

# %% [markdown]
# ## 主成分分析（效果不好）

# %%
# from sklearn.decomposition import PCA

# full_col_name = list(df_train.columns)
# pca_col=[i for i in full_col_name if "loan" in i]

# modelPCA=PCA(n_components=0.9)
# temp=modelPCA.fit_transform(df_train[pca_col])
# temp1=modelPCA.transform(df_test[pca_col])
# for i in range(temp.shape[1]):
#     df_train['loan_pca'+str(i)]=temp[:,i]
#     df_test['loan_pca'+str(i)]=temp1[:,i]

# %% [markdown]
# ## 处理分类变量

# %%
cat_way = "no"

# %% [markdown]
# ## 转化为one-hot编码（不宜采用）

# %%
def to_one_hot(df, colnames):
    df = pd.get_dummies(df, columns=colnames)
    return df

# %% [markdown]
# ## 类型计数

# %%
type_count_cols = ['industry', 'scope', 'basic_13']

# %%
# def type_count(cols):
#     global df_train, df_test
#     df1 = df_train[['cust_id']+cols]
#     df2 = df_test[['cust_id']+cols]
#     df = pd.concat([df1, df2], axis=0, ignore_index=True)
#     for i in cols:
#         temp_df = df.groupby(i)['cust_id'].count()
#         temp_df = pd.DataFrame({(i+"_num"): temp_df})
#         df = pd.merge(df, temp_df, on=i, how="left")
#         del df[i], df1[i], df2[i]
#     df_train = pd.merge(df_train, df, on="cust_id",
#                         how="left", suffixes=("", "_y"))
#     df_test = pd.merge(df_test, df, on="cust_id",
#                        how="left", suffixes=("", "_y"))


# type_count(type_count_cols)

# %% [markdown]
# ## 证据权重

# %%
import pandas as pd
import numpy as np


def cal_woe(df, df_no_label, x_cols, y_col):
    for i in x_cols:
        x_set = pd.unique(df[i])
        x1_set = pd.unique(df_no_label[i])
        for j in x1_set:
            if j not in x_set:
                df_no_label[i].replace(j, 0.03, inplace=True)
                print(i, j, '不存在')
        for j in x_set:
            woe = np.mean(df[df[i] == j][y_col])
            if woe >= 0.1:
                n = np.sum(df[df[i] == j][y_col])
                print(i, '列：', j, ' 共有', int(n/woe), '个,其中',
                      int(n), '个label为1,woe为', woe, sep="")
            df[i].replace(j, woe, inplace=True)
            df_no_label[i].replace(j, woe, inplace=True)
    return df, df_no_label

# %%
type_col = ["basic_1",
            "basic_10",
            "basic_12",
            "basic_14",
            "loan1_16",
            "loan1_20",
            "loan1_23",
            "loan1_25", ]

# df_train,df_test=cal_woe(df_train,df_test,type_col,"label")

# %%
if cat_way == "auto" or cat_way == "no":
    type_col = ["basic_1",
                "basic_10",
                "basic_12",
                "basic_14",
                "loan1_16",
                "loan1_20",
                "loan1_23",
                "loan1_25",
                "loan2_1_y",
                "query_2_y",
                "query_3_y",
                "query_4_y",
                "query_5_y",
                "query_6_y", ]
if cat_way == "manual":
    woe_col = ['basic_1',
               'basic_5',
               'basic_6',
               'basic_10',
               'loan1_16',
               'loan1_20',
               'loan1_25',
               'loan1_23',
               'loan1_32',
               'loan2_4',
               'loan2_6',
               'overdue_2',
               'overdue_20',
               'overdue_21',
               'overdue_26',
               'overdue_27',
               'query_1',
               'query_2',
               'query_3',
               'query_4',
               'query_6',
               'query_7',
               'query_8',
               'query_10',
               'query_11', ]

    onehot_col = ['basic_12',
                  'basic_14',
                  'loan1_8',
                  'loan1_9',
                  'overdue_1',
                  'overdue_3',
                  'overdue_4',
                  'overdue_5',
                  'overdue_6',
                  'overdue_7',
                  'overdue_8',
                  'overdue_9',
                  'overdue_10',
                  'overdue_11',
                  'overdue_12',
                  'overdue_14',
                  'overdue_15',
                  'overdue_16',
                  'overdue_17',
                  'overdue_18',
                  'overdue_22',
                  'overdue_23',
                  'overdue_24',
                  'overdue_25',
                  'overdue_28',
                  'overdue_29',
                  'query_5',
                  'query_9', ]

    df_train, df_test = cal_woe(df_train, df_test, woe_col, "label")
    df_train = to_one_hot(df_train, onehot_col)
    df_test = to_one_hot(df_test, onehot_col)
    for i in df_train.columns:
        if i not in df_test.columns:
            df_test[i] = 0

# %%
full_col_name = list(df_train.columns)
basic_col = [i for i in full_col_name if "basic" in i]
loan_col = [i for i in full_col_name if "loan" in i]
overdue_col = [i for i in full_col_name if "overdue" in i]
query_col = [i for i in full_col_name if "query" in i]
judicial_col = [i for i in full_col_name if "judicial" in i]
date_col = [i for i in full_col_name if "date" in i]
# loan_pca_col = [i for i in full_col_name if "loan_pca" in i]

# for i in judicial_col:
#     df_train[i].astype("float")
#     df_test[i].astype("float")

# %% [markdown]
# ## rank化

# %%
def rank(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = np.argsort(df[i])
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


a = ['loan1_1', 'loan1_3', 'loan1_7', 'loan1_9']
b = ['_sum', '_mean']
c = []
for i in a:
    for j in b:
        c.append(i+j)
# rank(c)

# %% [markdown]
# ## 归一化

# %%
def norm(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.min(df[i]))/(np.max(df[i])-np.min(df[i]))
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# norm([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 标准化

# %%
def stand(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.mean(df[i], axis=0))/np.std(df[i], axis=0)
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# stand([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 设置哪些x作为模型自变量输入

# %%
# x_col = basic_col+loan_col+['nan_num'] + ['is_judicial']+ overdue_col+query_col
# x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col+['scope_num'] + \
#     ['industry_num']+['date_3_count', 'date_1_std', 'date_1_diff_std']

x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col
x_col = [i for i in x_col if i in full_col_name]

if cat_way == "auto":
    type_col = [i for i in type_col if i in x_col]
# categorize(df_train,type_col)
# categorize(df_test,type_col)

print('自变量个数为', len(x_col))
print(x_col)
# Out:
# 自变量个数为 112
# ['basic_1', 'basic_5', 'basic_6', 'basic_7', 'basic_10', 'basic_12', 'basic_13', 'basic_14', 'basic_1_y', 'basic_2_y', 'basic_3_y', 'is_judicial', 'loan1_2', 'loan1_3', 'loan1_4', 'loan1_5', 'loan1_6', 'loan1_7', 'loan1_8', 'loan1_9', 'loan1_10', 'loan1_11', 'loan1_12', 'loan1_13', 'loan1_14', 'loan1_15', 'loan1_16', 'loan1_18', 'loan1_19', 'loan1_20', 'loan1_21', 'loan1_22', 'loan1_23', 'loan1_24', 'loan1_25', 'loan1_26', 'loan1_27', 'loan1_28', 'loan1_29', 'loan1_30', 'loan1_32', 'loan1_33', 'loan2_1', 'loan2_2', 'loan2_3', 'loan2_4', 'loan2_5', 'loan2_6', 'loan2_7', 'loan2_8', 'loan2_9', 'loan2_10', 'loan2_11', 'loan2_12', 'loan2_1_y', 'loan2_2_y', 'loan2_3_y', 'loan2_4_y', 'loan2_5_y', 'loan1_2_sum', 'loan1_2_std', 'loan1_3_sum', 'loan1_3_std', 'loan1_7_sum', 'loan1_7_std', 'loan1_9_sum', 'loan1_9_std', 'query_1', 'query_2', 'query_3', 'query_4', 'query_5', 'query_6', 'query_7', 'query_8', 'query_9', 'query_10', 'query_11', 'query_1_y', 'query_2_y', 'query_3_y', 'query_4_y', 'query_5_y', 'query_6_y', 'overdue_1', 'overdue_2', 'overdue_3', 'overdue_4', 'overdue_5', 'overdue_6', 'overdue_7', 'overdue_8', 'overdue_9', 'overdue_10', 'overdue_11', 'overdue_12', 'overdue_13', 'overdue_14', 'overdue_15', 'overdue_16', 'overdue_17', 'overdue_18', 'overdue_20', 'overdue_21', 'overdue_22', 'overdue_23', 'overdue_24', 'overdue_25', 'overdue_26', 'overdue_27', 'overdue_28', 'overdue_29']

# %%
df_train = df_train[x_col+['label', 'cust_id']]
df_test = df_test[x_col+['cust_id']]

df_test.to_csv("test_input.csv", encoding='utf-8')

# %% [markdown]
# ## 对抗验证

# %%
from sklearn import model_selection
import xgboost as xgb

df_full = pd.concat([df_train[x_col+['cust_id']], df_test],
                    axis=0, ignore_index=True)
df_full['label_test'] = [1 if i in df_test['cust_id']
                         else 0 for i in df_full['cust_id']]

df_full.to_csv("full.csv", encoding='utf-8')

# %%
X = df_full[x_col+['cust_id']]
Y = df_full['label_test']

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(
    X, Y, test_size=0.5, stratify=Y, random_state=2022)

dtrain = xgb.DMatrix(X_train[x_col], label=Y_train)
dtest = xgb.DMatrix(X_test[x_col], label=Y_test)

param = {'max_depth': 5,
         'eta': 0.1,
         'objective': 'binary:logistic',
         "eval_metric": "auc",
         "scale_pos_weight": 1,
         "subsample": 1,
         "min_child_weight": 1,
         'tree_method': 'gpu_hist',
         'gpu_id': 0, }

bst = xgb.train(param, dtrain, 4000, evals=[(dtrain, "train"), (dtest, "test")],
                early_stopping_rounds=300, verbose_eval=True)
bst1 = xgb.train(param, dtest, 4000, evals=[(dtest, "train"), (dtrain, "test")],
                 early_stopping_rounds=300, verbose_eval=False)
# Out:
# [0]	train-auc:0.54199	test-auc:0.49115
# [1]	train-auc:0.54206	test-auc:0.49170
# [2]	train-auc:0.54160	test-auc:0.49211
# [3]	train-auc:0.54116	test-auc:0.49184
# [4]	train-auc:0.54113	test-auc:0.49193
# [5]	train-auc:0.54348	test-auc:0.49064
# [6]	train-auc:0.54331	test-auc:0.49074
# [7]	train-auc:0.54340	test-auc:0.49074
# [8]	train-auc:0.54362	test-auc:0.49068
# [9]	train-auc:0.54460	test-auc:0.49123
# [10]	train-auc:0.54480	test-auc:0.49127
# [11]	train-auc:0.54484	test-auc:0.49121
# [12]	train-auc:0.54489	test-auc:0.49125
# [13]	train-auc:0.54535	test-auc:0.49125
# [14]	train-auc:0.54823	test-auc:0.49063
# [15]	train-auc:0.54836	test-auc:0.49033
# [16]	train-auc:0.55338	test-auc:0.48926
# [17]	train-auc:0.55422	test-auc:0.48949
# [18]	train-auc:0.55431	test-auc:0.48993
# [19]	train-auc:0.55475	test-auc:0.48995
# [20]	train-auc:0.55570	test-auc:0.49042
# [21]	train-auc:0.55579	test-auc:0.49036
# [22]	train-auc:0.55691	test-auc:0.49002
# [23]	train-auc:0.55617	test-auc:0.49029
# [24]	train-auc:0.55643	test-auc:0.48994
# [25]	train-auc:0.55719	test-auc:0.49035
# [26]	train-auc:0.55728	test-auc:0.49028
# [27]	train-auc:0.55728	test-auc:0.49027
# [28]	train-auc:0.55832	test-auc:0.48966
# [29]	train-auc:0.55840	test-auc:0.48975
# [30]	train-auc:0.57760	test-auc:0.49363
# [31]	train-auc:0.57834	test-auc:0.49330
# [32]	train-auc:0.57992	test-auc:0.49274
# [33]	train-auc:0.57994	test-auc:0.49277
# [34]	train-auc:0.58106	test-auc:0.49269
# [35]	train-auc:0.58139	test-auc:0.49257
# [36]	train-auc:0.58168	test-auc:0.49245
# [37]	train-auc:0.58313	test-auc:0.49249
# [38]	train-auc:0.58361	test-auc:0.49292
# [39]	train-auc:0.58361	test-auc:0.49304
# [40]	train-auc:0.58375	test-auc:0.49308
# [41]	train-auc:0.58410	test-auc:0.49300
# [42]	train-auc:0.58463	test-auc:0.49298
# [43]	train-auc:0.58866	test-auc:0.49179
# [44]	train-auc:0.59036	test-auc:0.49236
# [45]	train-auc:0.59118	test-auc:0.49370
# [46]	train-auc:0.59130	test-auc:0.49380
# [47]	train-auc:0.59642	test-auc:0.49341
# [48]	train-auc:0.59901	test-auc:0.49317
# [49]	train-auc:0.59914	test-auc:0.49323
# [50]	train-auc:0.59919	test-auc:0.49336
# [51]	train-auc:0.60028	test-auc:0.49331
# [52]	train-auc:0.60060	test-auc:0.49312
# [53]	train-auc:0.60064	test-auc:0.49282
# [54]	train-auc:0.60101	test-auc:0.49284
# [55]	train-auc:0.60106	test-auc:0.49305
# [56]	train-auc:0.60076	test-auc:0.49263
# [57]	train-auc:0.60232	test-auc:0.49280
# [58]	train-auc:0.60365	test-auc:0.49293
# [59]	train-auc:0.60785	test-auc:0.49348
# [60]	train-auc:0.60978	test-auc:0.49319
# [61]	train-auc:0.60944	test-auc:0.49321
# [62]	train-auc:0.61292	test-auc:0.49197
# [63]	train-auc:0.61371	test-auc:0.49157
# [64]	train-auc:0.61549	test-auc:0.49162
# [65]	train-auc:0.61629	test-auc:0.49200
# [66]	train-auc:0.61811	test-auc:0.49190
# [67]	train-auc:0.61839	test-auc:0.49180
# [68]	train-auc:0.61987	test-auc:0.49173
# [69]	train-auc:0.62119	test-auc:0.49042
# [70]	train-auc:0.62150	test-auc:0.49046
# [71]	train-auc:0.62314	test-auc:0.49046
# [72]	train-auc:0.62607	test-auc:0.49148
# [73]	train-auc:0.62685	test-auc:0.49150
# [74]	train-auc:0.62714	test-auc:0.49132
# [75]	train-auc:0.62771	test-auc:0.49112
# [76]	train-auc:0.62845	test-auc:0.49109
# [77]	train-auc:0.62907	test-auc:0.49140
# [78]	train-auc:0.63003	test-auc:0.49125
# [79]	train-auc:0.62994	test-auc:0.49117
# [80]	train-auc:0.63017	test-auc:0.49100
# [81]	train-auc:0.63168	test-auc:0.49139
# [82]	train-auc:0.63196	test-auc:0.49153
# [83]	train-auc:0.63193	test-auc:0.49157
# [84]	train-auc:0.63244	test-auc:0.49145
# [85]	train-auc:0.63396	test-auc:0.49184
# [86]	train-auc:0.63871	test-auc:0.49163
# [87]	train-auc:0.64058	test-auc:0.49120
# [88]	train-auc:0.64042	test-auc:0.49125
# [89]	train-auc:0.64295	test-auc:0.49143
# [90]	train-auc:0.64354	test-auc:0.49161
# [91]	train-auc:0.64376	test-auc:0.49152
# [92]	train-auc:0.64610	test-auc:0.49137
# [93]	train-auc:0.64651	test-auc:0.49150
# [94]	train-auc:0.64861	test-auc:0.49143
# [95]	train-auc:0.65086	test-auc:0.49062
# [96]	train-auc:0.65117	test-auc:0.49075
# [97]	train-auc:0.65248	test-auc:0.49033
# [98]	train-auc:0.65307	test-auc:0.49011
# [99]	train-auc:0.65501	test-auc:0.48941
# [100]	train-auc:0.65572	test-auc:0.48931
# [101]	train-auc:0.66116	test-auc:0.48931
# [102]	train-auc:0.66137	test-auc:0.48946
# [103]	train-auc:0.66297	test-auc:0.48987
# [104]	train-auc:0.66430	test-auc:0.48962
# [105]	train-auc:0.66549	test-auc:0.48913
# [106]	train-auc:0.66607	test-auc:0.48899
# [107]	train-auc:0.66722	test-auc:0.48882
# [108]	train-auc:0.67099	test-auc:0.48994
# [109]	train-auc:0.67210	test-auc:0.48982
# [110]	train-auc:0.67322	test-auc:0.48980
# [111]	train-auc:0.67337	test-auc:0.48988
# [112]	train-auc:0.67556	test-auc:0.49038
# [113]	train-auc:0.67720	test-auc:0.49065
# [114]	train-auc:0.67793	test-auc:0.49079
# [115]	train-auc:0.67876	test-auc:0.49058
# [116]	train-auc:0.67960	test-auc:0.49086
# [117]	train-auc:0.68065	test-auc:0.49117
# [118]	train-auc:0.68180	test-auc:0.49075
# [119]	train-auc:0.68257	test-auc:0.49034
# [120]	train-auc:0.68342	test-auc:0.49009
# [121]	train-auc:0.68430	test-auc:0.49013
# [122]	train-auc:0.68478	test-auc:0.49012
# [123]	train-auc:0.68584	test-auc:0.49085
# [124]	train-auc:0.68682	test-auc:0.49097
# [125]	train-auc:0.68948	test-auc:0.49125
# [126]	train-auc:0.69108	test-auc:0.49204
# [127]	train-auc:0.69135	test-auc:0.49218
# [128]	train-auc:0.69229	test-auc:0.49244
# [129]	train-auc:0.69280	test-auc:0.49236
# [130]	train-auc:0.69324	test-auc:0.49252
# [131]	train-auc:0.69413	test-auc:0.49272
# [132]	train-auc:0.69514	test-auc:0.49273
# [133]	train-auc:0.69531	test-auc:0.49288
# [134]	train-auc:0.69741	test-auc:0.49297
# [135]	train-auc:0.69809	test-auc:0.49275
# [136]	train-auc:0.69876	test-auc:0.49268
# [137]	train-auc:0.69917	test-auc:0.49250
# [138]	train-auc:0.70166	test-auc:0.49318
# [139]	train-auc:0.70213	test-auc:0.49341
# [140]	train-auc:0.70268	test-auc:0.49396
# [141]	train-auc:0.70472	test-auc:0.49436
# [142]	train-auc:0.70536	test-auc:0.49408
# [143]	train-auc:0.70579	test-auc:0.49451
# [144]	train-auc:0.70623	test-auc:0.49511
# [145]	train-auc:0.70756	test-auc:0.49528
# [146]	train-auc:0.70807	test-auc:0.49517
# [147]	train-auc:0.70853	test-auc:0.49544
# [148]	train-auc:0.70881	test-auc:0.49525
# [149]	train-auc:0.71012	test-auc:0.49568
# [150]	train-auc:0.71312	test-auc:0.49560
# [151]	train-auc:0.71332	test-auc:0.49577
# [152]	train-auc:0.71505	test-auc:0.49631
# [153]	train-auc:0.71590	test-auc:0.49615
# [154]	train-auc:0.71618	test-auc:0.49607
# [155]	train-auc:0.71661	test-auc:0.49618
# [156]	train-auc:0.71669	test-auc:0.49643
# [157]	train-auc:0.71858	test-auc:0.49593
# [158]	train-auc:0.71965	test-auc:0.49580
# [159]	train-auc:0.72027	test-auc:0.49569
# [160]	train-auc:0.72107	test-auc:0.49600
# [161]	train-auc:0.72120	test-auc:0.49627
# [162]	train-auc:0.72226	test-auc:0.49649
# [163]	train-auc:0.72254	test-auc:0.49643
# [164]	train-auc:0.72291	test-auc:0.49628
# [165]	train-auc:0.72406	test-auc:0.49672
# [166]	train-auc:0.72543	test-auc:0.49692
# [167]	train-auc:0.72609	test-auc:0.49679
# [168]	train-auc:0.72639	test-auc:0.49673
# [169]	train-auc:0.72671	test-auc:0.49659
# [170]	train-auc:0.72709	test-auc:0.49669
# [171]	train-auc:0.72738	test-auc:0.49693
# [172]	train-auc:0.72756	test-auc:0.49692
# [173]	train-auc:0.72788	test-auc:0.49683
# [174]	train-auc:0.72865	test-auc:0.49720
# [175]	train-auc:0.72952	test-auc:0.49745
# [176]	train-auc:0.72983	test-auc:0.49744
# [177]	train-auc:0.73014	test-auc:0.49771
# [178]	train-auc:0.73106	test-auc:0.49753
# [179]	train-auc:0.73180	test-auc:0.49765
# [180]	train-auc:0.73277	test-auc:0.49776
# [181]	train-auc:0.73352	test-auc:0.49762
# [182]	train-auc:0.73363	test-auc:0.49757
# [183]	train-auc:0.73470	test-auc:0.49780
# [184]	train-auc:0.73540	test-auc:0.49793
# [185]	train-auc:0.73659	test-auc:0.49785
# [186]	train-auc:0.73711	test-auc:0.49798
# [187]	train-auc:0.73735	test-auc:0.49790
# [188]	train-auc:0.73774	test-auc:0.49783
# [189]	train-auc:0.73787	test-auc:0.49784
# [190]	train-auc:0.73820	test-auc:0.49761
# [191]	train-auc:0.73903	test-auc:0.49772
# [192]	train-auc:0.73929	test-auc:0.49765
# [193]	train-auc:0.73991	test-auc:0.49797
# [194]	train-auc:0.74055	test-auc:0.49792
# [195]	train-auc:0.74071	test-auc:0.49782
# [196]	train-auc:0.74170	test-auc:0.49775
# [197]	train-auc:0.74231	test-auc:0.49784
# [198]	train-auc:0.74270	test-auc:0.49761
# [199]	train-auc:0.74271	test-auc:0.49760
# [200]	train-auc:0.74302	test-auc:0.49758
# [201]	train-auc:0.74313	test-auc:0.49789
# [202]	train-auc:0.74384	test-auc:0.49795
# [203]	train-auc:0.74479	test-auc:0.49790
# [204]	train-auc:0.74486	test-auc:0.49777
# [205]	train-auc:0.74483	test-auc:0.49774
# [206]	train-auc:0.74500	test-auc:0.49765
# [207]	train-auc:0.74511	test-auc:0.49782
# [208]	train-auc:0.74534	test-auc:0.49762
# [209]	train-auc:0.74589	test-auc:0.49789
# [210]	train-auc:0.74594	test-auc:0.49792
# [211]	train-auc:0.74652	test-auc:0.49789
# [212]	train-auc:0.74692	test-auc:0.49780
# [213]	train-auc:0.74715	test-auc:0.49782
# [214]	train-auc:0.74745	test-auc:0.49758
# [215]	train-auc:0.74781	test-auc:0.49770
# [216]	train-auc:0.74789	test-auc:0.49791
# [217]	train-auc:0.74826	test-auc:0.49789
# [218]	train-auc:0.74826	test-auc:0.49793
# [219]	train-auc:0.74839	test-auc:0.49790
# [220]	train-auc:0.74910	test-auc:0.49806
# [221]	train-auc:0.74956	test-auc:0.49804
# [222]	train-auc:0.74966	test-auc:0.49810
# [223]	train-auc:0.75012	test-auc:0.49815
# [224]	train-auc:0.75113	test-auc:0.49835
# [225]	train-auc:0.75147	test-auc:0.49827
# [226]	train-auc:0.75257	test-auc:0.49811
# [227]	train-auc:0.75272	test-auc:0.49807
# [228]	train-auc:0.75328	test-auc:0.49791
# [229]	train-auc:0.75353	test-auc:0.49810
# [230]	train-auc:0.75355	test-auc:0.49805
# [231]	train-auc:0.75393	test-auc:0.49812
# [232]	train-auc:0.75458	test-auc:0.49825
# [233]	train-auc:0.75454	test-auc:0.49822
# [234]	train-auc:0.75491	test-auc:0.49822
# [235]	train-auc:0.75521	test-auc:0.49835
# [236]	train-auc:0.75528	test-auc:0.49836
# [237]	train-auc:0.75557	test-auc:0.49849
# [238]	train-auc:0.75585	test-auc:0.49854
# [239]	train-auc:0.75578	test-auc:0.49848
# [240]	train-auc:0.75592	test-auc:0.49832
# [241]	train-auc:0.75615	test-auc:0.49837
# [242]	train-auc:0.75626	test-auc:0.49833
# [243]	train-auc:0.75675	test-auc:0.49838
# [244]	train-auc:0.75701	test-auc:0.49848
# [245]	train-auc:0.75702	test-auc:0.49858
# [246]	train-auc:0.75726	test-auc:0.49851
# [247]	train-auc:0.75734	test-auc:0.49848
# [248]	train-auc:0.75761	test-auc:0.49863
# [249]	train-auc:0.75784	test-auc:0.49871
# [250]	train-auc:0.75869	test-auc:0.49859
# [251]	train-auc:0.75896	test-auc:0.49843
# [252]	train-auc:0.75899	test-auc:0.49850
# [253]	train-auc:0.75903	test-auc:0.49844
# [254]	train-auc:0.75929	test-auc:0.49854
# [255]	train-auc:0.75939	test-auc:0.49865
# [256]	train-auc:0.75986	test-auc:0.49880
# [257]	train-auc:0.76016	test-auc:0.49877
# [258]	train-auc:0.76059	test-auc:0.49875
# [259]	train-auc:0.76046	test-auc:0.49892
# [260]	train-auc:0.76060	test-auc:0.49892
# [261]	train-auc:0.76116	test-auc:0.49869
# [262]	train-auc:0.76152	test-auc:0.49866
# [263]	train-auc:0.76182	test-auc:0.49866
# [264]	train-auc:0.76257	test-auc:0.49850
# [265]	train-auc:0.76274	test-auc:0.49855
# [266]	train-auc:0.76313	test-auc:0.49861
# [267]	train-auc:0.76328	test-auc:0.49865
# [268]	train-auc:0.76360	test-auc:0.49855
# [269]	train-auc:0.76375	test-auc:0.49844
# [270]	train-auc:0.76387	test-auc:0.49848
# [271]	train-auc:0.76504	test-auc:0.49852
# [272]	train-auc:0.76549	test-auc:0.49890
# [273]	train-auc:0.76557	test-auc:0.49877
# [274]	train-auc:0.76596	test-auc:0.49889
# [275]	train-auc:0.76654	test-auc:0.49898
# [276]	train-auc:0.76673	test-auc:0.49890
# [277]	train-auc:0.76708	test-auc:0.49895
# [278]	train-auc:0.76714	test-auc:0.49896
# [279]	train-auc:0.76731	test-auc:0.49900
# [280]	train-auc:0.76761	test-auc:0.49908
# [281]	train-auc:0.76827	test-auc:0.49915
# [282]	train-auc:0.76839	test-auc:0.49923
# [283]	train-auc:0.76868	test-auc:0.49928
# [284]	train-auc:0.76907	test-auc:0.49906
# [285]	train-auc:0.77001	test-auc:0.49901
# [286]	train-auc:0.77013	test-auc:0.49897
# [287]	train-auc:0.77008	test-auc:0.49916
# [288]	train-auc:0.77032	test-auc:0.49904
# [289]	train-auc:0.77035	test-auc:0.49904
# [290]	train-auc:0.77050	test-auc:0.49904
# [291]	train-auc:0.77074	test-auc:0.49904
# [292]	train-auc:0.77130	test-auc:0.49898
# [293]	train-auc:0.77137	test-auc:0.49895
# [294]	train-auc:0.77187	test-auc:0.49901
# [295]	train-auc:0.77207	test-auc:0.49900
# [296]	train-auc:0.77232	test-auc:0.49904
# [297]	train-auc:0.77244	test-auc:0.49887
# [298]	train-auc:0.77289	test-auc:0.49908
# [299]	train-auc:0.77295	test-auc:0.49903
# [300]	train-auc:0.77375	test-auc:0.49904
# [301]	train-auc:0.77387	test-auc:0.49924
# [302]	train-auc:0.77418	test-auc:0.49905
# [303]	train-auc:0.77451	test-auc:0.49915
# [304]	train-auc:0.77466	test-auc:0.49918
# [305]	train-auc:0.77487	test-auc:0.49924
# [306]	train-auc:0.77538	test-auc:0.49918
# [307]	train-auc:0.77553	test-auc:0.49917
# [308]	train-auc:0.77626	test-auc:0.49919
# [309]	train-auc:0.77640	test-auc:0.49920
# [310]	train-auc:0.77688	test-auc:0.49919
# [311]	train-auc:0.77700	test-auc:0.49923
# [312]	train-auc:0.77721	test-auc:0.49922
# [313]	train-auc:0.77751	test-auc:0.49914
# [314]	train-auc:0.77766	test-auc:0.49901
# [315]	train-auc:0.77773	test-auc:0.49902
# [316]	train-auc:0.77797	test-auc:0.49894
# [317]	train-auc:0.77805	test-auc:0.49900
# [318]	train-auc:0.77814	test-auc:0.49894
# [319]	train-auc:0.77872	test-auc:0.49894
# [320]	train-auc:0.77890	test-auc:0.49893
# [321]	train-auc:0.77937	test-auc:0.49908
# [322]	train-auc:0.78019	test-auc:0.49921
# [323]	train-auc:0.78058	test-auc:0.49950
# [324]	train-auc:0.78112	test-auc:0.49961
# [325]	train-auc:0.78128	test-auc:0.49960
# [326]	train-auc:0.78178	test-auc:0.49948
# [389]	train-auc:0.79818	test-auc:0.49957
# [390]	train-auc:0.79849	test-auc:0.49952
# [391]	train-auc:0.79867	test-auc:0.49948
# [392]	train-auc:0.79876	test-auc:0.49946
# [393]	train-auc:0.79909	test-auc:0.49955
# [394]	train-auc:0.79932	test-auc:0.49973
# [395]	train-auc:0.79957	test-auc:0.49956
# [396]	train-auc:0.79972	test-auc:0.49961
# [397]	train-auc:0.79986	test-auc:0.49954
# [398]	train-auc:0.79991	test-auc:0.49956
# [399]	train-auc:0.80002	test-auc:0.49963
# [400]	train-auc:0.80017	test-auc:0.49973
# [401]	train-auc:0.80019	test-auc:0.49966
# [402]	train-auc:0.80023	test-auc:0.49966
# [403]	train-auc:0.80045	test-auc:0.49961
# [404]	train-auc:0.80050	test-auc:0.49971
# [405]	train-auc:0.80054	test-auc:0.49975
# [406]	train-auc:0.80063	test-auc:0.49974
# [407]	train-auc:0.80104	test-auc:0.49982
# [408]	train-auc:0.80124	test-auc:0.49984
# [409]	train-auc:0.80152	test-auc:0.49990
# [410]	train-auc:0.80168	test-auc:0.49988
# [411]	train-auc:0.80180	test-auc:0.49991
# [412]	train-auc:0.80179	test-auc:0.49996
# [413]	train-auc:0.80185	test-auc:0.49989
# [414]	train-auc:0.80205	test-auc:0.49979
# [415]	train-auc:0.80216	test-auc:0.49975
# [416]	train-auc:0.80225	test-auc:0.49979
# [417]	train-auc:0.80255	test-auc:0.49986
# [418]	train-auc:0.80256	test-auc:0.49991
# [419]	train-auc:0.80271	test-auc:0.49990
# [420]	train-auc:0.80275	test-auc:0.49991
# [421]	train-auc:0.80316	test-auc:0.49999
# [422]	train-auc:0.80323	test-auc:0.49993
# [423]	train-auc:0.80335	test-auc:0.49996
# [424]	train-auc:0.80421	test-auc:0.49998
# [425]	train-auc:0.80421	test-auc:0.49985
# [426]	train-auc:0.80430	test-auc:0.49982
# [427]	train-auc:0.80477	test-auc:0.49991
# [428]	train-auc:0.80493	test-auc:0.49991
# [429]	train-auc:0.80495	test-auc:0.49992
# [430]	train-auc:0.80521	test-auc:0.49999
# [431]	train-auc:0.80528	test-auc:0.49986
# [432]	train-auc:0.80568	test-auc:0.49994
# [433]	train-auc:0.80575	test-auc:0.49987
# [434]	train-auc:0.80606	test-auc:0.49995
# [435]	train-auc:0.80617	test-auc:0.50000
# [436]	train-auc:0.80641	test-auc:0.50006
# [437]	train-auc:0.80644	test-auc:0.50011
# [438]	train-auc:0.80722	test-auc:0.50010
# [439]	train-auc:0.80733	test-auc:0.50003
# [440]	train-auc:0.80779	test-auc:0.50004
# [441]	train-auc:0.80789	test-auc:0.50005
# [442]	train-auc:0.80796	test-auc:0.50000
# [443]	train-auc:0.80827	test-auc:0.50007
# [444]	train-auc:0.80826	test-auc:0.50007
# [445]	train-auc:0.80828	test-auc:0.50008
# [446]	train-auc:0.80837	test-auc:0.50010
# [447]	train-auc:0.80852	test-auc:0.50002
# [448]	train-auc:0.80901	test-auc:0.50011
# [449]	train-auc:0.80912	test-auc:0.50011
# [450]	train-auc:0.80928	test-auc:0.50012
# [451]	train-auc:0.80965	test-auc:0.50013
# [452]	train-auc:0.80974	test-auc:0.50008
# [453]	train-auc:0.80982	test-auc:0.50006
# [454]	train-auc:0.80994	test-auc:0.50013
# [455]	train-auc:0.80998	test-auc:0.50014
# [456]	train-auc:0.81062	test-auc:0.50013
# [457]	train-auc:0.81063	test-auc:0.50013
# [458]	train-auc:0.81070	test-auc:0.50016
# [459]	train-auc:0.81092	test-auc:0.50025
# [460]	train-auc:0.81130	test-auc:0.50030
# [461]	train-auc:0.81149	test-auc:0.50029
# [462]	train-auc:0.81154	test-auc:0.50020
# [463]	train-auc:0.81154	test-auc:0.50020
# [464]	train-auc:0.81187	test-auc:0.50030
# [465]	train-auc:0.81243	test-auc:0.50031
# [466]	train-auc:0.81251	test-auc:0.50030
# [467]	train-auc:0.81301	test-auc:0.50035
# [468]	train-auc:0.81346	test-auc:0.50047
# [469]	train-auc:0.81350	test-auc:0.50052
# [470]	train-auc:0.81364	test-auc:0.50049
# [471]	train-auc:0.81385	test-auc:0.50052
# [472]	train-auc:0.81404	test-auc:0.50056
# [473]	train-auc:0.81414	test-auc:0.50056
# [474]	train-auc:0.81414	test-auc:0.50055
# [475]	train-auc:0.81470	test-auc:0.50051
# [476]	train-auc:0.81474	test-auc:0.50057
# [477]	train-auc:0.81487	test-auc:0.50055
# [478]	train-auc:0.81526	test-auc:0.50061
# [479]	train-auc:0.81529	test-auc:0.50070
# [480]	train-auc:0.81567	test-auc:0.50078
# [481]	train-auc:0.81579	test-auc:0.50084
# [482]	train-auc:0.81581	test-auc:0.50086
# [483]	train-auc:0.81584	test-auc:0.50097
# [484]	train-auc:0.81581	test-auc:0.50093
# [485]	train-auc:0.81609	test-auc:0.50101
# [486]	train-auc:0.81607	test-auc:0.50103
# [487]	train-auc:0.81618	test-auc:0.50096
# [488]	train-auc:0.81697	test-auc:0.50086
# [489]	train-auc:0.81701	test-auc:0.50084
# [490]	train-auc:0.81698	test-auc:0.50082
# [491]	train-auc:0.81705	test-auc:0.50083
# [492]	train-auc:0.81738	test-auc:0.50088
# [493]	train-auc:0.81746	test-auc:0.50089
# [494]	train-auc:0.81776	test-auc:0.50097
# [495]	train-auc:0.81788	test-auc:0.50099
# [496]	train-auc:0.81809	test-auc:0.50103
# [497]	train-auc:0.81830	test-auc:0.50109
# [498]	train-auc:0.81871	test-auc:0.50109
# [499]	train-auc:0.81873	test-auc:0.50108
# [500]	train-auc:0.81889	test-auc:0.50110
# [501]	train-auc:0.81902	test-auc:0.50123
# [502]	train-auc:0.81900	test-auc:0.50123
# [503]	train-auc:0.81908	test-auc:0.50121
# [504]	train-auc:0.81926	test-auc:0.50124
# [505]	train-auc:0.81933	test-auc:0.50125
# [506]	train-auc:0.81947	test-auc:0.50131
# [507]	train-auc:0.81946	test-auc:0.50130
# [508]	train-auc:0.81953	test-auc:0.50139
# [509]	train-auc:0.81978	test-auc:0.50147
# [510]	train-auc:0.81977	test-auc:0.50140
# [511]	train-auc:0.81981	test-auc:0.50137
# [512]	train-auc:0.81986	test-auc:0.50135
# [885]	train-auc:0.86845	test-auc:0.50310
# [886]	train-auc:0.86849	test-auc:0.50320
# [887]	train-auc:0.86851	test-auc:0.50320
# [888]	train-auc:0.86859	test-auc:0.50320
# [889]	train-auc:0.86884	test-auc:0.50311
# [890]	train-auc:0.86887	test-auc:0.50309
# [891]	train-auc:0.86902	test-auc:0.50314
# [892]	train-auc:0.86917	test-auc:0.50314
# [893]	train-auc:0.86958	test-auc:0.50303
# [894]	train-auc:0.86978	test-auc:0.50298
# [895]	train-auc:0.86983	test-auc:0.50298
# [896]	train-auc:0.87006	test-auc:0.50295
# [897]	train-auc:0.87014	test-auc:0.50288
# [898]	train-auc:0.87019	test-auc:0.50294
# [899]	train-auc:0.87018	test-auc:0.50298
# [900]	train-auc:0.87025	test-auc:0.50299
# [901]	train-auc:0.87048	test-auc:0.50299
# [902]	train-auc:0.87085	test-auc:0.50299
# [903]	train-auc:0.87118	test-auc:0.50305
# [904]	train-auc:0.87120	test-auc:0.50311
# [905]	train-auc:0.87135	test-auc:0.50306
# [906]	train-auc:0.87154	test-auc:0.50298
# [907]	train-auc:0.87157	test-auc:0.50307
# [908]	train-auc:0.87165	test-auc:0.50304
# [909]	train-auc:0.87203	test-auc:0.50307
# [910]	train-auc:0.87219	test-auc:0.50298
# [911]	train-auc:0.87221	test-auc:0.50301
# [912]	train-auc:0.87232	test-auc:0.50303
# [913]	train-auc:0.87241	test-auc:0.50299
# [914]	train-auc:0.87243	test-auc:0.50300
# [915]	train-auc:0.87262	test-auc:0.50291
# [916]	train-auc:0.87262	test-auc:0.50295
# [917]	train-auc:0.87265	test-auc:0.50294
# [918]	train-auc:0.87268	test-auc:0.50303
# [919]	train-auc:0.87283	test-auc:0.50295
# [920]	train-auc:0.87293	test-auc:0.50291
# [921]	train-auc:0.87293	test-auc:0.50293
# [922]	train-auc:0.87313	test-auc:0.50296
# [923]	train-auc:0.87318	test-auc:0.50303
# [924]	train-auc:0.87327	test-auc:0.50300
# [925]	train-auc:0.87343	test-auc:0.50292
# [926]	train-auc:0.87358	test-auc:0.50293
# [927]	train-auc:0.87383	test-auc:0.50288
# [928]	train-auc:0.87386	test-auc:0.50285
# [929]	train-auc:0.87389	test-auc:0.50284
# [930]	train-auc:0.87428	test-auc:0.50279
# [931]	train-auc:0.87428	test-auc:0.50283
# [932]	train-auc:0.87447	test-auc:0.50281
# [933]	train-auc:0.87449	test-auc:0.50289
# [934]	train-auc:0.87459	test-auc:0.50281
# [935]	train-auc:0.87486	test-auc:0.50276
# [936]	train-auc:0.87510	test-auc:0.50265
# [937]	train-auc:0.87516	test-auc:0.50259
# [938]	train-auc:0.87519	test-auc:0.50267
# [939]	train-auc:0.87530	test-auc:0.50259
# [940]	train-auc:0.87527	test-auc:0.50260
# [941]	train-auc:0.87547	test-auc:0.50264
# [942]	train-auc:0.87551	test-auc:0.50268
# [943]	train-auc:0.87572	test-auc:0.50266
# [944]	train-auc:0.87572	test-auc:0.50270
# [945]	train-auc:0.87578	test-auc:0.50269
# [946]	train-auc:0.87587	test-auc:0.50275
# [947]	train-auc:0.87589	test-auc:0.50278
# [948]	train-auc:0.87592	test-auc:0.50277
# [949]	train-auc:0.87599	test-auc:0.50271
# [950]	train-auc:0.87600	test-auc:0.50264
# [951]	train-auc:0.87600	test-auc:0.50267
# [952]	train-auc:0.87616	test-auc:0.50259
# [953]	train-auc:0.87645	test-auc:0.50263
# [954]	train-auc:0.87649	test-auc:0.50266
# [955]	train-auc:0.87659	test-auc:0.50265
# [956]	train-auc:0.87665	test-auc:0.50258
# [957]	train-auc:0.87668	test-auc:0.50257
# [958]	train-auc:0.87670	test-auc:0.50263
# [959]	train-auc:0.87700	test-auc:0.50264
# [960]	train-auc:0.87705	test-auc:0.50267
# [961]	train-auc:0.87706	test-auc:0.50269
# [962]	train-auc:0.87712	test-auc:0.50267
# [963]	train-auc:0.87716	test-auc:0.50269
# [964]	train-auc:0.87729	test-auc:0.50271
# [965]	train-auc:0.87729	test-auc:0.50274
# [966]	train-auc:0.87743	test-auc:0.50268
# [967]	train-auc:0.87756	test-auc:0.50266
# [968]	train-auc:0.87756	test-auc:0.50268
# [969]	train-auc:0.87759	test-auc:0.50262
# [970]	train-auc:0.87758	test-auc:0.50264
# [971]	train-auc:0.87778	test-auc:0.50272
# [972]	train-auc:0.87790	test-auc:0.50271
# [973]	train-auc:0.87810	test-auc:0.50266
# [974]	train-auc:0.87811	test-auc:0.50271
# [975]	train-auc:0.87828	test-auc:0.50267
# [976]	train-auc:0.87840	test-auc:0.50260
# [977]	train-auc:0.87840	test-auc:0.50259
# [978]	train-auc:0.87861	test-auc:0.50263
# [979]	train-auc:0.87873	test-auc:0.50267
# [980]	train-auc:0.87897	test-auc:0.50261
# [981]	train-auc:0.87922	test-auc:0.50263
# [982]	train-auc:0.87922	test-auc:0.50265
# [983]	train-auc:0.87922	test-auc:0.50268
# [984]	train-auc:0.87924	test-auc:0.50273
# [985]	train-auc:0.87928	test-auc:0.50277
# [986]	train-auc:0.87934	test-auc:0.50276
# [987]	train-auc:0.87952	test-auc:0.50273
# [988]	train-auc:0.87979	test-auc:0.50272
# [989]	train-auc:0.87979	test-auc:0.50274
# [990]	train-auc:0.87981	test-auc:0.50277
# [991]	train-auc:0.87985	test-auc:0.50273
# [992]	train-auc:0.87988	test-auc:0.50275
# [993]	train-auc:0.88002	test-auc:0.50283
# [994]	train-auc:0.88011	test-auc:0.50280
# [995]	train-auc:0.88027	test-auc:0.50276
# [996]	train-auc:0.88038	test-auc:0.50275
# [997]	train-auc:0.88037	test-auc:0.50276
# [998]	train-auc:0.88042	test-auc:0.50278
# [999]	train-auc:0.88042	test-auc:0.50279
# [1000]	train-auc:0.88045	test-auc:0.50277
# [1001]	train-auc:0.88063	test-auc:0.50269
# [1002]	train-auc:0.88081	test-auc:0.50270
# [1003]	train-auc:0.88081	test-auc:0.50271
# [1004]	train-auc:0.88080	test-auc:0.50272
# [1005]	train-auc:0.88108	test-auc:0.50260
# [1006]	train-auc:0.88109	test-auc:0.50265
# [1007]	train-auc:0.88111	test-auc:0.50262
# [1128]	train-auc:0.89173	test-auc:0.50220
# [1129]	train-auc:0.89186	test-auc:0.50229
# [1130]	train-auc:0.89216	test-auc:0.50223
# [1131]	train-auc:0.89218	test-auc:0.50219
# [1132]	train-auc:0.89223	test-auc:0.50221
# [1133]	train-auc:0.89234	test-auc:0.50217
# [1134]	train-auc:0.89233	test-auc:0.50217
# [1135]	train-auc:0.89234	test-auc:0.50217
# [1136]	train-auc:0.89245	test-auc:0.50215
# [1137]	train-auc:0.89250	test-auc:0.50216
# [1138]	train-auc:0.89250	test-auc:0.50217
# [1139]	train-auc:0.89253	test-auc:0.50218
# [1140]	train-auc:0.89254	test-auc:0.50219
# [1141]	train-auc:0.89261	test-auc:0.50214
# [1142]	train-auc:0.89275	test-auc:0.50211
# [1143]	train-auc:0.89323	test-auc:0.50215
# [1144]	train-auc:0.89331	test-auc:0.50216
# [1145]	train-auc:0.89331	test-auc:0.50218
# [1146]	train-auc:0.89342	test-auc:0.50214
# [1147]	train-auc:0.89342	test-auc:0.50216
# [1148]	train-auc:0.89355	test-auc:0.50223
# [1149]	train-auc:0.89372	test-auc:0.50216
# [1150]	train-auc:0.89387	test-auc:0.50216
# [1151]	train-auc:0.89391	test-auc:0.50217
# [1152]	train-auc:0.89404	test-auc:0.50215
# [1153]	train-auc:0.89403	test-auc:0.50215
# [1154]	train-auc:0.89404	test-auc:0.50214
# [1155]	train-auc:0.89413	test-auc:0.50217
# [1156]	train-auc:0.89416	test-auc:0.50222
# [1157]	train-auc:0.89425	test-auc:0.50224
# [1158]	train-auc:0.89424	test-auc:0.50224
# [1159]	train-auc:0.89423	test-auc:0.50224
# [1160]	train-auc:0.89438	test-auc:0.50220
# [1161]	train-auc:0.89449	test-auc:0.50218
# [1162]	train-auc:0.89466	test-auc:0.50210
# [1163]	train-auc:0.89467	test-auc:0.50211
# [1164]	train-auc:0.89468	test-auc:0.50213
# [1165]	train-auc:0.89480	test-auc:0.50220
# [1166]	train-auc:0.89482	test-auc:0.50231
# [1167]	train-auc:0.89486	test-auc:0.50232
# [1168]	train-auc:0.89499	test-auc:0.50225
# [1169]	train-auc:0.89507	test-auc:0.50221
# [1170]	train-auc:0.89509	test-auc:0.50221
# [1171]	train-auc:0.89519	test-auc:0.50223
# [1172]	train-auc:0.89519	test-auc:0.50225
# [1173]	train-auc:0.89538	test-auc:0.50224
# [1174]	train-auc:0.89539	test-auc:0.50224
# [1175]	train-auc:0.89552	test-auc:0.50219

# %%
df_res = pd.DataFrame(
    {'cust_id': X_test['cust_id'], 'p_test': bst.predict(dtest)})
df_res1 = pd.DataFrame(
    {'cust_id': X_train['cust_id'], 'p_test': bst1.predict(dtrain)})

df = pd.concat([df_res, df_res1], axis=0, ignore_index=True)

df_train = pd.merge(df_train, df, on="cust_id",
                    how="left", suffixes=("", "_y"))

# %%
temp = len(df_train)
df_train.to_csv("train_input.csv", encoding='utf-8')

df_train = df_train[df_train['p_test'] >= 0.1]


print("经过对抗验证，有", len(df_train), "条数据被保留，",
      temp-len(df_train), "条数据被抛弃", sep="")
# Out:
# 经过对抗验证，有17987条数据被保留，12条数据被抛弃

# %% [markdown]
# # 训练模型

# %% [markdown]
# ## 超参数

# %%
N = 60
num_round = 3000
local_test_size = 2000

# 共用
test_size = [0.2, 0.25, 0.3]
max_depth = [3, 4, 5]
subsample = [0.8, 0.75, 0.7, 0.65, 0.6]
early_stopping_rounds = 150

# XGB
eta = [0.007, 0.01]

# LGB
learning_rate = [0.03, 0.02, 0.025]

# %% [markdown]
# ### train划分为
# * 本地测试集（固定）d_localtest
# * 训练集（固定）
#   * 评估集（每次的模型不同）dtest
#   * 真正的训练集（每次的模型不同）dtrain

# %%
import copy
import xgboost as xgb
import random
from sklearn import model_selection
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from catboost import CatBoostClassifier


pred_labels = []
local_test_labels = []
loss_seq = []
max_auc_loss = 0
flag = 0
important_x_seq = []


d_full = xgb.DMatrix(df_train[x_col], label=df_train['label'])
X = df_train[x_col]
Y = df_train['label']

X, X_local_test, Y, Y_local_test = model_selection.train_test_split(
    X, Y, test_size=local_test_size, stratify=Y, random_state=2022)

d_localtest = xgb.DMatrix(X_local_test, label=Y_local_test)
x_perd = xgb.DMatrix(df_test[x_col])

d_localtest1 = lgb.Dataset(X_local_test, Y_local_test)
x_perd1 = lgb.Dataset(df_test[x_col])


lgbcallback = [early_stopping(early_stopping_rounds), log_evaluation(10000)]

# %%
for i in range(N):

    test_size_this_round = random.choice(test_size)
    X_train, X_test, y_train, y_test = model_selection.train_test_split(
        X, Y, test_size=test_size_this_round, stratify=Y)

    # XGB-----------------------------------------------
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    evallist = [(dtest, 'eval')]
    param = {
        'max_depth': random.choice(max_depth),
        'eta': random.choice(eta),
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'subsample': random.choice(subsample),
        'tree_method': 'gpu_hist',
        'gpu_id': 0,
    }

    bst = xgb.train(param, dtrain, num_round, evals=evallist,
                    early_stopping_rounds=early_stopping_rounds, verbose_eval=False)

    loss = roc_auc_score(y_test, bst.predict(dtest))
    train_loss = roc_auc_score(y_train, bst.predict(dtrain))
    local_test_loss = roc_auc_score(Y_local_test, bst.predict(d_localtest))
    global_auc = roc_auc_score(df_train['label'], bst.predict(d_full))

    pred_label = list(bst.predict(x_perd))
    test_label = list(bst.predict(d_localtest))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'xgb'}

    if flag == 0:
        info_df = pd.DataFrame(temp_dict, index=[i])
        flag = 1
    else:
        info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])

    # if loss > max_auc_loss:
    #     best_bst = copy.deepcopy(bst)
    #     max_auc_loss = loss

    # if False:
    #     pic = xgb.plot_importance(bst, max_num_features=50)
    #     temp = pic.get_ymajorticklabels()
    #     important_x = [str(i).split("\'")[1] for i in temp]
    #     important_x.reverse()
    #     important_x_seq += important_x

    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    # LGB--------------------------------------------------------
    param = {
        'task': 'train',
        "max_depth": random.choice(max_depth),
        'max_bin': 128,
        'boosting_type': 'gbdt',  # 设置提升类型
        'objective': 'binary',  # 目标函数
        'metric': 'auc',  # 评估函数
        'learning_rate': random.choice(learning_rate),  # 学习速率
        'bagging_fraction': random.choice(subsample),  # 建树的样本采样比例
        'bagging_freq': 1,  # k 意味着每 k 次迭代执行bagging
        'min_data_in_leaf': 1,
        'verbose': -1,  # <0 显示致命的, =0 显示错误 (警告), >0 显示信息
        'device_type': 'gpu',
    }

    dtrain = lgb.Dataset(X_train, y_train)
    dtest = lgb.Dataset(X_test, y_test)

    if cat_way == "auto":
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback, categorical_feature=type_col)
    else:
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback)

    loss = roc_auc_score(y_test, bst1.predict(X_test))
    train_loss = roc_auc_score(y_train, bst1.predict(X_train))
    local_test_loss = roc_auc_score(Y_local_test, bst1.predict(X_local_test))
    global_auc = roc_auc_score(
        df_train['label'], bst1.predict(df_train[x_col]))

    pred_label = list(bst1.predict(df_test[x_col]))
    test_label = list(bst1.predict(X_local_test))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'lgb'}

    info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    # CAT-----------------------------------------------------------
    # bst2 = CatBoostClassifier(iterations=num_round,
    #                        depth=random.choice(max_depth),
    #                        learning_rate=random.choice(learning_rate),
    #                        loss_function='Logloss',
    #                        subsample=random.choice(subsample),
    #                        early_stopping_rounds=early_stopping_rounds,
    #                        verbose=False)
    # bst2.fit(X_train, y_train,eval_set=(X_test,y_test))

    # loss = roc_auc_score(y_test, bst2.predict_proba(X_test)[:,1])
    # train_loss = roc_auc_score(y_train, bst2.predict_proba(X_train)[:,1])
    # local_test_loss = roc_auc_score(Y_local_test, bst2.predict_proba(X_local_test)[:,1])
    # global_auc = roc_auc_score(df_train['label'], bst2.predict_proba(df_train[x_col])[:,1])

    # pred_label = list(bst2.predict_proba(df_test[x_col])[:,1])
    # test_label = list(bst2.predict_proba(X_local_test)[:,1])

    # temp_dict = {"test_auc": loss, "train_auc": train_loss,
    #              'local_test_auc': local_test_loss,
    #              'model': 'cat'}

    # info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    # pred_labels.append(copy.deepcopy(pred_label))
    # local_test_labels.append(copy.deepcopy(test_label))


print('最大AUC:', max(info_df['local_test_auc']), sep="")
# Out:
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [222]	valid_0's auc: 0.752002
# Early stopping, best iteration is:
# [477]	valid_0's auc: 0.760131
# Early stopping, best iteration is:
# [477]	valid_0's auc: 0.760131
# Early stopping, best iteration is:
# [477]	valid_0's auc: 0.760131
# Early stopping, best iteration is:
# [477]	valid_0's auc: 0.760131
# Early stopping, best iteration is:
# [477]	valid_0's auc: 0.760131
# Early stopping, best iteration is:
# [477]	valid_0's auc: 0.760131
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# Early stopping, best iteration is:
# [288]	valid_0's auc: 0.781331
# 最大AUC:0.7691435269760077

# %%
info_df.to_csv("info.csv", encoding="utf-8", index=False)

# %%
# pic = xgb.plot_importance(bst, max_num_features=50)
# temp = pic.get_ymajorticklabels()
# important_x = [str(i).split("\'")[1] for i in temp]
# important_x.reverse()

# %%
# important_x

# %%
# pd.value_counts(important_x_seq)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6.5, 6), dpi=200)


plt.scatter(info_df[info_df['model'] == 'xgb']['local_test_auc'], info_df[info_df['model'] == 'xgb']['test_auc'],
            c='r', s=4, label="xgb")
plt.scatter(info_df[info_df['model'] == 'lgb']['local_test_auc'], info_df[info_df['model'] == 'lgb']['test_auc'],
            c='g', s=4, label="lgb")
# plt.scatter(info_df[info_df['model'] == 'cat']['local_test_auc'], info_df[info_df['model'] == 'cat']['test_auc'],
#             c='b', s=4,label="cat")
plt.legend()
plt.xlabel('local_test_auc')
plt.ylabel('test_auc')
plt.plot([0.6, 0.85], [0.6, 0.85])
plt.xlim(0.6, 0.85)
plt.ylim(0.6, 0.85)
plt.grid()
plt.show()

# %% [markdown]
# # 输出模块

# %%
import time
import numpy as np
from sklearn.metrics import roc_auc_score

date = time.strftime("%Y%m%d-%H%M%S", time.localtime())
res_num = np.argsort(
    [-i for i in (info_df['local_test_auc']+info_df['test_auc'])])

# 选择前n个结果进行平均（手动指定or在本地测试集排序选出）
if True:
    max_auc = -1
    list_temp = []
    auc_seq = []
    for i in range(N*2):
        list_temp.append(local_test_labels[res_num[i]])
        # 算数平均
        # temp = np.mean(list_temp, axis=0)
        # 几何平均(better)
        temp = np.exp(np.mean(np.log(list_temp), axis=0))
        temp_auc = roc_auc_score(Y_local_test, temp)
        # print(i, temp_auc)
        auc_seq.append(temp_auc)
        if temp_auc > max_auc:
            max_auc = temp_auc
            n = i+1
else:
    n = 40
    n = min(N, n)

res_num = res_num[0:n]

#final_pred_label = np.mean([pred_labels[i] for i in res_num], axis=0)
final_pred_label = np.exp(
    np.mean(np.log([pred_labels[i] for i in res_num]), axis=0))
#local_auc = roc_auc_score(y_test, final_pred_label)
print("本地测试集前", n, "个auc为", [
      list(info_df['local_test_auc'])[i] for i in res_num], sep="")
print("平均之后local_test_AUC为", max_auc, sep="")

res = pd.DataFrame({
    'cust_id': list(df_test["cust_id"]),
    'label': final_pred_label,
})
res.to_csv("./output/result"+date+".csv", encoding="utf-8", index=False)
# Out:
# 本地测试集前5个auc为[0.759331993667032, 0.757025636341493, 0.7492768846669102, 0.7560132748751675, 0.7601540616246499]
# 平均之后local_test_AUC为0.765139751552795

# %%
plt.figure(figsize=(10, 6), dpi=200)
plt.plot(list(range(len(auc_seq))), auc_seq)

# %% [markdown]
# # 一些tips
#
# * 提升n有一定提升(如何确定n？)
#   * n=40 0.6763
#   * n=10 0.6728
#   * n=100 0.6774
#   * 太大也不好
#
# # 一些进展
#
# * 随机参数
# * XGB模型
# * 本地测试集auc较高（0.75+）
# * 部分类型变量进行了one-hot处理
# * 把细分表除了loan与主表合并
#
# # tbd
#
# * 处理细分表的loan，给出指标
# * 确定变量类型，以便对所有（or重要）分类变量进行one-hot处理
# * 新模型？

# %% [markdown]
# ## 10-12
# * 0.6824（这次我留了代码\doge）
# * 把-99变为-1，本地有提升
# * 划出了一个本地测试集
#   * 本地测试集（固定）d_localtest
#   * 训练集（固定）
#     * 评估集（每次的模型不同）dtest
#     * 真正的训练集（每次的模型不同）dtrain
# * 添加参数nan_num（然并卵）
# * tbd
#   * 找特征
#   * 加x
#   * 分析一下参数作用
# ## 10-18
# * 不能把industry之类种类很多的分类变量做证据权重

# %% [markdown]
# # 记录
# * 1014-4
#   * 0.6823
#   * 证据权重
#   * 未添加贷款记录表
#   * 按test auc排序
# * 1014-5
#   * 0.6925
#   * 按local test auc排序
# * 1015-1
#   * 0.6834
#   * 处理-99
# * 1015-2
#   * 0.6628
#   * 添加贷款记录表
# * 1015-3
#   * 0.6772
#   * 不处理-99
#   * 去除贷款记录表
#   * 添加了type-col
# * 1015-4
#   * 0.6811
#   * 不做证据权重
# * 1015-5
#   * 0.6765
#   * gamma=0
# * 1016-1
#   * 0.6798
#   * 添加gamma
#   * 增大early stop round
# * 1016-2
#   * 0.6858
#   * early stop round=10
#   * 证据权重
# * 1016-3
#   * 0.685799
#   * 使用原始type-col
# * 1017-2
#   * 0.6655
