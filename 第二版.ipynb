# %%
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 数据读入

# %%
import pandas as pd

train_data = pd.read_csv("data\main\df_train_b1.csv", index_col=0)
test_data = pd.read_csv('data\main\df_test_b1.csv', index_col=0)

# %% [markdown]
# ## 要读入除了main之外的数在此处添加

# %%
import os
filenames = [  "data\detail\df_basic_b1.csv",
    "data\detail\df_corp_b1.csv",
    "data\detail\df_judicial_b1.csv",
    "data\detail\df_loan2_b1.csv",
    "data\detail\df_query_b1.csv"
]
for filename in filenames:
    temp = pd.read_csv(filename)
    train_data = pd.merge(train_data, temp, on="cust_id",
                          how="left", suffixes=("", "_y"))
    test_data = pd.merge(test_data, temp, on="cust_id",
                         how="left", suffixes=("", "_y"))

# %%
train_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in train_data['judicial_reason']]
test_data['is_judicial'] = [0 if pd.isna(
    i) else 1 for i in test_data['judicial_reason']]

# %%
# train_data['nan_num'] = (train_data == 0).astype(int).sum(axis=1)
# test_data['nan_num'] = (test_data == 0).astype(int).sum(axis=1)

# %%
drop_col = []

train_data.drop(drop_col, inplace=True)
test_data.drop(drop_col, inplace=True)

# %% [markdown]
# ## loan1表

# %%
if True:

    import pandas as pd
    temp_df = pd.read_csv("./data/detail/df_loan1_b1.csv")

    def chuli_loan(df, colname, ways):
        cust_id = list(range(len(set(df['cust_id']))))
        res_df = pd.DataFrame({'cust_id': cust_id})
        
        if len(ways) == 0:
            return res_df
        if 'mean' in ways:
            res_df[colname+'_mean'] = df.groupby('cust_id')[colname].mean()
        if 'sum' in ways:
            res_df[colname+'_sum'] = df.groupby('cust_id')[colname].sum()
        if 'count' in ways:
            res_df[colname+'_count'] = df.groupby('cust_id')[colname].count()
        if 'std' in ways:
            res_df[colname+'_std'] = df.groupby('cust_id')[colname].std()
        if 'diff_std' in ways:
            res_df[colname+'_diff_std'] = df.groupby('cust_id')[colname].apply(
                lambda x: x.sort_values(ascending=True).diff()[2:].std())
        return res_df

    for colname in ['loan1_2','loan1_3','loan1_7','loan1_9']:
        df = chuli_loan(temp_df, colname, ('sum','std'))
        train_data = pd.merge(train_data, df, on="cust_id",
                              how="left", suffixes=("", "_y"))
        test_data = pd.merge(test_data, df, on="cust_id",
                             how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_3', ('count',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'date_1', ('std', 'diff_std'))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_10', ('mean',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_11', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    # df = chuli_loan(temp_df, 'loan1_12', ('sum',))
    # train_data = pd.merge(train_data, df, on="cust_id",
    #                       how="left", suffixes=("", "_y"))
    # test_data = pd.merge(test_data, df, on="cust_id",
    #                      how="left", suffixes=("", "_y"))

    train_data.to_csv('./data/df_train.csv')
    test_data.to_csv('./data/df_test.csv')

# %%
# data = temp_df.dropna(axis=0,subset = ["date_1"])
# data['date2-date1'] = data['date_2'] - data['date_1']
# data['date3-date2'] = data['date_3'] - data['date_2']
# data['dateinterval_max'] = data[['date2-date1','date3-date2']].max(axis=1)
# data = data.groupby('cust_id').agg({'date_2':['count'],'date_3':['count'],'dateinterval_max':['mean']})
# train_data = pd.merge(train_data, data, on="cust_id",
#                           how="left", suffixes=("", "_y"))
# test_data = pd.merge(test_data, data, on="cust_id",
#                          how="left", suffixes=("", "_y"))

# %% [markdown]
# ## 处理NAN

# %%
def delnan(df):
    df = df.dropna(how="all", axis=1)  # 删除全是空值的列
    df = df.fillna(-99)
    return df

# %%
df_train = delnan(train_data)
df_test = delnan(test_data)

# %% [markdown]
# ## 处理-99

# %%
# df_train.replace(-99, -1, inplace=True)
# df_test.replace(-99, -1, inplace=True)

# %% [markdown]
# ## 主成分分析（效果不好）

# %%
# from sklearn.decomposition import PCA

# full_col_name = list(df_train.columns)
# pca_col=[i for i in full_col_name if "loan" in i]

# modelPCA=PCA(n_components=0.9)
# temp=modelPCA.fit_transform(df_train[pca_col])
# temp1=modelPCA.transform(df_test[pca_col])
# for i in range(temp.shape[1]):
#     df_train['loan_pca'+str(i)]=temp[:,i]
#     df_test['loan_pca'+str(i)]=temp1[:,i]

# %% [markdown]
# ## 处理分类变量

# %%
cat_way = "no"

# %% [markdown]
# ## 转化为one-hot编码（不宜采用）

# %%
def to_one_hot(df, colnames):
    df = pd.get_dummies(df, columns=colnames)
    return df

# %% [markdown]
# ## 类型计数

# %%
type_count_cols = ['industry', 'scope', 'basic_13']

# %%
# def type_count(cols):
#     global df_train, df_test
#     df1 = df_train[['cust_id']+cols]
#     df2 = df_test[['cust_id']+cols]
#     df = pd.concat([df1, df2], axis=0, ignore_index=True)
#     for i in cols:
#         temp_df = df.groupby(i)['cust_id'].count()
#         temp_df = pd.DataFrame({(i+"_num"): temp_df})
#         df = pd.merge(df, temp_df, on=i, how="left")
#         del df[i], df1[i], df2[i]
#     df_train = pd.merge(df_train, df, on="cust_id",
#                         how="left", suffixes=("", "_y"))
#     df_test = pd.merge(df_test, df, on="cust_id",
#                        how="left", suffixes=("", "_y"))


# type_count(type_count_cols)

# %% [markdown]
# ## 证据权重

# %%
import pandas as pd
import numpy as np


def cal_woe(df, df_no_label, x_cols, y_col):
    for i in x_cols:
        x_set = pd.unique(df[i])
        x1_set = pd.unique(df_no_label[i])
        for j in x1_set:
            if j not in x_set:
                df_no_label[i].replace(j, 0.03, inplace=True)
                print(i, j, '不存在')
        for j in x_set:
            woe = np.mean(df[df[i] == j][y_col])
            if woe >= 0.1:
                n = np.sum(df[df[i] == j][y_col])
                print(i, '列：', j, ' 共有', int(n/woe), '个,其中',
                      int(n), '个label为1,woe为', woe, sep="")
            df[i].replace(j, woe, inplace=True)
            df_no_label[i].replace(j, woe, inplace=True)
    return df, df_no_label

# %%
type_col = ["basic_1",
            "basic_10",
            "basic_12",
            "basic_14",
            "loan1_16",
            "loan1_20",
            "loan1_23",
            "loan1_25",]

# df_train,df_test=cal_woe(df_train,df_test,type_col,"label")

# %%
if cat_way == "auto" or cat_way=="no":
    type_col = ["basic_1",
                "basic_10",
                "basic_12",
                "basic_14",
                "loan1_16",
                "loan1_20",
                "loan1_23",
                "loan1_25",
                "loan2_1_y",
                "query_2_y",
                "query_3_y",
                "query_4_y",
                "query_5_y",
                "query_6_y", ]
if cat_way == "manual":
    woe_col = ['basic_1',
               'basic_5',
               'basic_6',
               'basic_10',
               'loan1_16',
               'loan1_20',
               'loan1_25',
               'loan1_23',
               'loan1_32',
               'loan2_4',
               'loan2_6',
               'overdue_2',
               'overdue_20',
               'overdue_21',
               'overdue_26',
               'overdue_27',
               'query_1',
               'query_2',
               'query_3',
               'query_4',
               'query_6',
               'query_7',
               'query_8',
               'query_10',
               'query_11', ]

    onehot_col = ['basic_12',
                  'basic_14',
                  'loan1_8',
                  'loan1_9',
                  'overdue_1',
                  'overdue_3',
                  'overdue_4',
                  'overdue_5',
                  'overdue_6',
                  'overdue_7',
                  'overdue_8',
                  'overdue_9',
                  'overdue_10',
                  'overdue_11',
                  'overdue_12',
                  'overdue_14',
                  'overdue_15',
                  'overdue_16',
                  'overdue_17',
                  'overdue_18',
                  'overdue_22',
                  'overdue_23',
                  'overdue_24',
                  'overdue_25',
                  'overdue_28',
                  'overdue_29',
                  'query_5',
                  'query_9', ]

    df_train, df_test = cal_woe(df_train, df_test, woe_col, "label")
    df_train = to_one_hot(df_train, onehot_col)
    df_test = to_one_hot(df_test, onehot_col)
    for i in df_train.columns:
        if i not in df_test.columns:
            df_test[i] = 0

# %%
full_col_name = list(df_train.columns)
basic_col = [i for i in full_col_name if "basic" in i]
loan_col = [i for i in full_col_name if "loan" in i]
overdue_col = [i for i in full_col_name if "overdue" in i]
query_col = [i for i in full_col_name if "query" in i]
judicial_col = [i for i in full_col_name if "judicial" in i]
date_col = [i for i in full_col_name if "date" in i]
# loan_pca_col = [i for i in full_col_name if "loan_pca" in i]

# for i in judicial_col:
#     df_train[i].astype("float")
#     df_test[i].astype("float")

# %% [markdown]
# ## rank化

# %%
def rank(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = np.argsort(df[i])
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


a = ['loan1_1', 'loan1_3', 'loan1_7', 'loan1_9']
b = ['_sum', '_mean']
c = []
for i in a:
    for j in b:
        c.append(i+j)
# rank(c)

# %% [markdown]
# ## 归一化

# %%
def norm(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.min(df[i]))/(np.max(df[i])-np.min(df[i]))
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# norm([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 标准化

# %%
def stand(rank_col):
    global df_train, df_test
    df1 = df_train[['cust_id']+rank_col]
    df2 = df_test[['cust_id']+rank_col]
    df = pd.concat([df1, df2], axis=0, ignore_index=True)
    for i in rank_col:
        df[i] = (df[i]-np.mean(df[i], axis=0))/np.std(df[i], axis=0)
        del df_test[i]
        del df_train[i]
    df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))
    df_test = pd.merge(df_test, df, on="cust_id",
                       how="left", suffixes=("", "_y"))


# stand([i for i in loan_col if i not in type_col and 'count' not in i])

# %% [markdown]
# ## 设置哪些x作为模型自变量输入

# %%
# x_col = basic_col+loan_col+['nan_num'] + ['is_judicial']+ overdue_col+query_col
# x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col+['scope_num'] + \
#     ['industry_num']+['date_3_count', 'date_1_std', 'date_1_diff_std']

x_col = basic_col+['is_judicial']+loan_col+query_col+overdue_col
x_col = [i for i in x_col if i in full_col_name]

if cat_way == "auto":
    type_col = [i for i in type_col if i in x_col]
# categorize(df_train,type_col)
# categorize(df_test,type_col)

print('自变量个数为', len(x_col))
print(x_col)
# Out:
# 自变量个数为 123
# ['basic_1', 'basic_2', 'basic_3', 'basic_4', 'basic_5', 'basic_6', 'basic_7', 'basic_8', 'basic_9', 'basic_10', 'basic_11', 'basic_12', 'basic_13', 'basic_14', 'basic_15', 'basic_1_y', 'basic_2_y', 'basic_3_y', 'is_judicial', 'loan1_1', 'loan1_2', 'loan1_3', 'loan1_4', 'loan1_5', 'loan1_6', 'loan1_7', 'loan1_8', 'loan1_9', 'loan1_10', 'loan1_11', 'loan1_12', 'loan1_13', 'loan1_14', 'loan1_15', 'loan1_16', 'loan1_17', 'loan1_18', 'loan1_19', 'loan1_20', 'loan1_21', 'loan1_22', 'loan1_23', 'loan1_24', 'loan1_25', 'loan1_26', 'loan1_27', 'loan1_28', 'loan1_29', 'loan1_30', 'loan1_31', 'loan1_32', 'loan1_33', 'loan2_1', 'loan2_2', 'loan2_3', 'loan2_4', 'loan2_5', 'loan2_6', 'loan2_7', 'loan2_8', 'loan2_9', 'loan2_10', 'loan2_11', 'loan2_12', 'loan2_1_y', 'loan2_2_y', 'loan2_3_y', 'loan2_4_y', 'loan2_5_y', 'loan1_2_sum', 'loan1_2_std', 'loan1_3_sum', 'loan1_3_std', 'loan1_7_sum', 'loan1_7_std', 'loan1_9_sum', 'loan1_9_std', 'query_1', 'query_2', 'query_3', 'query_4', 'query_5', 'query_6', 'query_7', 'query_8', 'query_9', 'query_10', 'query_11', 'query_1_y', 'query_2_y', 'query_3_y', 'query_4_y', 'query_5_y', 'query_6_y', 'overdue_1', 'overdue_2', 'overdue_3', 'overdue_4', 'overdue_5', 'overdue_6', 'overdue_7', 'overdue_8', 'overdue_9', 'overdue_10', 'overdue_11', 'overdue_12', 'overdue_13', 'overdue_14', 'overdue_15', 'overdue_16', 'overdue_17', 'overdue_18', 'overdue_19', 'overdue_20', 'overdue_21', 'overdue_22', 'overdue_23', 'overdue_24', 'overdue_25', 'overdue_26', 'overdue_27', 'overdue_28', 'overdue_29']

# %%
df_train = df_train[x_col+['label', 'cust_id']]
df_test = df_test[x_col+['cust_id']]

df_test.to_csv("test_input.csv", encoding='utf-8')

# %% [markdown]
# ## 对抗验证

# %%
from sklearn import model_selection
import xgboost as xgb

df_full=pd.concat([df_train[x_col+['cust_id']],df_test],axis=0, ignore_index=True)
df_full['label_test']=[1 if i in df_test['cust_id'] else 0 for i in df_full['cust_id']]

df_full.to_csv("full.csv",encoding='utf-8')

# %%
X = df_full[x_col+['cust_id']]
Y = df_full['label_test']

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(
    X, Y, test_size=0.5, stratify=Y, random_state=2022)

dtrain=xgb.DMatrix(X_train[x_col],label=Y_train)
dtest=xgb.DMatrix(X_test[x_col],label=Y_test)

param = {'max_depth': 5,
         'eta': 0.01,
         'objective': 'binary:logistic',
         "eval_metric":"auc",
         "scale_pos_weight":1,
         "subsample":1,
         "min_child_weight":1,
         'tree_method': 'gpu_hist',
         'gpu_id': 0,}

bst = xgb.train(param, dtrain, 4000, evals=[(dtrain,"train"),(dtest,"test")],
                    early_stopping_rounds=300, verbose_eval=True)
bst1 = xgb.train(param, dtest, 4000, evals=[(dtest,"train"),(dtrain,"test")],
                    early_stopping_rounds=300, verbose_eval=False)
# Out:
# [0]	train-auc:0.54199	test-auc:0.49115
# [1]	train-auc:0.54206	test-auc:0.49170
# [2]	train-auc:0.54160	test-auc:0.49211
# [3]	train-auc:0.54116	test-auc:0.49184
# [4]	train-auc:0.54113	test-auc:0.49193
# [5]	train-auc:0.54463	test-auc:0.48983
# [6]	train-auc:0.54442	test-auc:0.48982
# [7]	train-auc:0.54470	test-auc:0.48984
# [8]	train-auc:0.54486	test-auc:0.48986
# [9]	train-auc:0.54490	test-auc:0.48989
# [10]	train-auc:0.54626	test-auc:0.49028
# [11]	train-auc:0.54637	test-auc:0.49022
# [12]	train-auc:0.54652	test-auc:0.49025
# [13]	train-auc:0.54668	test-auc:0.49013
# [14]	train-auc:0.54714	test-auc:0.49006
# [15]	train-auc:0.54722	test-auc:0.49008
# [16]	train-auc:0.54944	test-auc:0.48977
# [17]	train-auc:0.55019	test-auc:0.49021
# [18]	train-auc:0.55107	test-auc:0.49035
# [19]	train-auc:0.55094	test-auc:0.48972
# [20]	train-auc:0.55196	test-auc:0.49009
# [21]	train-auc:0.55960	test-auc:0.48842
# [22]	train-auc:0.56055	test-auc:0.48863
# [23]	train-auc:0.56361	test-auc:0.48852
# [24]	train-auc:0.56366	test-auc:0.48838
# [25]	train-auc:0.56810	test-auc:0.48762
# [26]	train-auc:0.57003	test-auc:0.48631
# [27]	train-auc:0.57113	test-auc:0.48606
# [28]	train-auc:0.57348	test-auc:0.48619
# [29]	train-auc:0.57332	test-auc:0.48610
# [30]	train-auc:0.57685	test-auc:0.48579
# [31]	train-auc:0.57713	test-auc:0.48585
# [32]	train-auc:0.57795	test-auc:0.48582
# [33]	train-auc:0.57829	test-auc:0.48614
# [34]	train-auc:0.57813	test-auc:0.48598
# [35]	train-auc:0.58131	test-auc:0.48488
# [36]	train-auc:0.58116	test-auc:0.48492
# [37]	train-auc:0.58149	test-auc:0.48514
# [38]	train-auc:0.58381	test-auc:0.48583
# [39]	train-auc:0.58459	test-auc:0.48582
# [40]	train-auc:0.58429	test-auc:0.48596
# [41]	train-auc:0.58479	test-auc:0.48586
# [42]	train-auc:0.58532	test-auc:0.48577
# [43]	train-auc:0.58548	test-auc:0.48605
# [44]	train-auc:0.58701	test-auc:0.48548
# [45]	train-auc:0.58756	test-auc:0.48547
# [46]	train-auc:0.58890	test-auc:0.48623
# [47]	train-auc:0.59070	test-auc:0.48628
# [48]	train-auc:0.59050	test-auc:0.48624
# [49]	train-auc:0.59232	test-auc:0.48660
# [50]	train-auc:0.59302	test-auc:0.48655
# [51]	train-auc:0.59808	test-auc:0.48601
# [52]	train-auc:0.59823	test-auc:0.48610
# [53]	train-auc:0.59935	test-auc:0.48626
# [54]	train-auc:0.60008	test-auc:0.48673
# [55]	train-auc:0.60259	test-auc:0.48702
# [56]	train-auc:0.60267	test-auc:0.48719
# [57]	train-auc:0.60403	test-auc:0.48701
# [58]	train-auc:0.60620	test-auc:0.48755
# [59]	train-auc:0.60667	test-auc:0.48730
# [60]	train-auc:0.60999	test-auc:0.48881
# [61]	train-auc:0.61326	test-auc:0.48939
# [62]	train-auc:0.61309	test-auc:0.48907
# [63]	train-auc:0.61537	test-auc:0.48851
# [64]	train-auc:0.61702	test-auc:0.48806
# [65]	train-auc:0.61716	test-auc:0.48806
# [66]	train-auc:0.61729	test-auc:0.48801
# [67]	train-auc:0.61929	test-auc:0.48782
# [68]	train-auc:0.62080	test-auc:0.48822
# [69]	train-auc:0.62135	test-auc:0.48798
# [70]	train-auc:0.62257	test-auc:0.48850
# [71]	train-auc:0.62268	test-auc:0.48840
# [72]	train-auc:0.62423	test-auc:0.48827
# [73]	train-auc:0.62491	test-auc:0.48874
# [74]	train-auc:0.62733	test-auc:0.48895
# [75]	train-auc:0.62798	test-auc:0.48924
# [76]	train-auc:0.62813	test-auc:0.48918
# [77]	train-auc:0.62893	test-auc:0.48900
# [78]	train-auc:0.62983	test-auc:0.48889
# [79]	train-auc:0.63193	test-auc:0.48943
# [80]	train-auc:0.63196	test-auc:0.48944
# [81]	train-auc:0.63201	test-auc:0.48941
# [82]	train-auc:0.63651	test-auc:0.48947
# [83]	train-auc:0.63729	test-auc:0.48973
# [84]	train-auc:0.63656	test-auc:0.48996
# [85]	train-auc:0.63865	test-auc:0.48954
# [86]	train-auc:0.64044	test-auc:0.48889
# [87]	train-auc:0.64345	test-auc:0.48842
# [88]	train-auc:0.64611	test-auc:0.48876
# [89]	train-auc:0.64732	test-auc:0.48819
# [90]	train-auc:0.64734	test-auc:0.48811
# [91]	train-auc:0.64884	test-auc:0.48835
# [92]	train-auc:0.64879	test-auc:0.48903
# [93]	train-auc:0.65001	test-auc:0.48954
# [94]	train-auc:0.65180	test-auc:0.48898
# [95]	train-auc:0.65269	test-auc:0.48873
# [96]	train-auc:0.65823	test-auc:0.48976
# [97]	train-auc:0.66068	test-auc:0.49022
# [98]	train-auc:0.66169	test-auc:0.48997
# [99]	train-auc:0.66223	test-auc:0.48973
# [100]	train-auc:0.66346	test-auc:0.48938
# [101]	train-auc:0.66422	test-auc:0.48987
# [102]	train-auc:0.66418	test-auc:0.48972
# [103]	train-auc:0.66519	test-auc:0.48954
# [104]	train-auc:0.66573	test-auc:0.48951
# [105]	train-auc:0.66703	test-auc:0.48986
# [106]	train-auc:0.66766	test-auc:0.48957
# [107]	train-auc:0.67055	test-auc:0.49032
# [108]	train-auc:0.67141	test-auc:0.48994
# [109]	train-auc:0.67226	test-auc:0.49019
# [110]	train-auc:0.67761	test-auc:0.49128
# [111]	train-auc:0.67814	test-auc:0.49136
# [112]	train-auc:0.67874	test-auc:0.49168
# [113]	train-auc:0.67933	test-auc:0.49185
# [114]	train-auc:0.68220	test-auc:0.49191
# [115]	train-auc:0.68289	test-auc:0.49144
# [116]	train-auc:0.68682	test-auc:0.49098
# [117]	train-auc:0.68693	test-auc:0.49089
# [118]	train-auc:0.68749	test-auc:0.49106
# [119]	train-auc:0.68788	test-auc:0.49129
# [120]	train-auc:0.69091	test-auc:0.49225
# [121]	train-auc:0.69137	test-auc:0.49245
# [122]	train-auc:0.69311	test-auc:0.49233
# [123]	train-auc:0.69438	test-auc:0.49244
# [124]	train-auc:0.69647	test-auc:0.49303
# [125]	train-auc:0.69652	test-auc:0.49317
# [126]	train-auc:0.69763	test-auc:0.49283
# [127]	train-auc:0.69871	test-auc:0.49288
# [128]	train-auc:0.69907	test-auc:0.49285
# [129]	train-auc:0.70056	test-auc:0.49278
# [130]	train-auc:0.70106	test-auc:0.49255
# [131]	train-auc:0.70192	test-auc:0.49260
# [132]	train-auc:0.70277	test-auc:0.49237
# [133]	train-auc:0.70450	test-auc:0.49316
# [134]	train-auc:0.70634	test-auc:0.49319
# [135]	train-auc:0.70703	test-auc:0.49315
# [136]	train-auc:0.70732	test-auc:0.49333
# [137]	train-auc:0.70804	test-auc:0.49319
# [138]	train-auc:0.70884	test-auc:0.49381
# [139]	train-auc:0.70908	test-auc:0.49388
# [140]	train-auc:0.71134	test-auc:0.49336
# [141]	train-auc:0.71201	test-auc:0.49340
# [142]	train-auc:0.71324	test-auc:0.49405
# [143]	train-auc:0.71407	test-auc:0.49409
# [144]	train-auc:0.71414	test-auc:0.49399
# [145]	train-auc:0.71463	test-auc:0.49398
# [146]	train-auc:0.71490	test-auc:0.49389
# [147]	train-auc:0.71515	test-auc:0.49383
# [148]	train-auc:0.71633	test-auc:0.49415
# [149]	train-auc:0.71707	test-auc:0.49394
# [150]	train-auc:0.71775	test-auc:0.49401
# [151]	train-auc:0.71874	test-auc:0.49371
# [152]	train-auc:0.71944	test-auc:0.49361
# [153]	train-auc:0.72040	test-auc:0.49367
# [154]	train-auc:0.72105	test-auc:0.49340
# [155]	train-auc:0.72162	test-auc:0.49363
# [156]	train-auc:0.72230	test-auc:0.49371
# [157]	train-auc:0.72246	test-auc:0.49385
# [158]	train-auc:0.72291	test-auc:0.49384
# [159]	train-auc:0.72319	test-auc:0.49372
# [160]	train-auc:0.72351	test-auc:0.49418
# [161]	train-auc:0.72405	test-auc:0.49422
# [162]	train-auc:0.72456	test-auc:0.49430
# [163]	train-auc:0.72509	test-auc:0.49431
# [164]	train-auc:0.72550	test-auc:0.49412
# [165]	train-auc:0.72636	test-auc:0.49475
# [166]	train-auc:0.72662	test-auc:0.49481
# [167]	train-auc:0.72797	test-auc:0.49477
# [168]	train-auc:0.72827	test-auc:0.49488
# [169]	train-auc:0.72866	test-auc:0.49490
# [170]	train-auc:0.72893	test-auc:0.49478
# [171]	train-auc:0.73119	test-auc:0.49506
# [172]	train-auc:0.73158	test-auc:0.49524
# [173]	train-auc:0.73208	test-auc:0.49528
# [174]	train-auc:0.73291	test-auc:0.49511
# [175]	train-auc:0.73324	test-auc:0.49490
# [176]	train-auc:0.73356	test-auc:0.49477
# [177]	train-auc:0.73540	test-auc:0.49533
# [178]	train-auc:0.73562	test-auc:0.49510
# [179]	train-auc:0.73662	test-auc:0.49496
# [180]	train-auc:0.73669	test-auc:0.49479
# [181]	train-auc:0.73687	test-auc:0.49482
# [182]	train-auc:0.73751	test-auc:0.49498
# [183]	train-auc:0.73827	test-auc:0.49501
# [184]	train-auc:0.73845	test-auc:0.49504
# [185]	train-auc:0.73954	test-auc:0.49527
# [186]	train-auc:0.74029	test-auc:0.49492
# [187]	train-auc:0.74113	test-auc:0.49527
# [188]	train-auc:0.74192	test-auc:0.49498
# [189]	train-auc:0.74207	test-auc:0.49497
# [190]	train-auc:0.74201	test-auc:0.49512
# [191]	train-auc:0.74285	test-auc:0.49542
# [192]	train-auc:0.74379	test-auc:0.49549
# [193]	train-auc:0.74426	test-auc:0.49554
# [194]	train-auc:0.74418	test-auc:0.49552
# [195]	train-auc:0.74488	test-auc:0.49563
# [196]	train-auc:0.74500	test-auc:0.49562
# [197]	train-auc:0.74568	test-auc:0.49545
# [198]	train-auc:0.74617	test-auc:0.49549
# [199]	train-auc:0.74712	test-auc:0.49577
# [200]	train-auc:0.74767	test-auc:0.49601
# [201]	train-auc:0.74804	test-auc:0.49592
# [202]	train-auc:0.74808	test-auc:0.49597
# [203]	train-auc:0.74855	test-auc:0.49576
# [204]	train-auc:0.74971	test-auc:0.49603
# [205]	train-auc:0.75042	test-auc:0.49595
# [206]	train-auc:0.75095	test-auc:0.49573
# [207]	train-auc:0.75154	test-auc:0.49595
# [208]	train-auc:0.75163	test-auc:0.49600
# [209]	train-auc:0.75240	test-auc:0.49624
# [210]	train-auc:0.75267	test-auc:0.49629
# [211]	train-auc:0.75302	test-auc:0.49605
# [212]	train-auc:0.75295	test-auc:0.49604
# [213]	train-auc:0.75333	test-auc:0.49633
# [214]	train-auc:0.75335	test-auc:0.49628
# [215]	train-auc:0.75373	test-auc:0.49621
# [216]	train-auc:0.75412	test-auc:0.49635
# [217]	train-auc:0.75458	test-auc:0.49664
# [218]	train-auc:0.75511	test-auc:0.49667
# [219]	train-auc:0.75617	test-auc:0.49701
# [220]	train-auc:0.75648	test-auc:0.49704
# [221]	train-auc:0.75680	test-auc:0.49726
# [222]	train-auc:0.75669	test-auc:0.49729
# [223]	train-auc:0.75703	test-auc:0.49716
# [224]	train-auc:0.75737	test-auc:0.49737
# [225]	train-auc:0.75762	test-auc:0.49722
# [226]	train-auc:0.75766	test-auc:0.49719
# [227]	train-auc:0.75791	test-auc:0.49741
# [228]	train-auc:0.75783	test-auc:0.49742
# [229]	train-auc:0.75861	test-auc:0.49764
# [230]	train-auc:0.75860	test-auc:0.49762
# [231]	train-auc:0.75865	test-auc:0.49761
# [232]	train-auc:0.75870	test-auc:0.49760
# [233]	train-auc:0.75888	test-auc:0.49759
# [234]	train-auc:0.75921	test-auc:0.49752
# [235]	train-auc:0.75997	test-auc:0.49777
# [236]	train-auc:0.76012	test-auc:0.49789
# [237]	train-auc:0.76034	test-auc:0.49807
# [238]	train-auc:0.76057	test-auc:0.49795
# [239]	train-auc:0.76168	test-auc:0.49773
# [240]	train-auc:0.76157	test-auc:0.49779
# [241]	train-auc:0.76191	test-auc:0.49797
# [242]	train-auc:0.76240	test-auc:0.49786
# [243]	train-auc:0.76245	test-auc:0.49785
# [244]	train-auc:0.76243	test-auc:0.49783
# [245]	train-auc:0.76259	test-auc:0.49796
# [308]	train-auc:0.78256	test-auc:0.50063
# [309]	train-auc:0.78259	test-auc:0.50062
# [310]	train-auc:0.78290	test-auc:0.50076
# [311]	train-auc:0.78289	test-auc:0.50078
# [312]	train-auc:0.78309	test-auc:0.50059
# [313]	train-auc:0.78330	test-auc:0.50075
# [314]	train-auc:0.78353	test-auc:0.50091
# [315]	train-auc:0.78374	test-auc:0.50093
# [316]	train-auc:0.78370	test-auc:0.50107
# [317]	train-auc:0.78381	test-auc:0.50102
# [318]	train-auc:0.78417	test-auc:0.50107
# [319]	train-auc:0.78488	test-auc:0.50107
# [320]	train-auc:0.78495	test-auc:0.50099
# [321]	train-auc:0.78511	test-auc:0.50097
# [322]	train-auc:0.78509	test-auc:0.50094
# [323]	train-auc:0.78507	test-auc:0.50101
# [324]	train-auc:0.78511	test-auc:0.50101
# [325]	train-auc:0.78508	test-auc:0.50108
# [326]	train-auc:0.78542	test-auc:0.50117
# [327]	train-auc:0.78585	test-auc:0.50096
# [328]	train-auc:0.78603	test-auc:0.50099
# [329]	train-auc:0.78612	test-auc:0.50103
# [330]	train-auc:0.78645	test-auc:0.50090
# [331]	train-auc:0.78661	test-auc:0.50088
# [332]	train-auc:0.78656	test-auc:0.50091
# [333]	train-auc:0.78677	test-auc:0.50082
# [334]	train-auc:0.78720	test-auc:0.50085
# [335]	train-auc:0.78743	test-auc:0.50086
# [336]	train-auc:0.78748	test-auc:0.50077
# [337]	train-auc:0.78775	test-auc:0.50072
# [338]	train-auc:0.78780	test-auc:0.50063
# [339]	train-auc:0.78774	test-auc:0.50070
# [340]	train-auc:0.78797	test-auc:0.50070
# [341]	train-auc:0.78815	test-auc:0.50074
# [342]	train-auc:0.78829	test-auc:0.50088
# [343]	train-auc:0.78874	test-auc:0.50092
# [344]	train-auc:0.78891	test-auc:0.50089
# [345]	train-auc:0.78906	test-auc:0.50089
# [346]	train-auc:0.78930	test-auc:0.50086
# [347]	train-auc:0.78959	test-auc:0.50092
# [348]	train-auc:0.78983	test-auc:0.50090
# [349]	train-auc:0.78987	test-auc:0.50094
# [350]	train-auc:0.78995	test-auc:0.50096
# [351]	train-auc:0.79014	test-auc:0.50095
# [352]	train-auc:0.79032	test-auc:0.50094
# [353]	train-auc:0.79047	test-auc:0.50097
# [354]	train-auc:0.79061	test-auc:0.50101
# [355]	train-auc:0.79102	test-auc:0.50105
# [356]	train-auc:0.79146	test-auc:0.50089
# [357]	train-auc:0.79166	test-auc:0.50089
# [358]	train-auc:0.79197	test-auc:0.50089
# [359]	train-auc:0.79228	test-auc:0.50094
# [360]	train-auc:0.79247	test-auc:0.50093
# [361]	train-auc:0.79247	test-auc:0.50080
# [362]	train-auc:0.79262	test-auc:0.50094
# [363]	train-auc:0.79283	test-auc:0.50096
# [364]	train-auc:0.79317	test-auc:0.50102
# [365]	train-auc:0.79317	test-auc:0.50118
# [366]	train-auc:0.79316	test-auc:0.50122
# [367]	train-auc:0.79353	test-auc:0.50124
# [368]	train-auc:0.79369	test-auc:0.50122
# [369]	train-auc:0.79406	test-auc:0.50122
# [493]	train-auc:0.81601	test-auc:0.50135
# [494]	train-auc:0.81630	test-auc:0.50122
# [495]	train-auc:0.81637	test-auc:0.50126
# [496]	train-auc:0.81634	test-auc:0.50118
# [497]	train-auc:0.81667	test-auc:0.50121
# [498]	train-auc:0.81689	test-auc:0.50122
# [499]	train-auc:0.81722	test-auc:0.50110
# [500]	train-auc:0.81739	test-auc:0.50116
# [501]	train-auc:0.81742	test-auc:0.50113
# [502]	train-auc:0.81784	test-auc:0.50120
# [503]	train-auc:0.81795	test-auc:0.50126
# [504]	train-auc:0.81799	test-auc:0.50123
# [505]	train-auc:0.81806	test-auc:0.50122
# [506]	train-auc:0.81812	test-auc:0.50115
# [507]	train-auc:0.81854	test-auc:0.50107
# [508]	train-auc:0.81855	test-auc:0.50101
# [509]	train-auc:0.81856	test-auc:0.50096
# [510]	train-auc:0.81865	test-auc:0.50101
# [511]	train-auc:0.81894	test-auc:0.50107
# [512]	train-auc:0.81940	test-auc:0.50101
# [513]	train-auc:0.81951	test-auc:0.50109
# [514]	train-auc:0.81964	test-auc:0.50105
# [515]	train-auc:0.81965	test-auc:0.50101
# [516]	train-auc:0.81965	test-auc:0.50105
# [517]	train-auc:0.81968	test-auc:0.50104
# [518]	train-auc:0.82007	test-auc:0.50113
# [519]	train-auc:0.82101	test-auc:0.50120
# [520]	train-auc:0.82116	test-auc:0.50127
# [521]	train-auc:0.82155	test-auc:0.50130
# [522]	train-auc:0.82166	test-auc:0.50130
# [523]	train-auc:0.82168	test-auc:0.50132
# [524]	train-auc:0.82227	test-auc:0.50141
# [525]	train-auc:0.82229	test-auc:0.50142
# [526]	train-auc:0.82244	test-auc:0.50134
# [527]	train-auc:0.82298	test-auc:0.50150
# [528]	train-auc:0.82312	test-auc:0.50144
# [529]	train-auc:0.82339	test-auc:0.50151
# [530]	train-auc:0.82343	test-auc:0.50145
# [531]	train-auc:0.82346	test-auc:0.50140
# [532]	train-auc:0.82364	test-auc:0.50141
# [533]	train-auc:0.82415	test-auc:0.50151
# [534]	train-auc:0.82437	test-auc:0.50156
# [535]	train-auc:0.82448	test-auc:0.50157
# [536]	train-auc:0.82450	test-auc:0.50157
# [537]	train-auc:0.82479	test-auc:0.50158
# [538]	train-auc:0.82477	test-auc:0.50163
# [539]	train-auc:0.82479	test-auc:0.50155
# [540]	train-auc:0.82513	test-auc:0.50152
# [541]	train-auc:0.82576	test-auc:0.50146
# [542]	train-auc:0.82584	test-auc:0.50145
# [543]	train-auc:0.82605	test-auc:0.50142
# [544]	train-auc:0.82619	test-auc:0.50152
# [545]	train-auc:0.82632	test-auc:0.50158
# [546]	train-auc:0.82633	test-auc:0.50158
# [547]	train-auc:0.82656	test-auc:0.50175
# [548]	train-auc:0.82652	test-auc:0.50176
# [549]	train-auc:0.82697	test-auc:0.50176
# [550]	train-auc:0.82729	test-auc:0.50176
# [551]	train-auc:0.82768	test-auc:0.50182
# [552]	train-auc:0.82812	test-auc:0.50175
# [553]	train-auc:0.82821	test-auc:0.50177
# [554]	train-auc:0.82843	test-auc:0.50181
# [863]	train-auc:0.86965	test-auc:0.50258
# [864]	train-auc:0.86978	test-auc:0.50250
# [865]	train-auc:0.87003	test-auc:0.50251
# [866]	train-auc:0.87018	test-auc:0.50257
# [867]	train-auc:0.87037	test-auc:0.50250
# [868]	train-auc:0.87038	test-auc:0.50250
# [869]	train-auc:0.87056	test-auc:0.50244
# [870]	train-auc:0.87058	test-auc:0.50247
# [871]	train-auc:0.87070	test-auc:0.50242
# [872]	train-auc:0.87078	test-auc:0.50238
# [873]	train-auc:0.87082	test-auc:0.50240
# [874]	train-auc:0.87092	test-auc:0.50242
# [875]	train-auc:0.87099	test-auc:0.50245
# [876]	train-auc:0.87121	test-auc:0.50241
# [877]	train-auc:0.87131	test-auc:0.50247
# [878]	train-auc:0.87139	test-auc:0.50242
# [879]	train-auc:0.87140	test-auc:0.50245
# [880]	train-auc:0.87159	test-auc:0.50254
# [881]	train-auc:0.87162	test-auc:0.50246
# [882]	train-auc:0.87178	test-auc:0.50240
# [883]	train-auc:0.87185	test-auc:0.50237
# [884]	train-auc:0.87203	test-auc:0.50249
# [885]	train-auc:0.87213	test-auc:0.50238
# [886]	train-auc:0.87216	test-auc:0.50240
# [887]	train-auc:0.87225	test-auc:0.50235
# [888]	train-auc:0.87239	test-auc:0.50248
# [889]	train-auc:0.87238	test-auc:0.50247
# [890]	train-auc:0.87242	test-auc:0.50245
# [891]	train-auc:0.87261	test-auc:0.50243
# [892]	train-auc:0.87276	test-auc:0.50234
# [893]	train-auc:0.87276	test-auc:0.50244
# [894]	train-auc:0.87279	test-auc:0.50246
# [895]	train-auc:0.87294	test-auc:0.50239
# [896]	train-auc:0.87313	test-auc:0.50249
# [897]	train-auc:0.87320	test-auc:0.50252
# [898]	train-auc:0.87324	test-auc:0.50253
# [899]	train-auc:0.87337	test-auc:0.50257
# [900]	train-auc:0.87347	test-auc:0.50260
# [901]	train-auc:0.87369	test-auc:0.50264
# [902]	train-auc:0.87386	test-auc:0.50269
# [903]	train-auc:0.87388	test-auc:0.50267
# [904]	train-auc:0.87390	test-auc:0.50271
# [905]	train-auc:0.87403	test-auc:0.50265
# [906]	train-auc:0.87406	test-auc:0.50258
# [907]	train-auc:0.87405	test-auc:0.50263
# [908]	train-auc:0.87418	test-auc:0.50257
# [909]	train-auc:0.87452	test-auc:0.50266
# [910]	train-auc:0.87460	test-auc:0.50263
# [911]	train-auc:0.87466	test-auc:0.50256
# [912]	train-auc:0.87484	test-auc:0.50261
# [913]	train-auc:0.87485	test-auc:0.50256
# [914]	train-auc:0.87486	test-auc:0.50265
# [915]	train-auc:0.87500	test-auc:0.50268
# [916]	train-auc:0.87524	test-auc:0.50266
# [917]	train-auc:0.87525	test-auc:0.50272
# [918]	train-auc:0.87526	test-auc:0.50274
# [919]	train-auc:0.87528	test-auc:0.50275
# [920]	train-auc:0.87559	test-auc:0.50277
# [921]	train-auc:0.87560	test-auc:0.50277
# [922]	train-auc:0.87571	test-auc:0.50284
# [923]	train-auc:0.87587	test-auc:0.50282
# [924]	train-auc:0.87611	test-auc:0.50282
# [925]	train-auc:0.87613	test-auc:0.50276
# [926]	train-auc:0.87615	test-auc:0.50270
# [927]	train-auc:0.87626	test-auc:0.50264
# [928]	train-auc:0.87633	test-auc:0.50259
# [929]	train-auc:0.87632	test-auc:0.50263
# [930]	train-auc:0.87638	test-auc:0.50262
# [931]	train-auc:0.87643	test-auc:0.50263
# [932]	train-auc:0.87661	test-auc:0.50261
# [933]	train-auc:0.87663	test-auc:0.50264
# [934]	train-auc:0.87664	test-auc:0.50266
# [935]	train-auc:0.87675	test-auc:0.50279
# [936]	train-auc:0.87677	test-auc:0.50273
# [937]	train-auc:0.87676	test-auc:0.50279
# [938]	train-auc:0.87680	test-auc:0.50277
# [939]	train-auc:0.87699	test-auc:0.50278
# [940]	train-auc:0.87704	test-auc:0.50276
# [941]	train-auc:0.87709	test-auc:0.50279
# [942]	train-auc:0.87716	test-auc:0.50277
# [943]	train-auc:0.87727	test-auc:0.50280
# [944]	train-auc:0.87728	test-auc:0.50280
# [945]	train-auc:0.87753	test-auc:0.50283
# [946]	train-auc:0.87775	test-auc:0.50286
# [947]	train-auc:0.87780	test-auc:0.50288
# [948]	train-auc:0.87794	test-auc:0.50291
# [949]	train-auc:0.87807	test-auc:0.50283
# [950]	train-auc:0.87809	test-auc:0.50292
# [951]	train-auc:0.87812	test-auc:0.50287
# [952]	train-auc:0.87821	test-auc:0.50281
# [953]	train-auc:0.87861	test-auc:0.50279
# [954]	train-auc:0.87864	test-auc:0.50281
# [955]	train-auc:0.87874	test-auc:0.50277
# [956]	train-auc:0.87879	test-auc:0.50271
# [957]	train-auc:0.87880	test-auc:0.50270
# [958]	train-auc:0.87881	test-auc:0.50271
# [959]	train-auc:0.87893	test-auc:0.50276
# [960]	train-auc:0.87896	test-auc:0.50278
# [961]	train-auc:0.87906	test-auc:0.50274
# [962]	train-auc:0.87908	test-auc:0.50272
# [963]	train-auc:0.87909	test-auc:0.50276
# [964]	train-auc:0.87924	test-auc:0.50265
# [965]	train-auc:0.87931	test-auc:0.50257
# [966]	train-auc:0.87961	test-auc:0.50262
# [967]	train-auc:0.87964	test-auc:0.50259
# [968]	train-auc:0.87968	test-auc:0.50261
# [969]	train-auc:0.87976	test-auc:0.50258
# [970]	train-auc:0.87991	test-auc:0.50245
# [971]	train-auc:0.87993	test-auc:0.50240
# [972]	train-auc:0.88031	test-auc:0.50236
# [973]	train-auc:0.88058	test-auc:0.50238
# [974]	train-auc:0.88067	test-auc:0.50239
# [975]	train-auc:0.88068	test-auc:0.50240
# [976]	train-auc:0.88069	test-auc:0.50239
# [977]	train-auc:0.88070	test-auc:0.50239
# [978]	train-auc:0.88077	test-auc:0.50234
# [979]	train-auc:0.88098	test-auc:0.50234
# [980]	train-auc:0.88138	test-auc:0.50227
# [981]	train-auc:0.88138	test-auc:0.50226
# [982]	train-auc:0.88138	test-auc:0.50230
# [983]	train-auc:0.88158	test-auc:0.50234
# [984]	train-auc:0.88178	test-auc:0.50238
# [985]	train-auc:0.88201	test-auc:0.50239
# [986]	train-auc:0.88218	test-auc:0.50238
# [1224]	train-auc:0.90557	test-auc:0.50210
# [1225]	train-auc:0.90574	test-auc:0.50212
# [1226]	train-auc:0.90596	test-auc:0.50215
# [1227]	train-auc:0.90600	test-auc:0.50213
# [1228]	train-auc:0.90616	test-auc:0.50205
# [1229]	train-auc:0.90615	test-auc:0.50206
# [1230]	train-auc:0.90619	test-auc:0.50200
# [1231]	train-auc:0.90638	test-auc:0.50202
# [1232]	train-auc:0.90641	test-auc:0.50202
# [1233]	train-auc:0.90648	test-auc:0.50206
# [1234]	train-auc:0.90685	test-auc:0.50205
# [1235]	train-auc:0.90707	test-auc:0.50199
# [1236]	train-auc:0.90725	test-auc:0.50197
# [1237]	train-auc:0.90736	test-auc:0.50192
# [1238]	train-auc:0.90738	test-auc:0.50190
# [1239]	train-auc:0.90753	test-auc:0.50194
# [1240]	train-auc:0.90780	test-auc:0.50183
# [1241]	train-auc:0.90795	test-auc:0.50183
# [1242]	train-auc:0.90809	test-auc:0.50180
# [1243]	train-auc:0.90810	test-auc:0.50182
# [1244]	train-auc:0.90829	test-auc:0.50172
# [1245]	train-auc:0.90846	test-auc:0.50168
# [1246]	train-auc:0.90850	test-auc:0.50170
# [1247]	train-auc:0.90854	test-auc:0.50168
# [1248]	train-auc:0.90862	test-auc:0.50169
# [1249]	train-auc:0.90878	test-auc:0.50174

# %%
df_res=pd.DataFrame({'cust_id':X_test['cust_id'],'p_test':bst.predict(dtest)})
df_res1=pd.DataFrame({'cust_id':X_train['cust_id'],'p_test':bst1.predict(dtrain)})

df=pd.concat([df_res,df_res1],axis=0,ignore_index=True)

df_train = pd.merge(df_train, df, on="cust_id",
                        how="left", suffixes=("", "_y"))

# %%
temp=len(df_train)
df_train.to_csv("train_input.csv", encoding='utf-8')

df_train=df_train[df_train['p_test']>=0.1]


print("经过对抗验证，有",len(df_train),"条数据被保留，",temp-len(df_train),"条数据被抛弃",sep="")
# Out:
# 经过对抗验证，有17980条数据被保留，19条数据被抛弃

# %% [markdown]
# # 训练模型

# %% [markdown]
# ## 超参数

# %%
N = 60
num_round = 3000
local_test_size = 2000

# 共用
test_size = [0.2, 0.25, 0.3]
max_depth = [3, 4, 5]
subsample = [0.8, 0.75, 0.7, 0.65, 0.6]
early_stopping_rounds = 150

# XGB
eta = [0.007, 0.01]

# LGB
learning_rate = [0.03, 0.02, 0.025]

# %% [markdown]
# ### train划分为
# * 本地测试集（固定）d_localtest
# * 训练集（固定）
#   * 评估集（每次的模型不同）dtest
#   * 真正的训练集（每次的模型不同）dtrain

# %%
import copy
import xgboost as xgb
import random
from sklearn import model_selection
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation
from catboost import CatBoostClassifier


pred_labels = []
local_test_labels = []
loss_seq = []
max_auc_loss = 0
flag = 0
important_x_seq = []


d_full = xgb.DMatrix(df_train[x_col], label=df_train['label'])
X = df_train[x_col]
Y = df_train['label']

X, X_local_test, Y, Y_local_test = model_selection.train_test_split(
    X, Y, test_size=local_test_size, stratify=Y, random_state=2022)

d_localtest = xgb.DMatrix(X_local_test, label=Y_local_test)
x_perd = xgb.DMatrix(df_test[x_col])

d_localtest1 = lgb.Dataset(X_local_test, Y_local_test)
x_perd1 = lgb.Dataset(df_test[x_col])


lgbcallback = [early_stopping(early_stopping_rounds), log_evaluation(10000)]

# %%
for i in range(N):

    test_size_this_round = random.choice(test_size)
    X_train, X_test, y_train, y_test = model_selection.train_test_split(
        X, Y, test_size=test_size_this_round, stratify=Y)

    #XGB-----------------------------------------------
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    evallist = [(dtest, 'eval')]
    param = {
        'max_depth': random.choice(max_depth),
        'eta': random.choice(eta),
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'subsample': random.choice(subsample),
        'tree_method': 'gpu_hist',
        'gpu_id': 0,
    }

    bst = xgb.train(param, dtrain, num_round, evals=evallist,
                    early_stopping_rounds=early_stopping_rounds, verbose_eval=False)

    loss = roc_auc_score(y_test, bst.predict(dtest))
    train_loss = roc_auc_score(y_train, bst.predict(dtrain))
    local_test_loss = roc_auc_score(Y_local_test, bst.predict(d_localtest))
    global_auc = roc_auc_score(df_train['label'], bst.predict(d_full))

    pred_label = list(bst.predict(x_perd))
    test_label = list(bst.predict(d_localtest))


    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'xgb'}

    if flag == 0:
        info_df = pd.DataFrame(temp_dict, index=[i])
        flag = 1
    else:
        info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])

    # if loss > max_auc_loss:
    #     best_bst = copy.deepcopy(bst)
    #     max_auc_loss = loss

    # if False:
    #     pic = xgb.plot_importance(bst, max_num_features=50)
    #     temp = pic.get_ymajorticklabels()
    #     important_x = [str(i).split("\'")[1] for i in temp]
    #     important_x.reverse()
    #     important_x_seq += important_x

    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))


    #LGB--------------------------------------------------------
    param = {
        'task': 'train',
        "max_depth": random.choice(max_depth),
        'max_bin':128,
        'boosting_type': 'gbdt',  # 设置提升类型
        'objective': 'binary',  # 目标函数
        'metric': 'auc',  # 评估函数
        'learning_rate': random.choice(learning_rate),  # 学习速率
        'bagging_fraction': random.choice(subsample),  # 建树的样本采样比例
        'bagging_freq': 1,  # k 意味着每 k 次迭代执行bagging
        'min_data_in_leaf': 1,
        'verbose': -1,  # <0 显示致命的, =0 显示错误 (警告), >0 显示信息
        'device_type': 'gpu',
    }

    dtrain = lgb.Dataset(X_train, y_train)
    dtest = lgb.Dataset(X_test, y_test)

    if cat_way == "auto":
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback, categorical_feature=type_col)
    else:
        bst1 = lgb.train(param, dtrain, num_round, valid_sets=[
            dtest], callbacks=lgbcallback)

    loss = roc_auc_score(y_test, bst1.predict(X_test))
    train_loss = roc_auc_score(y_train, bst1.predict(X_train))
    local_test_loss = roc_auc_score(Y_local_test, bst1.predict(X_local_test))
    global_auc = roc_auc_score(
        df_train['label'], bst1.predict(df_train[x_col]))

    pred_label = list(bst1.predict(df_test[x_col]))
    test_label = list(bst1.predict(X_local_test))

    temp_dict = {"test_auc": loss, "train_auc": train_loss,
                 'local_test_auc': local_test_loss,
                 'model': 'lgb'}

    info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    pred_labels.append(copy.deepcopy(pred_label))
    local_test_labels.append(copy.deepcopy(test_label))

    #CAT-----------------------------------------------------------
    # bst2 = CatBoostClassifier(iterations=num_round,
    #                        depth=random.choice(max_depth),
    #                        learning_rate=random.choice(learning_rate),
    #                        loss_function='Logloss',
    #                        subsample=random.choice(subsample),
    #                        early_stopping_rounds=early_stopping_rounds,
    #                        verbose=False)
    # bst2.fit(X_train, y_train,eval_set=(X_test,y_test))

    # loss = roc_auc_score(y_test, bst2.predict_proba(X_test)[:,1])
    # train_loss = roc_auc_score(y_train, bst2.predict_proba(X_train)[:,1])
    # local_test_loss = roc_auc_score(Y_local_test, bst2.predict_proba(X_local_test)[:,1])
    # global_auc = roc_auc_score(df_train['label'], bst2.predict_proba(df_train[x_col])[:,1])

    # pred_label = list(bst2.predict_proba(df_test[x_col])[:,1])
    # test_label = list(bst2.predict_proba(X_local_test)[:,1])

    # temp_dict = {"test_auc": loss, "train_auc": train_loss,
    #              'local_test_auc': local_test_loss,
    #              'model': 'cat'}

    # info_df = pd.concat([info_df, pd.DataFrame(temp_dict, index=[i])])
    # pred_labels.append(copy.deepcopy(pred_label))
    # local_test_labels.append(copy.deepcopy(test_label))


print('最大AUC:', max(info_df['local_test_auc']), sep="")
# Out:
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [258]	valid_0's auc: 0.720495
# Early stopping, best iteration is:
# [312]	valid_0's auc: 0.722362
# Early stopping, best iteration is:
# [327]	valid_0's auc: 0.747675
# Early stopping, best iteration is:
# [327]	valid_0's auc: 0.747675
# Early stopping, best iteration is:
# [183]	valid_0's auc: 0.7491
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# Early stopping, best iteration is:
# [281]	valid_0's auc: 0.79019
# 最大AUC:0.7820454268663987

# %%
info_df.to_csv("info.csv", encoding="utf-8", index=False)

# %%
# pic = xgb.plot_importance(bst, max_num_features=50)
# temp = pic.get_ymajorticklabels()
# important_x = [str(i).split("\'")[1] for i in temp]
# important_x.reverse()

# %%
# important_x

# %%
# pd.value_counts(important_x_seq)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6.5, 6), dpi=200)


plt.scatter(info_df[info_df['model'] == 'xgb']['local_test_auc'], info_df[info_df['model'] == 'xgb']['test_auc'],
            c='r', s=4,label="xgb")
plt.scatter(info_df[info_df['model'] == 'lgb']['local_test_auc'], info_df[info_df['model'] == 'lgb']['test_auc'],
            c='g', s=4,label="lgb")
# plt.scatter(info_df[info_df['model'] == 'cat']['local_test_auc'], info_df[info_df['model'] == 'cat']['test_auc'],
#             c='b', s=4,label="cat")
plt.legend()
plt.xlabel('local_test_auc')
plt.ylabel('test_auc')
plt.plot([0.6, 0.85], [0.6, 0.85])
plt.xlim(0.6, 0.85)
plt.ylim(0.6, 0.85)
plt.grid()
plt.show()

# %% [markdown]
# # 输出模块

# %%
import time
import numpy as np
from sklearn.metrics import roc_auc_score

date = time.strftime("%Y%m%d-%H%M%S", time.localtime())
res_num = np.argsort([-i for i in (info_df['local_test_auc']+info_df['test_auc'])])

# 选择前n个结果进行平均（手动指定or在本地测试集排序选出）
if True:
    max_auc = -1
    list_temp = []
    auc_seq = []
    for i in range(N*2):
        list_temp.append(local_test_labels[res_num[i]])
        # 算数平均
        # temp = np.mean(list_temp, axis=0)
        # 几何平均(better)
        temp = np.exp(np.mean(np.log(list_temp), axis=0))
        temp_auc = roc_auc_score(Y_local_test, temp)
        # print(i, temp_auc)
        auc_seq.append(temp_auc)
        if temp_auc > max_auc:
            max_auc = temp_auc
            n = i+1
else:
    n = 40
    n = min(N, n)

res_num = res_num[0:n]

#final_pred_label = np.mean([pred_labels[i] for i in res_num], axis=0)
final_pred_label = np.exp(
    np.mean(np.log([pred_labels[i] for i in res_num]), axis=0))
#local_auc = roc_auc_score(y_test, final_pred_label)
print("本地测试集前", n, "个auc为", [
      list(info_df['local_test_auc'])[i] for i in res_num], sep="")
print("平均之后local_test_AUC为", max_auc, sep="")

res = pd.DataFrame({
    'cust_id': list(df_test["cust_id"]),
    'label': final_pred_label,
})
res.to_csv("./output/result"+date+".csv", encoding="utf-8", index=False)
# Out:
# 本地测试集前13个auc为[0.7534328948970892, 0.7585936548532456, 0.7665935939593228, 0.7645993179880648, 0.7790844598709049, 0.7725383631713555, 0.7697448544635245, 0.766015101692851, 0.7687933869199854, 0.7649190110826939, 0.7634499451954695, 0.77084855681403, 0.7820454268663987]
# 平均之后local_test_AUC为0.7810254536597248

# %%
from sklearn.linear_model import LogisticRegression
res_df=pd.DataFrame()
pred_df=pd.DataFrame()
model_name=[]

for i in res_num:
    res_df['model'+str(i)]=local_test_labels[i]
    pred_df['model'+str(i)]=pred_labels[i]

logreg=LogisticRegression()
logreg.fit(res_df,Y_local_test)

print(roc_auc_score(Y_local_test,logreg.predict_proba(res_df)[:,1]))

log_pred=logreg.predict_proba(pred_df)[:,1]


res = pd.DataFrame({
    'cust_id': list(df_test["cust_id"]),
    'label': log_pred,
})
res.to_csv("./output/result"+date+"_stacking.csv", encoding="utf-8", index=False)
# Out:
# 0.7807285957861405

# %%
plt.figure(figsize=(10, 6), dpi=200)
plt.plot(list(range(len(auc_seq))), auc_seq)

# %% [markdown]
# # 一些tips
#
# * 提升n有一定提升(如何确定n？)
#   * n=40 0.6763
#   * n=10 0.6728
#   * n=100 0.6774
#   * 太大也不好
#
# # 一些进展
#
# * 随机参数
# * XGB模型
# * 本地测试集auc较高（0.75+）
# * 部分类型变量进行了one-hot处理
# * 把细分表除了loan与主表合并
#
# # tbd
#
# * 处理细分表的loan，给出指标
# * 确定变量类型，以便对所有（or重要）分类变量进行one-hot处理
# * 新模型？

# %% [markdown]
# ## 10-12
# * 0.6824（这次我留了代码\doge）
# * 把-99变为-1，本地有提升
# * 划出了一个本地测试集
#   * 本地测试集（固定）d_localtest
#   * 训练集（固定）
#     * 评估集（每次的模型不同）dtest
#     * 真正的训练集（每次的模型不同）dtrain
# * 添加参数nan_num（然并卵）
# * tbd
#   * 找特征
#   * 加x
#   * 分析一下参数作用
# ## 10-18
# * 不能把industry之类种类很多的分类变量做证据权重

# %% [markdown]
# # 记录
# * 1014-4
#   * 0.6823
#   * 证据权重
#   * 未添加贷款记录表
#   * 按test auc排序
# * 1014-5
#   * 0.6925
#   * 按local test auc排序
# * 1015-1
#   * 0.6834
#   * 处理-99
# * 1015-2
#   * 0.6628
#   * 添加贷款记录表
# * 1015-3
#   * 0.6772
#   * 不处理-99
#   * 去除贷款记录表
#   * 添加了type-col
# * 1015-4
#   * 0.6811
#   * 不做证据权重
# * 1015-5
#   * 0.6765
#   * gamma=0
# * 1016-1
#   * 0.6798
#   * 添加gamma
#   * 增大early stop round
# * 1016-2
#   * 0.6858
#   * early stop round=10
#   * 证据权重
# * 1016-3
#   * 0.685799
#   * 使用原始type-col
# * 1017-2
#   * 0.6655
